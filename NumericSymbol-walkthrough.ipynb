# %%
# %matplotlib notebook
import warnings
with warnings.catch_warnings():
    warnings.filterwarnings("ignore",category=FutureWarning)
    
    from game import Game
    from data_preprocess import get_data_points, get_dummy_data
    from utils import get_feature_extractor_model, get_features, message_to_image, message_to_image_sm
    from agents import get_agents
    
    import numpy as np
    import matplotlib.pyplot as plt
from sklearn.datasets import make_classification, make_blobs
# Out:
# Using TensorFlow backend.

# %%
sender_type = "aware"

n_features = 3
n_clusters = 5
n_samples = 3
n_vocab = 5

n_batches = 10
n_epochs = 1000000

n_all_features = 512

max_len = 2

img_dim = 0
img_rows = 0
img_cols = 0
img_features_len = 1

n_batches = 32
n_epochs = 10000000
action_size = 1
num_actions = n_vocab

ppo_config = "configs/ppo-big-200.json"
network_config = "configs/mlp3_network-200.json"
data_csv_path = "data_csvs/cifar_feats.csv"
feat_model_path = 'feature_extractors/feature_model.h5'
feature_model_json_path = 'feature_extractors/feature_model.json'

flip_s = False
flip_l = False
freq = 1
debug = True

# %%
# Get data, prepare Agents, get feature extractor, initialize logging, create game pool

X1, Y1, n_features = get_dummy_data(n_samples = 10000, n_features=3, centers=5)
Speaker, Listener = get_agents(ppo_config, network_config, sender_type, n_features, img_dim, img_features_len, n_samples, num_actions, action_size)
intermediate_layer_model = get_feature_extractor_model(feat_model_path, feature_model_json_path)

big_rewards = []
data = []
game_pool = []

for i in range(n_batches):
    game_pool.append(Game(n_features, n_clusters, n_samples, n_vocab, sender_type, [X1, Y1]))
# Out:
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
plt.ion()

fig.show()
fig.canvas.draw()
for i in range(n_epochs):

    message_batch = []
    img_batch = []
    r = i%(2*freq)
    if r<1*freq:
        flip_s = False
        flip_l = True
    if r>=1*freq:
        flip_s = True
        flip_l = False
    l_rewards = []
    strokes = []
    for b in range(n_batches):
        strokes = []
#         for idx in range(2):
#             if idx ==0:
#                 feat = np.zeros((10,10), np.uint8)
#             else:
#                 im = message_to_image_sm(strokes, img_dim, img_dim)
# #                 feat = get_features([im])[0]
#                 feat = im.flatten()
        message = Speaker.act(states= game_pool[b].speaker_input(), independent=flip_s)  # (scalar between 0 and 4)
        message_batch.append(message)
#             strokes.append(message)
#         img = message_to_image(strokes, img_rows, img_cols)
#         img_batch.append(img)
#         Speaker.reset()

#     features_batch = get_features(intermediate_layer_model, img_batch)
#     message = Speaker.act(states= game_pool[b].speaker_input(feat), independent=flip_s)
    out_batch = []
    reward_batch = []
    for b in range(n_batches):
        out = Listener.act(states = game_pool[b].listener_input(message_batch[b]), independent = flip_l)
        out_batch.append(out)
        rew = game_pool[b].reward(out)
        reward_batch.append(rew)
        game_pool[b].reset()
    speaker_terminals = []
    rew_speaker = []
    for rew in reward_batch:
        speaker_terminals.extend([True])
        rew_speaker.extend([rew])

    if not flip_s:
#         print('e1')
        e1 = Speaker.model.observe(reward=rew_speaker, terminal=speaker_terminals)
    if not flip_l:
#         print('e2')
        e2 = Listener.model.observe(reward=reward_batch, terminal=[True]*n_batches)
#     assert e1 == e2
#     e = e1
    big_rewards.extend(reward_batch)
    big_rewards = big_rewards[-600:]
    if i%(100)==0:
#         print(" output: ", out)
        avg_rew = sum(big_rewards)/len(big_rewards)
        print(" message: ", message, " output: ", out, " epoch no: ", i, " avg reward", avg_rew)
        print(" epoch no: ", i, " avg reward", avg_rew)

        if(i!=0):
            data.append(avg_rew)
        ax.clear()
        ax.plot(data)
        if not flip_s:
            ax.set_xlabel('speaker')
        else:
            ax.set_xlabel('listener')
        fig.canvas.draw()


#     if sum(big_rewards)/len(big_rewards)>.75:
#         break
# Out:
# <img src="data:image/png;base64,..." width="639.230792677615">
#  message:  [2]  output:  1  epoch no:  0  avg reward 0.375
#  epoch no:  0  avg reward 0.375
#  message:  [4]  output:  2  epoch no:  100  avg reward 0.3333333333333333
#  epoch no:  100  avg reward 0.3333333333333333
#  message:  [0]  output:  2  epoch no:  200  avg reward 0.345
#  epoch no:  200  avg reward 0.345
#  message:  [2]  output:  0  epoch no:  300  avg reward 0.365
#  epoch no:  300  avg reward 0.365
#  message:  [2]  output:  0  epoch no:  400  avg reward 0.30833333333333335
#  epoch no:  400  avg reward 0.30833333333333335
#  message:  [2]  output:  2  epoch no:  500  avg reward 0.38
#  epoch no:  500  avg reward 0.38
#  message:  [1]  output:  2  epoch no:  600  avg reward 0.35833333333333334
#  epoch no:  600  avg reward 0.35833333333333334
#  message:  [1]  output:  2  epoch no:  700  avg reward 0.305
#  epoch no:  700  avg reward 0.305
#  message:  [1]  output:  2  epoch no:  800  avg reward 0.35333333333333333
#  epoch no:  800  avg reward 0.35333333333333333
#  message:  [1]  output:  2  epoch no:  900  avg reward 0.39666666666666667
#  epoch no:  900  avg reward 0.39666666666666667
#  message:  [1]  output:  2  epoch no:  1000  avg reward 0.355
#  epoch no:  1000  avg reward 0.355
#  message:  [1]  output:  1  epoch no:  1100  avg reward 0.3433333333333333
#  epoch no:  1100  avg reward 0.3433333333333333
#  message:  [4]  output:  0  epoch no:  1200  avg reward 0.3516666666666667
#  epoch no:  1200  avg reward 0.3516666666666667
#  message:  [3]  output:  0  epoch no:  1300  avg reward 0.31666666666666665
#  epoch no:  1300  avg reward 0.31666666666666665
#  message:  [3]  output:  2  epoch no:  1400  avg reward 0.3466666666666667
#  epoch no:  1400  avg reward 0.3466666666666667
#  message:  [0]  output:  2  epoch no:  1500  avg reward 0.39666666666666667
#  epoch no:  1500  avg reward 0.39666666666666667
#  message:  [0]  output:  0  epoch no:  1600  avg reward 0.505
#  epoch no:  1600  avg reward 0.505
#  message:  [3]  output:  0  epoch no:  1700  avg reward 0.48833333333333334
#  epoch no:  1700  avg reward 0.48833333333333334
#  message:  [3]  output:  2  epoch no:  1800  avg reward 0.5283333333333333
#  epoch no:  1800  avg reward 0.5283333333333333
#  message:  [3]  output:  0  epoch no:  1900  avg reward 0.495
#  epoch no:  1900  avg reward 0.495
#  message:  [3]  output:  2  epoch no:  2000  avg reward 0.515
#  epoch no:  2000  avg reward 0.515
#  message:  [1]  output:  0  epoch no:  2100  avg reward 0.5383333333333333
#  epoch no:  2100  avg reward 0.5383333333333333
#  message:  [3]  output:  2  epoch no:  2200  avg reward 0.54
#  epoch no:  2200  avg reward 0.54
#  message:  [0]  output:  2  epoch no:  2300  avg reward 0.54
#  epoch no:  2300  avg reward 0.54
#  message:  [0]  output:  2  epoch no:  2400  avg reward 0.5683333333333334
#  epoch no:  2400  avg reward 0.5683333333333334
#  message:  [0]  output:  0  epoch no:  2500  avg reward 0.61
#  epoch no:  2500  avg reward 0.61
#  message:  [3]  output:  2  epoch no:  2600  avg reward 0.585
#  epoch no:  2600  avg reward 0.585
#  message:  [3]  output:  2  epoch no:  2700  avg reward 0.6266666666666667
#  epoch no:  2700  avg reward 0.6266666666666667
#  message:  [3]  output:  0  epoch no:  2800  avg reward 0.6333333333333333
#  epoch no:  2800  avg reward 0.6333333333333333
#  message:  [0]  output:  2  epoch no:  2900  avg reward 0.6516666666666666
#  epoch no:  2900  avg reward 0.6516666666666666
#  message:  [3]  output:  0  epoch no:  3000  avg reward 0.715
#  epoch no:  3000  avg reward 0.715
#  message:  [0]  output:  1  epoch no:  3100  avg reward 0.6966666666666667
#  epoch no:  3100  avg reward 0.6966666666666667
#  message:  [3]  output:  2  epoch no:  3200  avg reward 0.72
#  epoch no:  3200  avg reward 0.72
#  message:  [3]  output:  0  epoch no:  3300  avg reward 0.7383333333333333
#  epoch no:  3300  avg reward 0.7383333333333333
#  message:  [3]  output:  0  epoch no:  3400  avg reward 0.7666666666666667
#  epoch no:  3400  avg reward 0.7666666666666667
#  message:  [2]  output:  2  epoch no:  3500  avg reward 0.765
#  epoch no:  3500  avg reward 0.765
#  message:  [2]  output:  2  epoch no:  3600  avg reward 0.7883333333333333
#  epoch no:  3600  avg reward 0.7883333333333333
#  message:  [2]  output:  0  epoch no:  3700  avg reward 0.7783333333333333
#  epoch no:  3700  avg reward 0.7783333333333333
#  message:  [0]  output:  0  epoch no:  3800  avg reward 0.745
#  epoch no:  3800  avg reward 0.745
#  message:  [3]  output:  2  epoch no:  3900  avg reward 0.74
#  epoch no:  3900  avg reward 0.74
#  message:  [2]  output:  2  epoch no:  4000  avg reward 0.795
#  epoch no:  4000  avg reward 0.795
#  message:  [2]  output:  0  epoch no:  4100  avg reward 0.7766666666666666
#  epoch no:  4100  avg reward 0.7766666666666666
#  message:  [0]  output:  1  epoch no:  4200  avg reward 0.8316666666666667
#  epoch no:  4200  avg reward 0.8316666666666667
#  message:  [3]  output:  0  epoch no:  4300  avg reward 0.7766666666666666
#  epoch no:  4300  avg reward 0.7766666666666666
#  message:  [3]  output:  0  epoch no:  4400  avg reward 0.75
#  epoch no:  4400  avg reward 0.75
#  message:  [2]  output:  0  epoch no:  4500  avg reward 0.8083333333333333
#  epoch no:  4500  avg reward 0.8083333333333333
#  message:  [2]  output:  2  epoch no:  4600  avg reward 0.805
#  epoch no:  4600  avg reward 0.805
#  message:  [2]  output:  0  epoch no:  4700  avg reward 0.7966666666666666
#  epoch no:  4700  avg reward 0.7966666666666666
#  message:  [2]  output:  2  epoch no:  4800  avg reward 0.8016666666666666
#  epoch no:  4800  avg reward 0.8016666666666666
#  message:  [3]  output:  2  epoch no:  4900  avg reward 0.82
#  epoch no:  4900  avg reward 0.82
#  message:  [0]  output:  1  epoch no:  5000  avg reward 0.7983333333333333
#  epoch no:  5000  avg reward 0.7983333333333333
#  message:  [3]  output:  2  epoch no:  5100  avg reward 0.7983333333333333
#  epoch no:  5100  avg reward 0.7983333333333333
#  message:  [0]  output:  0  epoch no:  5200  avg reward 0.8066666666666666
#  epoch no:  5200  avg reward 0.8066666666666666
#  message:  [2]  output:  2  epoch no:  5300  avg reward 0.8116666666666666
#  epoch no:  5300  avg reward 0.8116666666666666
#  message:  [0]  output:  2  epoch no:  5400  avg reward 0.745
#  epoch no:  5400  avg reward 0.745
#  message:  [3]  output:  0  epoch no:  5500  avg reward 0.8116666666666666
#  epoch no:  5500  avg reward 0.8116666666666666
#  message:  [2]  output:  0  epoch no:  5600  avg reward 0.8383333333333334
#  epoch no:  5600  avg reward 0.8383333333333334
#  message:  [3]  output:  0  epoch no:  5700  avg reward 0.8383333333333334
#  epoch no:  5700  avg reward 0.8383333333333334
#  message:  [3]  output:  0  epoch no:  5800  avg reward 0.7783333333333333
#  epoch no:  5800  avg reward 0.7783333333333333
#  message:  [3]  output:  0  epoch no:  5900  avg reward 0.815
#  epoch no:  5900  avg reward 0.815
#  message:  [3]  output:  0  epoch no:  6000  avg reward 0.79
#  epoch no:  6000  avg reward 0.79
#  message:  [0]  output:  1  epoch no:  6100  avg reward 0.81
#  epoch no:  6100  avg reward 0.81
#  message:  [0]  output:  2  epoch no:  6200  avg reward 0.8133333333333334
#  epoch no:  6200  avg reward 0.8133333333333334
#  message:  [0]  output:  2  epoch no:  6300  avg reward 0.795
#  epoch no:  6300  avg reward 0.795
#  message:  [2]  output:  0  epoch no:  6400  avg reward 0.815
#  epoch no:  6400  avg reward 0.815
#  message:  [0]  output:  1  epoch no:  6500  avg reward 0.71
#  epoch no:  6500  avg reward 0.71
#  message:  [3]  output:  0  epoch no:  6600  avg reward 0.81
#  epoch no:  6600  avg reward 0.81
#  message:  [2]  output:  2  epoch no:  6700  avg reward 0.7916666666666666
#  epoch no:  6700  avg reward 0.7916666666666666
#  message:  [0]  output:  1  epoch no:  6800  avg reward 0.8216666666666667
#  epoch no:  6800  avg reward 0.8216666666666667
#  message:  [0]  output:  2  epoch no:  6900  avg reward 0.8283333333333334
#  epoch no:  6900  avg reward 0.8283333333333334
#  message:  [0]  output:  0  epoch no:  7000  avg reward 0.8166666666666667
#  epoch no:  7000  avg reward 0.8166666666666667
#  message:  [2]  output:  2  epoch no:  7100  avg reward 0.8516666666666667
#  epoch no:  7100  avg reward 0.8516666666666667
#  message:  [3]  output:  2  epoch no:  7200  avg reward 0.8666666666666667
#  epoch no:  7200  avg reward 0.8666666666666667
#  message:  [3]  output:  1  epoch no:  7300  avg reward 0.9366666666666666
#  epoch no:  7300  avg reward 0.9366666666666666
#  message:  [0]  output:  2  epoch no:  7400  avg reward 0.9466666666666667
#  epoch no:  7400  avg reward 0.9466666666666667
#  message:  [2]  output:  2  epoch no:  7500  avg reward 0.96
#  epoch no:  7500  avg reward 0.96
#  message:  [2]  output:  2  epoch no:  7600  avg reward 0.9633333333333334
#  epoch no:  7600  avg reward 0.9633333333333334
#  message:  [3]  output:  2  epoch no:  7700  avg reward 0.955
#  epoch no:  7700  avg reward 0.955
#  message:  [0]  output:  2  epoch no:  7800  avg reward 0.955
#  epoch no:  7800  avg reward 0.955
#  message:  [2]  output:  0  epoch no:  7900  avg reward 0.9583333333333334
#  epoch no:  7900  avg reward 0.9583333333333334
#  message:  [2]  output:  2  epoch no:  8000  avg reward 0.9316666666666666
#  epoch no:  8000  avg reward 0.9316666666666666
#  message:  [0]  output:  1  epoch no:  8100  avg reward 0.9566666666666667
#  epoch no:  8100  avg reward 0.9566666666666667
#  message:  [2]  output:  0  epoch no:  8200  avg reward 0.965
#  epoch no:  8200  avg reward 0.965
#  message:  [0]  output:  1  epoch no:  8300  avg reward 0.9616666666666667
#  epoch no:  8300  avg reward 0.9616666666666667
#  message:  [3]  output:  0  epoch no:  8400  avg reward 0.9716666666666667
#  epoch no:  8400  avg reward 0.9716666666666667
#  message:  [3]  output:  0  epoch no:  8500  avg reward 0.9683333333333334
#  epoch no:  8500  avg reward 0.9683333333333334
#  message:  [0]  output:  2  epoch no:  8600  avg reward 0.975
#  epoch no:  8600  avg reward 0.975
#  message:  [0]  output:  2  epoch no:  8700  avg reward 0.97
#  epoch no:  8700  avg reward 0.97
#  message:  [3]  output:  0  epoch no:  8800  avg reward 0.9833333333333333
#  epoch no:  8800  avg reward 0.9833333333333333
#  message:  [2]  output:  1  epoch no:  8900  avg reward 0.98
#  epoch no:  8900  avg reward 0.98
#  message:  [3]  output:  2  epoch no:  9000  avg reward 0.975
#  epoch no:  9000  avg reward 0.975
#  message:  [3]  output:  0  epoch no:  9100  avg reward 0.9766666666666667
#  epoch no:  9100  avg reward 0.9766666666666667
#  message:  [3]  output:  1  epoch no:  9200  avg reward 0.9816666666666667
#  epoch no:  9200  avg reward 0.9816666666666667
#  message:  [2]  output:  2  epoch no:  9300  avg reward 0.97
#  epoch no:  9300  avg reward 0.97
#  message:  [2]  output:  0  epoch no:  9400  avg reward 0.9833333333333333
#  epoch no:  9400  avg reward 0.9833333333333333
#  message:  [3]  output:  2  epoch no:  9500  avg reward 0.9716666666666667
#  epoch no:  9500  avg reward 0.9716666666666667
#  message:  [0]  output:  2  epoch no:  9600  avg reward 0.9766666666666667
#  epoch no:  9600  avg reward 0.9766666666666667
#  message:  [0]  output:  0  epoch no:  9700  avg reward 0.9783333333333334
#  epoch no:  9700  avg reward 0.9783333333333334
#  message:  [2]  output:  0  epoch no:  9800  avg reward 0.9866666666666667
#  epoch no:  9800  avg reward 0.9866666666666667
#  message:  [2]  output:  0  epoch no:  9900  avg reward 0.9883333333333333
#  epoch no:  9900  avg reward 0.9883333333333333
#  message:  [3]  output:  1  epoch no:  10000  avg reward 0.985
#  epoch no:  10000  avg reward 0.985
#  message:  [2]  output:  0  epoch no:  10100  avg reward 0.955
#  epoch no:  10100  avg reward 0.955
#  message:  [3]  output:  1  epoch no:  10200  avg reward 0.9933333333333333
#  epoch no:  10200  avg reward 0.9933333333333333
#  message:  [3]  output:  0  epoch no:  10300  avg reward 0.9666666666666667
#  epoch no:  10300  avg reward 0.9666666666666667
#  message:  [0]  output:  2  epoch no:  10400  avg reward 0.985
#  epoch no:  10400  avg reward 0.985
#  message:  [1]  output:  1  epoch no:  10500  avg reward 0.985
#  epoch no:  10500  avg reward 0.985
#  message:  [4]  output:  1  epoch no:  10600  avg reward 0.9766666666666667
#  epoch no:  10600  avg reward 0.9766666666666667
#  message:  [4]  output:  1  epoch no:  10700  avg reward 0.99
#  epoch no:  10700  avg reward 0.99
#  message:  [4]  output:  0  epoch no:  10800  avg reward 0.98
#  epoch no:  10800  avg reward 0.98
#  message:  [4]  output:  2  epoch no:  10900  avg reward 0.97
#  epoch no:  10900  avg reward 0.97
#  message:  [4]  output:  2  epoch no:  11000  avg reward 0.975
#  epoch no:  11000  avg reward 0.975
#  message:  [4]  output:  0  epoch no:  11100  avg reward 0.9883333333333333
#  epoch no:  11100  avg reward 0.9883333333333333
#  message:  [0]  output:  1  epoch no:  11200  avg reward 0.9783333333333334
#  epoch no:  11200  avg reward 0.9783333333333334
#  message:  [3]  output:  1  epoch no:  11300  avg reward 0.9766666666666667
#  epoch no:  11300  avg reward 0.9766666666666667
#  message:  [3]  output:  2  epoch no:  11400  avg reward 0.9816666666666667
#  epoch no:  11400  avg reward 0.9816666666666667
#  message:  [4]  output:  1  epoch no:  11500  avg reward 0.975
#  epoch no:  11500  avg reward 0.975
#  message:  [4]  output:  2  epoch no:  11600  avg reward 0.9916666666666667
#  epoch no:  11600  avg reward 0.9916666666666667
#  message:  [0]  output:  2  epoch no:  11700  avg reward 0.9783333333333334
#  epoch no:  11700  avg reward 0.9783333333333334
#  message:  [2]  output:  0  epoch no:  11800  avg reward 0.9933333333333333
#  epoch no:  11800  avg reward 0.9933333333333333
#  message:  [2]  output:  1  epoch no:  11900  avg reward 0.975
#  epoch no:  11900  avg reward 0.975
#  message:  [4]  output:  0  epoch no:  12000  avg reward 0.9916666666666667
#  epoch no:  12000  avg reward 0.9916666666666667
#  message:  [0]  output:  1  epoch no:  12100  avg reward 0.9766666666666667
#  epoch no:  12100  avg reward 0.9766666666666667
#  message:  [3]  output:  0  epoch no:  12200  avg reward 0.9783333333333334
#  epoch no:  12200  avg reward 0.9783333333333334
#  message:  [4]  output:  0  epoch no:  12300  avg reward 0.9833333333333333
#  epoch no:  12300  avg reward 0.9833333333333333
#  message:  [2]  output:  1  epoch no:  12400  avg reward 0.9816666666666667
#  epoch no:  12400  avg reward 0.9816666666666667
#  message:  [4]  output:  0  epoch no:  12500  avg reward 0.9866666666666667
#  epoch no:  12500  avg reward 0.9866666666666667
#  message:  [4]  output:  2  epoch no:  12600  avg reward 0.975
#  epoch no:  12600  avg reward 0.975
#  message:  [1]  output:  1  epoch no:  12700  avg reward 0.9883333333333333
#  epoch no:  12700  avg reward 0.9883333333333333
#  message:  [0]  output:  0  epoch no:  12800  avg reward 0.9916666666666667
#  epoch no:  12800  avg reward 0.9916666666666667
#  message:  [4]  output:  1  epoch no:  12900  avg reward 0.9766666666666667
#  epoch no:  12900  avg reward 0.9766666666666667
#  message:  [1]  output:  2  epoch no:  13000  avg reward 0.985
#  epoch no:  13000  avg reward 0.985
#  message:  [2]  output:  1  epoch no:  13100  avg reward 0.9883333333333333
#  epoch no:  13100  avg reward 0.9883333333333333
#  message:  [1]  output:  1  epoch no:  13200  avg reward 0.9766666666666667
#  epoch no:  13200  avg reward 0.9766666666666667
#  message:  [4]  output:  2  epoch no:  13300  avg reward 0.9916666666666667
#  epoch no:  13300  avg reward 0.9916666666666667
#  message:  [4]  output:  1  epoch no:  13400  avg reward 0.9866666666666667
#  epoch no:  13400  avg reward 0.9866666666666667
#  message:  [1]  output:  0  epoch no:  13500  avg reward 0.9783333333333334
#  epoch no:  13500  avg reward 0.9783333333333334
#  message:  [2]  output:  1  epoch no:  13600  avg reward 0.9833333333333333
#  epoch no:  13600  avg reward 0.9833333333333333
#  message:  [2]  output:  0  epoch no:  13700  avg reward 0.9933333333333333
#  epoch no:  13700  avg reward 0.9933333333333333
#  message:  [4]  output:  0  epoch no:  13800  avg reward 0.98
#  epoch no:  13800  avg reward 0.98
#  message:  [2]  output:  1  epoch no:  13900  avg reward 0.995
#  epoch no:  13900  avg reward 0.995
#  message:  [2]  output:  0  epoch no:  14000  avg reward 0.9916666666666667
#  epoch no:  14000  avg reward 0.9916666666666667
#  message:  [4]  output:  2  epoch no:  14100  avg reward 0.9816666666666667
#  epoch no:  14100  avg reward 0.9816666666666667
#  message:  [0]  output:  0  epoch no:  14200  avg reward 0.9833333333333333
#  epoch no:  14200  avg reward 0.9833333333333333
#  message:  [3]  output:  2  epoch no:  14300  avg reward 0.9833333333333333
#  epoch no:  14300  avg reward 0.9833333333333333
#  message:  [1]  output:  0  epoch no:  14400  avg reward 0.9833333333333333
#  epoch no:  14400  avg reward 0.9833333333333333
#  message:  [2]  output:  1  epoch no:  14500  avg reward 0.9933333333333333
#  epoch no:  14500  avg reward 0.9933333333333333
#  message:  [3]  output:  0  epoch no:  14600  avg reward 0.9883333333333333
#  epoch no:  14600  avg reward 0.9883333333333333
#  message:  [0]  output:  0  epoch no:  14700  avg reward 0.995
#  epoch no:  14700  avg reward 0.995
#  message:  [4]  output:  2  epoch no:  14800  avg reward 0.9966666666666667
#  epoch no:  14800  avg reward 0.9966666666666667
#  message:  [1]  output:  1  epoch no:  14900  avg reward 0.99
#  epoch no:  14900  avg reward 0.99
#  message:  [1]  output:  0  epoch no:  15000  avg reward 0.9816666666666667
#  epoch no:  15000  avg reward 0.9816666666666667
#  message:  [4]  output:  1  epoch no:  15100  avg reward 0.995
#  epoch no:  15100  avg reward 0.995
#  message:  [2]  output:  2  epoch no:  15200  avg reward 0.9866666666666667
#  epoch no:  15200  avg reward 0.9866666666666667
#  message:  [3]  output:  2  epoch no:  15300  avg reward 0.9866666666666667
#  epoch no:  15300  avg reward 0.9866666666666667
#  message:  [2]  output:  1  epoch no:  15400  avg reward 0.9916666666666667
#  epoch no:  15400  avg reward 0.9916666666666667
#  message:  [4]  output:  1  epoch no:  15500  avg reward 0.9933333333333333
#  epoch no:  15500  avg reward 0.9933333333333333
#  message:  [1]  output:  1  epoch no:  15600  avg reward 0.98
#  epoch no:  15600  avg reward 0.98
#  message:  [2]  output:  1  epoch no:  15700  avg reward 0.985
#  epoch no:  15700  avg reward 0.985
#  message:  [2]  output:  2  epoch no:  15800  avg reward 0.9866666666666667
#  epoch no:  15800  avg reward 0.9866666666666667
#  message:  [4]  output:  0  epoch no:  15900  avg reward 0.9733333333333334
#  epoch no:  15900  avg reward 0.9733333333333334
#  message:  [2]  output:  1  epoch no:  16000  avg reward 0.9916666666666667
#  epoch no:  16000  avg reward 0.9916666666666667
#  message:  [4]  output:  1  epoch no:  16100  avg reward 0.995
#  epoch no:  16100  avg reward 0.995
#  message:  [4]  output:  0  epoch no:  16200  avg reward 0.9883333333333333
#  epoch no:  16200  avg reward 0.9883333333333333
#  message:  [0]  output:  2  epoch no:  16300  avg reward 0.9933333333333333
#  epoch no:  16300  avg reward 0.9933333333333333
#  message:  [0]  output:  0  epoch no:  16400  avg reward 0.9883333333333333
#  epoch no:  16400  avg reward 0.9883333333333333
#  message:  [4]  output:  2  epoch no:  16500  avg reward 0.9833333333333333
#  epoch no:  16500  avg reward 0.9833333333333333
#  message:  [2]  output:  0  epoch no:  16600  avg reward 0.985
#  epoch no:  16600  avg reward 0.985
#  message:  [4]  output:  1  epoch no:  16700  avg reward 0.9966666666666667
#  epoch no:  16700  avg reward 0.9966666666666667
#  message:  [2]  output:  0  epoch no:  16800  avg reward 0.9933333333333333
#  epoch no:  16800  avg reward 0.9933333333333333
#  message:  [3]  output:  0  epoch no:  16900  avg reward 0.99
#  epoch no:  16900  avg reward 0.99
#  message:  [0]  output:  1  epoch no:  17000  avg reward 0.9916666666666667
#  epoch no:  17000  avg reward 0.9916666666666667
#  message:  [2]  output:  2  epoch no:  17100  avg reward 0.98
#  epoch no:  17100  avg reward 0.98
#  message:  [2]  output:  2  epoch no:  17200  avg reward 0.9866666666666667
#  epoch no:  17200  avg reward 0.9866666666666667
#  message:  [2]  output:  2  epoch no:  17300  avg reward 0.9833333333333333
#  epoch no:  17300  avg reward 0.9833333333333333
#  message:  [0]  output:  1  epoch no:  17400  avg reward 0.9866666666666667
#  epoch no:  17400  avg reward 0.9866666666666667
#  message:  [3]  output:  2  epoch no:  17500  avg reward 0.99
#  epoch no:  17500  avg reward 0.99
#  message:  [3]  output:  0  epoch no:  17600  avg reward 0.9916666666666667
#  epoch no:  17600  avg reward 0.9916666666666667
#  message:  [2]  output:  0  epoch no:  17700  avg reward 0.9833333333333333
#  epoch no:  17700  avg reward 0.9833333333333333
#  message:  [2]  output:  2  epoch no:  17800  avg reward 0.99
#  epoch no:  17800  avg reward 0.99
#  message:  [0]  output:  1  epoch no:  17900  avg reward 0.9883333333333333
#  epoch no:  17900  avg reward 0.9883333333333333
#  message:  [2]  output:  0  epoch no:  18000  avg reward 0.9866666666666667
#  epoch no:  18000  avg reward 0.9866666666666667
#  message:  [0]  output:  0  epoch no:  18100  avg reward 0.985
#  epoch no:  18100  avg reward 0.985
#  message:  [2]  output:  1  epoch no:  18200  avg reward 0.985
#  epoch no:  18200  avg reward 0.985
#  message:  [0]  output:  2  epoch no:  18300  avg reward 0.9783333333333334
#  epoch no:  18300  avg reward 0.9783333333333334
#  message:  [2]  output:  0  epoch no:  18400  avg reward 0.995
#  epoch no:  18400  avg reward 0.995
#  message:  [1]  output:  0  epoch no:  18500  avg reward 0.98
#  epoch no:  18500  avg reward 0.98
#  message:  [0]  output:  1  epoch no:  18600  avg reward 0.99
#  epoch no:  18600  avg reward 0.99
#  message:  [1]  output:  1  epoch no:  18700  avg reward 0.995
#  epoch no:  18700  avg reward 0.995
#  message:  [2]  output:  2  epoch no:  18800  avg reward 0.98
#  epoch no:  18800  avg reward 0.98
#  message:  [3]  output:  0  epoch no:  18900  avg reward 0.9883333333333333
#  epoch no:  18900  avg reward 0.9883333333333333
#  message:  [3]  output:  0  epoch no:  19000  avg reward 0.995
#  epoch no:  19000  avg reward 0.995
#  message:  [1]  output:  2  epoch no:  19100  avg reward 0.99
#  epoch no:  19100  avg reward 0.99
#  message:  [4]  output:  0  epoch no:  19200  avg reward 0.99
#  epoch no:  19200  avg reward 0.99
#  message:  [2]  output:  2  epoch no:  19300  avg reward 0.98
#  epoch no:  19300  avg reward 0.98
#  message:  [2]  output:  1  epoch no:  19400  avg reward 0.9933333333333333
#  epoch no:  19400  avg reward 0.9933333333333333
#  message:  [2]  output:  0  epoch no:  19500  avg reward 0.9866666666666667
#  epoch no:  19500  avg reward 0.9866666666666667
#  message:  [2]  output:  0  epoch no:  19600  avg reward 0.985
#  epoch no:  19600  avg reward 0.985
#  message:  [0]  output:  2  epoch no:  19700  avg reward 0.9983333333333333
#  epoch no:  19700  avg reward 0.9983333333333333
#  message:  [0]  output:  2  epoch no:  19800  avg reward 0.9933333333333333
#  epoch no:  19800  avg reward 0.9933333333333333
#  message:  [3]  output:  2  epoch no:  19900  avg reward 0.9866666666666667
#  epoch no:  19900  avg reward 0.9866666666666667
#  message:  [0]  output:  1  epoch no:  20000  avg reward 0.9866666666666667
#  epoch no:  20000  avg reward 0.9866666666666667
#  message:  [3]  output:  1  epoch no:  20100  avg reward 0.9833333333333333
#  epoch no:  20100  avg reward 0.9833333333333333
#  message:  [2]  output:  2  epoch no:  20200  avg reward 0.9983333333333333
#  epoch no:  20200  avg reward 0.9983333333333333
#  message:  [1]  output:  0  epoch no:  20300  avg reward 0.995
#  epoch no:  20300  avg reward 0.995
#  message:  [2]  output:  2  epoch no:  20400  avg reward 0.9916666666666667
#  epoch no:  20400  avg reward 0.9916666666666667
#  message:  [4]  output:  2  epoch no:  20500  avg reward 0.9966666666666667
#  epoch no:  20500  avg reward 0.9966666666666667
#  message:  [3]  output:  0  epoch no:  20600  avg reward 0.9883333333333333
#  epoch no:  20600  avg reward 0.9883333333333333
#  message:  [4]  output:  1  epoch no:  20700  avg reward 0.98
#  epoch no:  20700  avg reward 0.98
#  message:  [1]  output:  2  epoch no:  20800  avg reward 0.9966666666666667
#  epoch no:  20800  avg reward 0.9966666666666667
#  message:  [2]  output:  1  epoch no:  20900  avg reward 0.9966666666666667
#  epoch no:  20900  avg reward 0.9966666666666667
#  message:  [3]  output:  1  epoch no:  21000  avg reward 0.99
#  epoch no:  21000  avg reward 0.99
#  message:  [1]  output:  1  epoch no:  21100  avg reward 0.9833333333333333
#  epoch no:  21100  avg reward 0.9833333333333333
#  message:  [4]  output:  1  epoch no:  21200  avg reward 0.9916666666666667
#  epoch no:  21200  avg reward 0.9916666666666667
#  message:  [0]  output:  0  epoch no:  21300  avg reward 0.98
#  epoch no:  21300  avg reward 0.98
#  message:  [2]  output:  1  epoch no:  21400  avg reward 0.9733333333333334
#  epoch no:  21400  avg reward 0.9733333333333334
#  message:  [0]  output:  1  epoch no:  21500  avg reward 0.99
#  epoch no:  21500  avg reward 0.99
#  message:  [2]  output:  0  epoch no:  21600  avg reward 0.9966666666666667
#  epoch no:  21600  avg reward 0.9966666666666667
#  message:  [0]  output:  0  epoch no:  21700  avg reward 0.9916666666666667
#  epoch no:  21700  avg reward 0.9916666666666667
#  message:  [3]  output:  1  epoch no:  21800  avg reward 0.98
#  epoch no:  21800  avg reward 0.98
#  message:  [1]  output:  0  epoch no:  21900  avg reward 0.9816666666666667
#  epoch no:  21900  avg reward 0.9816666666666667
#  message:  [1]  output:  1  epoch no:  22000  avg reward 0.99
#  epoch no:  22000  avg reward 0.99
#  message:  [3]  output:  1  epoch no:  22100  avg reward 0.9933333333333333
#  epoch no:  22100  avg reward 0.9933333333333333
#  message:  [3]  output:  1  epoch no:  22200  avg reward 0.9883333333333333
#  epoch no:  22200  avg reward 0.9883333333333333
#  message:  [1]  output:  1  epoch no:  22300  avg reward 0.9716666666666667
#  epoch no:  22300  avg reward 0.9716666666666667
#  message:  [1]  output:  0  epoch no:  22400  avg reward 0.9883333333333333
#  epoch no:  22400  avg reward 0.9883333333333333
#  message:  [2]  output:  0  epoch no:  22500  avg reward 0.9933333333333333
#  epoch no:  22500  avg reward 0.9933333333333333
#  message:  [4]  output:  0  epoch no:  22600  avg reward 0.9883333333333333
#  epoch no:  22600  avg reward 0.9883333333333333
#  message:  [1]  output:  0  epoch no:  22700  avg reward 0.9933333333333333
#  epoch no:  22700  avg reward 0.9933333333333333
#  message:  [2]  output:  1  epoch no:  22800  avg reward 0.9816666666666667
#  epoch no:  22800  avg reward 0.9816666666666667
#  message:  [3]  output:  2  epoch no:  22900  avg reward 0.9916666666666667
#  epoch no:  22900  avg reward 0.9916666666666667
#  message:  [3]  output:  2  epoch no:  23000  avg reward 0.9933333333333333
#  epoch no:  23000  avg reward 0.9933333333333333
#  message:  [2]  output:  2  epoch no:  23100  avg reward 0.9983333333333333
#  epoch no:  23100  avg reward 0.9983333333333333
#  message:  [2]  output:  1  epoch no:  23200  avg reward 0.9783333333333334
#  epoch no:  23200  avg reward 0.9783333333333334
#  message:  [2]  output:  0  epoch no:  23300  avg reward 0.9983333333333333
#  epoch no:  23300  avg reward 0.9983333333333333
#  message:  [2]  output:  0  epoch no:  23400  avg reward 0.985
#  epoch no:  23400  avg reward 0.985
#  message:  [2]  output:  1  epoch no:  23500  avg reward 0.9933333333333333
#  epoch no:  23500  avg reward 0.9933333333333333
#  message:  [4]  output:  0  epoch no:  23600  avg reward 0.99
#  epoch no:  23600  avg reward 0.99
#  message:  [4]  output:  0  epoch no:  23700  avg reward 0.9966666666666667
#  epoch no:  23700  avg reward 0.9966666666666667
#  message:  [1]  output:  1  epoch no:  23800  avg reward 0.99
#  epoch no:  23800  avg reward 0.99
#  message:  [2]  output:  0  epoch no:  23900  avg reward 0.9866666666666667
#  epoch no:  23900  avg reward 0.9866666666666667
#  message:  [2]  output:  1  epoch no:  24000  avg reward 0.9933333333333333
#  epoch no:  24000  avg reward 0.9933333333333333
#  message:  [2]  output:  1  epoch no:  24100  avg reward 0.9866666666666667
#  epoch no:  24100  avg reward 0.9866666666666667
#  message:  [2]  output:  0  epoch no:  24200  avg reward 0.9933333333333333
#  epoch no:  24200  avg reward 0.9933333333333333
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-6b5d76730a40> in <module>
#      40     reward_batch = []
#      41     for b in range(n_batches):
# ---> 42         out = Listener.act(states = game_pool[b].listener_input(message_batch[b]), independent = flip_l)
#      43         out_batch.append(out)
#      44         rew = game_pool[b].reward(out)
#
# /usr/local/lib/python3.5/dist-packages/tensorforce/agents/agent.py in act(self, states, deterministic, independent, fetch_tensors, buffered)
#     146             internals=self.current_internals,
#     147             deterministic=deterministic,
# --> 148             independent=independent
#     149         )
#     150
#
# /usr/local/lib/python3.5/dist-packages/tensorforce/models/model.py in act(self, states, internals, deterministic, independent, fetch_tensors)
#    1391         )
#    1392
# -> 1393         fetch_list = self.monitored_session.run(fetches=fetches, feed_dict=feed_dict)
#    1394         actions, internals, timestep = fetch_list[0:3]
#    1395
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/training/monitored_session.py in run(self, fetches, feed_dict, options, run_metadata)
#     544                           feed_dict=feed_dict,
#     545                           options=options,
# --> 546                           run_metadata=run_metadata)
#     547
#     548   def run_step_fn(self, step_fn):
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/training/monitored_session.py in run(self, *args, **kwargs)
#    1096   def run(self, *args, **kwargs):
#    1097     try:
# -> 1098       return self._sess.run(*args, **kwargs)
#    1099     except _PREEMPTION_ERRORS:
#    1100       raise
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/training/monitored_session.py in run(self, fetches, feed_dict, options, run_metadata)
#    1168                                   feed_dict=feed_dict,
#    1169                                   options=options,
# -> 1170                                   run_metadata=run_metadata)
#    1171
#    1172     for hook in self._hooks:
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/training/monitored_session.py in run(self, *args, **kwargs)
#     948
#     949   def run(self, *args, **kwargs):
# --> 950     return self._sess.run(*args, **kwargs)
#     951
#     952   def run_step_fn(self, step_fn, raw_session, run_with_hooks):
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     903     try:
#     904       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 905                          run_metadata_ptr)
#     906       if run_metadata:
#     907         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1138     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1139       results = self._do_run(handle, final_targets, final_fetches,
# -> 1140                              feed_dict_tensor, options, run_metadata)
#    1141     else:
#    1142       results = []
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1319     if handle is None:
#    1320       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1321                            run_metadata)
#    1322     else:
#    1323       return self._do_call(_prun_fn, handle, feeds, fetches)
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1325   def _do_call(self, fn, *args):
#    1326     try:
# -> 1327       return fn(*args)
#    1328     except errors.OpError as e:
#    1329       message = compat.as_text(e.message)
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1310       self._extend_graph()
#    1311       return self._call_tf_sessionrun(
# -> 1312           options, feed_dict, fetch_list, target_list, run_metadata)
#    1313
#    1314     def _prun_fn(handle, feed_dict, fetch_list):
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1418         return tf_session.TF_Run(
#    1419             self._session, options, feed_dict, fetch_list, target_list,
# -> 1420             status, run_metadata)
#    1421
#    1422   def _call_tf_sessionprun(self, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:
