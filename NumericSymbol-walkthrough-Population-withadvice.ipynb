# %%
# %matplotlib notebook
import warnings
with warnings.catch_warnings():
    warnings.filterwarnings("ignore",category=FutureWarning)
    
    from game import Game
    from data_preprocess import get_data_points, get_dummy_data
    from utils import get_feature_extractor_model, get_features, message_to_image, message_to_image_sm
    from agents import get_agents
    
    import numpy as np
    import matplotlib.pyplot as plt
from sklearn.datasets import make_classification, make_blobs
# Out:
# Using TensorFlow backend.

# %%
sender_type = "aware"

n_features = 3
n_clusters = 7
n_samples = 3
n_vocab = 10

n_batches = 10
n_epochs = 1000000

n_all_features = 512

max_len = 2

img_dim = 0
img_rows = 0
img_cols = 0
img_features_len = 1

n_batches = 32
n_epochs = 10000000
action_size = 1
num_actions = n_vocab

n_population = 4

ppo_config = "configs/ppo-big-200.json"
network_config = "configs/mlp3_network-200.json"
data_csv_path = "data_csvs/cifar_feats.csv"
feat_model_path = 'feature_extractors/feature_model.h5'
feature_model_json_path = 'feature_extractors/feature_model.json'

flip_s = False
flip_l = False
freq = 1
debug = True

# %%
# Get data, prepare Agents, get feature extractor, initialize logging, create game pool

X1a, Y1a, n_features = get_dummy_data(n_samples = 16000, n_features=n_features, centers=n_clusters)
X1 = X1a[Y1a<=4]
Y1 = Y1a[Y1a<=4]
print(X1.shape, Y1.shape)
X1, X1_test, Y1, Y1_test = X1[:10000, :], X1[10000:, :], Y1[:10000], Y1[10000:]




print(X1.shape, Y1.shape, X1_test.shape, Y1_test.shape)

Speakers, Listeners = [], []

for it in range(n_population):
    Speaker1, Listener1 = get_agents(ppo_config, network_config, sender_type, n_features, img_dim, img_features_len, n_samples, num_actions, action_size)
    Speakers.append(Speaker1)
    Listeners.append(Listener1)
intermediate_layer_model = get_feature_extractor_model(feat_model_path, feature_model_json_path)

big_rewards = []
data = []
game_pool = []

for i in range(n_batches):
    game_pool.append(Game(n_features, n_clusters-2, n_samples, n_vocab, sender_type, [X1, Y1]))
# Out:
# (11430, 3) (11430,)
# (10000, 3) (10000,) (1430, 3) (1430,)
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.

# %%
### N population 1

fig = plt.figure()
ax = fig.add_subplot(111)
plt.ion()

fig.show()
fig.canvas.draw()
for i in range(n_epochs):
    Speaker = Speakers[np.random.choice(n_population)]
    Listener = Listeners[np.random.choice(n_population)]
    message_batch = []
    img_batch = []
    r = i%(2*freq)
    if r<1*freq:
        flip_s = False
        flip_l = True
    if r>=1*freq:
        flip_s = True
        flip_l = False
    l_rewards = []
    strokes = []
    for b in range(n_batches):
        strokes = []
#         for idx in range(2):
#             if idx ==0:
#                 feat = np.zeros((10,10), np.uint8)
#             else:
#                 im = message_to_image_sm(strokes, img_dim, img_dim)
# #                 feat = get_features([im])[0]
#                 feat = im.flatten()
        message = Speaker.act(states= game_pool[b].speaker_input(), independent=flip_s)  # (scalar between 0 and 4)
        message_batch.append(message)
#             strokes.append(message)
#         img = message_to_image(strokes, img_rows, img_cols)
#         img_batch.append(img)
#         Speaker.reset()

#     features_batch = get_features(intermediate_layer_model, img_batch)
#     message = Speaker.act(states= game_pool[b].speaker_input(feat), independent=flip_s)
    out_batch = []
    reward_batch = []
    for b in range(n_batches):
        out = Listener.act(states = game_pool[b].listener_input(message_batch[b]), independent = flip_l)
        out_batch.append(out)
        rew = game_pool[b].reward(out)
        reward_batch.append(rew)
        game_pool[b].reset()
    speaker_terminals = []
    rew_speaker = []
    for rew in reward_batch:
        speaker_terminals.extend([True])
        rew_speaker.extend([rew])

    if not flip_s:
#         print('e1')
        e1 = Speaker.model.observe(reward=rew_speaker, terminal=speaker_terminals)
    if not flip_l:
#         print('e2')
        e2 = Listener.model.observe(reward=reward_batch, terminal=[True]*n_batches)
#     assert e1 == e2
#     e = e1
    big_rewards.extend(reward_batch)
    big_rewards = big_rewards[-600:]
    if i%(100)==0:
#         print(" output: ", out)
        avg_rew = sum(big_rewards)/len(big_rewards)
        print(" message: ", message, " output: ", out, " epoch no: ", i, " avg reward", avg_rew)
        print(" epoch no: ", i, " avg reward", avg_rew)

        if(i!=0):
            data.append(avg_rew)
        ax.clear()
        ax.plot(data)
        if not flip_s:
            ax.set_xlabel('speaker')
        else:
            ax.set_xlabel('listener')
        fig.canvas.draw()


#     if sum(big_rewards)/len(big_rewards)>.75:
#         break
# Out:
# <img src="data:image/png;base64,..." width="639.230792677615">
#  message:  [0]  output:  2  epoch no:  0  avg reward 0.34375
#  epoch no:  0  avg reward 0.34375
#  message:  [1]  output:  1  epoch no:  100  avg reward 0.33
#  epoch no:  100  avg reward 0.33
#  message:  [2]  output:  1  epoch no:  200  avg reward 0.31333333333333335
#  epoch no:  200  avg reward 0.31333333333333335
#  message:  [2]  output:  2  epoch no:  300  avg reward 0.3466666666666667
#  epoch no:  300  avg reward 0.3466666666666667
#  message:  [1]  output:  2  epoch no:  400  avg reward 0.32166666666666666
#  epoch no:  400  avg reward 0.32166666666666666
#  message:  [0]  output:  2  epoch no:  500  avg reward 0.42333333333333334
#  epoch no:  500  avg reward 0.42333333333333334
#  message:  [0]  output:  2  epoch no:  600  avg reward 0.42
#  epoch no:  600  avg reward 0.42
#  message:  [0]  output:  1  epoch no:  700  avg reward 0.43333333333333335
#  epoch no:  700  avg reward 0.43333333333333335
#  message:  [0]  output:  2  epoch no:  800  avg reward 0.44333333333333336
#  epoch no:  800  avg reward 0.44333333333333336
#  message:  [2]  output:  2  epoch no:  900  avg reward 0.425
#  epoch no:  900  avg reward 0.425
#  message:  [0]  output:  1  epoch no:  1000  avg reward 0.455
#  epoch no:  1000  avg reward 0.455
#  message:  [2]  output:  2  epoch no:  1100  avg reward 0.43666666666666665
#  epoch no:  1100  avg reward 0.43666666666666665
#  message:  [2]  output:  2  epoch no:  1200  avg reward 0.43333333333333335
#  epoch no:  1200  avg reward 0.43333333333333335
#  message:  [2]  output:  2  epoch no:  1300  avg reward 0.42333333333333334
#  epoch no:  1300  avg reward 0.42333333333333334
#  message:  [4]  output:  2  epoch no:  1400  avg reward 0.435
#  epoch no:  1400  avg reward 0.435
#  message:  [0]  output:  1  epoch no:  1500  avg reward 0.48333333333333334
#  epoch no:  1500  avg reward 0.48333333333333334
#  message:  [0]  output:  0  epoch no:  1600  avg reward 0.4816666666666667
#  epoch no:  1600  avg reward 0.4816666666666667
#  message:  [0]  output:  1  epoch no:  1700  avg reward 0.5233333333333333
#  epoch no:  1700  avg reward 0.5233333333333333
#  message:  [0]  output:  2  epoch no:  1800  avg reward 0.5066666666666667
#  epoch no:  1800  avg reward 0.5066666666666667
#  message:  [3]  output:  2  epoch no:  1900  avg reward 0.49333333333333335
#  epoch no:  1900  avg reward 0.49333333333333335
#  message:  [1]  output:  2  epoch no:  2000  avg reward 0.5083333333333333
#  epoch no:  2000  avg reward 0.5083333333333333
#  message:  [3]  output:  2  epoch no:  2100  avg reward 0.53
#  epoch no:  2100  avg reward 0.53
#  message:  [3]  output:  2  epoch no:  2200  avg reward 0.5
#  epoch no:  2200  avg reward 0.5
#  message:  [0]  output:  0  epoch no:  2300  avg reward 0.5433333333333333
#  epoch no:  2300  avg reward 0.5433333333333333
#  message:  [1]  output:  2  epoch no:  2400  avg reward 0.5483333333333333
#  epoch no:  2400  avg reward 0.5483333333333333
#  message:  [1]  output:  0  epoch no:  2500  avg reward 0.525
#  epoch no:  2500  avg reward 0.525
#  message:  [1]  output:  0  epoch no:  2600  avg reward 0.5433333333333333
#  epoch no:  2600  avg reward 0.5433333333333333
#  message:  [1]  output:  2  epoch no:  2700  avg reward 0.5516666666666666
#  epoch no:  2700  avg reward 0.5516666666666666
#  message:  [4]  output:  2  epoch no:  2800  avg reward 0.5266666666666666
#  epoch no:  2800  avg reward 0.5266666666666666
#  message:  [1]  output:  2  epoch no:  2900  avg reward 0.5516666666666666
#  epoch no:  2900  avg reward 0.5516666666666666
#  message:  [0]  output:  1  epoch no:  3000  avg reward 0.5666666666666667
#  epoch no:  3000  avg reward 0.5666666666666667
#  message:  [0]  output:  1  epoch no:  3100  avg reward 0.5633333333333334
#  epoch no:  3100  avg reward 0.5633333333333334
#  message:  [1]  output:  2  epoch no:  3200  avg reward 0.5466666666666666
#  epoch no:  3200  avg reward 0.5466666666666666
#  message:  [0]  output:  0  epoch no:  3300  avg reward 0.5733333333333334
#  epoch no:  3300  avg reward 0.5733333333333334
#  message:  [1]  output:  0  epoch no:  3400  avg reward 0.6316666666666667
#  epoch no:  3400  avg reward 0.6316666666666667
#  message:  [0]  output:  2  epoch no:  3500  avg reward 0.675
#  epoch no:  3500  avg reward 0.675
#  message:  [3]  output:  0  epoch no:  3600  avg reward 0.6883333333333334
#  epoch no:  3600  avg reward 0.6883333333333334
#  message:  [3]  output:  0  epoch no:  3700  avg reward 0.6616666666666666
#  epoch no:  3700  avg reward 0.6616666666666666
#  message:  [3]  output:  2  epoch no:  3800  avg reward 0.6866666666666666
#  epoch no:  3800  avg reward 0.6866666666666666
#  message:  [0]  output:  1  epoch no:  3900  avg reward 0.7
#  epoch no:  3900  avg reward 0.7
#  message:  [3]  output:  2  epoch no:  4000  avg reward 0.7016666666666667
#  epoch no:  4000  avg reward 0.7016666666666667
#  message:  [3]  output:  2  epoch no:  4100  avg reward 0.6966666666666667
#  epoch no:  4100  avg reward 0.6966666666666667
#  message:  [2]  output:  0  epoch no:  4200  avg reward 0.71
#  epoch no:  4200  avg reward 0.71
#  message:  [2]  output:  2  epoch no:  4300  avg reward 0.6766666666666666
#  epoch no:  4300  avg reward 0.6766666666666666
#  message:  [0]  output:  2  epoch no:  4400  avg reward 0.6916666666666667
#  epoch no:  4400  avg reward 0.6916666666666667
#  message:  [0]  output:  2  epoch no:  4500  avg reward 0.7333333333333333
#  epoch no:  4500  avg reward 0.7333333333333333
#  message:  [1]  output:  2  epoch no:  4600  avg reward 0.6983333333333334
#  epoch no:  4600  avg reward 0.6983333333333334
#  message:  [3]  output:  0  epoch no:  4700  avg reward 0.7033333333333334
#  epoch no:  4700  avg reward 0.7033333333333334
#  message:  [1]  output:  2  epoch no:  4800  avg reward 0.7116666666666667
#  epoch no:  4800  avg reward 0.7116666666666667
#  message:  [0]  output:  0  epoch no:  4900  avg reward 0.7333333333333333
#  epoch no:  4900  avg reward 0.7333333333333333
#  message:  [1]  output:  2  epoch no:  5000  avg reward 0.725
#  epoch no:  5000  avg reward 0.725
#  message:  [0]  output:  2  epoch no:  5100  avg reward 0.7316666666666667
#  epoch no:  5100  avg reward 0.7316666666666667
#  message:  [0]  output:  1  epoch no:  5200  avg reward 0.7233333333333334
#  epoch no:  5200  avg reward 0.7233333333333334
#  message:  [0]  output:  1  epoch no:  5300  avg reward 0.735
#  epoch no:  5300  avg reward 0.735
#  message:  [0]  output:  1  epoch no:  5400  avg reward 0.7183333333333334
#  epoch no:  5400  avg reward 0.7183333333333334
#  message:  [0]  output:  0  epoch no:  5500  avg reward 0.7283333333333334
#  epoch no:  5500  avg reward 0.7283333333333334
#  message:  [0]  output:  2  epoch no:  5600  avg reward 0.7366666666666667
#  epoch no:  5600  avg reward 0.7366666666666667
#  message:  [2]  output:  0  epoch no:  5700  avg reward 0.7033333333333334
#  epoch no:  5700  avg reward 0.7033333333333334
#  message:  [1]  output:  2  epoch no:  5800  avg reward 0.7366666666666667
#  epoch no:  5800  avg reward 0.7366666666666667
#  message:  [1]  output:  0  epoch no:  5900  avg reward 0.74
#  epoch no:  5900  avg reward 0.74
#  message:  [1]  output:  0  epoch no:  6000  avg reward 0.7333333333333333
#  epoch no:  6000  avg reward 0.7333333333333333
#  message:  [1]  output:  2  epoch no:  6100  avg reward 0.7416666666666667
#  epoch no:  6100  avg reward 0.7416666666666667
#  message:  [1]  output:  2  epoch no:  6200  avg reward 0.7016666666666667
#  epoch no:  6200  avg reward 0.7016666666666667
#  message:  [1]  output:  2  epoch no:  6300  avg reward 0.6933333333333334
#  epoch no:  6300  avg reward 0.6933333333333334
#  message:  [2]  output:  2  epoch no:  6400  avg reward 0.735
#  epoch no:  6400  avg reward 0.735
#  message:  [0]  output:  1  epoch no:  6500  avg reward 0.7133333333333334
#  epoch no:  6500  avg reward 0.7133333333333334
#  message:  [0]  output:  1  epoch no:  6600  avg reward 0.695
#  epoch no:  6600  avg reward 0.695
#  message:  [1]  output:  0  epoch no:  6700  avg reward 0.7266666666666667
#  epoch no:  6700  avg reward 0.7266666666666667
#  message:  [3]  output:  0  epoch no:  6800  avg reward 0.7566666666666667
#  epoch no:  6800  avg reward 0.7566666666666667
#  message:  [2]  output:  2  epoch no:  6900  avg reward 0.74
#  epoch no:  6900  avg reward 0.74
#  message:  [1]  output:  0  epoch no:  7000  avg reward 0.71
#  epoch no:  7000  avg reward 0.71
#  message:  [0]  output:  1  epoch no:  7100  avg reward 0.735
#  epoch no:  7100  avg reward 0.735
#  message:  [1]  output:  0  epoch no:  7200  avg reward 0.765
#  epoch no:  7200  avg reward 0.765
#  message:  [2]  output:  0  epoch no:  7300  avg reward 0.7633333333333333
#  epoch no:  7300  avg reward 0.7633333333333333
#  message:  [1]  output:  2  epoch no:  7400  avg reward 0.74
#  epoch no:  7400  avg reward 0.74
#  message:  [4]  output:  2  epoch no:  7500  avg reward 0.765
#  epoch no:  7500  avg reward 0.765
#  message:  [1]  output:  0  epoch no:  7600  avg reward 0.7533333333333333
#  epoch no:  7600  avg reward 0.7533333333333333
#  message:  [0]  output:  1  epoch no:  7700  avg reward 0.78
#  epoch no:  7700  avg reward 0.78
#  message:  [4]  output:  2  epoch no:  7800  avg reward 0.7416666666666667
#  epoch no:  7800  avg reward 0.7416666666666667
#  message:  [1]  output:  0  epoch no:  7900  avg reward 0.7183333333333334
#  epoch no:  7900  avg reward 0.7183333333333334
#  message:  [0]  output:  2  epoch no:  8000  avg reward 0.7816666666666666
#  epoch no:  8000  avg reward 0.7816666666666666
#  message:  [4]  output:  2  epoch no:  8100  avg reward 0.765
#  epoch no:  8100  avg reward 0.765
#  message:  [0]  output:  0  epoch no:  8200  avg reward 0.79
#  epoch no:  8200  avg reward 0.79
#  message:  [3]  output:  0  epoch no:  8300  avg reward 0.7916666666666666
#  epoch no:  8300  avg reward 0.7916666666666666
#  message:  [0]  output:  2  epoch no:  8400  avg reward 0.7433333333333333
#  epoch no:  8400  avg reward 0.7433333333333333
#  message:  [0]  output:  2  epoch no:  8500  avg reward 0.7766666666666666
#  epoch no:  8500  avg reward 0.7766666666666666
#  message:  [0]  output:  1  epoch no:  8600  avg reward 0.8116666666666666
#  epoch no:  8600  avg reward 0.8116666666666666
#  message:  [0]  output:  1  epoch no:  8700  avg reward 0.765
#  epoch no:  8700  avg reward 0.765
#  message:  [0]  output:  2  epoch no:  8800  avg reward 0.78
#  epoch no:  8800  avg reward 0.78
#  message:  [4]  output:  2  epoch no:  8900  avg reward 0.775
#  epoch no:  8900  avg reward 0.775
#  message:  [1]  output:  0  epoch no:  9000  avg reward 0.7433333333333333
#  epoch no:  9000  avg reward 0.7433333333333333
#  message:  [0]  output:  2  epoch no:  9100  avg reward 0.7783333333333333
#  epoch no:  9100  avg reward 0.7783333333333333
#  message:  [2]  output:  2  epoch no:  9200  avg reward 0.8033333333333333
#  epoch no:  9200  avg reward 0.8033333333333333
#  message:  [0]  output:  1  epoch no:  9300  avg reward 0.785
#  epoch no:  9300  avg reward 0.785
#  message:  [2]  output:  2  epoch no:  9400  avg reward 0.77
#  epoch no:  9400  avg reward 0.77
#  message:  [1]  output:  2  epoch no:  9500  avg reward 0.7733333333333333
#  epoch no:  9500  avg reward 0.7733333333333333
#  message:  [0]  output:  1  epoch no:  9600  avg reward 0.7566666666666667
#  epoch no:  9600  avg reward 0.7566666666666667
#  message:  [4]  output:  2  epoch no:  9700  avg reward 0.8
#  epoch no:  9700  avg reward 0.8
#  message:  [4]  output:  0  epoch no:  9800  avg reward 0.77
#  epoch no:  9800  avg reward 0.77
#  message:  [1]  output:  1  epoch no:  9900  avg reward 0.7533333333333333
#  epoch no:  9900  avg reward 0.7533333333333333
#  message:  [1]  output:  0  epoch no:  10000  avg reward 0.7983333333333333
#  epoch no:  10000  avg reward 0.7983333333333333
#  message:  [1]  output:  2  epoch no:  10100  avg reward 0.7783333333333333
#  epoch no:  10100  avg reward 0.7783333333333333
#  message:  [1]  output:  0  epoch no:  10200  avg reward 0.7933333333333333
#  epoch no:  10200  avg reward 0.7933333333333333
#  message:  [1]  output:  2  epoch no:  10300  avg reward 0.775
#  epoch no:  10300  avg reward 0.775
#  message:  [2]  output:  0  epoch no:  10400  avg reward 0.7583333333333333
#  epoch no:  10400  avg reward 0.7583333333333333
#  message:  [4]  output:  0  epoch no:  10500  avg reward 0.7766666666666666
#  epoch no:  10500  avg reward 0.7766666666666666
#  message:  [0]  output:  1  epoch no:  10600  avg reward 0.7966666666666666
#  epoch no:  10600  avg reward 0.7966666666666666
#  message:  [1]  output:  2  epoch no:  10700  avg reward 0.7833333333333333
#  epoch no:  10700  avg reward 0.7833333333333333
#  message:  [1]  output:  2  epoch no:  10800  avg reward 0.7583333333333333
#  epoch no:  10800  avg reward 0.7583333333333333
#  message:  [1]  output:  0  epoch no:  10900  avg reward 0.7666666666666667
#  epoch no:  10900  avg reward 0.7666666666666667
#  message:  [0]  output:  1  epoch no:  11000  avg reward 0.7716666666666666
#  epoch no:  11000  avg reward 0.7716666666666666
#  message:  [0]  output:  2  epoch no:  11100  avg reward 0.77
#  epoch no:  11100  avg reward 0.77
#  message:  [0]  output:  2  epoch no:  11200  avg reward 0.8016666666666666
#  epoch no:  11200  avg reward 0.8016666666666666
#  message:  [0]  output:  1  epoch no:  11300  avg reward 0.7783333333333333
#  epoch no:  11300  avg reward 0.7783333333333333
#  message:  [0]  output:  1  epoch no:  11400  avg reward 0.82
#  epoch no:  11400  avg reward 0.82
#  message:  [0]  output:  0  epoch no:  11500  avg reward 0.7683333333333333
#  epoch no:  11500  avg reward 0.7683333333333333
#  message:  [4]  output:  2  epoch no:  11600  avg reward 0.805
#  epoch no:  11600  avg reward 0.805
#  message:  [2]  output:  2  epoch no:  11700  avg reward 0.79
#  epoch no:  11700  avg reward 0.79
#  message:  [4]  output:  0  epoch no:  11800  avg reward 0.7716666666666666
#  epoch no:  11800  avg reward 0.7716666666666666
#  message:  [2]  output:  0  epoch no:  11900  avg reward 0.8216666666666667
#  epoch no:  11900  avg reward 0.8216666666666667
#  message:  [3]  output:  2  epoch no:  12000  avg reward 0.8116666666666666
#  epoch no:  12000  avg reward 0.8116666666666666
#  message:  [0]  output:  1  epoch no:  12100  avg reward 0.7783333333333333
#  epoch no:  12100  avg reward 0.7783333333333333
#  message:  [0]  output:  2  epoch no:  12200  avg reward 0.7833333333333333
#  epoch no:  12200  avg reward 0.7833333333333333
#  message:  [1]  output:  0  epoch no:  12300  avg reward 0.8033333333333333
#  epoch no:  12300  avg reward 0.8033333333333333
#  message:  [0]  output:  0  epoch no:  12400  avg reward 0.7916666666666666
#  epoch no:  12400  avg reward 0.7916666666666666
#  message:  [4]  output:  0  epoch no:  12500  avg reward 0.7766666666666666
#  epoch no:  12500  avg reward 0.7766666666666666
#  message:  [0]  output:  2  epoch no:  12600  avg reward 0.7916666666666666
#  epoch no:  12600  avg reward 0.7916666666666666
#  message:  [2]  output:  2  epoch no:  12700  avg reward 0.7716666666666666
#  epoch no:  12700  avg reward 0.7716666666666666
#  message:  [1]  output:  0  epoch no:  12800  avg reward 0.79
#  epoch no:  12800  avg reward 0.79
#  message:  [1]  output:  0  epoch no:  12900  avg reward 0.7766666666666666
#  epoch no:  12900  avg reward 0.7766666666666666
#  message:  [2]  output:  0  epoch no:  13000  avg reward 0.775
#  epoch no:  13000  avg reward 0.775
#  message:  [4]  output:  0  epoch no:  13100  avg reward 0.7333333333333333
#  epoch no:  13100  avg reward 0.7333333333333333
#  message:  [2]  output:  2  epoch no:  13200  avg reward 0.7916666666666666
#  epoch no:  13200  avg reward 0.7916666666666666
#  message:  [4]  output:  0  epoch no:  13300  avg reward 0.8116666666666666
#  epoch no:  13300  avg reward 0.8116666666666666
#  message:  [4]  output:  2  epoch no:  13400  avg reward 0.7683333333333333
#  epoch no:  13400  avg reward 0.7683333333333333
#  message:  [2]  output:  2  epoch no:  13500  avg reward 0.795
#  epoch no:  13500  avg reward 0.795
#  message:  [3]  output:  2  epoch no:  13600  avg reward 0.805
#  epoch no:  13600  avg reward 0.805
#  message:  [0]  output:  1  epoch no:  13700  avg reward 0.8033333333333333
#  epoch no:  13700  avg reward 0.8033333333333333
#  message:  [0]  output:  2  epoch no:  13800  avg reward 0.7716666666666666
#  epoch no:  13800  avg reward 0.7716666666666666
#  message:  [1]  output:  2  epoch no:  13900  avg reward 0.8166666666666667
#  epoch no:  13900  avg reward 0.8166666666666667
#  message:  [1]  output:  2  epoch no:  14000  avg reward 0.795
#  epoch no:  14000  avg reward 0.795
#  message:  [1]  output:  0  epoch no:  14100  avg reward 0.8083333333333333
#  epoch no:  14100  avg reward 0.8083333333333333
#  message:  [0]  output:  2  epoch no:  14200  avg reward 0.7816666666666666
#  epoch no:  14200  avg reward 0.7816666666666666
#  message:  [1]  output:  2  epoch no:  14300  avg reward 0.82
#  epoch no:  14300  avg reward 0.82
#  message:  [3]  output:  0  epoch no:  14400  avg reward 0.7733333333333333
#  epoch no:  14400  avg reward 0.7733333333333333
#  message:  [0]  output:  1  epoch no:  14500  avg reward 0.7783333333333333
#  epoch no:  14500  avg reward 0.7783333333333333
#  message:  [1]  output:  2  epoch no:  14600  avg reward 0.82
#  epoch no:  14600  avg reward 0.82
#  message:  [1]  output:  2  epoch no:  14700  avg reward 0.7666666666666667
#  epoch no:  14700  avg reward 0.7666666666666667
#  message:  [3]  output:  0  epoch no:  14800  avg reward 0.785
#  epoch no:  14800  avg reward 0.785
#  message:  [3]  output:  2  epoch no:  14900  avg reward 0.775
#  epoch no:  14900  avg reward 0.775
#  message:  [4]  output:  2  epoch no:  15000  avg reward 0.8133333333333334
#  epoch no:  15000  avg reward 0.8133333333333334
#  message:  [3]  output:  0  epoch no:  15100  avg reward 0.8133333333333334
#  epoch no:  15100  avg reward 0.8133333333333334
#  message:  [2]  output:  0  epoch no:  15200  avg reward 0.7966666666666666
#  epoch no:  15200  avg reward 0.7966666666666666
#  message:  [4]  output:  2  epoch no:  15300  avg reward 0.8
#  epoch no:  15300  avg reward 0.8
#  message:  [3]  output:  0  epoch no:  15400  avg reward 0.7766666666666666
#  epoch no:  15400  avg reward 0.7766666666666666
#  message:  [3]  output:  0  epoch no:  15500  avg reward 0.805
#  epoch no:  15500  avg reward 0.805
#  message:  [4]  output:  2  epoch no:  15600  avg reward 0.8366666666666667
#  epoch no:  15600  avg reward 0.8366666666666667
#  message:  [0]  output:  0  epoch no:  15700  avg reward 0.79
#  epoch no:  15700  avg reward 0.79
#  message:  [0]  output:  1  epoch no:  15800  avg reward 0.7916666666666666
#  epoch no:  15800  avg reward 0.7916666666666666
#  message:  [1]  output:  0  epoch no:  15900  avg reward 0.7483333333333333
#  epoch no:  15900  avg reward 0.7483333333333333
#  message:  [2]  output:  0  epoch no:  16000  avg reward 0.8116666666666666
#  epoch no:  16000  avg reward 0.8116666666666666
#  message:  [1]  output:  0  epoch no:  16100  avg reward 0.81
#  epoch no:  16100  avg reward 0.81
#  message:  [1]  output:  0  epoch no:  16200  avg reward 0.7916666666666666
#  epoch no:  16200  avg reward 0.7916666666666666
#  message:  [0]  output:  0  epoch no:  16300  avg reward 0.8016666666666666
#  epoch no:  16300  avg reward 0.8016666666666666
#  message:  [2]  output:  2  epoch no:  16400  avg reward 0.765
#  epoch no:  16400  avg reward 0.765
#  message:  [1]  output:  1  epoch no:  16500  avg reward 0.7866666666666666
#  epoch no:  16500  avg reward 0.7866666666666666
#  message:  [1]  output:  2  epoch no:  16600  avg reward 0.7983333333333333
#  epoch no:  16600  avg reward 0.7983333333333333
#  message:  [3]  output:  2  epoch no:  16700  avg reward 0.785
#  epoch no:  16700  avg reward 0.785
#  message:  [3]  output:  0  epoch no:  16800  avg reward 0.8016666666666666
#  epoch no:  16800  avg reward 0.8016666666666666
#  message:  [0]  output:  1  epoch no:  16900  avg reward 0.8133333333333334
#  epoch no:  16900  avg reward 0.8133333333333334
#  message:  [4]  output:  0  epoch no:  17000  avg reward 0.805
#  epoch no:  17000  avg reward 0.805
#  message:  [4]  output:  0  epoch no:  17100  avg reward 0.7966666666666666
#  epoch no:  17100  avg reward 0.7966666666666666
#  message:  [0]  output:  1  epoch no:  17200  avg reward 0.7983333333333333
#  epoch no:  17200  avg reward 0.7983333333333333
#  message:  [1]  output:  2  epoch no:  17300  avg reward 0.7716666666666666
#  epoch no:  17300  avg reward 0.7716666666666666
#  message:  [1]  output:  2  epoch no:  17400  avg reward 0.7916666666666666
#  epoch no:  17400  avg reward 0.7916666666666666
#  message:  [0]  output:  0  epoch no:  17500  avg reward 0.7933333333333333
#  epoch no:  17500  avg reward 0.7933333333333333
#  message:  [0]  output:  2  epoch no:  17600  avg reward 0.8083333333333333
#  epoch no:  17600  avg reward 0.8083333333333333
#  message:  [1]  output:  2  epoch no:  17700  avg reward 0.7666666666666667
#  epoch no:  17700  avg reward 0.7666666666666667
#  message:  [4]  output:  0  epoch no:  17800  avg reward 0.805
#  epoch no:  17800  avg reward 0.805
#  message:  [4]  output:  0  epoch no:  17900  avg reward 0.8083333333333333
#  epoch no:  17900  avg reward 0.8083333333333333
#  message:  [0]  output:  2  epoch no:  18000  avg reward 0.8066666666666666
#  epoch no:  18000  avg reward 0.8066666666666666
#  message:  [1]  output:  2  epoch no:  18100  avg reward 0.8183333333333334
#  epoch no:  18100  avg reward 0.8183333333333334
#  message:  [0]  output:  1  epoch no:  18200  avg reward 0.8033333333333333
#  epoch no:  18200  avg reward 0.8033333333333333
#  message:  [1]  output:  2  epoch no:  18300  avg reward 0.8266666666666667
#  epoch no:  18300  avg reward 0.8266666666666667
#  message:  [1]  output:  2  epoch no:  18400  avg reward 0.825
#  epoch no:  18400  avg reward 0.825
#  message:  [1]  output:  0  epoch no:  18500  avg reward 0.78
#  epoch no:  18500  avg reward 0.78
#  message:  [0]  output:  1  epoch no:  18600  avg reward 0.785
#  epoch no:  18600  avg reward 0.785
#  message:  [2]  output:  0  epoch no:  18700  avg reward 0.8216666666666667
#  epoch no:  18700  avg reward 0.8216666666666667
#  message:  [2]  output:  2  epoch no:  18800  avg reward 0.8133333333333334
#  epoch no:  18800  avg reward 0.8133333333333334
#  message:  [4]  output:  2  epoch no:  18900  avg reward 0.82
#  epoch no:  18900  avg reward 0.82
#  message:  [2]  output:  2  epoch no:  19000  avg reward 0.815
#  epoch no:  19000  avg reward 0.815
#  message:  [3]  output:  0  epoch no:  19100  avg reward 0.795
#  epoch no:  19100  avg reward 0.795
#  message:  [2]  output:  0  epoch no:  19200  avg reward 0.7916666666666666
#  epoch no:  19200  avg reward 0.7916666666666666
#  message:  [2]  output:  0  epoch no:  19300  avg reward 0.7966666666666666
#  epoch no:  19300  avg reward 0.7966666666666666
#  message:  [0]  output:  0  epoch no:  19400  avg reward 0.7816666666666666
#  epoch no:  19400  avg reward 0.7816666666666666
#  message:  [2]  output:  0  epoch no:  19500  avg reward 0.8016666666666666
#  epoch no:  19500  avg reward 0.8016666666666666
#  message:  [0]  output:  1  epoch no:  19600  avg reward 0.815
#  epoch no:  19600  avg reward 0.815
#  message:  [1]  output:  2  epoch no:  19700  avg reward 0.7566666666666667
#  epoch no:  19700  avg reward 0.7566666666666667
#  message:  [2]  output:  2  epoch no:  19800  avg reward 0.8166666666666667
#  epoch no:  19800  avg reward 0.8166666666666667
#  message:  [1]  output:  0  epoch no:  19900  avg reward 0.7716666666666666
#  epoch no:  19900  avg reward 0.7716666666666666
#  message:  [1]  output:  0  epoch no:  20000  avg reward 0.8116666666666666
#  epoch no:  20000  avg reward 0.8116666666666666
#  message:  [3]  output:  2  epoch no:  20100  avg reward 0.82
#  epoch no:  20100  avg reward 0.82
#  message:  [1]  output:  0  epoch no:  20200  avg reward 0.8066666666666666
#  epoch no:  20200  avg reward 0.8066666666666666
#  message:  [2]  output:  0  epoch no:  20300  avg reward 0.8033333333333333
#  epoch no:  20300  avg reward 0.8033333333333333
#  message:  [3]  output:  0  epoch no:  20400  avg reward 0.8
#  epoch no:  20400  avg reward 0.8
#  message:  [0]  output:  1  epoch no:  20500  avg reward 0.8133333333333334
#  epoch no:  20500  avg reward 0.8133333333333334
#  message:  [2]  output:  0  epoch no:  20600  avg reward 0.8233333333333334
#  epoch no:  20600  avg reward 0.8233333333333334
#  message:  [0]  output:  1  epoch no:  20700  avg reward 0.795
#  epoch no:  20700  avg reward 0.795
#  message:  [3]  output:  0  epoch no:  20800  avg reward 0.7833333333333333
#  epoch no:  20800  avg reward 0.7833333333333333
#  message:  [1]  output:  1  epoch no:  20900  avg reward 0.7816666666666666
#  epoch no:  20900  avg reward 0.7816666666666666
#  message:  [1]  output:  2  epoch no:  21000  avg reward 0.805
#  epoch no:  21000  avg reward 0.805
#  message:  [1]  output:  0  epoch no:  21100  avg reward 0.775
#  epoch no:  21100  avg reward 0.775
#  message:  [0]  output:  2  epoch no:  21200  avg reward 0.8166666666666667
#  epoch no:  21200  avg reward 0.8166666666666667
#  message:  [4]  output:  2  epoch no:  21300  avg reward 0.78
#  epoch no:  21300  avg reward 0.78
#  message:  [1]  output:  0  epoch no:  21400  avg reward 0.805
#  epoch no:  21400  avg reward 0.805
#  message:  [0]  output:  0  epoch no:  21500  avg reward 0.8183333333333334
#  epoch no:  21500  avg reward 0.8183333333333334
#  message:  [4]  output:  0  epoch no:  21600  avg reward 0.8183333333333334
#  epoch no:  21600  avg reward 0.8183333333333334
#  message:  [1]  output:  2  epoch no:  21700  avg reward 0.785
#  epoch no:  21700  avg reward 0.785
#  message:  [2]  output:  0  epoch no:  21800  avg reward 0.8116666666666666
#  epoch no:  21800  avg reward 0.8116666666666666
#  message:  [0]  output:  1  epoch no:  21900  avg reward 0.7966666666666666
#  epoch no:  21900  avg reward 0.7966666666666666
#  message:  [4]  output:  0  epoch no:  22000  avg reward 0.8266666666666667
#  epoch no:  22000  avg reward 0.8266666666666667
#  message:  [0]  output:  2  epoch no:  22100  avg reward 0.77
#  epoch no:  22100  avg reward 0.77
#  message:  [1]  output:  2  epoch no:  22200  avg reward 0.8033333333333333
#  epoch no:  22200  avg reward 0.8033333333333333
#  message:  [0]  output:  2  epoch no:  22300  avg reward 0.8033333333333333
#  epoch no:  22300  avg reward 0.8033333333333333
#  message:  [2]  output:  0  epoch no:  22400  avg reward 0.8133333333333334
#  epoch no:  22400  avg reward 0.8133333333333334
#  message:  [3]  output:  2  epoch no:  22500  avg reward 0.8366666666666667
#  epoch no:  22500  avg reward 0.8366666666666667
#  message:  [2]  output:  0  epoch no:  22600  avg reward 0.8383333333333334
#  epoch no:  22600  avg reward 0.8383333333333334
#  message:  [0]  output:  2  epoch no:  22700  avg reward 0.8033333333333333
#  epoch no:  22700  avg reward 0.8033333333333333
#  message:  [4]  output:  0  epoch no:  22800  avg reward 0.805
#  epoch no:  22800  avg reward 0.805
#  message:  [0]  output:  2  epoch no:  22900  avg reward 0.8166666666666667
#  epoch no:  22900  avg reward 0.8166666666666667
#  message:  [4]  output:  0  epoch no:  23000  avg reward 0.7583333333333333
#  epoch no:  23000  avg reward 0.7583333333333333
#  message:  [4]  output:  0  epoch no:  23100  avg reward 0.8033333333333333
#  epoch no:  23100  avg reward 0.8033333333333333
#  message:  [0]  output:  1  epoch no:  23200  avg reward 0.815
#  epoch no:  23200  avg reward 0.815
#  message:  [0]  output:  0  epoch no:  23300  avg reward 0.8083333333333333
#  epoch no:  23300  avg reward 0.8083333333333333
#  message:  [1]  output:  2  epoch no:  23400  avg reward 0.835
#  epoch no:  23400  avg reward 0.835
#  message:  [0]  output:  1  epoch no:  23500  avg reward 0.8366666666666667
#  epoch no:  23500  avg reward 0.8366666666666667
#  message:  [3]  output:  0  epoch no:  23600  avg reward 0.8033333333333333
#  epoch no:  23600  avg reward 0.8033333333333333
#  message:  [2]  output:  0  epoch no:  23700  avg reward 0.7866666666666666
#  epoch no:  23700  avg reward 0.7866666666666666
#  message:  [0]  output:  2  epoch no:  23800  avg reward 0.81
#  epoch no:  23800  avg reward 0.81
#  message:  [0]  output:  0  epoch no:  23900  avg reward 0.8116666666666666
#  epoch no:  23900  avg reward 0.8116666666666666
#  message:  [4]  output:  0  epoch no:  24000  avg reward 0.8083333333333333
#  epoch no:  24000  avg reward 0.8083333333333333
#  message:  [1]  output:  0  epoch no:  24100  avg reward 0.83
#  epoch no:  24100  avg reward 0.83
#  message:  [1]  output:  1  epoch no:  24200  avg reward 0.7766666666666666
#  epoch no:  24200  avg reward 0.7766666666666666
#  message:  [0]  output:  1  epoch no:  24300  avg reward 0.8133333333333334
#  epoch no:  24300  avg reward 0.8133333333333334
#  message:  [0]  output:  1  epoch no:  24400  avg reward 0.7766666666666666
#  epoch no:  24400  avg reward 0.7766666666666666
#  message:  [2]  output:  0  epoch no:  24500  avg reward 0.8183333333333334
#  epoch no:  24500  avg reward 0.8183333333333334
#  message:  [1]  output:  2  epoch no:  24600  avg reward 0.8133333333333334
#  epoch no:  24600  avg reward 0.8133333333333334
#  message:  [0]  output:  1  epoch no:  24700  avg reward 0.7933333333333333
#  epoch no:  24700  avg reward 0.7933333333333333
#  message:  [0]  output:  0  epoch no:  24800  avg reward 0.7716666666666666
#  epoch no:  24800  avg reward 0.7716666666666666
#  message:  [1]  output:  0  epoch no:  24900  avg reward 0.835
#  epoch no:  24900  avg reward 0.835
#  message:  [3]  output:  2  epoch no:  25000  avg reward 0.8033333333333333
#  epoch no:  25000  avg reward 0.8033333333333333
#  message:  [0]  output:  2  epoch no:  25100  avg reward 0.7966666666666666
#  epoch no:  25100  avg reward 0.7966666666666666
#  message:  [1]  output:  0  epoch no:  25200  avg reward 0.805
#  epoch no:  25200  avg reward 0.805
#  message:  [1]  output:  1  epoch no:  25300  avg reward 0.8133333333333334
#  epoch no:  25300  avg reward 0.8133333333333334
#  message:  [0]  output:  0  epoch no:  25400  avg reward 0.8016666666666666
#  epoch no:  25400  avg reward 0.8016666666666666
#  message:  [1]  output:  1  epoch no:  25500  avg reward 0.8066666666666666
#  epoch no:  25500  avg reward 0.8066666666666666
#  message:  [0]  output:  1  epoch no:  25600  avg reward 0.7683333333333333
#  epoch no:  25600  avg reward 0.7683333333333333
#  message:  [3]  output:  0  epoch no:  25700  avg reward 0.8133333333333334
#  epoch no:  25700  avg reward 0.8133333333333334
#  message:  [0]  output:  2  epoch no:  25800  avg reward 0.7883333333333333
#  epoch no:  25800  avg reward 0.7883333333333333
#  message:  [4]  output:  2  epoch no:  25900  avg reward 0.8316666666666667
#  epoch no:  25900  avg reward 0.8316666666666667
#  message:  [3]  output:  0  epoch no:  26000  avg reward 0.7866666666666666
#  epoch no:  26000  avg reward 0.7866666666666666
#  message:  [0]  output:  2  epoch no:  26100  avg reward 0.775
#  epoch no:  26100  avg reward 0.775
#  message:  [0]  output:  0  epoch no:  26200  avg reward 0.8083333333333333
#  epoch no:  26200  avg reward 0.8083333333333333
#  message:  [0]  output:  0  epoch no:  26300  avg reward 0.8083333333333333
#  epoch no:  26300  avg reward 0.8083333333333333
#  message:  [4]  output:  2  epoch no:  26400  avg reward 0.8083333333333333
#  epoch no:  26400  avg reward 0.8083333333333333
#  message:  [0]  output:  1  epoch no:  26500  avg reward 0.82
#  epoch no:  26500  avg reward 0.82
#  message:  [1]  output:  2  epoch no:  26600  avg reward 0.7966666666666666
#  epoch no:  26600  avg reward 0.7966666666666666
#  message:  [1]  output:  0  epoch no:  26700  avg reward 0.7783333333333333
#  epoch no:  26700  avg reward 0.7783333333333333
#  message:  [1]  output:  0  epoch no:  26800  avg reward 0.8266666666666667
#  epoch no:  26800  avg reward 0.8266666666666667
#  message:  [3]  output:  0  epoch no:  26900  avg reward 0.815
#  epoch no:  26900  avg reward 0.815
#  message:  [2]  output:  2  epoch no:  27000  avg reward 0.8266666666666667
#  epoch no:  27000  avg reward 0.8266666666666667
#  message:  [4]  output:  2  epoch no:  27100  avg reward 0.7816666666666666
#  epoch no:  27100  avg reward 0.7816666666666666
#  message:  [0]  output:  0  epoch no:  27200  avg reward 0.8133333333333334
#  epoch no:  27200  avg reward 0.8133333333333334
#  message:  [0]  output:  1  epoch no:  27300  avg reward 0.825
#  epoch no:  27300  avg reward 0.825
#  message:  [4]  output:  2  epoch no:  27400  avg reward 0.8233333333333334
#  epoch no:  27400  avg reward 0.8233333333333334
#  message:  [0]  output:  0  epoch no:  27500  avg reward 0.7883333333333333
#  epoch no:  27500  avg reward 0.7883333333333333
#  message:  [3]  output:  2  epoch no:  27600  avg reward 0.8016666666666666
#  epoch no:  27600  avg reward 0.8016666666666666
#  message:  [3]  output:  0  epoch no:  27700  avg reward 0.8166666666666667
#  epoch no:  27700  avg reward 0.8166666666666667
#  message:  [3]  output:  0  epoch no:  27800  avg reward 0.8233333333333334
#  epoch no:  27800  avg reward 0.8233333333333334
#  message:  [1]  output:  0  epoch no:  27900  avg reward 0.825
#  epoch no:  27900  avg reward 0.825
#  message:  [2]  output:  0  epoch no:  28000  avg reward 0.8283333333333334
#  epoch no:  28000  avg reward 0.8283333333333334
#  message:  [0]  output:  2  epoch no:  28100  avg reward 0.7966666666666666
#  epoch no:  28100  avg reward 0.7966666666666666
#  message:  [1]  output:  0  epoch no:  28200  avg reward 0.81
#  epoch no:  28200  avg reward 0.81
#  message:  [0]  output:  2  epoch no:  28300  avg reward 0.835
#  epoch no:  28300  avg reward 0.835
#  message:  [3]  output:  0  epoch no:  28400  avg reward 0.8083333333333333
#  epoch no:  28400  avg reward 0.8083333333333333
#  message:  [3]  output:  2  epoch no:  28500  avg reward 0.785
#  epoch no:  28500  avg reward 0.785
#  message:  [4]  output:  2  epoch no:  28600  avg reward 0.8333333333333334
#  epoch no:  28600  avg reward 0.8333333333333334
#  message:  [1]  output:  2  epoch no:  28700  avg reward 0.7983333333333333
#  epoch no:  28700  avg reward 0.7983333333333333
#  message:  [4]  output:  0  epoch no:  28800  avg reward 0.7833333333333333
#  epoch no:  28800  avg reward 0.7833333333333333
#  message:  [1]  output:  0  epoch no:  28900  avg reward 0.83
#  epoch no:  28900  avg reward 0.83
#  message:  [0]  output:  2  epoch no:  29000  avg reward 0.785
#  epoch no:  29000  avg reward 0.785
#  message:  [4]  output:  0  epoch no:  29100  avg reward 0.81
#  epoch no:  29100  avg reward 0.81
#  message:  [0]  output:  2  epoch no:  29200  avg reward 0.8033333333333333
#  epoch no:  29200  avg reward 0.8033333333333333
#  message:  [3]  output:  2  epoch no:  29300  avg reward 0.8083333333333333
#  epoch no:  29300  avg reward 0.8083333333333333
#  message:  [0]  output:  1  epoch no:  29400  avg reward 0.7966666666666666
#  epoch no:  29400  avg reward 0.7966666666666666
#  message:  [0]  output:  1  epoch no:  29500  avg reward 0.7983333333333333
#  epoch no:  29500  avg reward 0.7983333333333333
#  message:  [2]  output:  2  epoch no:  29600  avg reward 0.815
#  epoch no:  29600  avg reward 0.815
#  message:  [0]  output:  0  epoch no:  29700  avg reward 0.825
#  epoch no:  29700  avg reward 0.825
#  message:  [3]  output:  0  epoch no:  29800  avg reward 0.8083333333333333
#  epoch no:  29800  avg reward 0.8083333333333333
#  message:  [2]  output:  0  epoch no:  29900  avg reward 0.8466666666666667
#  epoch no:  29900  avg reward 0.8466666666666667
#  message:  [0]  output:  0  epoch no:  30000  avg reward 0.8033333333333333
#  epoch no:  30000  avg reward 0.8033333333333333
#  message:  [0]  output:  1  epoch no:  30100  avg reward 0.8083333333333333
#  epoch no:  30100  avg reward 0.8083333333333333
#  message:  [1]  output:  1  epoch no:  30200  avg reward 0.8116666666666666
#  epoch no:  30200  avg reward 0.8116666666666666
#  message:  [0]  output:  2  epoch no:  30300  avg reward 0.9066666666666666
#  epoch no:  30300  avg reward 0.9066666666666666
#  message:  [0]  output:  0  epoch no:  30400  avg reward 0.9383333333333334
#  epoch no:  30400  avg reward 0.9383333333333334
#  message:  [1]  output:  0  epoch no:  30500  avg reward 0.98
#  epoch no:  30500  avg reward 0.98
#  message:  [4]  output:  2  epoch no:  30600  avg reward 0.9616666666666667
#  epoch no:  30600  avg reward 0.9616666666666667
#  message:  [1]  output:  2  epoch no:  30700  avg reward 0.9616666666666667
#  epoch no:  30700  avg reward 0.9616666666666667
#  message:  [3]  output:  1  epoch no:  30800  avg reward 0.9616666666666667
#  epoch no:  30800  avg reward 0.9616666666666667
#  message:  [4]  output:  2  epoch no:  30900  avg reward 0.9666666666666667
#  epoch no:  30900  avg reward 0.9666666666666667
#  message:  [1]  output:  0  epoch no:  31000  avg reward 0.9783333333333334
#  epoch no:  31000  avg reward 0.9783333333333334
#  message:  [0]  output:  2  epoch no:  31100  avg reward 0.9733333333333334
#  epoch no:  31100  avg reward 0.9733333333333334
#  message:  [3]  output:  0  epoch no:  31200  avg reward 0.9566666666666667
#  epoch no:  31200  avg reward 0.9566666666666667
#  message:  [1]  output:  1  epoch no:  31300  avg reward 0.9633333333333334
#  epoch no:  31300  avg reward 0.9633333333333334
#  message:  [4]  output:  1  epoch no:  31400  avg reward 0.9733333333333334
#  epoch no:  31400  avg reward 0.9733333333333334
#  message:  [3]  output:  1  epoch no:  31500  avg reward 0.98
#  epoch no:  31500  avg reward 0.98
#  message:  [3]  output:  2  epoch no:  31600  avg reward 0.96
#  epoch no:  31600  avg reward 0.96
#  message:  [1]  output:  1  epoch no:  31700  avg reward 0.975
#  epoch no:  31700  avg reward 0.975
#  message:  [0]  output:  0  epoch no:  31800  avg reward 0.9816666666666667
#  epoch no:  31800  avg reward 0.9816666666666667
#  message:  [1]  output:  0  epoch no:  31900  avg reward 0.9733333333333334
#  epoch no:  31900  avg reward 0.9733333333333334
#  message:  [3]  output:  1  epoch no:  32000  avg reward 0.975
#  epoch no:  32000  avg reward 0.975
#  message:  [0]  output:  1  epoch no:  32100  avg reward 0.9783333333333334
#  epoch no:  32100  avg reward 0.9783333333333334
#  message:  [0]  output:  0  epoch no:  32200  avg reward 0.9716666666666667
#  epoch no:  32200  avg reward 0.9716666666666667
#  message:  [1]  output:  2  epoch no:  32300  avg reward 0.9816666666666667
#  epoch no:  32300  avg reward 0.9816666666666667
#  message:  [3]  output:  0  epoch no:  32400  avg reward 0.9816666666666667
#  epoch no:  32400  avg reward 0.9816666666666667
#  message:  [0]  output:  1  epoch no:  32500  avg reward 0.9833333333333333
#  epoch no:  32500  avg reward 0.9833333333333333
#  message:  [1]  output:  1  epoch no:  32600  avg reward 0.975
#  epoch no:  32600  avg reward 0.975
#  message:  [1]  output:  0  epoch no:  32700  avg reward 0.985
#  epoch no:  32700  avg reward 0.985
#  message:  [1]  output:  2  epoch no:  32800  avg reward 0.9616666666666667
#  epoch no:  32800  avg reward 0.9616666666666667
#  message:  [1]  output:  2  epoch no:  32900  avg reward 0.9683333333333334
#  epoch no:  32900  avg reward 0.9683333333333334
#  message:  [3]  output:  0  epoch no:  33000  avg reward 0.9766666666666667
#  epoch no:  33000  avg reward 0.9766666666666667
#  message:  [2]  output:  2  epoch no:  33100  avg reward 0.9666666666666667
#  epoch no:  33100  avg reward 0.9666666666666667
#  message:  [0]  output:  0  epoch no:  33200  avg reward 0.9816666666666667
#  epoch no:  33200  avg reward 0.9816666666666667
#  message:  [3]  output:  0  epoch no:  33300  avg reward 0.9583333333333334
#  epoch no:  33300  avg reward 0.9583333333333334
#  message:  [4]  output:  2  epoch no:  33400  avg reward 0.965
#  epoch no:  33400  avg reward 0.965
#  message:  [0]  output:  2  epoch no:  33500  avg reward 0.9616666666666667
#  epoch no:  33500  avg reward 0.9616666666666667
#  message:  [1]  output:  2  epoch no:  33600  avg reward 0.97
#  epoch no:  33600  avg reward 0.97
#  message:  [1]  output:  1  epoch no:  33700  avg reward 0.9833333333333333
#  epoch no:  33700  avg reward 0.9833333333333333
#  message:  [4]  output:  0  epoch no:  33800  avg reward 0.985
#  epoch no:  33800  avg reward 0.985
#  message:  [0]  output:  1  epoch no:  33900  avg reward 0.9666666666666667
#  epoch no:  33900  avg reward 0.9666666666666667
#  message:  [1]  output:  1  epoch no:  34000  avg reward 0.9716666666666667
#  epoch no:  34000  avg reward 0.9716666666666667
#  message:  [0]  output:  2  epoch no:  34100  avg reward 0.9766666666666667
#  epoch no:  34100  avg reward 0.9766666666666667
#  message:  [0]  output:  1  epoch no:  34200  avg reward 0.9816666666666667
#  epoch no:  34200  avg reward 0.9816666666666667
#  message:  [1]  output:  1  epoch no:  34300  avg reward 0.9683333333333334
#  epoch no:  34300  avg reward 0.9683333333333334
#  message:  [3]  output:  0  epoch no:  34400  avg reward 0.9766666666666667
#  epoch no:  34400  avg reward 0.9766666666666667
#  message:  [3]  output:  2  epoch no:  34500  avg reward 0.9766666666666667
#  epoch no:  34500  avg reward 0.9766666666666667
#  message:  [0]  output:  1  epoch no:  34600  avg reward 0.965
#  epoch no:  34600  avg reward 0.965
#  message:  [0]  output:  0  epoch no:  34700  avg reward 0.9833333333333333
#  epoch no:  34700  avg reward 0.9833333333333333
#  message:  [1]  output:  1  epoch no:  34800  avg reward 0.9816666666666667
#  epoch no:  34800  avg reward 0.9816666666666667
#  message:  [4]  output:  1  epoch no:  34900  avg reward 0.9883333333333333
#  epoch no:  34900  avg reward 0.9883333333333333
#  message:  [0]  output:  1  epoch no:  35000  avg reward 0.9733333333333334
#  epoch no:  35000  avg reward 0.9733333333333334
#  message:  [1]  output:  0  epoch no:  35100  avg reward 0.9783333333333334
#  epoch no:  35100  avg reward 0.9783333333333334
#  message:  [0]  output:  1  epoch no:  35200  avg reward 0.9733333333333334
#  epoch no:  35200  avg reward 0.9733333333333334
#  message:  [1]  output:  2  epoch no:  35300  avg reward 0.975
#  epoch no:  35300  avg reward 0.975
#  message:  [0]  output:  2  epoch no:  35400  avg reward 0.9816666666666667
#  epoch no:  35400  avg reward 0.9816666666666667
#  message:  [1]  output:  2  epoch no:  35500  avg reward 0.9783333333333334
#  epoch no:  35500  avg reward 0.9783333333333334
#  message:  [4]  output:  0  epoch no:  35600  avg reward 0.9716666666666667
#  epoch no:  35600  avg reward 0.9716666666666667
#  message:  [0]  output:  0  epoch no:  35700  avg reward 0.9816666666666667
#  epoch no:  35700  avg reward 0.9816666666666667
#  message:  [3]  output:  0  epoch no:  35800  avg reward 0.9683333333333334
#  epoch no:  35800  avg reward 0.9683333333333334
#  message:  [4]  output:  2  epoch no:  35900  avg reward 0.9816666666666667
#  epoch no:  35900  avg reward 0.9816666666666667
#  message:  [2]  output:  0  epoch no:  36000  avg reward 0.9916666666666667
#  epoch no:  36000  avg reward 0.9916666666666667
#  message:  [4]  output:  2  epoch no:  36100  avg reward 0.975
#  epoch no:  36100  avg reward 0.975
#  message:  [3]  output:  1  epoch no:  36200  avg reward 0.9883333333333333
#  epoch no:  36200  avg reward 0.9883333333333333
#  message:  [4]  output:  2  epoch no:  36300  avg reward 0.98
#  epoch no:  36300  avg reward 0.98
#  message:  [1]  output:  1  epoch no:  36400  avg reward 0.985
#  epoch no:  36400  avg reward 0.985
#  message:  [0]  output:  0  epoch no:  36500  avg reward 0.9583333333333334
#  epoch no:  36500  avg reward 0.9583333333333334
#  message:  [1]  output:  1  epoch no:  36600  avg reward 0.9833333333333333
#  epoch no:  36600  avg reward 0.9833333333333333
#  message:  [3]  output:  0  epoch no:  36700  avg reward 0.9766666666666667
#  epoch no:  36700  avg reward 0.9766666666666667
#  message:  [3]  output:  0  epoch no:  36800  avg reward 0.9733333333333334
#  epoch no:  36800  avg reward 0.9733333333333334
#  message:  [0]  output:  2  epoch no:  36900  avg reward 0.975
#  epoch no:  36900  avg reward 0.975
#  message:  [2]  output:  1  epoch no:  37000  avg reward 0.97
#  epoch no:  37000  avg reward 0.97
#  message:  [0]  output:  0  epoch no:  37100  avg reward 0.9833333333333333
#  epoch no:  37100  avg reward 0.9833333333333333
#  message:  [0]  output:  2  epoch no:  37200  avg reward 0.985
#  epoch no:  37200  avg reward 0.985
#  message:  [1]  output:  2  epoch no:  37300  avg reward 0.9783333333333334
#  epoch no:  37300  avg reward 0.9783333333333334
#  message:  [0]  output:  0  epoch no:  37400  avg reward 0.9583333333333334
#  epoch no:  37400  avg reward 0.9583333333333334
#  message:  [1]  output:  0  epoch no:  37500  avg reward 0.9783333333333334
#  epoch no:  37500  avg reward 0.9783333333333334
#  message:  [4]  output:  0  epoch no:  37600  avg reward 0.9833333333333333
#  epoch no:  37600  avg reward 0.9833333333333333
#  message:  [0]  output:  0  epoch no:  37700  avg reward 0.9733333333333334
#  epoch no:  37700  avg reward 0.9733333333333334
#  message:  [4]  output:  1  epoch no:  37800  avg reward 0.975
#  epoch no:  37800  avg reward 0.975
#  message:  [0]  output:  1  epoch no:  37900  avg reward 0.9616666666666667
#  epoch no:  37900  avg reward 0.9616666666666667
#  message:  [1]  output:  0  epoch no:  38000  avg reward 0.98
#  epoch no:  38000  avg reward 0.98
#  message:  [4]  output:  2  epoch no:  38100  avg reward 0.9883333333333333
#  epoch no:  38100  avg reward 0.9883333333333333
#  message:  [4]  output:  2  epoch no:  38200  avg reward 0.975
#  epoch no:  38200  avg reward 0.975
#  message:  [4]  output:  1  epoch no:  38300  avg reward 0.9816666666666667
#  epoch no:  38300  avg reward 0.9816666666666667
#  message:  [1]  output:  1  epoch no:  38400  avg reward 0.9666666666666667
#  epoch no:  38400  avg reward 0.9666666666666667
#  message:  [4]  output:  1  epoch no:  38500  avg reward 0.9866666666666667
#  epoch no:  38500  avg reward 0.9866666666666667
#  message:  [1]  output:  0  epoch no:  38600  avg reward 0.9783333333333334
#  epoch no:  38600  avg reward 0.9783333333333334
#  message:  [0]  output:  1  epoch no:  38700  avg reward 0.965
#  epoch no:  38700  avg reward 0.965
#  message:  [0]  output:  1  epoch no:  38800  avg reward 0.9866666666666667
#  epoch no:  38800  avg reward 0.9866666666666667
#  message:  [0]  output:  2  epoch no:  38900  avg reward 0.965
#  epoch no:  38900  avg reward 0.965
#  message:  [0]  output:  1  epoch no:  39000  avg reward 0.98
#  epoch no:  39000  avg reward 0.98
#  message:  [0]  output:  0  epoch no:  39100  avg reward 0.9833333333333333
#  epoch no:  39100  avg reward 0.9833333333333333
#  message:  [1]  output:  2  epoch no:  39200  avg reward 0.99
#  epoch no:  39200  avg reward 0.99
#  message:  [1]  output:  1  epoch no:  39300  avg reward 0.9866666666666667
#  epoch no:  39300  avg reward 0.9866666666666667
#  message:  [4]  output:  2  epoch no:  39400  avg reward 0.9816666666666667
#  epoch no:  39400  avg reward 0.9816666666666667
#  message:  [2]  output:  1  epoch no:  39500  avg reward 0.98
#  epoch no:  39500  avg reward 0.98
#  message:  [3]  output:  1  epoch no:  39600  avg reward 0.99
#  epoch no:  39600  avg reward 0.99
#  message:  [1]  output:  0  epoch no:  39700  avg reward 0.9766666666666667
#  epoch no:  39700  avg reward 0.9766666666666667
#  message:  [2]  output:  1  epoch no:  39800  avg reward 0.9933333333333333
#  epoch no:  39800  avg reward 0.9933333333333333
#  message:  [1]  output:  1  epoch no:  39900  avg reward 0.9766666666666667
#  epoch no:  39900  avg reward 0.9766666666666667
#  message:  [4]  output:  0  epoch no:  40000  avg reward 0.9816666666666667
#  epoch no:  40000  avg reward 0.9816666666666667
#  message:  [1]  output:  0  epoch no:  40100  avg reward 0.9716666666666667
#  epoch no:  40100  avg reward 0.9716666666666667
#  message:  [0]  output:  2  epoch no:  40200  avg reward 0.9766666666666667
#  epoch no:  40200  avg reward 0.9766666666666667
#  message:  [0]  output:  1  epoch no:  40300  avg reward 0.9733333333333334
#  epoch no:  40300  avg reward 0.9733333333333334
#  message:  [2]  output:  0  epoch no:  40400  avg reward 0.98
#  epoch no:  40400  avg reward 0.98
#  message:  [1]  output:  0  epoch no:  40500  avg reward 0.985
#  epoch no:  40500  avg reward 0.985
#  message:  [4]  output:  0  epoch no:  40600  avg reward 0.97
#  epoch no:  40600  avg reward 0.97
#  message:  [1]  output:  1  epoch no:  40700  avg reward 0.985
#  epoch no:  40700  avg reward 0.985
#  message:  [0]  output:  0  epoch no:  40800  avg reward 0.985
#  epoch no:  40800  avg reward 0.985
#  message:  [0]  output:  0  epoch no:  40900  avg reward 0.975
#  epoch no:  40900  avg reward 0.975
#  message:  [4]  output:  0  epoch no:  41000  avg reward 0.9733333333333334
#  epoch no:  41000  avg reward 0.9733333333333334
#  message:  [2]  output:  1  epoch no:  41100  avg reward 0.975
# ...
#  message:  [4]  output:  2  epoch no:  57800  avg reward 0.9933333333333333
#  epoch no:  57800  avg reward 0.9933333333333333
#  message:  [0]  output:  0  epoch no:  57900  avg reward 0.99
#  epoch no:  57900  avg reward 0.99
#  message:  [0]  output:  1  epoch no:  58000  avg reward 0.9883333333333333
#  epoch no:  58000  avg reward 0.9883333333333333
#  message:  [0]  output:  1  epoch no:  58100  avg reward 0.9883333333333333
#  epoch no:  58100  avg reward 0.9883333333333333
#  message:  [3]  output:  1  epoch no:  58200  avg reward 0.98
#  epoch no:  58200  avg reward 0.98
#  message:  [2]  output:  2  epoch no:  58300  avg reward 0.9966666666666667
#  epoch no:  58300  avg reward 0.9966666666666667
#  message:  [0]  output:  2  epoch no:  58400  avg reward 0.985
#  epoch no:  58400  avg reward 0.985
#  message:  [1]  output:  0  epoch no:  58500  avg reward 0.9966666666666667
#  epoch no:  58500  avg reward 0.9966666666666667
#  message:  [4]  output:  1  epoch no:  58600  avg reward 0.985
#  epoch no:  58600  avg reward 0.985
#  message:  [1]  output:  2  epoch no:  58700  avg reward 0.9916666666666667
#  epoch no:  58700  avg reward 0.9916666666666667
#  message:  [0]  output:  1  epoch no:  58800  avg reward 0.98
#  epoch no:  58800  avg reward 0.98
#  message:  [2]  output:  0  epoch no:  58900  avg reward 0.9816666666666667
#  epoch no:  58900  avg reward 0.9816666666666667
#  message:  [1]  output:  2  epoch no:  59000  avg reward 0.975
#  epoch no:  59000  avg reward 0.975
#  message:  [1]  output:  2  epoch no:  59100  avg reward 0.9866666666666667
#  epoch no:  59100  avg reward 0.9866666666666667
#  message:  [1]  output:  1  epoch no:  59200  avg reward 0.9916666666666667
#  epoch no:  59200  avg reward 0.9916666666666667
#  message:  [0]  output:  0  epoch no:  59300  avg reward 0.9783333333333334
#  epoch no:  59300  avg reward 0.9783333333333334
#  message:  [2]  output:  2  epoch no:  59400  avg reward 0.9883333333333333
#  epoch no:  59400  avg reward 0.9883333333333333
#  message:  [3]  output:  1  epoch no:  59500  avg reward 0.995
#  epoch no:  59500  avg reward 0.995
#  message:  [1]  output:  1  epoch no:  59600  avg reward 0.9783333333333334
#  epoch no:  59600  avg reward 0.9783333333333334
#  message:  [0]  output:  1  epoch no:  59700  avg reward 0.995
#  epoch no:  59700  avg reward 0.995
#  message:  [0]  output:  0  epoch no:  59800  avg reward 0.9916666666666667
#  epoch no:  59800  avg reward 0.9916666666666667
#  message:  [0]  output:  0  epoch no:  59900  avg reward 0.9933333333333333
#  epoch no:  59900  avg reward 0.9933333333333333
#  message:  [0]  output:  1  epoch no:  60000  avg reward 0.9766666666666667
#  epoch no:  60000  avg reward 0.9766666666666667
#  message:  [1]  output:  1  epoch no:  60100  avg reward 0.9883333333333333
#  epoch no:  60100  avg reward 0.9883333333333333
#  message:  [1]  output:  1  epoch no:  60200  avg reward 0.9916666666666667
#  epoch no:  60200  avg reward 0.9916666666666667
#  message:  [0]  output:  2  epoch no:  60300  avg reward 0.985
#  epoch no:  60300  avg reward 0.985
#  message:  [0]  output:  1  epoch no:  60400  avg reward 0.9816666666666667
#  epoch no:  60400  avg reward 0.9816666666666667
#  message:  [2]  output:  1  epoch no:  60500  avg reward 0.99
#  epoch no:  60500  avg reward 0.99
#  message:  [3]  output:  2  epoch no:  60600  avg reward 0.9916666666666667
#  epoch no:  60600  avg reward 0.9916666666666667
#  message:  [4]  output:  0  epoch no:  60700  avg reward 0.9866666666666667
#  epoch no:  60700  avg reward 0.9866666666666667
#  message:  [0]  output:  2  epoch no:  60800  avg reward 0.9966666666666667
#  epoch no:  60800  avg reward 0.9966666666666667
#  message:  [0]  output:  1  epoch no:  60900  avg reward 0.9783333333333334
#  epoch no:  60900  avg reward 0.9783333333333334
#  message:  [3]  output:  0  epoch no:  61000  avg reward 0.995
#  epoch no:  61000  avg reward 0.995
#  message:  [4]  output:  1  epoch no:  61100  avg reward 0.9766666666666667
#  epoch no:  61100  avg reward 0.9766666666666667
#  message:  [1]  output:  0  epoch no:  61200  avg reward 0.9883333333333333
#  epoch no:  61200  avg reward 0.9883333333333333
#  message:  [0]  output:  2  epoch no:  61300  avg reward 0.9866666666666667
#  epoch no:  61300  avg reward 0.9866666666666667
#  message:  [0]  output:  2  epoch no:  61400  avg reward 0.9916666666666667
#  epoch no:  61400  avg reward 0.9916666666666667
#  message:  [2]  output:  2  epoch no:  61500  avg reward 0.9883333333333333
#  epoch no:  61500  avg reward 0.9883333333333333
#  message:  [4]  output:  1  epoch no:  61600  avg reward 0.9916666666666667
#  epoch no:  61600  avg reward 0.9916666666666667
#  message:  [0]  output:  2  epoch no:  61700  avg reward 0.975
#  epoch no:  61700  avg reward 0.975
#  message:  [4]  output:  0  epoch no:  61800  avg reward 0.9916666666666667
#  epoch no:  61800  avg reward 0.9916666666666667
#  message:  [3]  output:  2  epoch no:  61900  avg reward 0.985
#  epoch no:  61900  avg reward 0.985
#  message:  [1]  output:  2  epoch no:  62000  avg reward 0.9966666666666667
#  epoch no:  62000  avg reward 0.9966666666666667
#  message:  [0]  output:  1  epoch no:  62100  avg reward 0.9833333333333333
#  epoch no:  62100  avg reward 0.9833333333333333
#  message:  [0]  output:  0  epoch no:  62200  avg reward 0.9916666666666667
#  epoch no:  62200  avg reward 0.9916666666666667
#  message:  [1]  output:  1  epoch no:  62300  avg reward 0.985
#  epoch no:  62300  avg reward 0.985
#  message:  [0]  output:  2  epoch no:  62400  avg reward 0.99
#  epoch no:  62400  avg reward 0.99
#  message:  [1]  output:  1  epoch no:  62500  avg reward 0.9783333333333334
#  epoch no:  62500  avg reward 0.9783333333333334
#  message:  [0]  output:  2  epoch no:  62600  avg reward 0.9683333333333334
#  epoch no:  62600  avg reward 0.9683333333333334
#  message:  [1]  output:  1  epoch no:  62700  avg reward 0.9966666666666667
#  epoch no:  62700  avg reward 0.9966666666666667
#  message:  [3]  output:  2  epoch no:  62800  avg reward 0.985
#  epoch no:  62800  avg reward 0.985
#  message:  [0]  output:  1  epoch no:  62900  avg reward 0.9666666666666667
#  epoch no:  62900  avg reward 0.9666666666666667
#  message:  [4]  output:  1  epoch no:  63000  avg reward 0.995
#  epoch no:  63000  avg reward 0.995
#  message:  [1]  output:  2  epoch no:  63100  avg reward 0.9916666666666667
#  epoch no:  63100  avg reward 0.9916666666666667
#  message:  [1]  output:  0  epoch no:  63200  avg reward 0.975
#  epoch no:  63200  avg reward 0.975
#  message:  [2]  output:  1  epoch no:  63300  avg reward 0.985
#  epoch no:  63300  avg reward 0.985
#  message:  [0]  output:  0  epoch no:  63400  avg reward 0.9983333333333333
#  epoch no:  63400  avg reward 0.9983333333333333
#  message:  [0]  output:  2  epoch no:  63500  avg reward 0.98
#  epoch no:  63500  avg reward 0.98
#  message:  [3]  output:  0  epoch no:  63600  avg reward 0.985
#  epoch no:  63600  avg reward 0.985
#  message:  [1]  output:  2  epoch no:  63700  avg reward 0.9783333333333334
#  epoch no:  63700  avg reward 0.9783333333333334
#  message:  [1]  output:  0  epoch no:  63800  avg reward 0.9966666666666667
#  epoch no:  63800  avg reward 0.9966666666666667
#  message:  [1]  output:  2  epoch no:  63900  avg reward 0.985
#  epoch no:  63900  avg reward 0.985
#  message:  [1]  output:  0  epoch no:  64000  avg reward 0.99
#  epoch no:  64000  avg reward 0.99
#  message:  [0]  output:  1  epoch no:  64100  avg reward 0.9966666666666667
#  epoch no:  64100  avg reward 0.9966666666666667
#  message:  [4]  output:  0  epoch no:  64200  avg reward 1.0
#  epoch no:  64200  avg reward 1.0
#  message:  [1]  output:  1  epoch no:  64300  avg reward 0.975
#  epoch no:  64300  avg reward 0.975
#  message:  [0]  output:  0  epoch no:  64400  avg reward 0.9933333333333333
#  epoch no:  64400  avg reward 0.9933333333333333
#  message:  [1]  output:  0  epoch no:  64500  avg reward 0.9816666666666667
#  epoch no:  64500  avg reward 0.9816666666666667
#  message:  [1]  output:  1  epoch no:  64600  avg reward 1.0
#  epoch no:  64600  avg reward 1.0
#  message:  [2]  output:  0  epoch no:  64700  avg reward 1.0
#  epoch no:  64700  avg reward 1.0
#  message:  [1]  output:  1  epoch no:  64800  avg reward 0.97
#  epoch no:  64800  avg reward 0.97
#  message:  [1]  output:  0  epoch no:  64900  avg reward 0.9866666666666667
#  epoch no:  64900  avg reward 0.9866666666666667
#  message:  [0]  output:  1  epoch no:  65000  avg reward 0.9933333333333333
#  epoch no:  65000  avg reward 0.9933333333333333
#  message:  [4]  output:  1  epoch no:  65100  avg reward 0.9966666666666667
#  epoch no:  65100  avg reward 0.9966666666666667
#  message:  [2]  output:  1  epoch no:  65200  avg reward 0.9983333333333333
#  epoch no:  65200  avg reward 0.9983333333333333
#  message:  [0]  output:  0  epoch no:  65300  avg reward 0.9916666666666667
#  epoch no:  65300  avg reward 0.9916666666666667
#  message:  [0]  output:  1  epoch no:  65400  avg reward 0.9933333333333333
#  epoch no:  65400  avg reward 0.9933333333333333
#  message:  [1]  output:  1  epoch no:  65500  avg reward 0.995
#  epoch no:  65500  avg reward 0.995
#  message:  [4]  output:  1  epoch no:  65600  avg reward 0.9933333333333333
#  epoch no:  65600  avg reward 0.9933333333333333
#  message:  [0]  output:  0  epoch no:  65700  avg reward 0.9866666666666667
#  epoch no:  65700  avg reward 0.9866666666666667
#  message:  [0]  output:  1  epoch no:  65800  avg reward 0.985
#  epoch no:  65800  avg reward 0.985
#  message:  [1]  output:  2  epoch no:  65900  avg reward 0.9983333333333333
#  epoch no:  65900  avg reward 0.9983333333333333
#  message:  [1]  output:  2  epoch no:  66000  avg reward 0.9916666666666667
#  epoch no:  66000  avg reward 0.9916666666666667
#  message:  [3]  output:  0  epoch no:  66100  avg reward 0.9933333333333333
#  epoch no:  66100  avg reward 0.9933333333333333
#  message:  [0]  output:  1  epoch no:  66200  avg reward 0.9883333333333333
#  epoch no:  66200  avg reward 0.9883333333333333
#  message:  [1]  output:  2  epoch no:  66300  avg reward 0.9916666666666667
#  epoch no:  66300  avg reward 0.9916666666666667
#  message:  [2]  output:  2  epoch no:  66400  avg reward 0.9933333333333333
#  epoch no:  66400  avg reward 0.9933333333333333
#  message:  [1]  output:  0  epoch no:  66500  avg reward 0.9833333333333333
#  epoch no:  66500  avg reward 0.9833333333333333
#  message:  [1]  output:  0  epoch no:  66600  avg reward 0.9866666666666667
#  epoch no:  66600  avg reward 0.9866666666666667
#  message:  [1]  output:  2  epoch no:  66700  avg reward 0.985
#  epoch no:  66700  avg reward 0.985
#  message:  [3]  output:  1  epoch no:  66800  avg reward 0.9783333333333334
#  epoch no:  66800  avg reward 0.9783333333333334
#  message:  [2]  output:  1  epoch no:  66900  avg reward 0.9733333333333334
#  epoch no:  66900  avg reward 0.9733333333333334
#  message:  [1]  output:  2  epoch no:  67000  avg reward 0.9833333333333333
#  epoch no:  67000  avg reward 0.9833333333333333
#  message:  [0]  output:  0  epoch no:  67100  avg reward 0.9833333333333333
#  epoch no:  67100  avg reward 0.9833333333333333
#  message:  [0]  output:  1  epoch no:  67200  avg reward 0.9916666666666667
#  epoch no:  67200  avg reward 0.9916666666666667
#  message:  [0]  output:  0  epoch no:  67300  avg reward 0.96
#  epoch no:  67300  avg reward 0.96
#  message:  [2]  output:  1  epoch no:  67400  avg reward 0.99
#  epoch no:  67400  avg reward 0.99
#  message:  [1]  output:  2  epoch no:  67500  avg reward 0.9866666666666667
#  epoch no:  67500  avg reward 0.9866666666666667
#  message:  [0]  output:  0  epoch no:  67600  avg reward 0.9866666666666667
#  epoch no:  67600  avg reward 0.9866666666666667
#  message:  [1]  output:  1  epoch no:  67700  avg reward 0.9866666666666667
#  epoch no:  67700  avg reward 0.9866666666666667
#  message:  [3]  output:  0  epoch no:  67800  avg reward 0.985
#  epoch no:  67800  avg reward 0.985
#  message:  [3]  output:  0  epoch no:  67900  avg reward 0.9866666666666667
#  epoch no:  67900  avg reward 0.9866666666666667
#  message:  [1]  output:  1  epoch no:  68000  avg reward 0.9933333333333333
#  epoch no:  68000  avg reward 0.9933333333333333
#  message:  [0]  output:  2  epoch no:  68100  avg reward 0.985
#  epoch no:  68100  avg reward 0.985
#  message:  [2]  output:  0  epoch no:  68200  avg reward 0.9833333333333333
#  epoch no:  68200  avg reward 0.9833333333333333
#  message:  [3]  output:  2  epoch no:  68300  avg reward 0.9933333333333333
#  epoch no:  68300  avg reward 0.9933333333333333
#  message:  [2]  output:  1  epoch no:  68400  avg reward 0.9816666666666667
#  epoch no:  68400  avg reward 0.9816666666666667
#  message:  [3]  output:  0  epoch no:  68500  avg reward 0.9833333333333333
#  epoch no:  68500  avg reward 0.9833333333333333
#  message:  [0]  output:  1  epoch no:  68600  avg reward 0.9866666666666667
#  epoch no:  68600  avg reward 0.9866666666666667
#  message:  [3]  output:  1  epoch no:  68700  avg reward 0.99
#  epoch no:  68700  avg reward 0.99
#  message:  [1]  output:  1  epoch no:  68800  avg reward 0.975
#  epoch no:  68800  avg reward 0.975
#  message:  [1]  output:  2  epoch no:  68900  avg reward 0.9933333333333333
#  epoch no:  68900  avg reward 0.9933333333333333
#  message:  [1]  output:  2  epoch no:  69000  avg reward 0.995
#  epoch no:  69000  avg reward 0.995
#  message:  [2]  output:  0  epoch no:  69100  avg reward 0.9916666666666667
#  epoch no:  69100  avg reward 0.9916666666666667
#  message:  [1]  output:  0  epoch no:  69200  avg reward 0.985
#  epoch no:  69200  avg reward 0.985
#  message:  [1]  output:  0  epoch no:  69300  avg reward 0.985
#  epoch no:  69300  avg reward 0.985
#  message:  [0]  output:  2  epoch no:  69400  avg reward 0.9883333333333333
#  epoch no:  69400  avg reward 0.9883333333333333
#  message:  [4]  output:  1  epoch no:  69500  avg reward 0.985
#  epoch no:  69500  avg reward 0.985
#  message:  [0]  output:  2  epoch no:  69600  avg reward 0.9883333333333333
#  epoch no:  69600  avg reward 0.9883333333333333
#  message:  [2]  output:  1  epoch no:  69700  avg reward 0.9916666666666667
#  epoch no:  69700  avg reward 0.9916666666666667
#  message:  [0]  output:  0  epoch no:  69800  avg reward 0.985
#  epoch no:  69800  avg reward 0.985
#  message:  [4]  output:  0  epoch no:  69900  avg reward 0.9716666666666667
#  epoch no:  69900  avg reward 0.9716666666666667
#  message:  [0]  output:  0  epoch no:  70000  avg reward 0.9816666666666667
#  epoch no:  70000  avg reward 0.9816666666666667
#  message:  [1]  output:  1  epoch no:  70100  avg reward 0.99
#  epoch no:  70100  avg reward 0.99
#  message:  [1]  output:  2  epoch no:  70200  avg reward 0.9866666666666667
#  epoch no:  70200  avg reward 0.9866666666666667
#  message:  [0]  output:  1  epoch no:  70300  avg reward 0.99
#  epoch no:  70300  avg reward 0.99
#  message:  [0]  output:  1  epoch no:  70400  avg reward 0.9966666666666667
#  epoch no:  70400  avg reward 0.9966666666666667
#  message:  [0]  output:  0  epoch no:  70500  avg reward 0.9833333333333333
#  epoch no:  70500  avg reward 0.9833333333333333
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-428a1b64b220> in <module>
#      46         rew = game_pool[b].reward(out)
#      47         reward_batch.append(rew)
# ---> 48         game_pool[b].reset()
#      49     speaker_terminals = []
#      50     rew_speaker = []
#
# /media/petrichor/data/future/emergence-of-writing-systems/game.py in reset(self)
#      18     def reset(self):
#      19         self.nos = np.random.choice(range(self.c), self.s, replace=False).tolist()
# ---> 20         self.states = [self.X1[self.Y1==i][np.random.choice(self.X1[self.Y1==i].shape[0], 1)][0] for i in self.nos]
#      21         self.target = 0
#      22
#
# /media/petrichor/data/future/emergence-of-writing-systems/game.py in <listcomp>(.0)
#      18     def reset(self):
#      19         self.nos = np.random.choice(range(self.c), self.s, replace=False).tolist()
# ---> 20         self.states = [self.X1[self.Y1==i][np.random.choice(self.X1[self.Y1==i].shape[0], 1)][0] for i in self.nos]
#      21         self.target = 0
#      22
#
# KeyboardInterrupt:

# %%
databack=data.copy()

# %%
### N population 1

### Testing phase

game_pool = []
data=[]
xnew = X1a[Y1a>5]
ynew = Y1a[Y1a>5]

for i in range(n_batches):
    game_pool.append(Game(n_features, n_clusters, n_samples, n_vocab, sender_type, [X1a, Y1a]))
    
fig = plt.figure()
ax = fig.add_subplot(111)
plt.ion()

fig.show()
fig.canvas.draw()
for i in range(n_epochs):
    Speaker = Speakers[np.random.choice(n_population)]
    Listener = Listeners[np.random.choice(n_population)]
    message_batch = []
    img_batch = []
    r = i%(2*freq)
    if r<1*freq:
        flip_s = False
        flip_l = True
    if r>=1*freq:
        flip_s = True
        flip_l = False
    l_rewards = []
    strokes = []
    for b in range(n_batches):
        strokes = []
#         for idx in range(2):
#             if idx ==0:
#                 feat = np.zeros((10,10), np.uint8)
#             else:
#                 im = message_to_image_sm(strokes, img_dim, img_dim)
# #                 feat = get_features([im])[0]
#                 feat = im.flatten()
        message = Speaker.act(states= game_pool[b].speaker_input(), independent=True)  # (scalar between 0 and 4)
        message_batch.append(message)
#             strokes.append(message)
#         img = message_to_image(strokes, img_rows, img_cols)
#         img_batch.append(img)
#         Speaker.reset()

#     features_batch = get_features(intermediate_layer_model, img_batch)
#     message = Speaker.act(states= game_pool[b].speaker_input(feat), independent=flip_s)
    out_batch = []
    reward_batch = []
    for b in range(n_batches):
        out = Listener.act(states = game_pool[b].listener_input(message_batch[b]), independent = True)
        out_batch.append(out)
        rew = game_pool[b].reward(out)
        reward_batch.append(rew)
        game_pool[b].reset()
    speaker_terminals = []
    rew_speaker = []
    for rew in reward_batch:
        speaker_terminals.extend([True])
        rew_speaker.extend([rew])

#     if not flip_s:
# #         print('e1')
#         e1 = Speaker.model.observe(reward=rew_speaker, terminal=speaker_terminals)
#     if not flip_l:
# #         print('e2')
#         e2 = Listener.model.observe(reward=reward_batch, terminal=[True]*n_batches)
#     assert e1 == e2
#     e = e1
    big_rewards.extend(reward_batch)
    big_rewards = big_rewards[-600:]
    if i%(100)==0:
#         print(" output: ", out)
        avg_rew = sum(big_rewards)/len(big_rewards)
        print(" message: ", message, " output: ", out, " epoch no: ", i, " avg reward", avg_rew)
        print(" epoch no: ", i, " avg reward", avg_rew)

        if(i!=0):
            data.append(avg_rew)
        ax.clear()
        ax.plot(data,'r')
        if not flip_s:
            ax.set_xlabel('speaker')
        else:
            ax.set_xlabel('listener')
        fig.canvas.draw()


#     if sum(big_rewards)/len(big_rewards)>.75:
#         break
# Out:
# <img src="data:image/png;base64,..." width="639.230792677615">
#  message:  [1]  output:  0  epoch no:  0  avg reward 0.9866666666666667
#  epoch no:  0  avg reward 0.9866666666666667
#  message:  [1]  output:  2  epoch no:  100  avg reward 0.8816666666666667
#  epoch no:  100  avg reward 0.8816666666666667
#  message:  [3]  output:  2  epoch no:  200  avg reward 0.885
#  epoch no:  200  avg reward 0.885
#  message:  [0]  output:  1  epoch no:  300  avg reward 0.8816666666666667
#  epoch no:  300  avg reward 0.8816666666666667
#  message:  [3]  output:  0  epoch no:  400  avg reward 0.8866666666666667
#  epoch no:  400  avg reward 0.8866666666666667
#  message:  [4]  output:  2  epoch no:  500  avg reward 0.89
#  epoch no:  500  avg reward 0.89
#  message:  [1]  output:  0  epoch no:  600  avg reward 0.89
#  epoch no:  600  avg reward 0.89
#  message:  [4]  output:  0  epoch no:  700  avg reward 0.8933333333333333
#  epoch no:  700  avg reward 0.8933333333333333
#  message:  [4]  output:  2  epoch no:  800  avg reward 0.8683333333333333
#  epoch no:  800  avg reward 0.8683333333333333
#  message:  [0]  output:  2  epoch no:  900  avg reward 0.87
#  epoch no:  900  avg reward 0.87
#  message:  [1]  output:  2  epoch no:  1000  avg reward 0.8883333333333333
#  epoch no:  1000  avg reward 0.8883333333333333
#  message:  [1]  output:  1  epoch no:  1100  avg reward 0.875
#  epoch no:  1100  avg reward 0.875
#  message:  [0]  output:  2  epoch no:  1200  avg reward 0.885
#  epoch no:  1200  avg reward 0.885
#  message:  [0]  output:  1  epoch no:  1300  avg reward 0.8933333333333333
#  epoch no:  1300  avg reward 0.8933333333333333
#  message:  [1]  output:  2  epoch no:  1400  avg reward 0.8883333333333333
#  epoch no:  1400  avg reward 0.8883333333333333
#  message:  [0]  output:  0  epoch no:  1500  avg reward 0.895
#  epoch no:  1500  avg reward 0.895
#  message:  [2]  output:  0  epoch no:  1600  avg reward 0.88
#  epoch no:  1600  avg reward 0.88
#  message:  [1]  output:  2  epoch no:  1700  avg reward 0.8983333333333333
#  epoch no:  1700  avg reward 0.8983333333333333
#  message:  [0]  output:  0  epoch no:  1800  avg reward 0.8783333333333333
#  epoch no:  1800  avg reward 0.8783333333333333
#  message:  [0]  output:  0  epoch no:  1900  avg reward 0.8733333333333333
#  epoch no:  1900  avg reward 0.8733333333333333
#  message:  [1]  output:  1  epoch no:  2000  avg reward 0.8933333333333333
#  epoch no:  2000  avg reward 0.8933333333333333
#  message:  [0]  output:  0  epoch no:  2100  avg reward 0.895
#  epoch no:  2100  avg reward 0.895
#  message:  [2]  output:  1  epoch no:  2200  avg reward 0.88
#  epoch no:  2200  avg reward 0.88
#  message:  [1]  output:  0  epoch no:  2300  avg reward 0.8883333333333333
#  epoch no:  2300  avg reward 0.8883333333333333
#  message:  [3]  output:  2  epoch no:  2400  avg reward 0.88
#  epoch no:  2400  avg reward 0.88
#  message:  [3]  output:  0  epoch no:  2500  avg reward 0.8983333333333333
#  epoch no:  2500  avg reward 0.8983333333333333
#  message:  [0]  output:  0  epoch no:  2600  avg reward 0.8666666666666667
#  epoch no:  2600  avg reward 0.8666666666666667
#  message:  [2]  output:  1  epoch no:  2700  avg reward 0.8783333333333333
#  epoch no:  2700  avg reward 0.8783333333333333
#  message:  [3]  output:  2  epoch no:  2800  avg reward 0.8866666666666667
#  epoch no:  2800  avg reward 0.8866666666666667
#  message:  [1]  output:  1  epoch no:  2900  avg reward 0.8716666666666667
#  epoch no:  2900  avg reward 0.8716666666666667
#  message:  [0]  output:  2  epoch no:  3000  avg reward 0.8933333333333333
#  epoch no:  3000  avg reward 0.8933333333333333
#  message:  [1]  output:  1  epoch no:  3100  avg reward 0.8666666666666667
#  epoch no:  3100  avg reward 0.8666666666666667
#  message:  [0]  output:  0  epoch no:  3200  avg reward 0.8783333333333333
#  epoch no:  3200  avg reward 0.8783333333333333
#  message:  [1]  output:  2  epoch no:  3300  avg reward 0.8816666666666667
#  epoch no:  3300  avg reward 0.8816666666666667
#  message:  [0]  output:  1  epoch no:  3400  avg reward 0.875
#  epoch no:  3400  avg reward 0.875
#  message:  [0]  output:  1  epoch no:  3500  avg reward 0.9016666666666666
#  epoch no:  3500  avg reward 0.9016666666666666
#  message:  [0]  output:  0  epoch no:  3600  avg reward 0.8616666666666667
#  epoch no:  3600  avg reward 0.8616666666666667
#  message:  [4]  output:  0  epoch no:  3700  avg reward 0.9
#  epoch no:  3700  avg reward 0.9
#  message:  [0]  output:  1  epoch no:  3800  avg reward 0.8783333333333333
#  epoch no:  3800  avg reward 0.8783333333333333
#  message:  [2]  output:  1  epoch no:  3900  avg reward 0.895
#  epoch no:  3900  avg reward 0.895
#  message:  [0]  output:  2  epoch no:  4000  avg reward 0.895
#  epoch no:  4000  avg reward 0.895
#  message:  [4]  output:  1  epoch no:  4100  avg reward 0.8733333333333333
#  epoch no:  4100  avg reward 0.8733333333333333
#  message:  [4]  output:  2  epoch no:  4200  avg reward 0.8833333333333333
#  epoch no:  4200  avg reward 0.8833333333333333
#  message:  [3]  output:  2  epoch no:  4300  avg reward 0.9133333333333333
#  epoch no:  4300  avg reward 0.9133333333333333
#  message:  [0]  output:  2  epoch no:  4400  avg reward 0.9083333333333333
#  epoch no:  4400  avg reward 0.9083333333333333
#  message:  [1]  output:  2  epoch no:  4500  avg reward 0.87
#  epoch no:  4500  avg reward 0.87
#  message:  [3]  output:  2  epoch no:  4600  avg reward 0.885
#  epoch no:  4600  avg reward 0.885
#  message:  [1]  output:  2  epoch no:  4700  avg reward 0.9033333333333333
#  epoch no:  4700  avg reward 0.9033333333333333
#  message:  [0]  output:  1  epoch no:  4800  avg reward 0.8883333333333333
#  epoch no:  4800  avg reward 0.8883333333333333
#  message:  [2]  output:  1  epoch no:  4900  avg reward 0.8916666666666667
#  epoch no:  4900  avg reward 0.8916666666666667
#  message:  [1]  output:  0  epoch no:  5000  avg reward 0.8666666666666667
#  epoch no:  5000  avg reward 0.8666666666666667
#  message:  [1]  output:  1  epoch no:  5100  avg reward 0.8933333333333333
#  epoch no:  5100  avg reward 0.8933333333333333
#  message:  [0]  output:  0  epoch no:  5200  avg reward 0.8666666666666667
#  epoch no:  5200  avg reward 0.8666666666666667
#  message:  [0]  output:  1  epoch no:  5300  avg reward 0.8783333333333333
#  epoch no:  5300  avg reward 0.8783333333333333
#  message:  [0]  output:  1  epoch no:  5400  avg reward 0.87
#  epoch no:  5400  avg reward 0.87
#  message:  [4]  output:  0  epoch no:  5500  avg reward 0.905
#  epoch no:  5500  avg reward 0.905
#  message:  [0]  output:  1  epoch no:  5600  avg reward 0.9016666666666666
#  epoch no:  5600  avg reward 0.9016666666666666
#  message:  [1]  output:  0  epoch no:  5700  avg reward 0.88
#  epoch no:  5700  avg reward 0.88
#  message:  [1]  output:  2  epoch no:  5800  avg reward 0.87
#  epoch no:  5800  avg reward 0.87
#  message:  [1]  output:  1  epoch no:  5900  avg reward 0.8866666666666667
#  epoch no:  5900  avg reward 0.8866666666666667
#  message:  [1]  output:  0  epoch no:  6000  avg reward 0.87
#  epoch no:  6000  avg reward 0.87
#  message:  [1]  output:  2  epoch no:  6100  avg reward 0.8783333333333333
#  epoch no:  6100  avg reward 0.8783333333333333
#  message:  [0]  output:  0  epoch no:  6200  avg reward 0.8683333333333333
#  epoch no:  6200  avg reward 0.8683333333333333
#  message:  [0]  output:  0  epoch no:  6300  avg reward 0.8983333333333333
#  epoch no:  6300  avg reward 0.8983333333333333
#  message:  [2]  output:  1  epoch no:  6400  avg reward 0.9033333333333333
#  epoch no:  6400  avg reward 0.9033333333333333
#  message:  [1]  output:  0  epoch no:  6500  avg reward 0.8683333333333333
#  epoch no:  6500  avg reward 0.8683333333333333
#  message:  [4]  output:  1  epoch no:  6600  avg reward 0.855
#  epoch no:  6600  avg reward 0.855
#  message:  [1]  output:  0  epoch no:  6700  avg reward 0.8633333333333333
#  epoch no:  6700  avg reward 0.8633333333333333
#  message:  [0]  output:  1  epoch no:  6800  avg reward 0.8883333333333333
#  epoch no:  6800  avg reward 0.8883333333333333
#  message:  [1]  output:  2  epoch no:  6900  avg reward 0.89
#  epoch no:  6900  avg reward 0.89
#  message:  [2]  output:  1  epoch no:  7000  avg reward 0.8566666666666667
#  epoch no:  7000  avg reward 0.8566666666666667
#  message:  [3]  output:  2  epoch no:  7100  avg reward 0.885
#  epoch no:  7100  avg reward 0.885
#  message:  [1]  output:  2  epoch no:  7200  avg reward 0.8516666666666667
#  epoch no:  7200  avg reward 0.8516666666666667
#  message:  [0]  output:  1  epoch no:  7300  avg reward 0.87
#  epoch no:  7300  avg reward 0.87
#  message:  [0]  output:  2  epoch no:  7400  avg reward 0.9083333333333333
#  epoch no:  7400  avg reward 0.9083333333333333
#  message:  [3]  output:  2  epoch no:  7500  avg reward 0.8983333333333333
#  epoch no:  7500  avg reward 0.8983333333333333
#  message:  [0]  output:  1  epoch no:  7600  avg reward 0.885
#  epoch no:  7600  avg reward 0.885
#  message:  [1]  output:  0  epoch no:  7700  avg reward 0.91
#  epoch no:  7700  avg reward 0.91
#  message:  [2]  output:  0  epoch no:  7800  avg reward 0.8883333333333333
#  epoch no:  7800  avg reward 0.8883333333333333
#  message:  [1]  output:  0  epoch no:  7900  avg reward 0.8783333333333333
#  epoch no:  7900  avg reward 0.8783333333333333
#  message:  [1]  output:  2  epoch no:  8000  avg reward 0.895
#  epoch no:  8000  avg reward 0.895
#  message:  [1]  output:  0  epoch no:  8100  avg reward 0.885
#  epoch no:  8100  avg reward 0.885
#  message:  [1]  output:  2  epoch no:  8200  avg reward 0.8833333333333333
#  epoch no:  8200  avg reward 0.8833333333333333
#  message:  [0]  output:  2  epoch no:  8300  avg reward 0.8783333333333333
#  epoch no:  8300  avg reward 0.8783333333333333
#  message:  [1]  output:  0  epoch no:  8400  avg reward 0.89
#  epoch no:  8400  avg reward 0.89
#  message:  [3]  output:  0  epoch no:  8500  avg reward 0.8933333333333333
#  epoch no:  8500  avg reward 0.8933333333333333
#  message:  [2]  output:  1  epoch no:  8600  avg reward 0.9033333333333333
#  epoch no:  8600  avg reward 0.9033333333333333
#  message:  [2]  output:  0  epoch no:  8700  avg reward 0.88
#  epoch no:  8700  avg reward 0.88
#  message:  [0]  output:  0  epoch no:  8800  avg reward 0.8766666666666667
#  epoch no:  8800  avg reward 0.8766666666666667
#  message:  [1]  output:  0  epoch no:  8900  avg reward 0.8866666666666667
#  epoch no:  8900  avg reward 0.8866666666666667
#  message:  [4]  output:  0  epoch no:  9000  avg reward 0.8916666666666667
#  epoch no:  9000  avg reward 0.8916666666666667
#  message:  [1]  output:  1  epoch no:  9100  avg reward 0.89
#  epoch no:  9100  avg reward 0.89
#  message:  [4]  output:  0  epoch no:  9200  avg reward 0.89
#  epoch no:  9200  avg reward 0.89
#  message:  [0]  output:  2  epoch no:  9300  avg reward 0.865
#  epoch no:  9300  avg reward 0.865
#  message:  [0]  output:  0  epoch no:  9400  avg reward 0.8983333333333333
#  epoch no:  9400  avg reward 0.8983333333333333
#  message:  [2]  output:  2  epoch no:  9500  avg reward 0.915
#  epoch no:  9500  avg reward 0.915
#  message:  [1]  output:  2  epoch no:  9600  avg reward 0.8983333333333333
#  epoch no:  9600  avg reward 0.8983333333333333
#  message:  [1]  output:  2  epoch no:  9700  avg reward 0.8833333333333333
#  epoch no:  9700  avg reward 0.8833333333333333
#  message:  [1]  output:  2  epoch no:  9800  avg reward 0.8766666666666667
#  epoch no:  9800  avg reward 0.8766666666666667
#  message:  [1]  output:  1  epoch no:  9900  avg reward 0.8883333333333333
#  epoch no:  9900  avg reward 0.8883333333333333
#  message:  [1]  output:  1  epoch no:  10000  avg reward 0.8933333333333333
#  epoch no:  10000  avg reward 0.8933333333333333
#  message:  [2]  output:  1  epoch no:  10100  avg reward 0.8983333333333333
#  epoch no:  10100  avg reward 0.8983333333333333
#  message:  [1]  output:  0  epoch no:  10200  avg reward 0.8783333333333333
#  epoch no:  10200  avg reward 0.8783333333333333
#  message:  [1]  output:  0  epoch no:  10300  avg reward 0.8733333333333333
#  epoch no:  10300  avg reward 0.8733333333333333
#  message:  [0]  output:  2  epoch no:  10400  avg reward 0.86
#  epoch no:  10400  avg reward 0.86
#  message:  [0]  output:  0  epoch no:  10500  avg reward 0.8816666666666667
#  epoch no:  10500  avg reward 0.8816666666666667
#  message:  [0]  output:  0  epoch no:  10600  avg reward 0.8766666666666667
#  epoch no:  10600  avg reward 0.8766666666666667
#  message:  [2]  output:  2  epoch no:  10700  avg reward 0.89
#  epoch no:  10700  avg reward 0.89
#  message:  [3]  output:  1  epoch no:  10800  avg reward 0.8833333333333333
#  epoch no:  10800  avg reward 0.8833333333333333
#  message:  [1]  output:  1  epoch no:  10900  avg reward 0.8833333333333333
#  epoch no:  10900  avg reward 0.8833333333333333
#  message:  [3]  output:  1  epoch no:  11000  avg reward 0.895
#  epoch no:  11000  avg reward 0.895
#  message:  [0]  output:  2  epoch no:  11100  avg reward 0.8983333333333333
#  epoch no:  11100  avg reward 0.8983333333333333
#  message:  [0]  output:  1  epoch no:  11200  avg reward 0.8833333333333333
#  epoch no:  11200  avg reward 0.8833333333333333
#  message:  [1]  output:  1  epoch no:  11300  avg reward 0.8766666666666667
#  epoch no:  11300  avg reward 0.8766666666666667
#  message:  [2]  output:  1  epoch no:  11400  avg reward 0.8783333333333333
#  epoch no:  11400  avg reward 0.8783333333333333
#  message:  [1]  output:  2  epoch no:  11500  avg reward 0.87
#  epoch no:  11500  avg reward 0.87
#  message:  [4]  output:  0  epoch no:  11600  avg reward 0.8833333333333333
#  epoch no:  11600  avg reward 0.8833333333333333
#  message:  [0]  output:  0  epoch no:  11700  avg reward 0.86
#  epoch no:  11700  avg reward 0.86
#  message:  [1]  output:  2  epoch no:  11800  avg reward 0.885
#  epoch no:  11800  avg reward 0.885
#  message:  [1]  output:  2  epoch no:  11900  avg reward 0.8766666666666667
#  epoch no:  11900  avg reward 0.8766666666666667
#  message:  [1]  output:  0  epoch no:  12000  avg reward 0.8766666666666667
#  epoch no:  12000  avg reward 0.8766666666666667
#  message:  [1]  output:  0  epoch no:  12100  avg reward 0.8766666666666667
#  epoch no:  12100  avg reward 0.8766666666666667
#  message:  [4]  output:  0  epoch no:  12200  avg reward 0.8933333333333333
#  epoch no:  12200  avg reward 0.8933333333333333
#  message:  [3]  output:  0  epoch no:  12300  avg reward 0.88
#  epoch no:  12300  avg reward 0.88
#  message:  [1]  output:  0  epoch no:  12400  avg reward 0.8733333333333333
#  epoch no:  12400  avg reward 0.8733333333333333
#  message:  [0]  output:  1  epoch no:  12500  avg reward 0.89
#  epoch no:  12500  avg reward 0.89
#  message:  [1]  output:  2  epoch no:  12600  avg reward 0.8733333333333333
#  epoch no:  12600  avg reward 0.8733333333333333
#  message:  [3]  output:  0  epoch no:  12700  avg reward 0.895
#  epoch no:  12700  avg reward 0.895
#  message:  [4]  output:  0  epoch no:  12800  avg reward 0.8733333333333333
#  epoch no:  12800  avg reward 0.8733333333333333
#  message:  [1]  output:  2  epoch no:  12900  avg reward 0.8616666666666667
#  epoch no:  12900  avg reward 0.8616666666666667
#  message:  [3]  output:  1  epoch no:  13000  avg reward 0.8383333333333334
#  epoch no:  13000  avg reward 0.8383333333333334
#  message:  [1]  output:  2  epoch no:  13100  avg reward 0.8766666666666667
#  epoch no:  13100  avg reward 0.8766666666666667
#  message:  [1]  output:  2  epoch no:  13200  avg reward 0.8783333333333333
#  epoch no:  13200  avg reward 0.8783333333333333
#  message:  [1]  output:  2  epoch no:  13300  avg reward 0.9016666666666666
#  epoch no:  13300  avg reward 0.9016666666666666
#  message:  [2]  output:  2  epoch no:  13400  avg reward 0.8666666666666667
#  epoch no:  13400  avg reward 0.8666666666666667
#  message:  [2]  output:  0  epoch no:  13500  avg reward 0.9
#  epoch no:  13500  avg reward 0.9
#  message:  [1]  output:  1  epoch no:  13600  avg reward 0.8983333333333333
#  epoch no:  13600  avg reward 0.8983333333333333
#  message:  [0]  output:  2  epoch no:  13700  avg reward 0.8966666666666666
#  epoch no:  13700  avg reward 0.8966666666666666
#  message:  [0]  output:  1  epoch no:  13800  avg reward 0.8733333333333333
#  epoch no:  13800  avg reward 0.8733333333333333
#  message:  [1]  output:  1  epoch no:  13900  avg reward 0.885
#  epoch no:  13900  avg reward 0.885
#  message:  [0]  output:  2  epoch no:  14000  avg reward 0.895
#  epoch no:  14000  avg reward 0.895
#  message:  [0]  output:  2  epoch no:  14100  avg reward 0.8766666666666667
#  epoch no:  14100  avg reward 0.8766666666666667
#  message:  [0]  output:  1  epoch no:  14200  avg reward 0.8733333333333333
#  epoch no:  14200  avg reward 0.8733333333333333
#  message:  [3]  output:  2  epoch no:  14300  avg reward 0.8766666666666667
#  epoch no:  14300  avg reward 0.8766666666666667
#  message:  [3]  output:  1  epoch no:  14400  avg reward 0.8933333333333333
#  epoch no:  14400  avg reward 0.8933333333333333
#  message:  [2]  output:  0  epoch no:  14500  avg reward 0.9
#  epoch no:  14500  avg reward 0.9
#  message:  [1]  output:  1  epoch no:  14600  avg reward 0.8833333333333333
#  epoch no:  14600  avg reward 0.8833333333333333
#  message:  [0]  output:  2  epoch no:  14700  avg reward 0.885
#  epoch no:  14700  avg reward 0.885
#  message:  [1]  output:  0  epoch no:  14800  avg reward 0.8716666666666667
#  epoch no:  14800  avg reward 0.8716666666666667
#  message:  [0]  output:  2  epoch no:  14900  avg reward 0.8716666666666667
#  epoch no:  14900  avg reward 0.8716666666666667
#  message:  [1]  output:  0  epoch no:  15000  avg reward 0.8816666666666667
#  epoch no:  15000  avg reward 0.8816666666666667
#  message:  [2]  output:  2  epoch no:  15100  avg reward 0.8983333333333333
#  epoch no:  15100  avg reward 0.8983333333333333
#  message:  [1]  output:  2  epoch no:  15200  avg reward 0.8816666666666667
#  epoch no:  15200  avg reward 0.8816666666666667
#  message:  [2]  output:  2  epoch no:  15300  avg reward 0.8866666666666667
#  epoch no:  15300  avg reward 0.8866666666666667
#  message:  [0]  output:  0  epoch no:  15400  avg reward 0.8683333333333333
#  epoch no:  15400  avg reward 0.8683333333333333
#  message:  [0]  output:  0  epoch no:  15500  avg reward 0.8933333333333333
#  epoch no:  15500  avg reward 0.8933333333333333
#  message:  [0]  output:  2  epoch no:  15600  avg reward 0.885
#  epoch no:  15600  avg reward 0.885
#  message:  [0]  output:  1  epoch no:  15700  avg reward 0.8683333333333333
#  epoch no:  15700  avg reward 0.8683333333333333
#  message:  [1]  output:  2  epoch no:  15800  avg reward 0.8816666666666667
#  epoch no:  15800  avg reward 0.8816666666666667
#  message:  [2]  output:  1  epoch no:  15900  avg reward 0.87
#  epoch no:  15900  avg reward 0.87
#  message:  [1]  output:  1  epoch no:  16000  avg reward 0.8933333333333333
#  epoch no:  16000  avg reward 0.8933333333333333
#  message:  [4]  output:  1  epoch no:  16100  avg reward 0.895
#  epoch no:  16100  avg reward 0.895
#  message:  [3]  output:  0  epoch no:  16200  avg reward 0.885
#  epoch no:  16200  avg reward 0.885
#  message:  [1]  output:  2  epoch no:  16300  avg reward 0.8783333333333333
#  epoch no:  16300  avg reward 0.8783333333333333
#  message:  [1]  output:  2  epoch no:  16400  avg reward 0.89
#  epoch no:  16400  avg reward 0.89
#  message:  [4]  output:  1  epoch no:  16500  avg reward 0.885
#  epoch no:  16500  avg reward 0.885
#  message:  [0]  output:  2  epoch no:  16600  avg reward 0.885
#  epoch no:  16600  avg reward 0.885
#  message:  [0]  output:  1  epoch no:  16700  avg reward 0.8566666666666667
#  epoch no:  16700  avg reward 0.8566666666666667
#  message:  [1]  output:  0  epoch no:  16800  avg reward 0.8883333333333333
#  epoch no:  16800  avg reward 0.8883333333333333
#  message:  [1]  output:  0  epoch no:  16900  avg reward 0.8866666666666667
#  epoch no:  16900  avg reward 0.8866666666666667
#  message:  [3]  output:  1  epoch no:  17000  avg reward 0.8833333333333333
#  epoch no:  17000  avg reward 0.8833333333333333
#  message:  [2]  output:  1  epoch no:  17100  avg reward 0.8766666666666667
#  epoch no:  17100  avg reward 0.8766666666666667
#  message:  [1]  output:  0  epoch no:  17200  avg reward 0.88
#  epoch no:  17200  avg reward 0.88
#  message:  [0]  output:  2  epoch no:  17300  avg reward 0.89
#  epoch no:  17300  avg reward 0.89
#  message:  [0]  output:  2  epoch no:  17400  avg reward 0.9266666666666666
#  epoch no:  17400  avg reward 0.9266666666666666
#  message:  [0]  output:  1  epoch no:  17500  avg reward 0.8883333333333333
#  epoch no:  17500  avg reward 0.8883333333333333
#  message:  [2]  output:  0  epoch no:  17600  avg reward 0.8683333333333333
#  epoch no:  17600  avg reward 0.8683333333333333
#  message:  [4]  output:  1  epoch no:  17700  avg reward 0.8666666666666667
#  epoch no:  17700  avg reward 0.8666666666666667
#  message:  [1]  output:  0  epoch no:  17800  avg reward 0.8816666666666667
#  epoch no:  17800  avg reward 0.8816666666666667
#  message:  [2]  output:  0  epoch no:  17900  avg reward 0.8833333333333333
#  epoch no:  17900  avg reward 0.8833333333333333
#  message:  [2]  output:  2  epoch no:  18000  avg reward 0.89
#  epoch no:  18000  avg reward 0.89
#  message:  [0]  output:  2  epoch no:  18100  avg reward 0.8833333333333333
#  epoch no:  18100  avg reward 0.8833333333333333
#  message:  [1]  output:  0  epoch no:  18200  avg reward 0.8816666666666667
#  epoch no:  18200  avg reward 0.8816666666666667
#  message:  [0]  output:  2  epoch no:  18300  avg reward 0.8966666666666666
#  epoch no:  18300  avg reward 0.8966666666666666
#  message:  [4]  output:  2  epoch no:  18400  avg reward 0.9
#  epoch no:  18400  avg reward 0.9
#  message:  [0]  output:  0  epoch no:  18500  avg reward 0.875
#  epoch no:  18500  avg reward 0.875
#  message:  [0]  output:  1  epoch no:  18600  avg reward 0.9016666666666666
#  epoch no:  18600  avg reward 0.9016666666666666
#  message:  [1]  output:  2  epoch no:  18700  avg reward 0.8666666666666667
#  epoch no:  18700  avg reward 0.8666666666666667
#  message:  [0]  output:  0  epoch no:  18800  avg reward 0.875
#  epoch no:  18800  avg reward 0.875
#  message:  [4]  output:  0  epoch no:  18900  avg reward 0.9016666666666666
#  epoch no:  18900  avg reward 0.9016666666666666
#  message:  [4]  output:  0  epoch no:  19000  avg reward 0.89
#  epoch no:  19000  avg reward 0.89
#  message:  [4]  output:  1  epoch no:  19100  avg reward 0.88
#  epoch no:  19100  avg reward 0.88
#  message:  [0]  output:  1  epoch no:  19200  avg reward 0.8666666666666667
#  epoch no:  19200  avg reward 0.8666666666666667
#  message:  [2]  output:  2  epoch no:  19300  avg reward 0.895
#  epoch no:  19300  avg reward 0.895
#  message:  [0]  output:  1  epoch no:  19400  avg reward 0.885
#  epoch no:  19400  avg reward 0.885
#  message:  [0]  output:  0  epoch no:  19500  avg reward 0.89
#  epoch no:  19500  avg reward 0.89
#  message:  [0]  output:  0  epoch no:  19600  avg reward 0.89
#  epoch no:  19600  avg reward 0.89
#  message:  [1]  output:  2  epoch no:  19700  avg reward 0.9083333333333333
#  epoch no:  19700  avg reward 0.9083333333333333
#  message:  [1]  output:  0  epoch no:  19800  avg reward 0.8766666666666667
#  epoch no:  19800  avg reward 0.8766666666666667
#  message:  [0]  output:  0  epoch no:  19900  avg reward 0.8833333333333333
#  epoch no:  19900  avg reward 0.8833333333333333
#  message:  [1]  output:  2  epoch no:  20000  avg reward 0.8883333333333333
#  epoch no:  20000  avg reward 0.8883333333333333
#  message:  [3]  output:  0  epoch no:  20100  avg reward 0.8766666666666667
#  epoch no:  20100  avg reward 0.8766666666666667
#  message:  [0]  output:  1  epoch no:  20200  avg reward 0.9066666666666666
#  epoch no:  20200  avg reward 0.9066666666666666
#  message:  [2]  output:  1  epoch no:  20300  avg reward 0.88
#  epoch no:  20300  avg reward 0.88
#  message:  [2]  output:  0  epoch no:  20400  avg reward 0.8866666666666667
#  epoch no:  20400  avg reward 0.8866666666666667
#  message:  [4]  output:  0  epoch no:  20500  avg reward 0.8866666666666667
#  epoch no:  20500  avg reward 0.8866666666666667
#  message:  [1]  output:  2  epoch no:  20600  avg reward 0.8983333333333333
#  epoch no:  20600  avg reward 0.8983333333333333
#  message:  [2]  output:  2  epoch no:  20700  avg reward 0.86
#  epoch no:  20700  avg reward 0.86
#  message:  [0]  output:  1  epoch no:  20800  avg reward 0.8683333333333333
#  epoch no:  20800  avg reward 0.8683333333333333
#  message:  [4]  output:  1  epoch no:  20900  avg reward 0.9166666666666666
#  epoch no:  20900  avg reward 0.9166666666666666
#  message:  [1]  output:  2  epoch no:  21000  avg reward 0.8816666666666667
#  epoch no:  21000  avg reward 0.8816666666666667
#  message:  [0]  output:  1  epoch no:  21100  avg reward 0.9066666666666666
#  epoch no:  21100  avg reward 0.9066666666666666
#  message:  [2]  output:  2  epoch no:  21200  avg reward 0.8866666666666667
#  epoch no:  21200  avg reward 0.8866666666666667
#  message:  [1]  output:  2  epoch no:  21300  avg reward 0.8716666666666667
#  epoch no:  21300  avg reward 0.8716666666666667
#  message:  [1]  output:  0  epoch no:  21400  avg reward 0.8833333333333333
#  epoch no:  21400  avg reward 0.8833333333333333
#  message:  [2]  output:  2  epoch no:  21500  avg reward 0.9016666666666666
#  epoch no:  21500  avg reward 0.9016666666666666
#  message:  [0]  output:  1  epoch no:  21600  avg reward 0.9016666666666666
#  epoch no:  21600  avg reward 0.9016666666666666
#  message:  [1]  output:  1  epoch no:  21700  avg reward 0.8616666666666667
#  epoch no:  21700  avg reward 0.8616666666666667
#  message:  [1]  output:  2  epoch no:  21800  avg reward 0.8816666666666667
#  epoch no:  21800  avg reward 0.8816666666666667
#  message:  [1]  output:  0  epoch no:  21900  avg reward 0.8983333333333333
#  epoch no:  21900  avg reward 0.8983333333333333
#  message:  [3]  output:  0  epoch no:  22000  avg reward 0.8716666666666667
#  epoch no:  22000  avg reward 0.8716666666666667
#  message:  [4]  output:  1  epoch no:  22100  avg reward 0.9016666666666666
#  epoch no:  22100  avg reward 0.9016666666666666
#  message:  [0]  output:  0  epoch no:  22200  avg reward 0.875
#  epoch no:  22200  avg reward 0.875
#  message:  [0]  output:  1  epoch no:  22300  avg reward 0.8733333333333333
#  epoch no:  22300  avg reward 0.8733333333333333
#  message:  [1]  output:  2  epoch no:  22400  avg reward 0.8916666666666667
#  epoch no:  22400  avg reward 0.8916666666666667
#  message:  [0]  output:  1  epoch no:  22500  avg reward 0.8666666666666667
#  epoch no:  22500  avg reward 0.8666666666666667
#  message:  [0]  output:  2  epoch no:  22600  avg reward 0.88
#  epoch no:  22600  avg reward 0.88
#  message:  [1]  output:  2  epoch no:  22700  avg reward 0.8833333333333333
#  epoch no:  22700  avg reward 0.8833333333333333
#  message:  [4]  output:  2  epoch no:  22800  avg reward 0.875
#  epoch no:  22800  avg reward 0.875
#  message:  [0]  output:  1  epoch no:  22900  avg reward 0.8816666666666667
#  epoch no:  22900  avg reward 0.8816666666666667
#  message:  [0]  output:  1  epoch no:  23000  avg reward 0.8866666666666667
#  epoch no:  23000  avg reward 0.8866666666666667
#  message:  [2]  output:  1  epoch no:  23100  avg reward 0.885
#  epoch no:  23100  avg reward 0.885
#  message:  [0]  output:  1  epoch no:  23200  avg reward 0.905
#  epoch no:  23200  avg reward 0.905
#  message:  [1]  output:  1  epoch no:  23300  avg reward 0.9066666666666666
#  epoch no:  23300  avg reward 0.9066666666666666
#  message:  [4]  output:  0  epoch no:  23400  avg reward 0.8866666666666667
#  epoch no:  23400  avg reward 0.8866666666666667
#  message:  [1]  output:  2  epoch no:  23500  avg reward 0.8883333333333333
#  epoch no:  23500  avg reward 0.8883333333333333
#  message:  [3]  output:  2  epoch no:  23600  avg reward 0.86
#  epoch no:  23600  avg reward 0.86
#  message:  [4]  output:  2  epoch no:  23700  avg reward 0.8833333333333333
#  epoch no:  23700  avg reward 0.8833333333333333
#  message:  [4]  output:  0  epoch no:  23800  avg reward 0.8833333333333333
#  epoch no:  23800  avg reward 0.8833333333333333
#  message:  [4]  output:  1  epoch no:  23900  avg reward 0.8783333333333333
#  epoch no:  23900  avg reward 0.8783333333333333
#  message:  [0]  output:  1  epoch no:  24000  avg reward 0.9216666666666666
#  epoch no:  24000  avg reward 0.9216666666666666
#  message:  [0]  output:  1  epoch no:  24100  avg reward 0.9
#  epoch no:  24100  avg reward 0.9
#  message:  [1]  output:  2  epoch no:  24200  avg reward 0.8766666666666667
#  epoch no:  24200  avg reward 0.8766666666666667
#  message:  [1]  output:  0  epoch no:  24300  avg reward 0.885
#  epoch no:  24300  avg reward 0.885
#  message:  [1]  output:  0  epoch no:  24400  avg reward 0.875
#  epoch no:  24400  avg reward 0.875
#  message:  [1]  output:  2  epoch no:  24500  avg reward 0.8866666666666667
#  epoch no:  24500  avg reward 0.8866666666666667
#  message:  [1]  output:  2  epoch no:  24600  avg reward 0.875
#  epoch no:  24600  avg reward 0.875
#  message:  [1]  output:  2  epoch no:  24700  avg reward 0.8683333333333333
#  epoch no:  24700  avg reward 0.8683333333333333
#  message:  [3]  output:  1  epoch no:  24800  avg reward 0.9016666666666666
#  epoch no:  24800  avg reward 0.9016666666666666
#  message:  [0]  output:  2  epoch no:  24900  avg reward 0.9033333333333333
#  epoch no:  24900  avg reward 0.9033333333333333
#  message:  [1]  output:  2  epoch no:  25000  avg reward 0.8683333333333333
#  epoch no:  25000  avg reward 0.8683333333333333
#  message:  [2]  output:  2  epoch no:  25100  avg reward 0.895
#  epoch no:  25100  avg reward 0.895
#  message:  [0]  output:  2  epoch no:  25200  avg reward 0.88
#  epoch no:  25200  avg reward 0.88
#  message:  [1]  output:  0  epoch no:  25300  avg reward 0.87
#  epoch no:  25300  avg reward 0.87
#  message:  [1]  output:  2  epoch no:  25400  avg reward 0.85
#  epoch no:  25400  avg reward 0.85
#  message:  [0]  output:  1  epoch no:  25500  avg reward 0.8866666666666667
#  epoch no:  25500  avg reward 0.8866666666666667
#  message:  [0]  output:  2  epoch no:  25600  avg reward 0.8916666666666667
#  epoch no:  25600  avg reward 0.8916666666666667
#  message:  [0]  output:  1  epoch no:  25700  avg reward 0.89
#  epoch no:  25700  avg reward 0.89
#  message:  [0]  output:  1  epoch no:  25800  avg reward 0.8816666666666667
#  epoch no:  25800  avg reward 0.8816666666666667
#  message:  [1]  output:  1  epoch no:  25900  avg reward 0.8716666666666667
#  epoch no:  25900  avg reward 0.8716666666666667
#  message:  [1]  output:  2  epoch no:  26000  avg reward 0.8833333333333333
#  epoch no:  26000  avg reward 0.8833333333333333
#  message:  [0]  output:  0  epoch no:  26100  avg reward 0.9016666666666666
#  epoch no:  26100  avg reward 0.9016666666666666
#  message:  [4]  output:  0  epoch no:  26200  avg reward 0.895
#  epoch no:  26200  avg reward 0.895
#  message:  [0]  output:  2  epoch no:  26300  avg reward 0.88
#  epoch no:  26300  avg reward 0.88
#  message:  [1]  output:  2  epoch no:  26400  avg reward 0.8833333333333333
#  epoch no:  26400  avg reward 0.8833333333333333
#  message:  [1]  output:  2  epoch no:  26500  avg reward 0.8716666666666667
#  epoch no:  26500  avg reward 0.8716666666666667
#  message:  [0]  output:  2  epoch no:  26600  avg reward 0.8733333333333333
#  epoch no:  26600  avg reward 0.8733333333333333
#  message:  [2]  output:  1  epoch no:  26700  avg reward 0.89
#  epoch no:  26700  avg reward 0.89
#  message:  [1]  output:  0  epoch no:  26800  avg reward 0.8783333333333333
#  epoch no:  26800  avg reward 0.8783333333333333
#  message:  [0]  output:  1  epoch no:  26900  avg reward 0.8933333333333333
#  epoch no:  26900  avg reward 0.8933333333333333
#  message:  [3]  output:  2  epoch no:  27000  avg reward 0.8783333333333333
#  epoch no:  27000  avg reward 0.8783333333333333
#  message:  [1]  output:  2  epoch no:  27100  avg reward 0.8666666666666667
#  epoch no:  27100  avg reward 0.8666666666666667
#  message:  [3]  output:  0  epoch no:  27200  avg reward 0.885
#  epoch no:  27200  avg reward 0.885
#  message:  [0]  output:  2  epoch no:  27300  avg reward 0.91
#  epoch no:  27300  avg reward 0.91
#  message:  [1]  output:  0  epoch no:  27400  avg reward 0.9033333333333333
#  epoch no:  27400  avg reward 0.9033333333333333
#  message:  [0]  output:  1  epoch no:  27500  avg reward 0.8933333333333333
#  epoch no:  27500  avg reward 0.8933333333333333
#  message:  [0]  output:  1  epoch no:  27600  avg reward 0.8416666666666667
#  epoch no:  27600  avg reward 0.8416666666666667
#  message:  [1]  output:  2  epoch no:  27700  avg reward 0.8883333333333333
#  epoch no:  27700  avg reward 0.8883333333333333
#  message:  [1]  output:  0  epoch no:  27800  avg reward 0.8983333333333333
#  epoch no:  27800  avg reward 0.8983333333333333
#  message:  [4]  output:  2  epoch no:  27900  avg reward 0.895
#  epoch no:  27900  avg reward 0.895
#  message:  [4]  output:  1  epoch no:  28000  avg reward 0.8783333333333333
#  epoch no:  28000  avg reward 0.8783333333333333
#  message:  [2]  output:  1  epoch no:  28100  avg reward 0.8966666666666666
#  epoch no:  28100  avg reward 0.8966666666666666
#  message:  [0]  output:  0  epoch no:  28200  avg reward 0.8933333333333333
#  epoch no:  28200  avg reward 0.8933333333333333
#  message:  [1]  output:  2  epoch no:  28300  avg reward 0.8916666666666667
#  epoch no:  28300  avg reward 0.8916666666666667
#  message:  [1]  output:  2  epoch no:  28400  avg reward 0.8766666666666667
#  epoch no:  28400  avg reward 0.8766666666666667
#  message:  [3]  output:  1  epoch no:  28500  avg reward 0.88
#  epoch no:  28500  avg reward 0.88
#  message:  [3]  output:  2  epoch no:  28600  avg reward 0.9033333333333333
#  epoch no:  28600  avg reward 0.9033333333333333
#  message:  [0]  output:  0  epoch no:  28700  avg reward 0.865
#  epoch no:  28700  avg reward 0.865
#  message:  [0]  output:  0  epoch no:  28800  avg reward 0.8833333333333333
#  epoch no:  28800  avg reward 0.8833333333333333
#  message:  [1]  output:  2  epoch no:  28900  avg reward 0.8616666666666667
#  epoch no:  28900  avg reward 0.8616666666666667
#  message:  [0]  output:  2  epoch no:  29000  avg reward 0.89
#  epoch no:  29000  avg reward 0.89
#  message:  [0]  output:  2  epoch no:  29100  avg reward 0.89
#  epoch no:  29100  avg reward 0.89
#  message:  [1]  output:  1  epoch no:  29200  avg reward 0.88
#  epoch no:  29200  avg reward 0.88
#  message:  [0]  output:  2  epoch no:  29300  avg reward 0.9033333333333333
#  epoch no:  29300  avg reward 0.9033333333333333
#  message:  [1]  output:  0  epoch no:  29400  avg reward 0.8633333333333333
#  epoch no:  29400  avg reward 0.8633333333333333
#  message:  [1]  output:  0  epoch no:  29500  avg reward 0.8933333333333333
#  epoch no:  29500  avg reward 0.8933333333333333
#  message:  [2]  output:  2  epoch no:  29600  avg reward 0.88
#  epoch no:  29600  avg reward 0.88
#  message:  [0]  output:  1  epoch no:  29700  avg reward 0.875
#  epoch no:  29700  avg reward 0.875
#  message:  [1]  output:  0  epoch no:  29800  avg reward 0.8916666666666667
#  epoch no:  29800  avg reward 0.8916666666666667
#  message:  [4]  output:  0  epoch no:  29900  avg reward 0.8716666666666667
#  epoch no:  29900  avg reward 0.8716666666666667
#  message:  [0]  output:  0  epoch no:  30000  avg reward 0.9033333333333333
#  epoch no:  30000  avg reward 0.9033333333333333
#  message:  [3]  output:  1  epoch no:  30100  avg reward 0.885
#  epoch no:  30100  avg reward 0.885
#  message:  [2]  output:  2  epoch no:  30200  avg reward 0.8816666666666667
#  epoch no:  30200  avg reward 0.8816666666666667
#  message:  [3]  output:  2  epoch no:  30300  avg reward 0.8783333333333333
#  epoch no:  30300  avg reward 0.8783333333333333
#  message:  [1]  output:  0  epoch no:  30400  avg reward 0.9033333333333333
#  epoch no:  30400  avg reward 0.9033333333333333
#  message:  [4]  output:  1  epoch no:  30500  avg reward 0.9016666666666666
#  epoch no:  30500  avg reward 0.9016666666666666
#  message:  [4]  output:  0  epoch no:  30600  avg reward 0.8966666666666666
#  epoch no:  30600  avg reward 0.8966666666666666
#  message:  [4]  output:  1  epoch no:  30700  avg reward 0.8816666666666667
#  epoch no:  30700  avg reward 0.8816666666666667
#  message:  [3]  output:  1  epoch no:  30800  avg reward 0.8883333333333333
#  epoch no:  30800  avg reward 0.8883333333333333
#  message:  [0]  output:  0  epoch no:  30900  avg reward 0.8916666666666667
#  epoch no:  30900  avg reward 0.8916666666666667
#  message:  [2]  output:  0  epoch no:  31000  avg reward 0.9016666666666666
#  epoch no:  31000  avg reward 0.9016666666666666
#  message:  [4]  output:  2  epoch no:  31100  avg reward 0.8766666666666667
#  epoch no:  31100  avg reward 0.8766666666666667
#  message:  [4]  output:  0  epoch no:  31200  avg reward 0.885
#  epoch no:  31200  avg reward 0.885
#  message:  [0]  output:  2  epoch no:  31300  avg reward 0.8883333333333333
#  epoch no:  31300  avg reward 0.8883333333333333
#  message:  [0]  output:  0  epoch no:  31400  avg reward 0.87
#  epoch no:  31400  avg reward 0.87
#  message:  [0]  output:  0  epoch no:  31500  avg reward 0.89
#  epoch no:  31500  avg reward 0.89
#  message:  [0]  output:  0  epoch no:  31600  avg reward 0.8916666666666667
#  epoch no:  31600  avg reward 0.8916666666666667
#  message:  [1]  output:  2  epoch no:  31700  avg reward 0.895
#  epoch no:  31700  avg reward 0.895
#  message:  [0]  output:  2  epoch no:  31800  avg reward 0.8783333333333333
#  epoch no:  31800  avg reward 0.8783333333333333
#  message:  [3]  output:  1  epoch no:  31900  avg reward 0.8883333333333333
#  epoch no:  31900  avg reward 0.8883333333333333
#  message:  [0]  output:  2  epoch no:  32000  avg reward 0.875
#  epoch no:  32000  avg reward 0.875
#  message:  [1]  output:  1  epoch no:  32100  avg reward 0.8816666666666667
#  epoch no:  32100  avg reward 0.8816666666666667
#  message:  [1]  output:  2  epoch no:  32200  avg reward 0.8666666666666667
#  epoch no:  32200  avg reward 0.8666666666666667
#  message:  [1]  output:  1  epoch no:  32300  avg reward 0.8983333333333333
#  epoch no:  32300  avg reward 0.8983333333333333
#  message:  [1]  output:  0  epoch no:  32400  avg reward 0.8733333333333333
#  epoch no:  32400  avg reward 0.8733333333333333
#  message:  [4]  output:  0  epoch no:  32500  avg reward 0.8916666666666667
#  epoch no:  32500  avg reward 0.8916666666666667
#  message:  [0]  output:  0  epoch no:  32600  avg reward 0.875
#  epoch no:  32600  avg reward 0.875
#  message:  [4]  output:  2  epoch no:  32700  avg reward 0.8916666666666667
#  epoch no:  32700  avg reward 0.8916666666666667
#  message:  [0]  output:  1  epoch no:  32800  avg reward 0.8933333333333333
#  epoch no:  32800  avg reward 0.8933333333333333
#  message:  [0]  output:  2  epoch no:  32900  avg reward 0.9033333333333333
#  epoch no:  32900  avg reward 0.9033333333333333
#  message:  [1]  output:  2  epoch no:  33000  avg reward 0.87
#  epoch no:  33000  avg reward 0.87
#  message:  [4]  output:  0  epoch no:  33100  avg reward 0.8883333333333333
#  epoch no:  33100  avg reward 0.8883333333333333
#  message:  [1]  output:  2  epoch no:  33200  avg reward 0.8766666666666667
#  epoch no:  33200  avg reward 0.8766666666666667
#  message:  [1]  output:  0  epoch no:  33300  avg reward 0.875
#  epoch no:  33300  avg reward 0.875
#  message:  [0]  output:  1  epoch no:  33400  avg reward 0.87
#  epoch no:  33400  avg reward 0.87
#  message:  [2]  output:  2  epoch no:  33500  avg reward 0.88
#  epoch no:  33500  avg reward 0.88
#  message:  [0]  output:  1  epoch no:  33600  avg reward 0.9016666666666666
#  epoch no:  33600  avg reward 0.9016666666666666
#  message:  [2]  output:  2  epoch no:  33700  avg reward 0.8683333333333333
#  epoch no:  33700  avg reward 0.8683333333333333
#  message:  [0]  output:  1  epoch no:  33800  avg reward 0.8916666666666667
#  epoch no:  33800  avg reward 0.8916666666666667
#  message:  [2]  output:  1  epoch no:  33900  avg reward 0.8833333333333333
#  epoch no:  33900  avg reward 0.8833333333333333
#  message:  [2]  output:  2  epoch no:  34000  avg reward 0.8666666666666667
#  epoch no:  34000  avg reward 0.8666666666666667
#  message:  [0]  output:  0  epoch no:  34100  avg reward 0.9133333333333333
#  epoch no:  34100  avg reward 0.9133333333333333
#  message:  [1]  output:  1  epoch no:  34200  avg reward 0.8666666666666667
#  epoch no:  34200  avg reward 0.8666666666666667
#  message:  [0]  output:  0  epoch no:  34300  avg reward 0.8716666666666667
#  epoch no:  34300  avg reward 0.8716666666666667
#  message:  [0]  output:  0  epoch no:  34400  avg reward 0.9083333333333333
#  epoch no:  34400  avg reward 0.9083333333333333
#  message:  [3]  output:  1  epoch no:  34500  avg reward 0.865
#  epoch no:  34500  avg reward 0.865
#  message:  [0]  output:  1  epoch no:  34600  avg reward 0.8883333333333333
#  epoch no:  34600  avg reward 0.8883333333333333
#  message:  [1]  output:  0  epoch no:  34700  avg reward 0.9
#  epoch no:  34700  avg reward 0.9
#  message:  [1]  output:  2  epoch no:  34800  avg reward 0.8733333333333333
#  epoch no:  34800  avg reward 0.8733333333333333
#  message:  [0]  output:  2  epoch no:  34900  avg reward 0.89
#  epoch no:  34900  avg reward 0.89
#  message:  [4]  output:  2  epoch no:  35000  avg reward 0.8983333333333333
#  epoch no:  35000  avg reward 0.8983333333333333
#  message:  [1]  output:  2  epoch no:  35100  avg reward 0.8916666666666667
#  epoch no:  35100  avg reward 0.8916666666666667
#  message:  [3]  output:  0  epoch no:  35200  avg reward 0.8966666666666666
#  epoch no:  35200  avg reward 0.8966666666666666
#  message:  [2]  output:  2  epoch no:  35300  avg reward 0.8783333333333333
#  epoch no:  35300  avg reward 0.8783333333333333
#  message:  [3]  output:  2  epoch no:  35400  avg reward 0.8816666666666667
#  epoch no:  35400  avg reward 0.8816666666666667
#  message:  [1]  output:  1  epoch no:  35500  avg reward 0.875
#  epoch no:  35500  avg reward 0.875
#  message:  [0]  output:  1  epoch no:  35600  avg reward 0.8766666666666667
#  epoch no:  35600  avg reward 0.8766666666666667
#  message:  [0]  output:  1  epoch no:  35700  avg reward 0.88
#  epoch no:  35700  avg reward 0.88
#  message:  [1]  output:  0  epoch no:  35800  avg reward 0.8816666666666667
#  epoch no:  35800  avg reward 0.8816666666666667
#  message:  [0]  output:  1  epoch no:  35900  avg reward 0.885
#  epoch no:  35900  avg reward 0.885
#  message:  [2]  output:  0  epoch no:  36000  avg reward 0.89
#  epoch no:  36000  avg reward 0.89
#  message:  [0]  output:  2  epoch no:  36100  avg reward 0.8766666666666667
#  epoch no:  36100  avg reward 0.8766666666666667
#  message:  [0]  output:  1  epoch no:  36200  avg reward 0.8783333333333333
#  epoch no:  36200  avg reward 0.8783333333333333
#  message:  [0]  output:  0  epoch no:  36300  avg reward 0.8783333333333333
#  epoch no:  36300  avg reward 0.8783333333333333
#  message:  [1]  output:  0  epoch no:  36400  avg reward 0.8966666666666666
#  epoch no:  36400  avg reward 0.8966666666666666
#  message:  [0]  output:  1  epoch no:  36500  avg reward 0.9
#  epoch no:  36500  avg reward 0.9
#  message:  [1]  output:  1  epoch no:  36600  avg reward 0.895
#  epoch no:  36600  avg reward 0.895
#  message:  [0]  output:  2  epoch no:  36700  avg reward 0.885
#  epoch no:  36700  avg reward 0.885
#  message:  [0]  output:  1  epoch no:  36800  avg reward 0.8916666666666667
#  epoch no:  36800  avg reward 0.8916666666666667
#  message:  [1]  output:  0  epoch no:  36900  avg reward 0.8583333333333333
#  epoch no:  36900  avg reward 0.8583333333333333
#  message:  [0]  output:  2  epoch no:  37000  avg reward 0.8766666666666667
#  epoch no:  37000  avg reward 0.8766666666666667
#  message:  [2]  output:  1  epoch no:  37100  avg reward 0.885
#  epoch no:  37100  avg reward 0.885
#  message:  [0]  output:  0  epoch no:  37200  avg reward 0.8633333333333333
#  epoch no:  37200  avg reward 0.8633333333333333
#  message:  [0]  output:  2  epoch no:  37300  avg reward 0.8816666666666667
#  epoch no:  37300  avg reward 0.8816666666666667
#  message:  [0]  output:  0  epoch no:  37400  avg reward 0.8933333333333333
#  epoch no:  37400  avg reward 0.8933333333333333
#  message:  [0]  output:  2  epoch no:  37500  avg reward 0.865
#  epoch no:  37500  avg reward 0.865
#  message:  [1]  output:  2  epoch no:  37600  avg reward 0.8833333333333333
#  epoch no:  37600  avg reward 0.8833333333333333
#  message:  [4]  output:  2  epoch no:  37700  avg reward 0.8833333333333333
#  epoch no:  37700  avg reward 0.8833333333333333
#  message:  [1]  output:  0  epoch no:  37800  avg reward 0.8766666666666667
#  epoch no:  37800  avg reward 0.8766666666666667
#  message:  [0]  output:  2  epoch no:  37900  avg reward 0.8666666666666667
#  epoch no:  37900  avg reward 0.8666666666666667
#  message:  [3]  output:  1  epoch no:  38000  avg reward 0.8966666666666666
#  epoch no:  38000  avg reward 0.8966666666666666
#  message:  [1]  output:  2  epoch no:  38100  avg reward 0.8883333333333333
#  epoch no:  38100  avg reward 0.8883333333333333
#  message:  [0]  output:  2  epoch no:  38200  avg reward 0.8833333333333333
#  epoch no:  38200  avg reward 0.8833333333333333
#  message:  [3]  output:  2  epoch no:  38300  avg reward 0.8966666666666666
#  epoch no:  38300  avg reward 0.8966666666666666
#  message:  [2]  output:  0  epoch no:  38400  avg reward 0.875
#  epoch no:  38400  avg reward 0.875
#  message:  [2]  output:  1  epoch no:  38500  avg reward 0.87
#  epoch no:  38500  avg reward 0.87
#  message:  [0]  output:  2  epoch no:  38600  avg reward 0.885
#  epoch no:  38600  avg reward 0.885
#  message:  [0]  output:  2  epoch no:  38700  avg reward 0.8883333333333333
#  epoch no:  38700  avg reward 0.8883333333333333
#  message:  [1]  output:  2  epoch no:  38800  avg reward 0.885
#  epoch no:  38800  avg reward 0.885
#  message:  [1]  output:  0  epoch no:  38900  avg reward 0.8733333333333333
#  epoch no:  38900  avg reward 0.8733333333333333
#  message:  [1]  output:  0  epoch no:  39000  avg reward 0.8883333333333333
#  epoch no:  39000  avg reward 0.8883333333333333
#  message:  [1]  output:  1  epoch no:  39100  avg reward 0.89
#  epoch no:  39100  avg reward 0.89
#  message:  [1]  output:  2  epoch no:  39200  avg reward 0.885
#  epoch no:  39200  avg reward 0.885
#  message:  [1]  output:  1  epoch no:  39300  avg reward 0.855
#  epoch no:  39300  avg reward 0.855
#  message:  [3]  output:  0  epoch no:  39400  avg reward 0.8866666666666667
#  epoch no:  39400  avg reward 0.8866666666666667
#  message:  [0]  output:  2  epoch no:  39500  avg reward 0.88
#  epoch no:  39500  avg reward 0.88
#  message:  [1]  output:  1  epoch no:  39600  avg reward 0.89
#  epoch no:  39600  avg reward 0.89
#  message:  [0]  output:  0  epoch no:  39700  avg reward 0.8883333333333333
#  epoch no:  39700  avg reward 0.8883333333333333
#  message:  [0]  output:  1  epoch no:  39800  avg reward 0.8833333333333333
#  epoch no:  39800  avg reward 0.8833333333333333
#  message:  [4]  output:  1  epoch no:  39900  avg reward 0.8866666666666667
#  epoch no:  39900  avg reward 0.8866666666666667
#  message:  [0]  output:  2  epoch no:  40000  avg reward 0.88
#  epoch no:  40000  avg reward 0.88
#  message:  [0]  output:  2  epoch no:  40100  avg reward 0.8883333333333333
#  epoch no:  40100  avg reward 0.8883333333333333
#  message:  [1]  output:  0  epoch no:  40200  avg reward 0.8733333333333333
#  epoch no:  40200  avg reward 0.8733333333333333
#  message:  [1]  output:  2  epoch no:  40300  avg reward 0.9033333333333333
#  epoch no:  40300  avg reward 0.9033333333333333
#  message:  [4]  output:  0  epoch no:  40400  avg reward 0.8816666666666667
#  epoch no:  40400  avg reward 0.8816666666666667
#  message:  [2]  output:  1  epoch no:  40500  avg reward 0.9
#  epoch no:  40500  avg reward 0.9
#  message:  [2]  output:  1  epoch no:  40600  avg reward 0.9016666666666666
#  epoch no:  40600  avg reward 0.9016666666666666
#  message:  [1]  output:  0  epoch no:  40700  avg reward 0.8883333333333333
#  epoch no:  40700  avg reward 0.8883333333333333
#  message:  [4]  output:  0  epoch no:  40800  avg reward 0.91
#  epoch no:  40800  avg reward 0.91
#  message:  [4]  output:  1  epoch no:  40900  avg reward 0.895
#  epoch no:  40900  avg reward 0.895
#  message:  [3]  output:  1  epoch no:  41000  avg reward 0.8866666666666667
#  epoch no:  41000  avg reward 0.8866666666666667
#  message:  [3]  output:  0  epoch no:  41100  avg reward 0.9066666666666666
#  epoch no:  41100  avg reward 0.9066666666666666
#  message:  [0]  output:  1  epoch no:  41200  avg reward 0.8583333333333333
#  epoch no:  41200  avg reward 0.8583333333333333
#  message:  [2]  output:  0  epoch no:  41300  avg reward 0.8716666666666667
#  epoch no:  41300  avg reward 0.8716666666666667
#  message:  [2]  output:  2  epoch no:  41400  avg reward 0.8883333333333333
#  epoch no:  41400  avg reward 0.8883333333333333
#  message:  [4]  output:  1  epoch no:  41500  avg reward 0.8866666666666667
#  epoch no:  41500  avg reward 0.8866666666666667
#  message:  [0]  output:  0  epoch no:  41600  avg reward 0.89
#  epoch no:  41600  avg reward 0.89
#  message:  [1]  output:  1  epoch no:  41700  avg reward 0.895
#  epoch no:  41700  avg reward 0.895
#  message:  [2]  output:  1  epoch no:  41800  avg reward 0.8866666666666667
#  epoch no:  41800  avg reward 0.8866666666666667
#  message:  [3]  output:  0  epoch no:  41900  avg reward 0.885
#  epoch no:  41900  avg reward 0.885
#  message:  [0]  output:  1  epoch no:  42000  avg reward 0.8966666666666666
#  epoch no:  42000  avg reward 0.8966666666666666
#  message:  [4]  output:  1  epoch no:  42100  avg reward 0.8883333333333333
#  epoch no:  42100  avg reward 0.8883333333333333
#  message:  [0]  output:  2  epoch no:  42200  avg reward 0.8833333333333333
#  epoch no:  42200  avg reward 0.8833333333333333
#  message:  [1]  output:  1  epoch no:  42300  avg reward 0.9016666666666666
#  epoch no:  42300  avg reward 0.9016666666666666
#  message:  [1]  output:  1  epoch no:  42400  avg reward 0.8716666666666667
#  epoch no:  42400  avg reward 0.8716666666666667
#  message:  [2]  output:  2  epoch no:  42500  avg reward 0.8966666666666666
#  epoch no:  42500  avg reward 0.8966666666666666
#  message:  [1]  output:  2  epoch no:  42600  avg reward 0.8666666666666667
#  epoch no:  42600  avg reward 0.8666666666666667
#  message:  [2]  output:  0  epoch no:  42700  avg reward 0.8933333333333333
#  epoch no:  42700  avg reward 0.8933333333333333
#  message:  [1]  output:  1  epoch no:  42800  avg reward 0.9
#  epoch no:  42800  avg reward 0.9
#  message:  [1]  output:  0  epoch no:  42900  avg reward 0.885
#  epoch no:  42900  avg reward 0.885
#  message:  [1]  output:  1  epoch no:  43000  avg reward 0.8983333333333333
#  epoch no:  43000  avg reward 0.8983333333333333
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-4a74c62e25d3> in <module>
#      56         rew = game_pool[b].reward(out)
#      57         reward_batch.append(rew)
# ---> 58         game_pool[b].reset()
#      59     speaker_terminals = []
#      60     rew_speaker = []
#
# /media/petrichor/data/future/emergence-of-writing-systems/game.py in reset(self)
#      18     def reset(self):
#      19         self.nos = np.random.choice(range(self.c), self.s, replace=False).tolist()
# ---> 20         self.states = [self.X1[self.Y1==i][np.random.choice(self.X1[self.Y1==i].shape[0], 1)][0] for i in self.nos]
#      21         self.target = 0
#      22
#
# /media/petrichor/data/future/emergence-of-writing-systems/game.py in <listcomp>(.0)
#      18     def reset(self):
#      19         self.nos = np.random.choice(range(self.c), self.s, replace=False).tolist()
# ---> 20         self.states = [self.X1[self.Y1==i][np.random.choice(self.X1[self.Y1==i].shape[0], 1)][0] for i in self.nos]
#      21         self.target = 0
#      22
#
# KeyboardInterrupt:

# %%
### N population 2

fig = plt.figure()
ax = fig.add_subplot(111)
plt.ion()

fig.show()
fig.canvas.draw()
for i in range(n_epochs):
    Speaker = Speakers[np.random.choice(n_population)]
    Listener = Listeners[np.random.choice(n_population)]
    message_batch = []
    img_batch = []
    r = i%(2*freq)
    if r<1*freq:
        flip_s = False
        flip_l = True
    if r>=1*freq:
        flip_s = True
        flip_l = False
    l_rewards = []
    strokes = []
    for b in range(n_batches):
        strokes = []
#         for idx in range(2):
#             if idx ==0:
#                 feat = np.zeros((10,10), np.uint8)
#             else:
#                 im = message_to_image_sm(strokes, img_dim, img_dim)
# #                 feat = get_features([im])[0]
#                 feat = im.flatten()
        message = Speaker.act(states= game_pool[b].speaker_input(), independent=flip_s)  # (scalar between 0 and 4)
        message_batch.append(message)
#             strokes.append(message)
#         img = message_to_image(strokes, img_rows, img_cols)
#         img_batch.append(img)
#         Speaker.reset()

#     features_batch = get_features(intermediate_layer_model, img_batch)
#     message = Speaker.act(states= game_pool[b].speaker_input(feat), independent=flip_s)
    out_batch = []
    reward_batch = []
    for b in range(n_batches):
        out = Listener.act(states = game_pool[b].listener_input(message_batch[b]), independent = flip_l)
        out_batch.append(out)
        rew = game_pool[b].reward(out)
        reward_batch.append(rew)
        game_pool[b].reset()
    speaker_terminals = []
    rew_speaker = []
    for rew in reward_batch:
        speaker_terminals.extend([True])
        rew_speaker.extend([rew])

    if not flip_s:
#         print('e1')
        e1 = Speaker.model.observe(reward=rew_speaker, terminal=speaker_terminals)
    if not flip_l:
#         print('e2')
        e2 = Listener.model.observe(reward=reward_batch, terminal=[True]*n_batches)
#     assert e1 == e2
#     e = e1
    big_rewards.extend(reward_batch)
    big_rewards = big_rewards[-600:]
    if i%(100)==0:
#         print(" output: ", out)
        avg_rew = sum(big_rewards)/len(big_rewards)
        print(" message: ", message, " output: ", out, " epoch no: ", i, " avg reward", avg_rew)
        print(" epoch no: ", i, " avg reward", avg_rew)

        if(i!=0):
            data.append(avg_rew)
        ax.clear()
        ax.plot(data)
        if not flip_s:
            ax.set_xlabel('speaker')
        else:
            ax.set_xlabel('listener')
        fig.canvas.draw()


#     if sum(big_rewards)/len(big_rewards)>.75:
#         break
# Out:
# <img src="data:image/png;base64,..." width="639.230792677615">
#  message:  [0]  output:  2  epoch no:  0  avg reward 0.4375
#  epoch no:  0  avg reward 0.4375
#  message:  [1]  output:  0  epoch no:  100  avg reward 0.33666666666666667
#  epoch no:  100  avg reward 0.33666666666666667
#  message:  [0]  output:  0  epoch no:  200  avg reward 0.3516666666666667
#  epoch no:  200  avg reward 0.3516666666666667
#  message:  [0]  output:  0  epoch no:  300  avg reward 0.37166666666666665
#  epoch no:  300  avg reward 0.37166666666666665
#  message:  [1]  output:  0  epoch no:  400  avg reward 0.3283333333333333
#  epoch no:  400  avg reward 0.3283333333333333
#  message:  [1]  output:  0  epoch no:  500  avg reward 0.32
#  epoch no:  500  avg reward 0.32
#  message:  [0]  output:  0  epoch no:  600  avg reward 0.31833333333333336
#  epoch no:  600  avg reward 0.31833333333333336
#  message:  [3]  output:  0  epoch no:  700  avg reward 0.32666666666666666
#  epoch no:  700  avg reward 0.32666666666666666
#  message:  [1]  output:  0  epoch no:  800  avg reward 0.32
#  epoch no:  800  avg reward 0.32
#  message:  [3]  output:  0  epoch no:  900  avg reward 0.355
#  epoch no:  900  avg reward 0.355
#  message:  [3]  output:  0  epoch no:  1000  avg reward 0.28833333333333333
#  epoch no:  1000  avg reward 0.28833333333333333
#  message:  [3]  output:  0  epoch no:  1100  avg reward 0.32166666666666666
#  epoch no:  1100  avg reward 0.32166666666666666
#  message:  [4]  output:  0  epoch no:  1200  avg reward 0.31166666666666665
#  epoch no:  1200  avg reward 0.31166666666666665
#  message:  [1]  output:  0  epoch no:  1300  avg reward 0.31333333333333335
#  epoch no:  1300  avg reward 0.31333333333333335
#  message:  [1]  output:  1  epoch no:  1400  avg reward 0.32666666666666666
#  epoch no:  1400  avg reward 0.32666666666666666
#  message:  [3]  output:  0  epoch no:  1500  avg reward 0.3566666666666667
#  epoch no:  1500  avg reward 0.3566666666666667
#  message:  [0]  output:  0  epoch no:  1600  avg reward 0.3466666666666667
#  epoch no:  1600  avg reward 0.3466666666666667
#  message:  [0]  output:  0  epoch no:  1700  avg reward 0.35
#  epoch no:  1700  avg reward 0.35
#  message:  [3]  output:  0  epoch no:  1800  avg reward 0.325
#  epoch no:  1800  avg reward 0.325
#  message:  [4]  output:  1  epoch no:  1900  avg reward 0.38
#  epoch no:  1900  avg reward 0.38
#  message:  [0]  output:  1  epoch no:  2000  avg reward 0.3983333333333333
#  epoch no:  2000  avg reward 0.3983333333333333
#  message:  [1]  output:  0  epoch no:  2100  avg reward 0.44333333333333336
#  epoch no:  2100  avg reward 0.44333333333333336
#  message:  [4]  output:  2  epoch no:  2200  avg reward 0.5166666666666667
#  epoch no:  2200  avg reward 0.5166666666666667
#  message:  [4]  output:  1  epoch no:  2300  avg reward 0.52
#  epoch no:  2300  avg reward 0.52
#  message:  [0]  output:  1  epoch no:  2400  avg reward 0.5316666666666666
#  epoch no:  2400  avg reward 0.5316666666666666
#  message:  [0]  output:  1  epoch no:  2500  avg reward 0.55
#  epoch no:  2500  avg reward 0.55
#  message:  [3]  output:  2  epoch no:  2600  avg reward 0.5233333333333333
#  epoch no:  2600  avg reward 0.5233333333333333
#  message:  [4]  output:  0  epoch no:  2700  avg reward 0.5383333333333333
#  epoch no:  2700  avg reward 0.5383333333333333
#  message:  [3]  output:  1  epoch no:  2800  avg reward 0.5533333333333333
#  epoch no:  2800  avg reward 0.5533333333333333
#  message:  [3]  output:  1  epoch no:  2900  avg reward 0.5683333333333334
#  epoch no:  2900  avg reward 0.5683333333333334
#  message:  [1]  output:  0  epoch no:  3000  avg reward 0.6033333333333334
#  epoch no:  3000  avg reward 0.6033333333333334
#  message:  [0]  output:  1  epoch no:  3100  avg reward 0.59
#  epoch no:  3100  avg reward 0.59
#  message:  [3]  output:  0  epoch no:  3200  avg reward 0.5783333333333334
#  epoch no:  3200  avg reward 0.5783333333333334
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-c2167f400047> in <module>
#      58     if not flip_l:
#      59 #         print('e2')
# ---> 60         e2 = Listener.model.observe(reward=reward_batch, terminal=[True]*n_batches)
#      61 #     assert e1 == e2
#      62 #     e = e1
#
# /usr/local/lib/python3.5/dist-packages/tensorforce/models/model.py in observe(self, terminal, reward)
#    1423         feed_dict = self.get_feed_dict(terminal=terminal, reward=reward)
#    1424
# -> 1425         episode = self.monitored_session.run(fetches=fetches, feed_dict=feed_dict)
#    1426
#    1427         return episode
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/training/monitored_session.py in run(self, fetches, feed_dict, options, run_metadata)
#     544                           feed_dict=feed_dict,
#     545                           options=options,
# --> 546                           run_metadata=run_metadata)
#     547
#     548   def run_step_fn(self, step_fn):
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/training/monitored_session.py in run(self, *args, **kwargs)
#    1096   def run(self, *args, **kwargs):
#    1097     try:
# -> 1098       return self._sess.run(*args, **kwargs)
#    1099     except _PREEMPTION_ERRORS:
#    1100       raise
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/training/monitored_session.py in run(self, fetches, feed_dict, options, run_metadata)
#    1168                                   feed_dict=feed_dict,
#    1169                                   options=options,
# -> 1170                                   run_metadata=run_metadata)
#    1171
#    1172     for hook in self._hooks:
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/training/monitored_session.py in run(self, *args, **kwargs)
#     948
#     949   def run(self, *args, **kwargs):
# --> 950     return self._sess.run(*args, **kwargs)
#     951
#     952   def run_step_fn(self, step_fn, raw_session, run_with_hooks):
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     903     try:
#     904       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 905                          run_metadata_ptr)
#     906       if run_metadata:
#     907         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1138     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1139       results = self._do_run(handle, final_targets, final_fetches,
# -> 1140                              feed_dict_tensor, options, run_metadata)
#    1141     else:
#    1142       results = []
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1319     if handle is None:
#    1320       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1321                            run_metadata)
#    1322     else:
#    1323       return self._do_call(_prun_fn, handle, feeds, fetches)
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1325   def _do_call(self, fn, *args):
#    1326     try:
# -> 1327       return fn(*args)
#    1328     except errors.OpError as e:
#    1329       message = compat.as_text(e.message)
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1310       self._extend_graph()
#    1311       return self._call_tf_sessionrun(
# -> 1312           options, feed_dict, fetch_list, target_list, run_metadata)
#    1313
#    1314     def _prun_fn(handle, feed_dict, fetch_list):
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1418         return tf_session.TF_Run(
#    1419             self._session, options, feed_dict, fetch_list, target_list,
# -> 1420             status, run_metadata)
#    1421
#    1422   def _call_tf_sessionprun(self, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %%
### N population  actually 1
from collections import Counter

result_mapping = {i:[-1] for i in range(n_clusters)}
result_common_mapping = {i:[-1] for i in range(n_clusters)}
magic_moment = False
fig = plt.figure(figsize=(10, 10))
ax = fig.add_subplot(311)
ax2 = fig.add_subplot(312)
ax3 = fig.add_subplot(313)
plt.ion()


fig.show()
fig.canvas.draw()
n_cl = n_clusters-2

def magic():
    global n_cl, n_clusters
    n_cl = n_clusters
    game_pool = []
    for i in range(n_batches):
        game_pool.append(Game(n_features, n_cl, n_samples, n_vocab, sender_type, [X1a, Y1a]))
    
    return game_pool
for i in range(n_epochs):
#     if i>15000:
#         break
    Speaker = Speakers[np.random.choice(n_population)]
    Listener = Listeners[np.random.choice(n_population)]
    message_batch = []
    img_batch = []
    r = i%(2*freq)
    if r<1*freq:
        flip_s = False
        flip_l = True
    if r>=1*freq:
        flip_s = True
        flip_l = False
    l_rewards = []
    strokes = []
    for b in range(n_batches):
        strokes = []
#         for idx in range(2):
#             if idx ==0:
#                 feat = np.zeros((10,10), np.uint8)
#             else:
#                 im = message_to_image_sm(strokes, img_dim, img_dim)
# #                 feat = get_features([im])[0]
#                 feat = im.flatten()
        message = Speaker.act(states= game_pool[b].speaker_input(), independent=flip_s)  # (scalar between 0 and 4)
        message_batch.append(message)
#             strokes.append(message)
#         img = message_to_image(strokes, img_rows, img_cols)
#         img_batch.append(img)
#         Speaker.reset()

#     features_batch = get_features(intermediate_layer_model, img_batch)
#     message = Speaker.act(states= game_pool[b].speaker_input(feat), independent=flip_s)
    out_batch = []
    reward_batch = []
    for b in range(n_batches):
        out = Listener.act(states = game_pool[b].listener_input(message_batch[b]), independent = flip_l)
        out_batch.append(out)
        rew = game_pool[b].reward(out)
        reward_batch.append(rew)
        result_mapping[game_pool[b].nos[0]].append(message_batch[b][0])
        game_pool[b].reset()
        
    speaker_terminals = []
    rew_speaker = []
    for rew in reward_batch:
        speaker_terminals.extend([True])
        rew_speaker.extend([rew])

    if not flip_s:
#         print('e1')
        e1 = Speaker.model.observe(reward=rew_speaker, terminal=speaker_terminals)
    if not flip_l:
#         print('e2')
        e2 = Listener.model.observe(reward=reward_batch, terminal=[True]*n_batches)
#     assert e1 == e2
#     e = e1
    big_rewards.extend(reward_batch)
    big_rewards = big_rewards[-600:]
    if i%(100)==0:
#         print(" output: ", out)
        avg_rew = sum(big_rewards)/len(big_rewards)
        print(" message: ", message, " output: ", out, " epoch no: ", i, " avg reward", avg_rew)
        print(" epoch no: ", i, " avg reward", avg_rew)
        if avg_rew>.7 and not magic_moment:
            game_pool = magic()
            magic_moment = True
            
        if(i!=0):
            data.append(avg_rew)
        ax.clear()
        ax.plot(data)
        ax2.clear()
        for cluster in range(n_clusters):
            all_counts = result_mapping[cluster][-100:]
#             if len(all_counts)<100:
#                 break
            most_common, n = Counter(all_counts).most_common(1)[0]
            
            result_common_mapping[cluster].append(most_common)
            
            if cluster>4:
                linestyle='--'
                start = len(result_common_mapping[0])
                end = start+len(result_common_mapping[cluster])
                print("hi")
                ax3.plot(result_common_mapping[cluster], linestyle=linestyle)
                
            else:
                linestyle='-'
                ax2.plot(result_common_mapping[cluster], linestyle=linestyle)

        if not flip_s:
            ax.set_xlabel('speaker')
        else:
            ax.set_xlabel('listener')
        fig.canvas.draw()


#     if sum(big_rewards)/len(big_rewards)>.75:
#         break
# Out:
# <img src="data:image/png;base64,..." width="999.2308058823368">
#  message:  [8]  output:  1  epoch no:  0  avg reward 0.53125
#  epoch no:  0  avg reward 0.53125
# hi
# hi
#  message:  [9]  output:  0  epoch no:  100  avg reward 0.325
#  epoch no:  100  avg reward 0.325
# hi
# hi
#  message:  [8]  output:  0  epoch no:  200  avg reward 0.29333333333333333
#  epoch no:  200  avg reward 0.29333333333333333
# hi
# hi
#  message:  [6]  output:  1  epoch no:  300  avg reward 0.33166666666666667
#  epoch no:  300  avg reward 0.33166666666666667
# hi
# hi
#  message:  [4]  output:  0  epoch no:  400  avg reward 0.335
#  epoch no:  400  avg reward 0.335
# hi
# hi
#  message:  [4]  output:  2  epoch no:  500  avg reward 0.3383333333333333
#  epoch no:  500  avg reward 0.3383333333333333
# hi
# hi
#  message:  [9]  output:  1  epoch no:  600  avg reward 0.33166666666666667
#  epoch no:  600  avg reward 0.33166666666666667
# hi
# hi
#  message:  [2]  output:  2  epoch no:  700  avg reward 0.325
#  epoch no:  700  avg reward 0.325
# hi
# hi
#  message:  [4]  output:  1  epoch no:  800  avg reward 0.3233333333333333
#  epoch no:  800  avg reward 0.3233333333333333
# hi
# hi
#  message:  [7]  output:  1  epoch no:  900  avg reward 0.34
#  epoch no:  900  avg reward 0.34
# hi
# hi
#  message:  [4]  output:  2  epoch no:  1000  avg reward 0.3233333333333333
#  epoch no:  1000  avg reward 0.3233333333333333
# hi
# hi
#  message:  [6]  output:  1  epoch no:  1100  avg reward 0.305
#  epoch no:  1100  avg reward 0.305
# hi
# hi
#  message:  [1]  output:  0  epoch no:  1200  avg reward 0.30333333333333334
#  epoch no:  1200  avg reward 0.30333333333333334
# hi
# hi
#  message:  [2]  output:  0  epoch no:  1300  avg reward 0.345
#  epoch no:  1300  avg reward 0.345
# hi
# hi
#  message:  [6]  output:  1  epoch no:  1400  avg reward 0.305
#  epoch no:  1400  avg reward 0.305
# hi
# hi
#  message:  [6]  output:  2  epoch no:  1500  avg reward 0.33666666666666667
#  epoch no:  1500  avg reward 0.33666666666666667
# hi
# hi
#  message:  [3]  output:  1  epoch no:  1600  avg reward 0.31833333333333336
#  epoch no:  1600  avg reward 0.31833333333333336
# hi
# hi
#  message:  [4]  output:  1  epoch no:  1700  avg reward 0.35333333333333333
#  epoch no:  1700  avg reward 0.35333333333333333
# hi
# hi
#  message:  [8]  output:  0  epoch no:  1800  avg reward 0.3233333333333333
#  epoch no:  1800  avg reward 0.3233333333333333
# hi
# hi
#  message:  [3]  output:  2  epoch no:  1900  avg reward 0.3433333333333333
#  epoch no:  1900  avg reward 0.3433333333333333
# hi
# hi
#  message:  [5]  output:  0  epoch no:  2000  avg reward 0.33
#  epoch no:  2000  avg reward 0.33
# hi
# hi
#  message:  [8]  output:  2  epoch no:  2100  avg reward 0.365
#  epoch no:  2100  avg reward 0.365
# hi
# hi
#  message:  [8]  output:  0  epoch no:  2200  avg reward 0.31
#  epoch no:  2200  avg reward 0.31
# hi
# hi
#  message:  [5]  output:  2  epoch no:  2300  avg reward 0.33
#  epoch no:  2300  avg reward 0.33
# hi
# hi
#  message:  [8]  output:  1  epoch no:  2400  avg reward 0.305
#  epoch no:  2400  avg reward 0.305
# hi
# hi
#  message:  [8]  output:  0  epoch no:  2500  avg reward 0.3
#  epoch no:  2500  avg reward 0.3
# hi
# hi
#  message:  [4]  output:  1  epoch no:  2600  avg reward 0.31
#  epoch no:  2600  avg reward 0.31
# hi
# hi
#  message:  [8]  output:  1  epoch no:  2700  avg reward 0.29833333333333334
#  epoch no:  2700  avg reward 0.29833333333333334
# hi
# hi
#  message:  [3]  output:  0  epoch no:  2800  avg reward 0.35
#  epoch no:  2800  avg reward 0.35
# hi
# hi
#  message:  [4]  output:  1  epoch no:  2900  avg reward 0.3516666666666667
#  epoch no:  2900  avg reward 0.3516666666666667
# hi
# hi
#  message:  [2]  output:  2  epoch no:  3000  avg reward 0.35
#  epoch no:  3000  avg reward 0.35
# hi
# hi
#  message:  [6]  output:  1  epoch no:  3100  avg reward 0.33
#  epoch no:  3100  avg reward 0.33
# hi
# hi
#  message:  [8]  output:  2  epoch no:  3200  avg reward 0.355
#  epoch no:  3200  avg reward 0.355
# hi
# hi
#  message:  [9]  output:  1  epoch no:  3300  avg reward 0.3333333333333333
#  epoch no:  3300  avg reward 0.3333333333333333
# hi
# hi
#  message:  [7]  output:  1  epoch no:  3400  avg reward 0.3466666666666667
#  epoch no:  3400  avg reward 0.3466666666666667
# hi
# hi
#  message:  [6]  output:  1  epoch no:  3500  avg reward 0.31666666666666665
#  epoch no:  3500  avg reward 0.31666666666666665
# hi
# hi
#  message:  [8]  output:  0  epoch no:  3600  avg reward 0.32666666666666666
#  epoch no:  3600  avg reward 0.32666666666666666
# hi
# hi
#  message:  [8]  output:  1  epoch no:  3700  avg reward 0.305
#  epoch no:  3700  avg reward 0.305
# hi
# hi
#  message:  [3]  output:  0  epoch no:  3800  avg reward 0.335
#  epoch no:  3800  avg reward 0.335
# hi
# hi
#  message:  [6]  output:  2  epoch no:  3900  avg reward 0.34
#  epoch no:  3900  avg reward 0.34
# hi
# hi
#  message:  [4]  output:  2  epoch no:  4000  avg reward 0.32666666666666666
#  epoch no:  4000  avg reward 0.32666666666666666
# hi
# hi
#  message:  [7]  output:  2  epoch no:  4100  avg reward 0.35333333333333333
#  epoch no:  4100  avg reward 0.35333333333333333
# hi
# hi
#  message:  [4]  output:  2  epoch no:  4200  avg reward 0.375
#  epoch no:  4200  avg reward 0.375
# hi
# hi
#  message:  [7]  output:  1  epoch no:  4300  avg reward 0.315
#  epoch no:  4300  avg reward 0.315
# hi
# hi
#  message:  [5]  output:  2  epoch no:  4400  avg reward 0.35
#  epoch no:  4400  avg reward 0.35
# hi
# hi
#  message:  [6]  output:  2  epoch no:  4500  avg reward 0.33166666666666667
#  epoch no:  4500  avg reward 0.33166666666666667
# hi
# hi
#  message:  [8]  output:  1  epoch no:  4600  avg reward 0.3283333333333333
#  epoch no:  4600  avg reward 0.3283333333333333
# hi
# hi
#  message:  [2]  output:  0  epoch no:  4700  avg reward 0.365
#  epoch no:  4700  avg reward 0.365
# hi
# hi
#  message:  [7]  output:  2  epoch no:  4800  avg reward 0.34833333333333333
#  epoch no:  4800  avg reward 0.34833333333333333
# hi
# hi
#  message:  [6]  output:  2  epoch no:  4900  avg reward 0.34833333333333333
#  epoch no:  4900  avg reward 0.34833333333333333
# hi
# hi
#  message:  [8]  output:  0  epoch no:  5000  avg reward 0.36
#  epoch no:  5000  avg reward 0.36
# hi
# hi
#  message:  [3]  output:  2  epoch no:  5100  avg reward 0.3333333333333333
#  epoch no:  5100  avg reward 0.3333333333333333
# hi
# hi
#  message:  [7]  output:  1  epoch no:  5200  avg reward 0.35833333333333334
#  epoch no:  5200  avg reward 0.35833333333333334
# hi
# hi
#  message:  [6]  output:  1  epoch no:  5300  avg reward 0.335
#  epoch no:  5300  avg reward 0.335
# hi
# hi
#  message:  [8]  output:  1  epoch no:  5400  avg reward 0.325
#  epoch no:  5400  avg reward 0.325
# hi
# hi
#  message:  [2]  output:  0  epoch no:  5500  avg reward 0.3433333333333333
#  epoch no:  5500  avg reward 0.3433333333333333
# hi
# hi
#  message:  [8]  output:  1  epoch no:  5600  avg reward 0.3
#  epoch no:  5600  avg reward 0.3
# hi
# hi
#  message:  [8]  output:  2  epoch no:  5700  avg reward 0.3333333333333333
#  epoch no:  5700  avg reward 0.3333333333333333
# hi
# hi
#  message:  [8]  output:  0  epoch no:  5800  avg reward 0.3433333333333333
#  epoch no:  5800  avg reward 0.3433333333333333
# hi
# hi
#  message:  [6]  output:  2  epoch no:  5900  avg reward 0.34833333333333333
#  epoch no:  5900  avg reward 0.34833333333333333
# hi
# hi
#  message:  [6]  output:  1  epoch no:  6000  avg reward 0.365
#  epoch no:  6000  avg reward 0.365
# hi
# hi
#  message:  [8]  output:  0  epoch no:  6100  avg reward 0.34
#  epoch no:  6100  avg reward 0.34
# hi
# hi
#  message:  [8]  output:  2  epoch no:  6200  avg reward 0.33
#  epoch no:  6200  avg reward 0.33
# hi
# hi
#  message:  [8]  output:  0  epoch no:  6300  avg reward 0.35833333333333334
#  epoch no:  6300  avg reward 0.35833333333333334
# hi
# hi
#  message:  [4]  output:  2  epoch no:  6400  avg reward 0.33666666666666667
#  epoch no:  6400  avg reward 0.33666666666666667
# hi
# hi
#  message:  [6]  output:  1  epoch no:  6500  avg reward 0.32
#  epoch no:  6500  avg reward 0.32
# hi
# hi
#  message:  [8]  output:  1  epoch no:  6600  avg reward 0.31666666666666665
#  epoch no:  6600  avg reward 0.31666666666666665
# hi
# hi
#  message:  [8]  output:  2  epoch no:  6700  avg reward 0.3566666666666667
#  epoch no:  6700  avg reward 0.3566666666666667
# hi
# hi
#  message:  [8]  output:  0  epoch no:  6800  avg reward 0.36666666666666664
#  epoch no:  6800  avg reward 0.36666666666666664
# hi
# hi
#  message:  [7]  output:  1  epoch no:  6900  avg reward 0.335
#  epoch no:  6900  avg reward 0.335
# hi
# hi
#  message:  [2]  output:  2  epoch no:  7000  avg reward 0.3333333333333333
#  epoch no:  7000  avg reward 0.3333333333333333
# hi
# hi
#  message:  [6]  output:  1  epoch no:  7100  avg reward 0.3383333333333333
#  epoch no:  7100  avg reward 0.3383333333333333
# hi
# hi
#  message:  [4]  output:  0  epoch no:  7200  avg reward 0.3466666666666667
#  epoch no:  7200  avg reward 0.3466666666666667
# hi
# hi
#  message:  [6]  output:  0  epoch no:  7300  avg reward 0.355
#  epoch no:  7300  avg reward 0.355
# hi
# hi
#  message:  [7]  output:  2  epoch no:  7400  avg reward 0.3333333333333333
#  epoch no:  7400  avg reward 0.3333333333333333
# hi
# hi
#  message:  [3]  output:  1  epoch no:  7500  avg reward 0.3416666666666667
#  epoch no:  7500  avg reward 0.3416666666666667
# hi
# hi
#  message:  [4]  output:  0  epoch no:  7600  avg reward 0.31833333333333336
#  epoch no:  7600  avg reward 0.31833333333333336
# hi
# hi
#  message:  [3]  output:  2  epoch no:  7700  avg reward 0.3466666666666667
#  epoch no:  7700  avg reward 0.3466666666666667
# hi
# hi
#  message:  [7]  output:  2  epoch no:  7800  avg reward 0.335
#  epoch no:  7800  avg reward 0.335
# hi
# hi
#  message:  [7]  output:  2  epoch no:  7900  avg reward 0.32166666666666666
#  epoch no:  7900  avg reward 0.32166666666666666
# hi
# hi
#  message:  [3]  output:  2  epoch no:  8000  avg reward 0.3516666666666667
#  epoch no:  8000  avg reward 0.3516666666666667
# hi
# hi
#  message:  [4]  output:  0  epoch no:  8100  avg reward 0.36333333333333334
#  epoch no:  8100  avg reward 0.36333333333333334
# hi
# hi
#  message:  [2]  output:  0  epoch no:  8200  avg reward 0.32166666666666666
#  epoch no:  8200  avg reward 0.32166666666666666
# hi
# hi
#  message:  [2]  output:  1  epoch no:  8300  avg reward 0.31
#  epoch no:  8300  avg reward 0.31
# hi
# hi
#  message:  [2]  output:  0  epoch no:  8400  avg reward 0.31166666666666665
#  epoch no:  8400  avg reward 0.31166666666666665
# hi
# hi
#  message:  [8]  output:  2  epoch no:  8500  avg reward 0.335
#  epoch no:  8500  avg reward 0.335
# hi
# hi
#  message:  [9]  output:  0  epoch no:  8600  avg reward 0.30333333333333334
#  epoch no:  8600  avg reward 0.30333333333333334
# hi
# hi
#  message:  [3]  output:  1  epoch no:  8700  avg reward 0.325
#  epoch no:  8700  avg reward 0.325
# hi
# hi
#  message:  [6]  output:  2  epoch no:  8800  avg reward 0.315
#  epoch no:  8800  avg reward 0.315
# hi
# hi
#  message:  [7]  output:  0  epoch no:  8900  avg reward 0.30333333333333334
#  epoch no:  8900  avg reward 0.30333333333333334
# hi
# hi
#  message:  [3]  output:  1  epoch no:  9000  avg reward 0.3016666666666667
#  epoch no:  9000  avg reward 0.3016666666666667
# hi
# hi
#  message:  [0]  output:  0  epoch no:  9100  avg reward 0.3333333333333333
#  epoch no:  9100  avg reward 0.3333333333333333
# hi
# hi
#  message:  [2]  output:  2  epoch no:  9200  avg reward 0.3416666666666667
#  epoch no:  9200  avg reward 0.3416666666666667
# hi
# hi
#  message:  [2]  output:  0  epoch no:  9300  avg reward 0.35333333333333333
#  epoch no:  9300  avg reward 0.35333333333333333
# hi
# hi
#  message:  [6]  output:  1  epoch no:  9400  avg reward 0.365
#  epoch no:  9400  avg reward 0.365
# hi
# hi
#  message:  [6]  output:  0  epoch no:  9500  avg reward 0.31666666666666665
#  epoch no:  9500  avg reward 0.31666666666666665
# hi
# hi
#  message:  [3]  output:  1  epoch no:  9600  avg reward 0.32
#  epoch no:  9600  avg reward 0.32
# hi
# hi
#  message:  [3]  output:  1  epoch no:  9700  avg reward 0.335
#  epoch no:  9700  avg reward 0.335
# hi
# hi
#  message:  [5]  output:  0  epoch no:  9800  avg reward 0.325
#  epoch no:  9800  avg reward 0.325
# hi
# hi
#  message:  [6]  output:  0  epoch no:  9900  avg reward 0.34833333333333333
#  epoch no:  9900  avg reward 0.34833333333333333
# hi
# hi
#  message:  [7]  output:  0  epoch no:  10000  avg reward 0.31
#  epoch no:  10000  avg reward 0.31
# hi
# hi
#  message:  [7]  output:  1  epoch no:  10100  avg reward 0.34
#  epoch no:  10100  avg reward 0.34
# hi
# hi
#  message:  [8]  output:  0  epoch no:  10200  avg reward 0.32666666666666666
#  epoch no:  10200  avg reward 0.32666666666666666
# hi
# hi
#  message:  [3]  output:  0  epoch no:  10300  avg reward 0.31166666666666665
#  epoch no:  10300  avg reward 0.31166666666666665
# hi
# hi
#  message:  [7]  output:  1  epoch no:  10400  avg reward 0.33666666666666667
#  epoch no:  10400  avg reward 0.33666666666666667
# hi
# hi
#  message:  [3]  output:  1  epoch no:  10500  avg reward 0.36333333333333334
#  epoch no:  10500  avg reward 0.36333333333333334
# hi
# hi
#  message:  [7]  output:  0  epoch no:  10600  avg reward 0.36333333333333334
#  epoch no:  10600  avg reward 0.36333333333333334
# hi
# hi
#  message:  [7]  output:  1  epoch no:  10700  avg reward 0.34833333333333333
#  epoch no:  10700  avg reward 0.34833333333333333
# hi
# hi
#  message:  [8]  output:  2  epoch no:  10800  avg reward 0.355
#  epoch no:  10800  avg reward 0.355
# hi
# hi
#  message:  [8]  output:  2  epoch no:  10900  avg reward 0.39666666666666667
#  epoch no:  10900  avg reward 0.39666666666666667
# hi
# hi
#  message:  [7]  output:  0  epoch no:  11000  avg reward 0.40166666666666667
#  epoch no:  11000  avg reward 0.40166666666666667
# hi
# hi
#  message:  [7]  output:  0  epoch no:  11100  avg reward 0.36666666666666664
#  epoch no:  11100  avg reward 0.36666666666666664
# hi
# hi
#  message:  [2]  output:  2  epoch no:  11200  avg reward 0.36666666666666664
#  epoch no:  11200  avg reward 0.36666666666666664
# hi
# hi
#  message:  [2]  output:  2  epoch no:  11300  avg reward 0.37
#  epoch no:  11300  avg reward 0.37
# hi
# hi
#  message:  [7]  output:  1  epoch no:  11400  avg reward 0.4033333333333333
#  epoch no:  11400  avg reward 0.4033333333333333
# hi
# hi
#  message:  [8]  output:  1  epoch no:  11500  avg reward 0.36333333333333334
#  epoch no:  11500  avg reward 0.36333333333333334
# hi
# hi
#  message:  [3]  output:  0  epoch no:  11600  avg reward 0.4033333333333333
#  epoch no:  11600  avg reward 0.4033333333333333
# hi
# hi
#  message:  [8]  output:  0  epoch no:  11700  avg reward 0.39166666666666666
#  epoch no:  11700  avg reward 0.39166666666666666
# hi
# hi
#  message:  [8]  output:  2  epoch no:  11800  avg reward 0.4216666666666667
#  epoch no:  11800  avg reward 0.4216666666666667
# hi
# hi
#  message:  [8]  output:  0  epoch no:  11900  avg reward 0.425
#  epoch no:  11900  avg reward 0.425
# hi
# hi
#  message:  [6]  output:  2  epoch no:  12000  avg reward 0.37833333333333335
#  epoch no:  12000  avg reward 0.37833333333333335
# hi
# hi
#  message:  [2]  output:  0  epoch no:  12100  avg reward 0.39
#  epoch no:  12100  avg reward 0.39
# hi
# hi
#  message:  [2]  output:  1  epoch no:  12200  avg reward 0.4683333333333333
#  epoch no:  12200  avg reward 0.4683333333333333
# hi
# hi
#  message:  [8]  output:  2  epoch no:  12300  avg reward 0.45
#  epoch no:  12300  avg reward 0.45
# hi
# hi
#  message:  [2]  output:  0  epoch no:  12400  avg reward 0.44666666666666666
#  epoch no:  12400  avg reward 0.44666666666666666
# hi
# hi
#  message:  [2]  output:  2  epoch no:  12500  avg reward 0.44333333333333336
#  epoch no:  12500  avg reward 0.44333333333333336
# hi
# hi
#  message:  [8]  output:  0  epoch no:  12600  avg reward 0.48333333333333334
#  epoch no:  12600  avg reward 0.48333333333333334
# hi
# hi
#  message:  [1]  output:  0  epoch no:  12700  avg reward 0.4583333333333333
#  epoch no:  12700  avg reward 0.4583333333333333
# hi
# hi
#  message:  [9]  output:  2  epoch no:  12800  avg reward 0.47
#  epoch no:  12800  avg reward 0.47
# hi
# hi
#  message:  [6]  output:  0  epoch no:  12900  avg reward 0.4533333333333333
#  epoch no:  12900  avg reward 0.4533333333333333
# hi
# hi
#  message:  [6]  output:  2  epoch no:  13000  avg reward 0.4683333333333333
#  epoch no:  13000  avg reward 0.4683333333333333
# hi
# hi
#  message:  [8]  output:  2  epoch no:  13100  avg reward 0.4533333333333333
#  epoch no:  13100  avg reward 0.4533333333333333
# hi
# hi
#  message:  [9]  output:  2  epoch no:  13200  avg reward 0.4866666666666667
#  epoch no:  13200  avg reward 0.4866666666666667
# hi
# hi
#  message:  [8]  output:  2  epoch no:  13300  avg reward 0.475
#  epoch no:  13300  avg reward 0.475
# hi
# hi
#  message:  [1]  output:  0  epoch no:  13400  avg reward 0.4483333333333333
#  epoch no:  13400  avg reward 0.4483333333333333
# hi
# hi
#  message:  [1]  output:  1  epoch no:  13500  avg reward 0.4583333333333333
#  epoch no:  13500  avg reward 0.4583333333333333
# hi
# hi
#  message:  [8]  output:  2  epoch no:  13600  avg reward 0.4766666666666667
#  epoch no:  13600  avg reward 0.4766666666666667
# hi
# hi
#  message:  [2]  output:  0  epoch no:  13700  avg reward 0.5116666666666667
#  epoch no:  13700  avg reward 0.5116666666666667
# hi
# hi
#  message:  [2]  output:  2  epoch no:  13800  avg reward 0.5116666666666667
#  epoch no:  13800  avg reward 0.5116666666666667
# hi
# hi
#  message:  [2]  output:  2  epoch no:  13900  avg reward 0.475
#  epoch no:  13900  avg reward 0.475
# hi
# hi
#  message:  [2]  output:  1  epoch no:  14000  avg reward 0.49666666666666665
#  epoch no:  14000  avg reward 0.49666666666666665
# hi
# hi
#  message:  [7]  output:  0  epoch no:  14100  avg reward 0.49
#  epoch no:  14100  avg reward 0.49
# hi
# hi
#  message:  [6]  output:  1  epoch no:  14200  avg reward 0.5283333333333333
#  epoch no:  14200  avg reward 0.5283333333333333
# hi
# hi
#  message:  [8]  output:  0  epoch no:  14300  avg reward 0.54
#  epoch no:  14300  avg reward 0.54
# hi
# hi
#  message:  [8]  output:  0  epoch no:  14400  avg reward 0.5066666666666667
#  epoch no:  14400  avg reward 0.5066666666666667
# hi
# hi
#  message:  [1]  output:  2  epoch no:  14500  avg reward 0.4683333333333333
#  epoch no:  14500  avg reward 0.4683333333333333
# hi
# hi
#  message:  [1]  output:  1  epoch no:  14600  avg reward 0.5033333333333333
#  epoch no:  14600  avg reward 0.5033333333333333
# hi
# hi
#  message:  [8]  output:  2  epoch no:  14700  avg reward 0.49
#  epoch no:  14700  avg reward 0.49
# hi
# hi
#  message:  [8]  output:  2  epoch no:  14800  avg reward 0.46
#  epoch no:  14800  avg reward 0.46
# hi
# hi
#  message:  [6]  output:  1  epoch no:  14900  avg reward 0.46
#  epoch no:  14900  avg reward 0.46
# hi
# hi
#  message:  [2]  output:  0  epoch no:  15000  avg reward 0.515
#  epoch no:  15000  avg reward 0.515
# hi
# hi
#  message:  [2]  output:  2  epoch no:  15100  avg reward 0.5083333333333333
#  epoch no:  15100  avg reward 0.5083333333333333
# hi
# hi
#  message:  [8]  output:  2  epoch no:  15200  avg reward 0.5083333333333333
#  epoch no:  15200  avg reward 0.5083333333333333
# hi
# hi
#  message:  [1]  output:  1  epoch no:  15300  avg reward 0.4816666666666667
#  epoch no:  15300  avg reward 0.4816666666666667
# hi
# hi
#  message:  [7]  output:  2  epoch no:  15400  avg reward 0.5533333333333333
#  epoch no:  15400  avg reward 0.5533333333333333
# hi
# hi
#  message:  [2]  output:  2  epoch no:  15500  avg reward 0.5116666666666667
#  epoch no:  15500  avg reward 0.5116666666666667
# hi
# hi
#  message:  [6]  output:  1  epoch no:  15600  avg reward 0.49833333333333335
#  epoch no:  15600  avg reward 0.49833333333333335
# hi
# hi
#  message:  [2]  output:  2  epoch no:  15700  avg reward 0.555
#  epoch no:  15700  avg reward 0.555
# hi
# hi
#  message:  [2]  output:  0  epoch no:  15800  avg reward 0.5233333333333333
#  epoch no:  15800  avg reward 0.5233333333333333
# hi
# hi
#  message:  [1]  output:  2  epoch no:  15900  avg reward 0.52
#  epoch no:  15900  avg reward 0.52
# hi
# hi
#  message:  [2]  output:  0  epoch no:  16000  avg reward 0.5033333333333333
#  epoch no:  16000  avg reward 0.5033333333333333
# hi
# hi
#  message:  [1]  output:  0  epoch no:  16100  avg reward 0.5183333333333333
#  epoch no:  16100  avg reward 0.5183333333333333
# hi
# hi
#  message:  [1]  output:  2  epoch no:  16200  avg reward 0.555
#  epoch no:  16200  avg reward 0.555
# hi
# hi
#  message:  [6]  output:  2  epoch no:  16300  avg reward 0.5366666666666666
#  epoch no:  16300  avg reward 0.5366666666666666
# hi
# hi
#  message:  [1]  output:  1  epoch no:  16400  avg reward 0.5216666666666666
#  epoch no:  16400  avg reward 0.5216666666666666
# hi
# hi
#  message:  [6]  output:  2  epoch no:  16500  avg reward 0.5583333333333333
#  epoch no:  16500  avg reward 0.5583333333333333
# hi
# hi
#  message:  [8]  output:  1  epoch no:  16600  avg reward 0.5433333333333333
#  epoch no:  16600  avg reward 0.5433333333333333
# hi
# hi
#  message:  [8]  output:  0  epoch no:  16700  avg reward 0.5333333333333333
#  epoch no:  16700  avg reward 0.5333333333333333
# hi
# hi
#  message:  [8]  output:  1  epoch no:  16800  avg reward 0.5566666666666666
#  epoch no:  16800  avg reward 0.5566666666666666
# hi
# hi
#  message:  [2]  output:  1  epoch no:  16900  avg reward 0.5933333333333334
#  epoch no:  16900  avg reward 0.5933333333333334
# hi
# hi
#  message:  [8]  output:  0  epoch no:  17000  avg reward 0.545
#  epoch no:  17000  avg reward 0.545
# hi
# hi
#  message:  [2]  output:  2  epoch no:  17100  avg reward 0.5666666666666667
#  epoch no:  17100  avg reward 0.5666666666666667
# hi
# hi
#  message:  [2]  output:  0  epoch no:  17200  avg reward 0.555
#  epoch no:  17200  avg reward 0.555
# hi
# hi
#  message:  [0]  output:  0  epoch no:  17300  avg reward 0.5566666666666666
#  epoch no:  17300  avg reward 0.5566666666666666
# hi
# hi
#  message:  [6]  output:  2  epoch no:  17400  avg reward 0.5716666666666667
#  epoch no:  17400  avg reward 0.5716666666666667
# hi
# hi
#  message:  [1]  output:  2  epoch no:  17500  avg reward 0.565
#  epoch no:  17500  avg reward 0.565
# hi
# hi
#  message:  [8]  output:  2  epoch no:  17600  avg reward 0.54
#  epoch no:  17600  avg reward 0.54
# hi
# hi
#  message:  [0]  output:  1  epoch no:  17700  avg reward 0.5066666666666667
#  epoch no:  17700  avg reward 0.5066666666666667
# hi
# hi
#  message:  [0]  output:  0  epoch no:  17800  avg reward 0.5816666666666667
#  epoch no:  17800  avg reward 0.5816666666666667
# hi
# hi
#  message:  [1]  output:  1  epoch no:  17900  avg reward 0.5533333333333333
#  epoch no:  17900  avg reward 0.5533333333333333
# hi
# hi
#  message:  [2]  output:  0  epoch no:  18000  avg reward 0.5566666666666666
#  epoch no:  18000  avg reward 0.5566666666666666
# hi
# hi
#  message:  [6]  output:  0  epoch no:  18100  avg reward 0.5433333333333333
#  epoch no:  18100  avg reward 0.5433333333333333
# hi
# hi
#  message:  [8]  output:  2  epoch no:  18200  avg reward 0.5866666666666667
#  epoch no:  18200  avg reward 0.5866666666666667
# hi
# hi
#  message:  [0]  output:  1  epoch no:  18300  avg reward 0.6166666666666667
#  epoch no:  18300  avg reward 0.6166666666666667
# hi
# hi
#  message:  [2]  output:  1  epoch no:  18400  avg reward 0.5616666666666666
#  epoch no:  18400  avg reward 0.5616666666666666
# hi
# hi
#  message:  [0]  output:  2  epoch no:  18500  avg reward 0.58
#  epoch no:  18500  avg reward 0.58
# hi
# hi
#  message:  [0]  output:  2  epoch no:  18600  avg reward 0.61
#  epoch no:  18600  avg reward 0.61
# hi
# hi
#  message:  [6]  output:  2  epoch no:  18700  avg reward 0.58
#  epoch no:  18700  avg reward 0.58
# hi
# hi
#  message:  [2]  output:  0  epoch no:  18800  avg reward 0.5733333333333334
#  epoch no:  18800  avg reward 0.5733333333333334
# hi
# hi
#  message:  [1]  output:  2  epoch no:  18900  avg reward 0.5583333333333333
#  epoch no:  18900  avg reward 0.5583333333333333
# hi
# hi
#  message:  [0]  output:  0  epoch no:  19000  avg reward 0.6366666666666667
#  epoch no:  19000  avg reward 0.6366666666666667
# hi
# hi
#  message:  [0]  output:  0  epoch no:  19100  avg reward 0.5716666666666667
#  epoch no:  19100  avg reward 0.5716666666666667
# hi
# hi
#  message:  [6]  output:  0  epoch no:  19200  avg reward 0.565
#  epoch no:  19200  avg reward 0.565
# hi
# hi
#  message:  [1]  output:  1  epoch no:  19300  avg reward 0.58
#  epoch no:  19300  avg reward 0.58
# hi
# hi
#  message:  [0]  output:  0  epoch no:  19400  avg reward 0.58
#  epoch no:  19400  avg reward 0.58
# hi
# hi
#  message:  [0]  output:  2  epoch no:  19500  avg reward 0.6533333333333333
#  epoch no:  19500  avg reward 0.6533333333333333
# hi
# hi
#  message:  [7]  output:  0  epoch no:  19600  avg reward 0.62
#  epoch no:  19600  avg reward 0.62
# hi
# hi
#  message:  [8]  output:  2  epoch no:  19700  avg reward 0.5516666666666666
#  epoch no:  19700  avg reward 0.5516666666666666
# hi
# hi
#  message:  [1]  output:  0  epoch no:  19800  avg reward 0.5783333333333334
#  epoch no:  19800  avg reward 0.5783333333333334
# hi
# hi
#  message:  [1]  output:  0  epoch no:  19900  avg reward 0.6016666666666667
#  epoch no:  19900  avg reward 0.6016666666666667
# hi
# hi
#  message:  [2]  output:  0  epoch no:  20000  avg reward 0.5516666666666666
#  epoch no:  20000  avg reward 0.5516666666666666
# hi
# hi
#  message:  [0]  output:  2  epoch no:  20100  avg reward 0.5883333333333334
#  epoch no:  20100  avg reward 0.5883333333333334
# hi
# hi
#  message:  [2]  output:  2  epoch no:  20200  avg reward 0.6033333333333334
#  epoch no:  20200  avg reward 0.6033333333333334
# hi
# hi
#  message:  [0]  output:  0  epoch no:  20300  avg reward 0.5716666666666667
#  epoch no:  20300  avg reward 0.5716666666666667
# hi
# hi
#  message:  [7]  output:  2  epoch no:  20400  avg reward 0.61
#  epoch no:  20400  avg reward 0.61
# hi
# hi
#  message:  [1]  output:  0  epoch no:  20500  avg reward 0.6533333333333333
#  epoch no:  20500  avg reward 0.6533333333333333
# hi
# hi
#  message:  [0]  output:  2  epoch no:  20600  avg reward 0.605
#  epoch no:  20600  avg reward 0.605
# hi
# hi
#  message:  [6]  output:  0  epoch no:  20700  avg reward 0.5866666666666667
#  epoch no:  20700  avg reward 0.5866666666666667
# hi
# hi
#  message:  [4]  output:  2  epoch no:  20800  avg reward 0.6233333333333333
#  epoch no:  20800  avg reward 0.6233333333333333
# hi
# hi
#  message:  [8]  output:  2  epoch no:  20900  avg reward 0.6133333333333333
#  epoch no:  20900  avg reward 0.6133333333333333
# hi
# hi
#  message:  [0]  output:  1  epoch no:  21000  avg reward 0.5933333333333334
#  epoch no:  21000  avg reward 0.5933333333333334
# hi
# hi
#  message:  [7]  output:  2  epoch no:  21100  avg reward 0.615
#  epoch no:  21100  avg reward 0.615
# hi
# hi
#  message:  [8]  output:  2  epoch no:  21200  avg reward 0.62
#  epoch no:  21200  avg reward 0.62
# hi
# hi
#  message:  [2]  output:  0  epoch no:  21300  avg reward 0.5633333333333334
#  epoch no:  21300  avg reward 0.5633333333333334
# hi
# hi
#  message:  [9]  output:  2  epoch no:  21400  avg reward 0.5633333333333334
#  epoch no:  21400  avg reward 0.5633333333333334
# hi
# hi
#  message:  [6]  output:  2  epoch no:  21500  avg reward 0.6233333333333333
#  epoch no:  21500  avg reward 0.6233333333333333
# hi
# hi
#  message:  [2]  output:  0  epoch no:  21600  avg reward 0.59
#  epoch no:  21600  avg reward 0.59
# hi
# hi
#  message:  [6]  output:  2  epoch no:  21700  avg reward 0.5966666666666667
#  epoch no:  21700  avg reward 0.5966666666666667
# hi
# hi
#  message:  [1]  output:  0  epoch no:  21800  avg reward 0.6233333333333333
#  epoch no:  21800  avg reward 0.6233333333333333
# hi
# hi
#  message:  [9]  output:  0  epoch no:  21900  avg reward 0.6216666666666667
#  epoch no:  21900  avg reward 0.6216666666666667
# hi
# hi
#  message:  [6]  output:  2  epoch no:  22000  avg reward 0.6066666666666667
#  epoch no:  22000  avg reward 0.6066666666666667
# hi
# hi
#  message:  [4]  output:  0  epoch no:  22100  avg reward 0.585
#  epoch no:  22100  avg reward 0.585
# hi
# hi
#  message:  [2]  output:  0  epoch no:  22200  avg reward 0.5716666666666667
#  epoch no:  22200  avg reward 0.5716666666666667
# hi
# hi
#  message:  [1]  output:  2  epoch no:  22300  avg reward 0.59
#  epoch no:  22300  avg reward 0.59
# hi
# hi
#  message:  [8]  output:  0  epoch no:  22400  avg reward 0.5633333333333334
#  epoch no:  22400  avg reward 0.5633333333333334
# hi
# hi
#  message:  [2]  output:  2  epoch no:  22500  avg reward 0.56
#  epoch no:  22500  avg reward 0.56
# hi
# hi
#  message:  [6]  output:  2  epoch no:  22600  avg reward 0.6183333333333333
#  epoch no:  22600  avg reward 0.6183333333333333
# hi
# hi
#  message:  [2]  output:  0  epoch no:  22700  avg reward 0.6283333333333333
#  epoch no:  22700  avg reward 0.6283333333333333
# hi
# hi
#  message:  [2]  output:  2  epoch no:  22800  avg reward 0.6133333333333333
#  epoch no:  22800  avg reward 0.6133333333333333
# hi
# hi
#  message:  [6]  output:  0  epoch no:  22900  avg reward 0.63
#  epoch no:  22900  avg reward 0.63
# hi
# hi
#  message:  [2]  output:  0  epoch no:  23000  avg reward 0.6066666666666667
#  epoch no:  23000  avg reward 0.6066666666666667
# hi
# hi
#  message:  [6]  output:  2  epoch no:  23100  avg reward 0.59
#  epoch no:  23100  avg reward 0.59
# hi
# hi
#  message:  [9]  output:  1  epoch no:  23200  avg reward 0.6516666666666666
#  epoch no:  23200  avg reward 0.6516666666666666
# hi
# hi
#  message:  [6]  output:  2  epoch no:  23300  avg reward 0.605
#  epoch no:  23300  avg reward 0.605
# hi
# hi
#  message:  [6]  output:  2  epoch no:  23400  avg reward 0.6233333333333333
#  epoch no:  23400  avg reward 0.6233333333333333
# hi
# hi
#  message:  [1]  output:  1  epoch no:  23500  avg reward 0.635
#  epoch no:  23500  avg reward 0.635
# hi
# hi
#  message:  [1]  output:  2  epoch no:  23600  avg reward 0.5983333333333334
#  epoch no:  23600  avg reward 0.5983333333333334
# hi
# hi
#  message:  [2]  output:  1  epoch no:  23700  avg reward 0.6166666666666667
#  epoch no:  23700  avg reward 0.6166666666666667
# hi
# hi
#  message:  [9]  output:  0  epoch no:  23800  avg reward 0.6166666666666667
#  epoch no:  23800  avg reward 0.6166666666666667
# hi
# hi
#  message:  [0]  output:  1  epoch no:  23900  avg reward 0.65
#  epoch no:  23900  avg reward 0.65
# hi
# hi
#  message:  [0]  output:  2  epoch no:  24000  avg reward 0.61
#  epoch no:  24000  avg reward 0.61
# hi
# hi
#  message:  [6]  output:  2  epoch no:  24100  avg reward 0.6766666666666666
#  epoch no:  24100  avg reward 0.6766666666666666
# hi
# hi
#  message:  [0]  output:  1  epoch no:  24200  avg reward 0.6233333333333333
#  epoch no:  24200  avg reward 0.6233333333333333
# hi
# hi
#  message:  [0]  output:  2  epoch no:  24300  avg reward 0.6333333333333333
#  epoch no:  24300  avg reward 0.6333333333333333
# hi
# hi
#  message:  [6]  output:  2  epoch no:  24400  avg reward 0.6733333333333333
#  epoch no:  24400  avg reward 0.6733333333333333
# hi
# hi
#  message:  [6]  output:  1  epoch no:  24500  avg reward 0.63
#  epoch no:  24500  avg reward 0.63
# hi
# hi
#  message:  [9]  output:  0  epoch no:  24600  avg reward 0.6366666666666667
#  epoch no:  24600  avg reward 0.6366666666666667
# hi
# hi
#  message:  [6]  output:  1  epoch no:  24700  avg reward 0.6666666666666666
#  epoch no:  24700  avg reward 0.6666666666666666
# hi
# hi
#  message:  [8]  output:  0  epoch no:  24800  avg reward 0.64
#  epoch no:  24800  avg reward 0.64
# hi
# hi
#  message:  [1]  output:  1  epoch no:  24900  avg reward 0.64
#  epoch no:  24900  avg reward 0.64
# hi
# hi
#  message:  [2]  output:  2  epoch no:  25000  avg reward 0.685
#  epoch no:  25000  avg reward 0.685
# hi
# hi
#  message:  [9]  output:  0  epoch no:  25100  avg reward 0.6733333333333333
#  epoch no:  25100  avg reward 0.6733333333333333
# hi
# hi
#  message:  [0]  output:  2  epoch no:  25200  avg reward 0.6383333333333333
#  epoch no:  25200  avg reward 0.6383333333333333
# hi
# hi
#  message:  [1]  output:  1  epoch no:  25300  avg reward 0.6333333333333333
#  epoch no:  25300  avg reward 0.6333333333333333
# hi
# hi
#  message:  [8]  output:  2  epoch no:  25400  avg reward 0.6416666666666667
#  epoch no:  25400  avg reward 0.6416666666666667
# hi
# hi
#  message:  [0]  output:  2  epoch no:  25500  avg reward 0.6433333333333333
#  epoch no:  25500  avg reward 0.6433333333333333
# hi
# hi
#  message:  [0]  output:  2  epoch no:  25600  avg reward 0.6733333333333333
#  epoch no:  25600  avg reward 0.6733333333333333
# hi
# hi
#  message:  [5]  output:  0  epoch no:  25700  avg reward 0.6833333333333333
#  epoch no:  25700  avg reward 0.6833333333333333
# hi
# hi
#  message:  [0]  output:  1  epoch no:  25800  avg reward 0.675
#  epoch no:  25800  avg reward 0.675
# hi
# hi
#  message:  [8]  output:  0  epoch no:  25900  avg reward 0.6316666666666667
#  epoch no:  25900  avg reward 0.6316666666666667
# hi
# hi
#  message:  [2]  output:  0  epoch no:  26000  avg reward 0.6466666666666666
#  epoch no:  26000  avg reward 0.6466666666666666
# hi
# hi
#  message:  [0]  output:  0  epoch no:  26100  avg reward 0.6933333333333334
#  epoch no:  26100  avg reward 0.6933333333333334
# hi
# hi
#  message:  [2]  output:  1  epoch no:  26200  avg reward 0.6516666666666666
#  epoch no:  26200  avg reward 0.6516666666666666
# hi
# hi
#  message:  [0]  output:  0  epoch no:  26300  avg reward 0.6933333333333334
#  epoch no:  26300  avg reward 0.6933333333333334
# hi
# hi
#  message:  [0]  output:  0  epoch no:  26400  avg reward 0.665
#  epoch no:  26400  avg reward 0.665
# hi
# hi
#  message:  [6]  output:  2  epoch no:  26500  avg reward 0.6766666666666666
#  epoch no:  26500  avg reward 0.6766666666666666
# hi
# hi
#  message:  [2]  output:  2  epoch no:  26600  avg reward 0.64
#  epoch no:  26600  avg reward 0.64
# hi
# hi
#  message:  [2]  output:  0  epoch no:  26700  avg reward 0.66
#  epoch no:  26700  avg reward 0.66
# hi
# hi
#  message:  [0]  output:  2  epoch no:  26800  avg reward 0.6533333333333333
#  epoch no:  26800  avg reward 0.6533333333333333
# hi
# hi
#  message:  [0]  output:  0  epoch no:  26900  avg reward 0.6483333333333333
#  epoch no:  26900  avg reward 0.6483333333333333
# hi
# hi
#  message:  [2]  output:  2  epoch no:  27000  avg reward 0.6466666666666666
#  epoch no:  27000  avg reward 0.6466666666666666
# hi
# hi
#  message:  [7]  output:  0  epoch no:  27100  avg reward 0.6666666666666666
#  epoch no:  27100  avg reward 0.6666666666666666
# hi
# hi
#  message:  [1]  output:  0  epoch no:  27200  avg reward 0.6783333333333333
#  epoch no:  27200  avg reward 0.6783333333333333
# hi
# hi
#  message:  [9]  output:  2  epoch no:  27300  avg reward 0.6716666666666666
#  epoch no:  27300  avg reward 0.6716666666666666
# hi
# hi
#  message:  [2]  output:  0  epoch no:  27400  avg reward 0.6833333333333333
#  epoch no:  27400  avg reward 0.6833333333333333
# hi
# hi
#  message:  [2]  output:  0  epoch no:  27500  avg reward 0.6616666666666666
#  epoch no:  27500  avg reward 0.6616666666666666
# hi
# hi
#  message:  [6]  output:  2  epoch no:  27600  avg reward 0.6783333333333333
#  epoch no:  27600  avg reward 0.6783333333333333
# hi
# hi
#  message:  [8]  output:  0  epoch no:  27700  avg reward 0.6383333333333333
#  epoch no:  27700  avg reward 0.6383333333333333
# hi
# hi
#  message:  [2]  output:  1  epoch no:  27800  avg reward 0.6633333333333333
#  epoch no:  27800  avg reward 0.6633333333333333
# hi
# hi
#  message:  [1]  output:  0  epoch no:  27900  avg reward 0.6266666666666667
#  epoch no:  27900  avg reward 0.6266666666666667
# hi
# hi
#  message:  [0]  output:  1  epoch no:  28000  avg reward 0.655
#  epoch no:  28000  avg reward 0.655
# hi
# hi
#  message:  [6]  output:  0  epoch no:  28100  avg reward 0.6716666666666666
#  epoch no:  28100  avg reward 0.6716666666666666
# hi
# hi
#  message:  [2]  output:  0  epoch no:  28200  avg reward 0.715
#  epoch no:  28200  avg reward 0.715
# hi
# hi
#  message:  [0]  output:  2  epoch no:  28300  avg reward 0.6383333333333333
#  epoch no:  28300  avg reward 0.6383333333333333
# hi
# hi
#  message:  [2]  output:  2  epoch no:  28400  avg reward 0.6833333333333333
#  epoch no:  28400  avg reward 0.6833333333333333
# hi
# hi
#  message:  [2]  output:  0  epoch no:  28500  avg reward 0.675
#  epoch no:  28500  avg reward 0.675
# hi
# hi
#  message:  [7]  output:  2  epoch no:  28600  avg reward 0.6633333333333333
#  epoch no:  28600  avg reward 0.6633333333333333
# hi
# hi
#  message:  [6]  output:  0  epoch no:  28700  avg reward 0.6716666666666666
#  epoch no:  28700  avg reward 0.6716666666666666
# hi
# hi
#  message:  [0]  output:  1  epoch no:  28800  avg reward 0.6916666666666667
#  epoch no:  28800  avg reward 0.6916666666666667
# hi
# hi
#  message:  [0]  output:  1  epoch no:  28900  avg reward 0.6583333333333333
#  epoch no:  28900  avg reward 0.6583333333333333
# hi
# hi
#  message:  [1]  output:  0  epoch no:  29000  avg reward 0.6816666666666666
#  epoch no:  29000  avg reward 0.6816666666666666
# hi
# hi
#  message:  [0]  output:  2  epoch no:  29100  avg reward 0.6516666666666666
#  epoch no:  29100  avg reward 0.6516666666666666
# hi
# hi
#  message:  [9]  output:  1  epoch no:  29200  avg reward 0.7016666666666667
#  epoch no:  29200  avg reward 0.7016666666666667
# hi
# hi
#  message:  [0]  output:  1  epoch no:  29300  avg reward 0.6783333333333333
#  epoch no:  29300  avg reward 0.6783333333333333
# hi
# hi
#  message:  [7]  output:  2  epoch no:  29400  avg reward 0.675
#  epoch no:  29400  avg reward 0.675
# hi
# hi
#  message:  [5]  output:  0  epoch no:  29500  avg reward 0.6933333333333334
#  epoch no:  29500  avg reward 0.6933333333333334
# hi
# hi
#  message:  [4]  output:  0  epoch no:  29600  avg reward 0.6716666666666666
#  epoch no:  29600  avg reward 0.6716666666666666
# hi
# hi
#  message:  [0]  output:  0  epoch no:  29700  avg reward 0.6916666666666667
#  epoch no:  29700  avg reward 0.6916666666666667
# hi
# hi
#  message:  [2]  output:  0  epoch no:  29800  avg reward 0.6583333333333333
#  epoch no:  29800  avg reward 0.6583333333333333
# hi
# hi
#  message:  [0]  output:  0  epoch no:  29900  avg reward 0.675
#  epoch no:  29900  avg reward 0.675
# hi
# hi
#  message:  [0]  output:  1  epoch no:  30000  avg reward 0.68
#  epoch no:  30000  avg reward 0.68
# hi
# hi
#  message:  [8]  output:  0  epoch no:  30100  avg reward 0.6533333333333333
#  epoch no:  30100  avg reward 0.6533333333333333
# hi
# hi
#  message:  [0]  output:  2  epoch no:  30200  avg reward 0.6883333333333334
#  epoch no:  30200  avg reward 0.6883333333333334
# hi
# hi
#  message:  [6]  output:  2  epoch no:  30300  avg reward 0.6416666666666667
#  epoch no:  30300  avg reward 0.6416666666666667
# hi
# hi
#  message:  [0]  output:  2  epoch no:  30400  avg reward 0.715
#  epoch no:  30400  avg reward 0.715
# hi
# hi
#  message:  [6]  output:  1  epoch no:  30500  avg reward 0.66
#  epoch no:  30500  avg reward 0.66
# hi
# hi
#  message:  [0]  output:  0  epoch no:  30600  avg reward 0.6683333333333333
#  epoch no:  30600  avg reward 0.6683333333333333
# hi
# hi
#  message:  [0]  output:  1  epoch no:  30700  avg reward 0.665
#  epoch no:  30700  avg reward 0.665
# hi
# hi
#  message:  [6]  output:  1  epoch no:  30800  avg reward 0.6816666666666666
#  epoch no:  30800  avg reward 0.6816666666666666
# hi
# hi
#  message:  [1]  output:  0  epoch no:  30900  avg reward 0.67
#  epoch no:  30900  avg reward 0.67
# hi
# hi
#  message:  [0]  output:  2  epoch no:  31000  avg reward 0.6866666666666666
#  epoch no:  31000  avg reward 0.6866666666666666
# hi
# hi
#  message:  [0]  output:  2  epoch no:  31100  avg reward 0.6866666666666666
#  epoch no:  31100  avg reward 0.6866666666666666
# hi
# hi
#  message:  [0]  output:  1  epoch no:  31200  avg reward 0.6683333333333333
#  epoch no:  31200  avg reward 0.6683333333333333
# hi
# hi
#  message:  [1]  output:  2  epoch no:  31300  avg reward 0.705
#  epoch no:  31300  avg reward 0.705
# hi
# hi
#  message:  [0]  output:  0  epoch no:  31400  avg reward 0.6966666666666667
#  epoch no:  31400  avg reward 0.6966666666666667
# hi
# hi
#  message:  [2]  output:  1  epoch no:  31500  avg reward 0.655
#  epoch no:  31500  avg reward 0.655
# hi
# hi
#  message:  [0]  output:  0  epoch no:  31600  avg reward 0.705
#  epoch no:  31600  avg reward 0.705
# hi
# hi
#  message:  [2]  output:  0  epoch no:  31700  avg reward 0.7
#  epoch no:  31700  avg reward 0.7
# hi
# hi
#  message:  [0]  output:  0  epoch no:  31800  avg reward 0.7083333333333334
#  epoch no:  31800  avg reward 0.7083333333333334
# hi
# hi
#  message:  [1]  output:  1  epoch no:  31900  avg reward 0.715
#  epoch no:  31900  avg reward 0.715
# hi
# hi
#  message:  [1]  output:  0  epoch no:  32000  avg reward 0.7
#  epoch no:  32000  avg reward 0.7
# hi
# hi
#  message:  [1]  output:  1  epoch no:  32100  avg reward 0.6933333333333334
#  epoch no:  32100  avg reward 0.6933333333333334
# hi
# hi
#  message:  [9]  output:  0  epoch no:  32200  avg reward 0.6916666666666667
#  epoch no:  32200  avg reward 0.6916666666666667
# hi
# hi
#  message:  [1]  output:  1  epoch no:  32300  avg reward 0.6916666666666667
#  epoch no:  32300  avg reward 0.6916666666666667
# hi
# hi
#  message:  [2]  output:  1  epoch no:  32400  avg reward 0.68
#  epoch no:  32400  avg reward 0.68
# hi
# hi
#  message:  [1]  output:  0  epoch no:  32500  avg reward 0.6966666666666667
#  epoch no:  32500  avg reward 0.6966666666666667
# hi
# hi
#  message:  [0]  output:  1  epoch no:  32600  avg reward 0.6683333333333333
#  epoch no:  32600  avg reward 0.6683333333333333
# hi
# hi
#  message:  [2]  output:  1  epoch no:  32700  avg reward 0.705
#  epoch no:  32700  avg reward 0.705
# hi
# hi
#  message:  [2]  output:  0  epoch no:  32800  avg reward 0.6933333333333334
#  epoch no:  32800  avg reward 0.6933333333333334
# hi
# hi
#  message:  [1]  output:  2  epoch no:  32900  avg reward 0.6833333333333333
#  epoch no:  32900  avg reward 0.6833333333333333
# hi
# hi
#  message:  [2]  output:  1  epoch no:  33000  avg reward 0.6683333333333333
#  epoch no:  33000  avg reward 0.6683333333333333
# hi
# hi
#  message:  [9]  output:  2  epoch no:  33100  avg reward 0.6966666666666667
#  epoch no:  33100  avg reward 0.6966666666666667
# hi
# hi
#  message:  [2]  output:  2  epoch no:  33200  avg reward 0.72
#  epoch no:  33200  avg reward 0.72
# hi
# hi
#  message:  [0]  output:  1  epoch no:  33300  avg reward 0.6983333333333334
#  epoch no:  33300  avg reward 0.6983333333333334
# hi
# hi
#  message:  [0]  output:  2  epoch no:  33400  avg reward 0.7016666666666667
#  epoch no:  33400  avg reward 0.7016666666666667
# hi
# hi
#  message:  [0]  output:  0  epoch no:  33500  avg reward 0.685
#  epoch no:  33500  avg reward 0.685
# hi
# hi
#  message:  [0]  output:  2  epoch no:  33600  avg reward 0.7183333333333334
#  epoch no:  33600  avg reward 0.7183333333333334
# hi
# hi
#  message:  [9]  output:  1  epoch no:  33700  avg reward 0.7066666666666667
#  epoch no:  33700  avg reward 0.7066666666666667
# hi
# hi
#  message:  [0]  output:  0  epoch no:  33800  avg reward 0.6433333333333333
#  epoch no:  33800  avg reward 0.6433333333333333
# hi
# hi
#  message:  [2]  output:  1  epoch no:  33900  avg reward 0.7133333333333334
#  epoch no:  33900  avg reward 0.7133333333333334
# hi
# hi
#  message:  [0]  output:  0  epoch no:  34000  avg reward 0.6766666666666666
#  epoch no:  34000  avg reward 0.6766666666666666
# hi
# hi
#  message:  [2]  output:  0  epoch no:  34100  avg reward 0.675
#  epoch no:  34100  avg reward 0.675
# hi
# hi
#  message:  [1]  output:  0  epoch no:  34200  avg reward 0.6366666666666667
#  epoch no:  34200  avg reward 0.6366666666666667
# hi
# hi
#  message:  [7]  output:  1  epoch no:  34300  avg reward 0.715
#  epoch no:  34300  avg reward 0.715
# hi
# hi
#  message:  [1]  output:  1  epoch no:  34400  avg reward 0.6733333333333333
#  epoch no:  34400  avg reward 0.6733333333333333
# hi
# hi
#  message:  [0]  output:  1  epoch no:  34500  avg reward 0.7316666666666667
#  epoch no:  34500  avg reward 0.7316666666666667
# hi
# hi
#  message:  [0]  output:  0  epoch no:  34600  avg reward 0.675
#  epoch no:  34600  avg reward 0.675
# hi
# hi
#  message:  [0]  output:  1  epoch no:  34700  avg reward 0.675
#  epoch no:  34700  avg reward 0.675
# hi
# hi
#  message:  [0]  output:  2  epoch no:  34800  avg reward 0.6783333333333333
#  epoch no:  34800  avg reward 0.6783333333333333
# hi
# hi
#  message:  [7]  output:  2  epoch no:  34900  avg reward 0.6666666666666666
#  epoch no:  34900  avg reward 0.6666666666666666
# hi
# hi
#  message:  [0]  output:  2  epoch no:  35000  avg reward 0.7233333333333334
#  epoch no:  35000  avg reward 0.7233333333333334
# hi
# hi
#  message:  [3]  output:  1  epoch no:  35100  avg reward 0.6733333333333333
#  epoch no:  35100  avg reward 0.6733333333333333
# hi
# hi
#  message:  [0]  output:  0  epoch no:  35200  avg reward 0.6483333333333333
#  epoch no:  35200  avg reward 0.6483333333333333
# hi
# hi
#  message:  [7]  output:  2  epoch no:  35300  avg reward 0.7033333333333334
#  epoch no:  35300  avg reward 0.7033333333333334
# hi
# hi
#  message:  [7]  output:  0  epoch no:  35400  avg reward 0.745
#  epoch no:  35400  avg reward 0.745
# hi
# hi
#  message:  [2]  output:  0  epoch no:  35500  avg reward 0.6816666666666666
#  epoch no:  35500  avg reward 0.6816666666666666
# hi
# hi
#  message:  [2]  output:  2  epoch no:  35600  avg reward 0.7216666666666667
#  epoch no:  35600  avg reward 0.7216666666666667
# hi
# hi
#  message:  [0]  output:  2  epoch no:  35700  avg reward 0.6883333333333334
#  epoch no:  35700  avg reward 0.6883333333333334
# hi
# hi
#  message:  [0]  output:  1  epoch no:  35800  avg reward 0.6983333333333334
#  epoch no:  35800  avg reward 0.6983333333333334
# hi
# hi
#  message:  [7]  output:  0  epoch no:  35900  avg reward 0.6966666666666667
#  epoch no:  35900  avg reward 0.6966666666666667
# hi
# hi
#  message:  [2]  output:  0  epoch no:  36000  avg reward 0.6783333333333333
#  epoch no:  36000  avg reward 0.6783333333333333
# hi
# hi
#  message:  [0]  output:  2  epoch no:  36100  avg reward 0.6916666666666667
#  epoch no:  36100  avg reward 0.6916666666666667
# hi
# hi
#  message:  [1]  output:  0  epoch no:  36200  avg reward 0.71
#  epoch no:  36200  avg reward 0.71
# hi
# hi
#  message:  [2]  output:  0  epoch no:  36300  avg reward 0.695
#  epoch no:  36300  avg reward 0.695
# hi
# hi
#  message:  [1]  output:  0  epoch no:  36400  avg reward 0.7066666666666667
#  epoch no:  36400  avg reward 0.7066666666666667
# hi
# hi
#  message:  [7]  output:  2  epoch no:  36500  avg reward 0.7033333333333334
#  epoch no:  36500  avg reward 0.7033333333333334
# hi
# hi
#  message:  [7]  output:  2  epoch no:  36600  avg reward 0.7083333333333334
#  epoch no:  36600  avg reward 0.7083333333333334
# hi
# hi
#  message:  [2]  output:  0  epoch no:  36700  avg reward 0.7183333333333334
#  epoch no:  36700  avg reward 0.7183333333333334
# hi
# hi
#  message:  [0]  output:  2  epoch no:  36800  avg reward 0.715
#  epoch no:  36800  avg reward 0.715
# hi
# hi
#  message:  [2]  output:  0  epoch no:  36900  avg reward 0.69
#  epoch no:  36900  avg reward 0.69
# hi
# hi
#  message:  [0]  output:  1  epoch no:  37000  avg reward 0.725
#  epoch no:  37000  avg reward 0.725
# hi
# hi
#  message:  [9]  output:  1  epoch no:  37100  avg reward 0.7083333333333334
#  epoch no:  37100  avg reward 0.7083333333333334
# hi
# hi
#  message:  [7]  output:  2  epoch no:  37200  avg reward 0.71
#  epoch no:  37200  avg reward 0.71
# hi
# hi
#  message:  [2]  output:  0  epoch no:  37300  avg reward 0.75
#  epoch no:  37300  avg reward 0.75
# hi
# hi
#  message:  [9]  output:  1  epoch no:  37400  avg reward 0.7233333333333334
#  epoch no:  37400  avg reward 0.7233333333333334
# hi
# hi
#  message:  [0]  output:  2  epoch no:  37500  avg reward 0.6866666666666666
#  epoch no:  37500  avg reward 0.6866666666666666
# hi
# hi
#  message:  [7]  output:  0  epoch no:  37600  avg reward 0.7166666666666667
#  epoch no:  37600  avg reward 0.7166666666666667
# hi
# hi
#  message:  [7]  output:  1  epoch no:  37700  avg reward 0.6983333333333334
#  epoch no:  37700  avg reward 0.6983333333333334
# hi
# hi
#  message:  [1]  output:  1  epoch no:  37800  avg reward 0.6883333333333334
#  epoch no:  37800  avg reward 0.6883333333333334
# hi
# hi
#  message:  [1]  output:  2  epoch no:  37900  avg reward 0.705
#  epoch no:  37900  avg reward 0.705
# hi
# hi
#  message:  [2]  output:  0  epoch no:  38000  avg reward 0.7033333333333334
#  epoch no:  38000  avg reward 0.7033333333333334
# hi
# hi
#  message:  [0]  output:  0  epoch no:  38100  avg reward 0.7216666666666667
#  epoch no:  38100  avg reward 0.7216666666666667
# hi
# hi
#  message:  [7]  output:  1  epoch no:  38200  avg reward 0.7066666666666667
#  epoch no:  38200  avg reward 0.7066666666666667
# hi
# hi
#  message:  [9]  output:  1  epoch no:  38300  avg reward 0.7183333333333334
#  epoch no:  38300  avg reward 0.7183333333333334
# hi
# hi
#  message:  [0]  output:  2  epoch no:  38400  avg reward 0.695
#  epoch no:  38400  avg reward 0.695
# hi
# hi
#  message:  [1]  output:  2  epoch no:  38500  avg reward 0.7416666666666667
#  epoch no:  38500  avg reward 0.7416666666666667
# hi
# hi
#  message:  [8]  output:  2  epoch no:  38600  avg reward 0.6916666666666667
#  epoch no:  38600  avg reward 0.6916666666666667
# hi
# hi
#  message:  [9]  output:  1  epoch no:  38700  avg reward 0.6716666666666666
#  epoch no:  38700  avg reward 0.6716666666666666
# hi
# hi
#  message:  [1]  output:  0  epoch no:  38800  avg reward 0.705
#  epoch no:  38800  avg reward 0.705
# hi
# hi
#  message:  [9]  output:  2  epoch no:  38900  avg reward 0.7083333333333334
#  epoch no:  38900  avg reward 0.7083333333333334
# hi
# hi
#  message:  [2]  output:  0  epoch no:  39000  avg reward 0.7083333333333334
#  epoch no:  39000  avg reward 0.7083333333333334
# hi
# hi
#  message:  [0]  output:  1  epoch no:  39100  avg reward 0.7266666666666667
#  epoch no:  39100  avg reward 0.7266666666666667
# hi
# hi
#  message:  [7]  output:  0  epoch no:  39200  avg reward 0.715
#  epoch no:  39200  avg reward 0.715
# hi
# hi
#  message:  [0]  output:  1  epoch no:  39300  avg reward 0.715
#  epoch no:  39300  avg reward 0.715
# hi
# hi
# ...
#  epoch no:  70400  avg reward 0.88
# hi
# hi
#  message:  [2]  output:  2  epoch no:  70500  avg reward 0.915
#  epoch no:  70500  avg reward 0.915
# hi
# hi
#  message:  [5]  output:  0  epoch no:  70600  avg reward 0.8933333333333333
#  epoch no:  70600  avg reward 0.8933333333333333
# hi
# hi
#  message:  [0]  output:  2  epoch no:  70700  avg reward 0.8866666666666667
#  epoch no:  70700  avg reward 0.8866666666666667
# hi
# hi
#  message:  [1]  output:  1  epoch no:  70800  avg reward 0.92
#  epoch no:  70800  avg reward 0.92
# hi
# hi
#  message:  [2]  output:  0  epoch no:  70900  avg reward 0.9166666666666666
#  epoch no:  70900  avg reward 0.9166666666666666
# hi
# hi
#  message:  [1]  output:  2  epoch no:  71000  avg reward 0.88
#  epoch no:  71000  avg reward 0.88
# hi
# hi
#  message:  [2]  output:  1  epoch no:  71100  avg reward 0.9083333333333333
#  epoch no:  71100  avg reward 0.9083333333333333
# hi
# hi
#  message:  [2]  output:  2  epoch no:  71200  avg reward 0.895
#  epoch no:  71200  avg reward 0.895
# hi
# hi
#  message:  [1]  output:  0  epoch no:  71300  avg reward 0.8883333333333333
#  epoch no:  71300  avg reward 0.8883333333333333
# hi
# hi
#  message:  [2]  output:  1  epoch no:  71400  avg reward 0.9
#  epoch no:  71400  avg reward 0.9
# hi
# hi
#  message:  [1]  output:  2  epoch no:  71500  avg reward 0.9
#  epoch no:  71500  avg reward 0.9
# hi
# hi
#  message:  [0]  output:  1  epoch no:  71600  avg reward 0.9083333333333333
#  epoch no:  71600  avg reward 0.9083333333333333
# hi
# hi
#  message:  [1]  output:  2  epoch no:  71700  avg reward 0.905
#  epoch no:  71700  avg reward 0.905
# hi
# hi
#  message:  [2]  output:  2  epoch no:  71800  avg reward 0.8933333333333333
#  epoch no:  71800  avg reward 0.8933333333333333
# hi
# hi
#  message:  [0]  output:  2  epoch no:  71900  avg reward 0.8766666666666667
#  epoch no:  71900  avg reward 0.8766666666666667
# hi
# hi
#  message:  [0]  output:  2  epoch no:  72000  avg reward 0.885
#  epoch no:  72000  avg reward 0.885
# hi
# hi
#  message:  [2]  output:  0  epoch no:  72100  avg reward 0.8983333333333333
#  epoch no:  72100  avg reward 0.8983333333333333
# hi
# hi
#  message:  [5]  output:  0  epoch no:  72200  avg reward 0.9133333333333333
#  epoch no:  72200  avg reward 0.9133333333333333
# hi
# hi
#  message:  [2]  output:  1  epoch no:  72300  avg reward 0.88
#  epoch no:  72300  avg reward 0.88
# hi
# hi
#  message:  [4]  output:  2  epoch no:  72400  avg reward 0.9083333333333333
#  epoch no:  72400  avg reward 0.9083333333333333
# hi
# hi
#  message:  [0]  output:  0  epoch no:  72500  avg reward 0.9083333333333333
#  epoch no:  72500  avg reward 0.9083333333333333
# hi
# hi
#  message:  [3]  output:  1  epoch no:  72600  avg reward 0.8916666666666667
#  epoch no:  72600  avg reward 0.8916666666666667
# hi
# hi
#  message:  [8]  output:  1  epoch no:  72700  avg reward 0.93
#  epoch no:  72700  avg reward 0.93
# hi
# hi
#  message:  [0]  output:  0  epoch no:  72800  avg reward 0.8733333333333333
#  epoch no:  72800  avg reward 0.8733333333333333
# hi
# hi
#  message:  [0]  output:  2  epoch no:  72900  avg reward 0.8933333333333333
#  epoch no:  72900  avg reward 0.8933333333333333
# hi
# hi
#  message:  [0]  output:  2  epoch no:  73000  avg reward 0.92
#  epoch no:  73000  avg reward 0.92
# hi
# hi
#  message:  [1]  output:  1  epoch no:  73100  avg reward 0.895
#  epoch no:  73100  avg reward 0.895
# hi
# hi
#  message:  [9]  output:  2  epoch no:  73200  avg reward 0.915
#  epoch no:  73200  avg reward 0.915
# hi
# hi
#  message:  [0]  output:  2  epoch no:  73300  avg reward 0.875
#  epoch no:  73300  avg reward 0.875
# hi
# hi
#  message:  [8]  output:  2  epoch no:  73400  avg reward 0.8816666666666667
#  epoch no:  73400  avg reward 0.8816666666666667
# hi
# hi
#  message:  [2]  output:  2  epoch no:  73500  avg reward 0.9033333333333333
#  epoch no:  73500  avg reward 0.9033333333333333
# hi
# hi
#  message:  [0]  output:  2  epoch no:  73600  avg reward 0.9033333333333333
#  epoch no:  73600  avg reward 0.9033333333333333
# hi
# hi
#  message:  [6]  output:  1  epoch no:  73700  avg reward 0.9066666666666666
#  epoch no:  73700  avg reward 0.9066666666666666
# hi
# hi
#  message:  [0]  output:  0  epoch no:  73800  avg reward 0.89
#  epoch no:  73800  avg reward 0.89
# hi
# hi
#  message:  [1]  output:  2  epoch no:  73900  avg reward 0.9066666666666666
#  epoch no:  73900  avg reward 0.9066666666666666
# hi
# hi
#  message:  [2]  output:  1  epoch no:  74000  avg reward 0.8916666666666667
#  epoch no:  74000  avg reward 0.8916666666666667
# hi
# hi
#  message:  [3]  output:  2  epoch no:  74100  avg reward 0.915
#  epoch no:  74100  avg reward 0.915
# hi
# hi
#  message:  [2]  output:  1  epoch no:  74200  avg reward 0.915
#  epoch no:  74200  avg reward 0.915
# hi
# hi
#  message:  [4]  output:  0  epoch no:  74300  avg reward 0.9083333333333333
#  epoch no:  74300  avg reward 0.9083333333333333
# hi
# hi
#  message:  [0]  output:  0  epoch no:  74400  avg reward 0.9016666666666666
#  epoch no:  74400  avg reward 0.9016666666666666
# hi
# hi
#  message:  [0]  output:  0  epoch no:  74500  avg reward 0.9116666666666666
#  epoch no:  74500  avg reward 0.9116666666666666
# hi
# hi
#  message:  [5]  output:  1  epoch no:  74600  avg reward 0.875
#  epoch no:  74600  avg reward 0.875
# hi
# hi
#  message:  [0]  output:  1  epoch no:  74700  avg reward 0.925
#  epoch no:  74700  avg reward 0.925
# hi
# hi
#  message:  [6]  output:  1  epoch no:  74800  avg reward 0.925
#  epoch no:  74800  avg reward 0.925
# hi
# hi
#  message:  [9]  output:  1  epoch no:  74900  avg reward 0.8883333333333333
#  epoch no:  74900  avg reward 0.8883333333333333
# hi
# hi
#  message:  [1]  output:  2  epoch no:  75000  avg reward 0.9083333333333333
#  epoch no:  75000  avg reward 0.9083333333333333
# hi
# hi
#  message:  [4]  output:  2  epoch no:  75100  avg reward 0.9166666666666666
#  epoch no:  75100  avg reward 0.9166666666666666
# hi
# hi
#  message:  [1]  output:  1  epoch no:  75200  avg reward 0.9133333333333333
#  epoch no:  75200  avg reward 0.9133333333333333
# hi
# hi
#  message:  [3]  output:  2  epoch no:  75300  avg reward 0.94
#  epoch no:  75300  avg reward 0.94
# hi
# hi
#  message:  [0]  output:  2  epoch no:  75400  avg reward 0.9216666666666666
#  epoch no:  75400  avg reward 0.9216666666666666
# hi
# hi
#  message:  [0]  output:  2  epoch no:  75500  avg reward 0.9166666666666666
#  epoch no:  75500  avg reward 0.9166666666666666
# hi
# hi
#  message:  [4]  output:  1  epoch no:  75600  avg reward 0.9083333333333333
#  epoch no:  75600  avg reward 0.9083333333333333
# hi
# hi
#  message:  [2]  output:  0  epoch no:  75700  avg reward 0.915
#  epoch no:  75700  avg reward 0.915
# hi
# hi
#  message:  [2]  output:  2  epoch no:  75800  avg reward 0.9333333333333333
#  epoch no:  75800  avg reward 0.9333333333333333
# hi
# hi
#  message:  [2]  output:  0  epoch no:  75900  avg reward 0.9416666666666667
#  epoch no:  75900  avg reward 0.9416666666666667
# hi
# hi
#  message:  [8]  output:  2  epoch no:  76000  avg reward 0.8766666666666667
#  epoch no:  76000  avg reward 0.8766666666666667
# hi
# hi
#  message:  [2]  output:  1  epoch no:  76100  avg reward 0.9083333333333333
#  epoch no:  76100  avg reward 0.9083333333333333
# hi
# hi
#  message:  [0]  output:  2  epoch no:  76200  avg reward 0.935
#  epoch no:  76200  avg reward 0.935
# hi
# hi
#  message:  [1]  output:  2  epoch no:  76300  avg reward 0.92
#  epoch no:  76300  avg reward 0.92
# hi
# hi
#  message:  [6]  output:  1  epoch no:  76400  avg reward 0.8933333333333333
#  epoch no:  76400  avg reward 0.8933333333333333
# hi
# hi
#  message:  [1]  output:  2  epoch no:  76500  avg reward 0.92
#  epoch no:  76500  avg reward 0.92
# hi
# hi
#  message:  [2]  output:  0  epoch no:  76600  avg reward 0.9133333333333333
#  epoch no:  76600  avg reward 0.9133333333333333
# hi
# hi
#  message:  [2]  output:  2  epoch no:  76700  avg reward 0.9216666666666666
#  epoch no:  76700  avg reward 0.9216666666666666
# hi
# hi
#  message:  [0]  output:  2  epoch no:  76800  avg reward 0.9383333333333334
#  epoch no:  76800  avg reward 0.9383333333333334
# hi
# hi
#  message:  [9]  output:  1  epoch no:  76900  avg reward 0.9066666666666666
#  epoch no:  76900  avg reward 0.9066666666666666
# hi
# hi
#  message:  [0]  output:  2  epoch no:  77000  avg reward 0.9266666666666666
#  epoch no:  77000  avg reward 0.9266666666666666
# hi
# hi
#  message:  [1]  output:  1  epoch no:  77100  avg reward 0.9016666666666666
#  epoch no:  77100  avg reward 0.9016666666666666
# hi
# hi
#  message:  [8]  output:  2  epoch no:  77200  avg reward 0.92
#  epoch no:  77200  avg reward 0.92
# hi
# hi
#  message:  [7]  output:  1  epoch no:  77300  avg reward 0.92
#  epoch no:  77300  avg reward 0.92
# hi
# hi
#  message:  [0]  output:  1  epoch no:  77400  avg reward 0.9283333333333333
#  epoch no:  77400  avg reward 0.9283333333333333
# hi
# hi
#  message:  [1]  output:  1  epoch no:  77500  avg reward 0.8966666666666666
#  epoch no:  77500  avg reward 0.8966666666666666
# hi
# hi
#  message:  [3]  output:  0  epoch no:  77600  avg reward 0.8966666666666666
#  epoch no:  77600  avg reward 0.8966666666666666
# hi
# hi
#  message:  [0]  output:  2  epoch no:  77700  avg reward 0.92
#  epoch no:  77700  avg reward 0.92
# hi
# hi
#  message:  [7]  output:  0  epoch no:  77800  avg reward 0.925
#  epoch no:  77800  avg reward 0.925
# hi
# hi
#  message:  [0]  output:  2  epoch no:  77900  avg reward 0.9333333333333333
#  epoch no:  77900  avg reward 0.9333333333333333
# hi
# hi
#  message:  [1]  output:  2  epoch no:  78000  avg reward 0.9283333333333333
#  epoch no:  78000  avg reward 0.9283333333333333
# hi
# hi
#  message:  [1]  output:  2  epoch no:  78100  avg reward 0.9266666666666666
#  epoch no:  78100  avg reward 0.9266666666666666
# hi
# hi
#  message:  [2]  output:  1  epoch no:  78200  avg reward 0.895
#  epoch no:  78200  avg reward 0.895
# hi
# hi
#  message:  [0]  output:  2  epoch no:  78300  avg reward 0.93
#  epoch no:  78300  avg reward 0.93
# hi
# hi
#  message:  [0]  output:  1  epoch no:  78400  avg reward 0.9216666666666666
#  epoch no:  78400  avg reward 0.9216666666666666
# hi
# hi
#  message:  [0]  output:  1  epoch no:  78500  avg reward 0.9233333333333333
#  epoch no:  78500  avg reward 0.9233333333333333
# hi
# hi
#  message:  [0]  output:  0  epoch no:  78600  avg reward 0.9466666666666667
#  epoch no:  78600  avg reward 0.9466666666666667
# hi
# hi
#  message:  [0]  output:  1  epoch no:  78700  avg reward 0.9033333333333333
#  epoch no:  78700  avg reward 0.9033333333333333
# hi
# hi
#  message:  [0]  output:  0  epoch no:  78800  avg reward 0.915
#  epoch no:  78800  avg reward 0.915
# hi
# hi
#  message:  [6]  output:  0  epoch no:  78900  avg reward 0.9116666666666666
#  epoch no:  78900  avg reward 0.9116666666666666
# hi
# hi
#  message:  [0]  output:  2  epoch no:  79000  avg reward 0.9366666666666666
#  epoch no:  79000  avg reward 0.9366666666666666
# hi
# hi
#  message:  [2]  output:  0  epoch no:  79100  avg reward 0.94
#  epoch no:  79100  avg reward 0.94
# hi
# hi
#  message:  [0]  output:  2  epoch no:  79200  avg reward 0.9266666666666666
#  epoch no:  79200  avg reward 0.9266666666666666
# hi
# hi
#  message:  [5]  output:  2  epoch no:  79300  avg reward 0.9366666666666666
#  epoch no:  79300  avg reward 0.9366666666666666
# hi
# hi
#  message:  [0]  output:  1  epoch no:  79400  avg reward 0.9383333333333334
#  epoch no:  79400  avg reward 0.9383333333333334
# hi
# hi
#  message:  [7]  output:  2  epoch no:  79500  avg reward 0.9316666666666666
#  epoch no:  79500  avg reward 0.9316666666666666
# hi
# hi
#  message:  [8]  output:  1  epoch no:  79600  avg reward 0.945
#  epoch no:  79600  avg reward 0.945
# hi
# hi
#  message:  [2]  output:  2  epoch no:  79700  avg reward 0.9083333333333333
#  epoch no:  79700  avg reward 0.9083333333333333
# hi
# hi
#  message:  [3]  output:  1  epoch no:  79800  avg reward 0.9283333333333333
#  epoch no:  79800  avg reward 0.9283333333333333
# hi
# hi
#  message:  [9]  output:  1  epoch no:  79900  avg reward 0.9133333333333333
#  epoch no:  79900  avg reward 0.9133333333333333
# hi
# hi
#  message:  [0]  output:  1  epoch no:  80000  avg reward 0.91
#  epoch no:  80000  avg reward 0.91
# hi
# hi
#  message:  [2]  output:  2  epoch no:  80100  avg reward 0.9616666666666667
#  epoch no:  80100  avg reward 0.9616666666666667
# hi
# hi
#  message:  [4]  output:  1  epoch no:  80200  avg reward 0.9033333333333333
#  epoch no:  80200  avg reward 0.9033333333333333
# hi
# hi
#  message:  [0]  output:  2  epoch no:  80300  avg reward 0.92
#  epoch no:  80300  avg reward 0.92
# hi
# hi
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-46-b58739b22edb> in <module>
#      49 # #                 feat = get_features([im])[0]
#      50 #                 feat = im.flatten()
# ---> 51         message = Speaker.act(states= game_pool[b].speaker_input(), independent=flip_s)  # (scalar between 0 and 4)
#      52         message_batch.append(message)
#      53 #             strokes.append(message)
#
# /usr/local/lib/python3.5/dist-packages/tensorforce/agents/agent.py in act(self, states, deterministic, independent, fetch_tensors, buffered)
#     146             internals=self.current_internals,
#     147             deterministic=deterministic,
# --> 148             independent=independent
#     149         )
#     150
#
# /usr/local/lib/python3.5/dist-packages/tensorforce/models/model.py in act(self, states, internals, deterministic, independent, fetch_tensors)
#    1391         )
#    1392
# -> 1393         fetch_list = self.monitored_session.run(fetches=fetches, feed_dict=feed_dict)
#    1394         actions, internals, timestep = fetch_list[0:3]
#    1395
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/training/monitored_session.py in run(self, fetches, feed_dict, options, run_metadata)
#     544                           feed_dict=feed_dict,
#     545                           options=options,
# --> 546                           run_metadata=run_metadata)
#     547
#     548   def run_step_fn(self, step_fn):
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/training/monitored_session.py in run(self, *args, **kwargs)
#    1096   def run(self, *args, **kwargs):
#    1097     try:
# -> 1098       return self._sess.run(*args, **kwargs)
#    1099     except _PREEMPTION_ERRORS:
#    1100       raise
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/training/monitored_session.py in run(self, fetches, feed_dict, options, run_metadata)
#    1168                                   feed_dict=feed_dict,
#    1169                                   options=options,
# -> 1170                                   run_metadata=run_metadata)
#    1171
#    1172     for hook in self._hooks:
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/training/monitored_session.py in run(self, *args, **kwargs)
#     948
#     949   def run(self, *args, **kwargs):
# --> 950     return self._sess.run(*args, **kwargs)
#     951
#     952   def run_step_fn(self, step_fn, raw_session, run_with_hooks):
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     903     try:
#     904       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 905                          run_metadata_ptr)
#     906       if run_metadata:
#     907         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1110
#    1111           if (not is_tensor_handle_feed and
# -> 1112               not subfeed_t.get_shape().is_compatible_with(np_val.shape)):
#    1113             raise ValueError('Cannot feed value of shape %r for Tensor %r, '
#    1114                              'which has shape %r' %
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/framework/tensor_shape.py in is_compatible_with(self, other)
#     742     other = as_shape(other)
#     743     if self._dims is not None and other.dims is not None:
# --> 744       if self.ndims != other.ndims:
#     745         return False
#     746       for x_dim, y_dim in zip(self._dims, other.dims):
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/framework/tensor_shape.py in ndims(self)
#     487     else:
#     488       if self._ndims is None:
# --> 489         self._ndims = len(self._dims)
#     490       return self._ndims
#     491
#
# KeyboardInterrupt:

# %%
len(result_common_mapping[5])
# Out:
# 110

# %%
### N population  actually 4
from collections import Counter

result_mapping = {i:[] for i in range(n_clusters)}
result_common_mapping = {i:[] for i in range(n_clusters)}
magic_moment = False
fig = plt.figure(figsize=(10, 10))
ax = fig.add_subplot(211)
ax2 = fig.add_subplot(212)
plt.ion()


fig.show()
fig.canvas.draw()
n_cl = n_clusters-2

def magic():
    global n_cl, n_clusters
    n_cl = n_clusters
    game_pool = []
    for i in range(n_batches):
        game_pool.append(Game(n_features, n_cl, n_samples, n_vocab, sender_type, [X1a, Y1a]))
    
    return game_pool
for i in range(n_epochs):
    Speaker = Speakers[np.random.choice(n_population)]
    Listener = Listeners[np.random.choice(n_population)]
    message_batch = []
    img_batch = []
    r = i%(2*freq)
    if r<1*freq:
        flip_s = False
        flip_l = True
    if r>=1*freq:
        flip_s = True
        flip_l = False
    l_rewards = []
    strokes = []
    for b in range(n_batches):
        strokes = []
#         for idx in range(2):
#             if idx ==0:
#                 feat = np.zeros((10,10), np.uint8)
#             else:
#                 im = message_to_image_sm(strokes, img_dim, img_dim)
# #                 feat = get_features([im])[0]
#                 feat = im.flatten()
        message = Speaker.act(states= game_pool[b].speaker_input(), independent=flip_s)  # (scalar between 0 and 4)
        message_batch.append(message)
#             strokes.append(message)
#         img = message_to_image(strokes, img_rows, img_cols)
#         img_batch.append(img)
#         Speaker.reset()

#     features_batch = get_features(intermediate_layer_model, img_batch)
#     message = Speaker.act(states= game_pool[b].speaker_input(feat), independent=flip_s)
    out_batch = []
    reward_batch = []
    for b in range(n_batches):
        out = Listener.act(states = game_pool[b].listener_input(message_batch[b]), independent = flip_l)
        out_batch.append(out)
        rew = game_pool[b].reward(out)
        reward_batch.append(rew)
        result_mapping[game_pool[b].nos[0]].append(message_batch[b][0])
        game_pool[b].reset()
        
    speaker_terminals = []
    rew_speaker = []
    for rew in reward_batch:
        speaker_terminals.extend([True])
        rew_speaker.extend([rew])

    if not flip_s:
#         print('e1')
        e1 = Speaker.model.observe(reward=rew_speaker, terminal=speaker_terminals)
    if not flip_l:
#         print('e2')
        e2 = Listener.model.observe(reward=reward_batch, terminal=[True]*n_batches)
#     assert e1 == e2
#     e = e1
    big_rewards.extend(reward_batch)
    big_rewards = big_rewards[-600:]
    if i%(100)==0:
#         print(" output: ", out)
        avg_rew = sum(big_rewards)/len(big_rewards)
        print(" message: ", message, " output: ", out, " epoch no: ", i, " avg reward", avg_rew)
        print(" epoch no: ", i, " avg reward", avg_rew)
        if avg_rew>.8 and not magic_moment:
            game_pool = magic()
            magic_moment = True
            val_now = i
            
        if(i!=0):
            data.append(avg_rew)
        ax.clear()
        ax.plot(data)
        ax2.clear()
        for cluster in range(n_cl):
            all_counts = result_mapping[cluster][-100:]
            if len(all_counts)<100:
                break
            most_common, n = Counter(all_counts).most_common(1)[0]
            
            result_common_mapping[cluster].append(most_common)
            
            if cluster>5:
                linestyle='--'
                ax2.plot(x=range(len(result_common_mapping[0]), len(result_common_mapping[0])+len(result_common_mapping[cluster])), y=result_common_mapping[cluster], linestyle=linestyle)
                
            else:
                linestyle='-'
                ax2.plot(result_common_mapping[cluster], linestyle=linestyle)

        if not flip_s:
            ax.set_xlabel('speaker')
        else:
            ax.set_xlabel('listener')
        fig.canvas.draw()


#     if sum(big_rewards)/len(big_rewards)>.75:
#         break
# Out:
# <img src="data:image/png;base64,..." width="999.2308058823368">
#  message:  [0]  output:  0  epoch no:  0  avg reward 0.34375
#  epoch no:  0  avg reward 0.34375
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-20-5f4c22727e5f> in <module>
#      76     if not flip_l:
#      77 #         print('e2')
# ---> 78         e2 = Listener.model.observe(reward=reward_batch, terminal=[True]*n_batches)
#      79 #     assert e1 == e2
#      80 #     e = e1
#
# /usr/local/lib/python3.5/dist-packages/tensorforce/models/model.py in observe(self, terminal, reward)
#    1423         feed_dict = self.get_feed_dict(terminal=terminal, reward=reward)
#    1424
# -> 1425         episode = self.monitored_session.run(fetches=fetches, feed_dict=feed_dict)
#    1426
#    1427         return episode
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/training/monitored_session.py in run(self, fetches, feed_dict, options, run_metadata)
#     544                           feed_dict=feed_dict,
#     545                           options=options,
# --> 546                           run_metadata=run_metadata)
#     547
#     548   def run_step_fn(self, step_fn):
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/training/monitored_session.py in run(self, *args, **kwargs)
#    1096   def run(self, *args, **kwargs):
#    1097     try:
# -> 1098       return self._sess.run(*args, **kwargs)
#    1099     except _PREEMPTION_ERRORS:
#    1100       raise
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/training/monitored_session.py in run(self, fetches, feed_dict, options, run_metadata)
#    1168                                   feed_dict=feed_dict,
#    1169                                   options=options,
# -> 1170                                   run_metadata=run_metadata)
#    1171
#    1172     for hook in self._hooks:
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/training/monitored_session.py in run(self, *args, **kwargs)
#     948
#     949   def run(self, *args, **kwargs):
# --> 950     return self._sess.run(*args, **kwargs)
#     951
#     952   def run_step_fn(self, step_fn, raw_session, run_with_hooks):
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     903     try:
#     904       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 905                          run_metadata_ptr)
#     906       if run_metadata:
#     907         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1138     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1139       results = self._do_run(handle, final_targets, final_fetches,
# -> 1140                              feed_dict_tensor, options, run_metadata)
#    1141     else:
#    1142       results = []
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1319     if handle is None:
#    1320       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1321                            run_metadata)
#    1322     else:
#    1323       return self._do_call(_prun_fn, handle, feeds, fetches)
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1325   def _do_call(self, fn, *args):
#    1326     try:
# -> 1327       return fn(*args)
#    1328     except errors.OpError as e:
#    1329       message = compat.as_text(e.message)
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1310       self._extend_graph()
#    1311       return self._call_tf_sessionrun(
# -> 1312           options, feed_dict, fetch_list, target_list, run_metadata)
#    1313
#    1314     def _prun_fn(handle, feed_dict, fetch_list):
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1418         return tf_session.TF_Run(
#    1419             self._session, options, feed_dict, fetch_list, target_list,
# -> 1420             status, run_metadata)
#    1421
#    1422   def _call_tf_sessionprun(self, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %%
s1 = Speakers.copy()
l1 = Listeners.copy()
rm = result_mapping.copy()
rcm = result_common_mapping.copy()

# %%
data1back = data.copy()

# %%
print(s1[0].save_model(directory='dummy/'))
print(l1[0].save_model(directory='dummy/'))
# Out:
# dummy/-360224
# dummy/-360160

# %%
Speakers[0].restore

# %%
### N population 4
from collections import Counter

Speakers = s1.copy()
Listeners = l1.copy()
Speakers[0].reset()
Listeners[0].reset()

for i in range(n_batches):
    game_pool.append(Game(n_features, n_clusters-2, n_samples, n_vocab, sender_type, [X1, Y1]))
    
result_mapping = {i:[] for i in range(n_clusters)}
result_common_mapping = {i:[] for i in range(n_clusters)}

fig = plt.figure(figsize=(10, 10))
ax = fig.add_subplot(211)
ax2 = fig.add_subplot(212)
plt.ion()


fig.show()
fig.canvas.draw()
for i in range(n_epochs):
    if i>15000:
        break
    Speaker = Speakers[np.random.choice(n_population)]
    Listener = Listeners[np.random.choice(n_population)]
    message_batch = []
    img_batch = []
    r = i%(2*freq)
    if r<1*freq:
        flip_s = False
        flip_l = True
    if r>=1*freq:
        flip_s = True
        flip_l = False
    l_rewards = []
    strokes = []
    for b in range(n_batches):
        strokes = []
#         for idx in range(2):
#             if idx ==0:
#                 feat = np.zeros((10,10), np.uint8)
#             else:
#                 im = message_to_image_sm(strokes, img_dim, img_dim)
# #                 feat = get_features([im])[0]
#                 feat = im.flatten()
        message = Speaker.act(states= game_pool[b].speaker_input(), independent=False)  # (scalar between 0 and 4)
        message_batch.append(message)
#             strokes.append(message)
#         img = message_to_image(strokes, img_rows, img_cols)
#         img_batch.append(img)
#         Speaker.reset()

#     features_batch = get_features(intermediate_layer_model, img_batch)
#     message = Speaker.act(states= game_pool[b].speaker_input(feat), independent=flip_s)
    out_batch = []
    reward_batch = []
    for b in range(n_batches):
        out = Listener.act(states = game_pool[b].listener_input(message_batch[b]), independent = False)
        out_batch.append(out)
        rew = game_pool[b].reward(out)
        reward_batch.append(rew)
        result_mapping[game_pool[b].nos[0]].append(message_batch[b][0])
        game_pool[b].reset()
        
    speaker_terminals = []
    rew_speaker = []
    for rew in reward_batch:
        speaker_terminals.extend([True])
        rew_speaker.extend([rew])

    if not flip_s:
#         print('e1')
        e1 = Speaker.model.observe(reward=rew_speaker, terminal=speaker_terminals)
    if not flip_l:
#         print('e2')
        e2 = Listener.model.observe(reward=reward_batch, terminal=[True]*n_batches)
#     assert e1 == e2
#     e = e1
    big_rewards.extend(reward_batch)
    big_rewards = big_rewards[-600:]
    if i%(100)==0:
#         print(" output: ", out)
        avg_rew = sum(big_rewards)/len(big_rewards)
        print(" message: ", message, " output: ", out, " epoch no: ", i, " avg reward", avg_rew)
        print(" epoch no: ", i, " avg reward", avg_rew)

        if(i!=0):
            data.append(avg_rew)
        ax.clear()
        ax.plot(data)
        ax2.clear()
        for cluster in range(n_clusters-2):
            all_counts = result_mapping[cluster][-100:]
            most_common, n = Counter(all_counts).most_common(1)[0]
            
            result_common_mapping[cluster].append(most_common)
            if cluster>5:
                linestyle='--'
            else:
                linestyle='-'
            ax2.plot(result_common_mapping[cluster], linestyle=linestyle)
        if not flip_s:
            ax.set_xlabel('speaker')
        else:
            ax.set_xlabel('listener')
        fig.canvas.draw()


#     if sum(big_rewards)/len(big_rewards)>.75:
#         break
# Out:
# <img src="data:image/png;base64,..." width="999.2308058823368">
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1326     try:
# -> 1327       return fn(*args)
#    1328     except errors.OpError as e:
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1311       return self._call_tf_sessionrun(
# -> 1312           options, feed_dict, fetch_list, target_list, run_metadata)
#    1313
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1419             self._session, options, feed_dict, fetch_list, target_list,
# -> 1420             status, run_metadata)
#    1421
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/framework/errors_impl.py in __exit__(self, type_arg, value_arg, traceback_arg)
#     515             compat.as_text(c_api.TF_Message(self.status.status)),
# --> 516             c_api.TF_GetCode(self.status.status))
#     517     # Delete the underlying status object from memory otherwise it stays alive
#
# InvalidArgumentError: Must have updates.shape = indices.shape + params.shape[1:], got updates.shape [128,1], indices.shape [32], params.shape [32000,1]
# 	 [[Node: ppo/observe-timestep/store/ScatterUpdate_1 = ScatterUpdate[T=DT_INT32, Tindices=DT_INT32, _class=["loc:@ppo/initialize/latest/initialize/action-action"], use_locking=true, _device="/job:localhost/replica:0/task:0/device:CPU:0"](ppo/initialize/latest/initialize/action-action, ppo/observe-timestep/store/mod, ppo/strided_slice_1, ^ppo/observe-timestep/store/AssignSub)]]
#
# During handling of the above exception, another exception occurred:
#
# InvalidArgumentError                      Traceback (most recent call last)
# <ipython-input-82-9bca7e8d01e6> in <module>
#      73     if not flip_s:
#      74 #         print('e1')
# ---> 75         e1 = Speaker.model.observe(reward=rew_speaker, terminal=speaker_terminals)
#      76     if not flip_l:
#      77 #         print('e2')
#
# /usr/local/lib/python3.5/dist-packages/tensorforce/models/model.py in observe(self, terminal, reward)
#    1423         feed_dict = self.get_feed_dict(terminal=terminal, reward=reward)
#    1424
# -> 1425         episode = self.monitored_session.run(fetches=fetches, feed_dict=feed_dict)
#    1426
#    1427         return episode
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/training/monitored_session.py in run(self, fetches, feed_dict, options, run_metadata)
#     544                           feed_dict=feed_dict,
#     545                           options=options,
# --> 546                           run_metadata=run_metadata)
#     547
#     548   def run_step_fn(self, step_fn):
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/training/monitored_session.py in run(self, *args, **kwargs)
#    1111         raise six.reraise(*original_exc_info)
#    1112       else:
# -> 1113         raise six.reraise(*original_exc_info)
#    1114
#    1115
#
# /usr/local/lib/python3.5/dist-packages/six.py in reraise(tp, value, tb)
#     691             if value.__traceback__ is not tb:
#     692                 raise value.with_traceback(tb)
# --> 693             raise value
#     694         finally:
#     695             value = None
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/training/monitored_session.py in run(self, *args, **kwargs)
#    1096   def run(self, *args, **kwargs):
#    1097     try:
# -> 1098       return self._sess.run(*args, **kwargs)
#    1099     except _PREEMPTION_ERRORS:
#    1100       raise
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/training/monitored_session.py in run(self, fetches, feed_dict, options, run_metadata)
#    1168                                   feed_dict=feed_dict,
#    1169                                   options=options,
# -> 1170                                   run_metadata=run_metadata)
#    1171
#    1172     for hook in self._hooks:
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/training/monitored_session.py in run(self, *args, **kwargs)
#     948
#     949   def run(self, *args, **kwargs):
# --> 950     return self._sess.run(*args, **kwargs)
#     951
#     952   def run_step_fn(self, step_fn, raw_session, run_with_hooks):
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     903     try:
#     904       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 905                          run_metadata_ptr)
#     906       if run_metadata:
#     907         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1138     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1139       results = self._do_run(handle, final_targets, final_fetches,
# -> 1140                              feed_dict_tensor, options, run_metadata)
#    1141     else:
#    1142       results = []
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1319     if handle is None:
#    1320       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1321                            run_metadata)
#    1322     else:
#    1323       return self._do_call(_prun_fn, handle, feeds, fetches)
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1338         except KeyError:
#    1339           pass
# -> 1340       raise type(e)(node_def, op, message)
#    1341
#    1342   def _extend_graph(self):
#
# InvalidArgumentError: Must have updates.shape = indices.shape + params.shape[1:], got updates.shape [128,1], indices.shape [32], params.shape [32000,1]
# 	 [[Node: ppo/observe-timestep/store/ScatterUpdate_1 = ScatterUpdate[T=DT_INT32, Tindices=DT_INT32, _class=["loc:@ppo/initialize/latest/initialize/action-action"], use_locking=true, _device="/job:localhost/replica:0/task:0/device:CPU:0"](ppo/initialize/latest/initialize/action-action, ppo/observe-timestep/store/mod, ppo/strided_slice_1, ^ppo/observe-timestep/store/AssignSub)]]
#
# Caused by op 'ppo/observe-timestep/store/ScatterUpdate_1', defined at:
#   File "/usr/lib/python3.5/runpy.py", line 184, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/usr/lib/python3.5/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/usr/local/lib/python3.5/dist-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/usr/local/lib/python3.5/dist-packages/ipykernel/kernelapp.py", line 499, in start
#     self.io_loop.start()
#   File "/usr/local/lib/python3.5/dist-packages/tornado/platform/asyncio.py", line 132, in start
#     self.asyncio_loop.run_forever()
#   File "/usr/lib/python3.5/asyncio/base_events.py", line 345, in run_forever
#     self._run_once()
#   File "/usr/lib/python3.5/asyncio/base_events.py", line 1312, in _run_once
#     handle._run()
#   File "/usr/lib/python3.5/asyncio/events.py", line 125, in _run
#     self._callback(*self._args)
#   File "/usr/local/lib/python3.5/dist-packages/tornado/ioloop.py", line 758, in _run_callback
#     ret = callback()
#   File "/usr/local/lib/python3.5/dist-packages/tornado/stack_context.py", line 300, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/usr/local/lib/python3.5/dist-packages/tornado/gen.py", line 1233, in inner
#     self.run()
#   File "/usr/local/lib/python3.5/dist-packages/tornado/gen.py", line 1147, in run
#     yielded = self.gen.send(value)
#   File "/usr/local/lib/python3.5/dist-packages/ipykernel/kernelbase.py", line 346, in process_one
#     yield gen.maybe_future(dispatch(*args))
#   File "/usr/local/lib/python3.5/dist-packages/tornado/gen.py", line 326, in wrapper
#     yielded = next(result)
#   File "/usr/local/lib/python3.5/dist-packages/ipykernel/kernelbase.py", line 259, in dispatch_shell
#     yield gen.maybe_future(handler(stream, idents, msg))
#   File "/usr/local/lib/python3.5/dist-packages/tornado/gen.py", line 326, in wrapper
#     yielded = next(result)
#   File "/usr/local/lib/python3.5/dist-packages/ipykernel/kernelbase.py", line 513, in execute_request
#     user_expressions, allow_stdin,
#   File "/usr/local/lib/python3.5/dist-packages/tornado/gen.py", line 326, in wrapper
#     yielded = next(result)
#   File "/usr/local/lib/python3.5/dist-packages/ipykernel/ipkernel.py", line 294, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/usr/local/lib/python3.5/dist-packages/ipykernel/zmqshell.py", line 536, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/usr/local/lib/python3.5/dist-packages/IPython/core/interactiveshell.py", line 2817, in run_cell
#     raw_cell, store_history, silent, shell_futures)
#   File "/usr/local/lib/python3.5/dist-packages/IPython/core/interactiveshell.py", line 2843, in _run_cell
#     return runner(coro)
#   File "/usr/local/lib/python3.5/dist-packages/IPython/core/async_helpers.py", line 67, in _pseudo_sync_runner
#     coro.send(None)
#   File "/usr/local/lib/python3.5/dist-packages/IPython/core/interactiveshell.py", line 3018, in run_cell_async
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/usr/local/lib/python3.5/dist-packages/IPython/core/interactiveshell.py", line 3183, in run_ast_nodes
#     if (yield from self.run_code(code, result)):
#   File "/usr/local/lib/python3.5/dist-packages/IPython/core/interactiveshell.py", line 3265, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-64-4ea12ecdb827>", line 17, in <module>
#     Speaker1, Listener1 = get_agents(ppo_config, network_config, sender_type, n_features, img_dim, img_features_len, n_samples, num_actions, action_size)
#   File "/media/petrichor/data/future/emergence-of-writing-systems/agents.py", line 22, in get_agents
#     network=network_deep,
#   File "/usr/local/lib/python3.5/dist-packages/tensorforce/agents/agent.py", line 283, in from_spec
#     kwargs=kwargs
#   File "/usr/local/lib/python3.5/dist-packages/tensorforce/util.py", line 192, in get_object
#     return obj(*args, **kwargs)
#   File "/usr/local/lib/python3.5/dist-packages/tensorforce/agents/ppo_agent.py", line 155, in __init__
#     entropy_regularization=entropy_regularization
#   File "/usr/local/lib/python3.5/dist-packages/tensorforce/agents/learning_agent.py", line 141, in __init__
#     batching_capacity=batching_capacity
#   File "/usr/local/lib/python3.5/dist-packages/tensorforce/agents/agent.py", line 80, in __init__
#     self.model = self.initialize_model()
#   File "/usr/local/lib/python3.5/dist-packages/tensorforce/agents/ppo_agent.py", line 183, in initialize_model
#     likelihood_ratio_clipping=self.likelihood_ratio_clipping
#   File "/usr/local/lib/python3.5/dist-packages/tensorforce/models/pg_prob_ratio_model.py", line 88, in __init__
#     gae_lambda=gae_lambda
#   File "/usr/local/lib/python3.5/dist-packages/tensorforce/models/pg_model.py", line 98, in __init__
#     requires_deterministic=False
#   File "/usr/local/lib/python3.5/dist-packages/tensorforce/models/distribution_model.py", line 90, in __init__
#     discount=discount
#   File "/usr/local/lib/python3.5/dist-packages/tensorforce/models/memory_model.py", line 114, in __init__
#     reward_preprocessing=reward_preprocessing
#   File "/usr/local/lib/python3.5/dist-packages/tensorforce/models/model.py", line 217, in __init__
#     self.setup()
#   File "/usr/local/lib/python3.5/dist-packages/tensorforce/models/model.py", line 290, in setup
#     independent=independent
#   File "/usr/local/lib/python3.5/dist-packages/tensorforce/models/memory_model.py", line 605, in create_operations
#     independent=independent
#   File "/usr/local/lib/python3.5/dist-packages/tensorforce/models/model.py", line 1195, in create_operations
#     self.create_observe_operations(reward=reward, terminal=terminal)
#   File "/usr/local/lib/python3.5/dist-packages/tensorforce/models/model.py", line 1129, in create_observe_operations
#     reward=reward
#   File "/usr/local/lib/python3.5/dist-packages/tensorflow/python/ops/template.py", line 464, in __call__
#     result = self._call_func(args, kwargs)
#   File "/usr/local/lib/python3.5/dist-packages/tensorflow/python/ops/template.py", line 406, in _call_func
#     result = self._func(*args, **kwargs)
#   File "/usr/local/lib/python3.5/dist-packages/tensorforce/models/memory_model.py", line 504, in tf_observe_timestep
#     reward=reward
#   File "/usr/local/lib/python3.5/dist-packages/tensorflow/python/ops/template.py", line 455, in __call__
#     result = self._call_func(args, kwargs)
#   File "/usr/local/lib/python3.5/dist-packages/tensorflow/python/ops/template.py", line 400, in _call_func
#     result = self._func(*args, **kwargs)
#   File "/usr/local/lib/python3.5/dist-packages/tensorforce/core/memories/queue.py", line 188, in tf_store
#     updates=actions[name]
#   File "/usr/local/lib/python3.5/dist-packages/tensorflow/python/ops/state_ops.py", line 356, in scatter_update
#     use_locking=use_locking, name=name)
#   File "/usr/local/lib/python3.5/dist-packages/tensorflow/python/ops/gen_state_ops.py", line 984, in scatter_update
#     use_locking=use_locking, name=name)
#   File "/usr/local/lib/python3.5/dist-packages/tensorflow/python/framework/op_def_library.py", line 787, in _apply_op_helper
#     op_def=op_def)
#   File "/usr/local/lib/python3.5/dist-packages/tensorflow/python/framework/ops.py", line 3290, in create_op
#     op_def=op_def)
#   File "/usr/local/lib/python3.5/dist-packages/tensorflow/python/framework/ops.py", line 1654, in __init__
#     self._traceback = self._graph._extract_stack()  # pylint: disable=protected-access
#
# InvalidArgumentError (see above for traceback): Must have updates.shape = indices.shape + params.shape[1:], got updates.shape [128,1], indices.shape [32], params.shape [32000,1]
# 	 [[Node: ppo/observe-timestep/store/ScatterUpdate_1 = ScatterUpdate[T=DT_INT32, Tindices=DT_INT32, _class=["loc:@ppo/initialize/latest/initialize/action-action"], use_locking=true, _device="/job:localhost/replica:0/task:0/device:CPU:0"](ppo/initialize/latest/initialize/action-action, ppo/observe-timestep/store/mod, ppo/strided_slice_1, ^ppo/observe-timestep/store/AssignSub)]]

# %%
### N population 4

### Training on new phase
from collections import Counter

result_mapping = {i:[] for i in range(n_clusters)}
result_common_mapping = {i:[] for i in range(n_clusters)}
game_pool = []
data=[]
xnew = X1a[Y1a>5]
ynew = Y1a[Y1a>5]

for i in range(n_batches):
    game_pool.append(Game(n_features, n_clusters, n_samples, n_vocab, sender_type, [X1a, Y1a]))
    
fig = plt.figure(figsize=(10, 10))
ax = fig.add_subplot(211)
ax2 = fig.add_subplot(212)
plt.ion()

fig.show()
fig.canvas.draw()

for i in range(n_population):
    Speakers[i].reset()
    Listeners[i].reset()

for i in range(n_epochs):
    Speaker = Speakers[np.random.choice(n_population)]
    Listener = Listeners[np.random.choice(n_population)]
    message_batch = []
    img_batch = []
    r = i%(2*freq)
    if r<1*freq:
        flip_s = False
        flip_l = True
    if r>=1*freq:
        flip_s = True
        flip_l = False
    l_rewards = []
    strokes = []
    for b in range(n_batches):
        strokes = []
#         for idx in range(2):
#             if idx ==0:
#                 feat = np.zeros((10,10), np.uint8)
#             else:
#                 im = message_to_image_sm(strokes, img_dim, img_dim)
# #                 feat = get_features([im])[0]
#                 feat = im.flatten()
        message = Speaker.act(states= game_pool[b].speaker_input(), independent=False)  # (scalar between 0 and 4)
        message_batch.append(message)
#             strokes.append(message)
#         img = message_to_image(strokes, img_rows, img_cols)
#         img_batch.append(img)
#         Speaker.reset()

#     features_batch = get_features(intermediate_layer_model, img_batch)
#     message = Speaker.act(states= game_pool[b].speaker_input(feat), independent=flip_s)
    out_batch = []
    reward_batch = []
    for b in range(n_batches):
        out = Listener.act(states = game_pool[b].listener_input(message_batch[b]), independent = False)
        out_batch.append(out)
        rew = game_pool[b].reward(out)
        reward_batch.append(rew)
        game_pool[b].reset()
        result_mapping[game_pool[b].nos[game_pool[b].target]].append(message_batch[b][0])
        
    speaker_terminals = []
    rew_speaker = []
    for rew in reward_batch:
        speaker_terminals.extend([True])
        rew_speaker.extend([rew])

    if not flip_s:
#         print('e1')
        e1 = Speaker.model.observe(reward=rew_speaker, terminal=speaker_terminals)
    if not flip_l:
#         print('e2')
        e2 = Listener.model.observe(reward=reward_batch, terminal=[True]*n_batches)
#     assert e1 == e2
#     e = e1
    big_rewards.extend(reward_batch)
    big_rewards = big_rewards[-600:]
    if i%(100)==0:
#         print(" output: ", out)
        avg_rew = sum(big_rewards)/len(big_rewards)
        print(" message: ", message, " output: ", out, " epoch no: ", i, " avg reward", avg_rew)
        print(" epoch no: ", i, " avg reward", avg_rew)

        if(i!=0):
            data.append(avg_rew)
        ax.clear()
        ax2.clear()
        for cluster in range(n_clusters):
            all_counts = result_mapping[cluster][-100:]
#             print(all_counts)
            most_common, n = Counter(all_counts).most_common(1)[0]
            result_common_mapping[cluster].append(most_common)
            ax2.plot(result_common_mapping[cluster])
            
        
        ax.plot(data,'r')
        if not flip_s:
            ax.set_xlabel('speaker')
        else:
            ax.set_xlabel('listener')
        fig.canvas.draw()


#     if sum(big_rewards)/len(big_rewards)>.75:
#         break
# Out:
# <img src="data:image/png;base64,..." width="999.2308058823368">
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1326     try:
# -> 1327       return fn(*args)
#    1328     except errors.OpError as e:
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1311       return self._call_tf_sessionrun(
# -> 1312           options, feed_dict, fetch_list, target_list, run_metadata)
#    1313
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1419             self._session, options, feed_dict, fetch_list, target_list,
# -> 1420             status, run_metadata)
#    1421
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/framework/errors_impl.py in __exit__(self, type_arg, value_arg, traceback_arg)
#     515             compat.as_text(c_api.TF_Message(self.status.status)),
# --> 516             c_api.TF_GetCode(self.status.status))
#     517     # Delete the underlying status object from memory otherwise it stays alive
#
# InvalidArgumentError: Must have updates.shape = indices.shape + params.shape[1:], got updates.shape [64,9], indices.shape [32], params.shape [32000,9]
# 	 [[Node: ppo/observe-timestep/store/ScatterUpdate = ScatterUpdate[T=DT_FLOAT, Tindices=DT_INT32, _class=["loc:@ppo/initialize/latest/initialize/state-state"], use_locking=true, _device="/job:localhost/replica:0/task:0/device:CPU:0"](ppo/initialize/latest/initialize/state-state, ppo/observe-timestep/store/mod, ppo/strided_slice, ^ppo/observe-timestep/store/AssignSub)]]
#
# During handling of the above exception, another exception occurred:
#
# InvalidArgumentError                      Traceback (most recent call last)
# <ipython-input-59-17ca63f02503> in <module>
#      76     if not flip_s:
#      77 #         print('e1')
# ---> 78         e1 = Speaker.model.observe(reward=rew_speaker, terminal=speaker_terminals)
#      79     if not flip_l:
#      80 #         print('e2')
#
# /usr/local/lib/python3.5/dist-packages/tensorforce/models/model.py in observe(self, terminal, reward)
#    1423         feed_dict = self.get_feed_dict(terminal=terminal, reward=reward)
#    1424
# -> 1425         episode = self.monitored_session.run(fetches=fetches, feed_dict=feed_dict)
#    1426
#    1427         return episode
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/training/monitored_session.py in run(self, fetches, feed_dict, options, run_metadata)
#     544                           feed_dict=feed_dict,
#     545                           options=options,
# --> 546                           run_metadata=run_metadata)
#     547
#     548   def run_step_fn(self, step_fn):
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/training/monitored_session.py in run(self, *args, **kwargs)
#    1111         raise six.reraise(*original_exc_info)
#    1112       else:
# -> 1113         raise six.reraise(*original_exc_info)
#    1114
#    1115
#
# /usr/local/lib/python3.5/dist-packages/six.py in reraise(tp, value, tb)
#     691             if value.__traceback__ is not tb:
#     692                 raise value.with_traceback(tb)
# --> 693             raise value
#     694         finally:
#     695             value = None
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/training/monitored_session.py in run(self, *args, **kwargs)
#    1096   def run(self, *args, **kwargs):
#    1097     try:
# -> 1098       return self._sess.run(*args, **kwargs)
#    1099     except _PREEMPTION_ERRORS:
#    1100       raise
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/training/monitored_session.py in run(self, fetches, feed_dict, options, run_metadata)
#    1168                                   feed_dict=feed_dict,
#    1169                                   options=options,
# -> 1170                                   run_metadata=run_metadata)
#    1171
#    1172     for hook in self._hooks:
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/training/monitored_session.py in run(self, *args, **kwargs)
#     948
#     949   def run(self, *args, **kwargs):
# --> 950     return self._sess.run(*args, **kwargs)
#     951
#     952   def run_step_fn(self, step_fn, raw_session, run_with_hooks):
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     903     try:
#     904       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 905                          run_metadata_ptr)
#     906       if run_metadata:
#     907         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1138     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1139       results = self._do_run(handle, final_targets, final_fetches,
# -> 1140                              feed_dict_tensor, options, run_metadata)
#    1141     else:
#    1142       results = []
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1319     if handle is None:
#    1320       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1321                            run_metadata)
#    1322     else:
#    1323       return self._do_call(_prun_fn, handle, feeds, fetches)
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1338         except KeyError:
#    1339           pass
# -> 1340       raise type(e)(node_def, op, message)
#    1341
#    1342   def _extend_graph(self):
#
# InvalidArgumentError: Must have updates.shape = indices.shape + params.shape[1:], got updates.shape [64,9], indices.shape [32], params.shape [32000,9]
# 	 [[Node: ppo/observe-timestep/store/ScatterUpdate = ScatterUpdate[T=DT_FLOAT, Tindices=DT_INT32, _class=["loc:@ppo/initialize/latest/initialize/state-state"], use_locking=true, _device="/job:localhost/replica:0/task:0/device:CPU:0"](ppo/initialize/latest/initialize/state-state, ppo/observe-timestep/store/mod, ppo/strided_slice, ^ppo/observe-timestep/store/AssignSub)]]
#
# Caused by op 'ppo/observe-timestep/store/ScatterUpdate', defined at:
#   File "/usr/lib/python3.5/runpy.py", line 184, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/usr/lib/python3.5/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/usr/local/lib/python3.5/dist-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/usr/local/lib/python3.5/dist-packages/ipykernel/kernelapp.py", line 499, in start
#     self.io_loop.start()
#   File "/usr/local/lib/python3.5/dist-packages/tornado/platform/asyncio.py", line 132, in start
#     self.asyncio_loop.run_forever()
#   File "/usr/lib/python3.5/asyncio/base_events.py", line 345, in run_forever
#     self._run_once()
#   File "/usr/lib/python3.5/asyncio/base_events.py", line 1312, in _run_once
#     handle._run()
#   File "/usr/lib/python3.5/asyncio/events.py", line 125, in _run
#     self._callback(*self._args)
#   File "/usr/local/lib/python3.5/dist-packages/tornado/ioloop.py", line 758, in _run_callback
#     ret = callback()
#   File "/usr/local/lib/python3.5/dist-packages/tornado/stack_context.py", line 300, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/usr/local/lib/python3.5/dist-packages/tornado/gen.py", line 1233, in inner
#     self.run()
#   File "/usr/local/lib/python3.5/dist-packages/tornado/gen.py", line 1147, in run
#     yielded = self.gen.send(value)
#   File "/usr/local/lib/python3.5/dist-packages/ipykernel/kernelbase.py", line 346, in process_one
#     yield gen.maybe_future(dispatch(*args))
#   File "/usr/local/lib/python3.5/dist-packages/tornado/gen.py", line 326, in wrapper
#     yielded = next(result)
#   File "/usr/local/lib/python3.5/dist-packages/ipykernel/kernelbase.py", line 259, in dispatch_shell
#     yield gen.maybe_future(handler(stream, idents, msg))
#   File "/usr/local/lib/python3.5/dist-packages/tornado/gen.py", line 326, in wrapper
#     yielded = next(result)
#   File "/usr/local/lib/python3.5/dist-packages/ipykernel/kernelbase.py", line 513, in execute_request
#     user_expressions, allow_stdin,
#   File "/usr/local/lib/python3.5/dist-packages/tornado/gen.py", line 326, in wrapper
#     yielded = next(result)
#   File "/usr/local/lib/python3.5/dist-packages/ipykernel/ipkernel.py", line 294, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/usr/local/lib/python3.5/dist-packages/ipykernel/zmqshell.py", line 536, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/usr/local/lib/python3.5/dist-packages/IPython/core/interactiveshell.py", line 2817, in run_cell
#     raw_cell, store_history, silent, shell_futures)
#   File "/usr/local/lib/python3.5/dist-packages/IPython/core/interactiveshell.py", line 2843, in _run_cell
#     return runner(coro)
#   File "/usr/local/lib/python3.5/dist-packages/IPython/core/async_helpers.py", line 67, in _pseudo_sync_runner
#     coro.send(None)
#   File "/usr/local/lib/python3.5/dist-packages/IPython/core/interactiveshell.py", line 3018, in run_cell_async
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/usr/local/lib/python3.5/dist-packages/IPython/core/interactiveshell.py", line 3183, in run_ast_nodes
#     if (yield from self.run_code(code, result)):
#   File "/usr/local/lib/python3.5/dist-packages/IPython/core/interactiveshell.py", line 3265, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-34-4ea12ecdb827>", line 17, in <module>
#     Speaker1, Listener1 = get_agents(ppo_config, network_config, sender_type, n_features, img_dim, img_features_len, n_samples, num_actions, action_size)
#   File "/media/petrichor/data/future/emergence-of-writing-systems/agents.py", line 22, in get_agents
#     network=network_deep,
#   File "/usr/local/lib/python3.5/dist-packages/tensorforce/agents/agent.py", line 283, in from_spec
#     kwargs=kwargs
#   File "/usr/local/lib/python3.5/dist-packages/tensorforce/util.py", line 192, in get_object
#     return obj(*args, **kwargs)
#   File "/usr/local/lib/python3.5/dist-packages/tensorforce/agents/ppo_agent.py", line 155, in __init__
#     entropy_regularization=entropy_regularization
#   File "/usr/local/lib/python3.5/dist-packages/tensorforce/agents/learning_agent.py", line 141, in __init__
#     batching_capacity=batching_capacity
#   File "/usr/local/lib/python3.5/dist-packages/tensorforce/agents/agent.py", line 80, in __init__
#     self.model = self.initialize_model()
#   File "/usr/local/lib/python3.5/dist-packages/tensorforce/agents/ppo_agent.py", line 183, in initialize_model
#     likelihood_ratio_clipping=self.likelihood_ratio_clipping
#   File "/usr/local/lib/python3.5/dist-packages/tensorforce/models/pg_prob_ratio_model.py", line 88, in __init__
#     gae_lambda=gae_lambda
#   File "/usr/local/lib/python3.5/dist-packages/tensorforce/models/pg_model.py", line 98, in __init__
#     requires_deterministic=False
#   File "/usr/local/lib/python3.5/dist-packages/tensorforce/models/distribution_model.py", line 90, in __init__
#     discount=discount
#   File "/usr/local/lib/python3.5/dist-packages/tensorforce/models/memory_model.py", line 114, in __init__
#     reward_preprocessing=reward_preprocessing
#   File "/usr/local/lib/python3.5/dist-packages/tensorforce/models/model.py", line 217, in __init__
#     self.setup()
#   File "/usr/local/lib/python3.5/dist-packages/tensorforce/models/model.py", line 290, in setup
#     independent=independent
#   File "/usr/local/lib/python3.5/dist-packages/tensorforce/models/memory_model.py", line 605, in create_operations
#     independent=independent
#   File "/usr/local/lib/python3.5/dist-packages/tensorforce/models/model.py", line 1195, in create_operations
#     self.create_observe_operations(reward=reward, terminal=terminal)
#   File "/usr/local/lib/python3.5/dist-packages/tensorforce/models/model.py", line 1129, in create_observe_operations
#     reward=reward
#   File "/usr/local/lib/python3.5/dist-packages/tensorflow/python/ops/template.py", line 464, in __call__
#     result = self._call_func(args, kwargs)
#   File "/usr/local/lib/python3.5/dist-packages/tensorflow/python/ops/template.py", line 406, in _call_func
#     result = self._func(*args, **kwargs)
#   File "/usr/local/lib/python3.5/dist-packages/tensorforce/models/memory_model.py", line 504, in tf_observe_timestep
#     reward=reward
#   File "/usr/local/lib/python3.5/dist-packages/tensorflow/python/ops/template.py", line 455, in __call__
#     result = self._call_func(args, kwargs)
#   File "/usr/local/lib/python3.5/dist-packages/tensorflow/python/ops/template.py", line 400, in _call_func
#     result = self._func(*args, **kwargs)
#   File "/usr/local/lib/python3.5/dist-packages/tensorforce/core/memories/queue.py", line 176, in tf_store
#     updates=states[name]
#   File "/usr/local/lib/python3.5/dist-packages/tensorflow/python/ops/state_ops.py", line 356, in scatter_update
#     use_locking=use_locking, name=name)
#   File "/usr/local/lib/python3.5/dist-packages/tensorflow/python/ops/gen_state_ops.py", line 984, in scatter_update
#     use_locking=use_locking, name=name)
#   File "/usr/local/lib/python3.5/dist-packages/tensorflow/python/framework/op_def_library.py", line 787, in _apply_op_helper
#     op_def=op_def)
#   File "/usr/local/lib/python3.5/dist-packages/tensorflow/python/framework/ops.py", line 3290, in create_op
#     op_def=op_def)
#   File "/usr/local/lib/python3.5/dist-packages/tensorflow/python/framework/ops.py", line 1654, in __init__
#     self._traceback = self._graph._extract_stack()  # pylint: disable=protected-access
#
# InvalidArgumentError (see above for traceback): Must have updates.shape = indices.shape + params.shape[1:], got updates.shape [64,9], indices.shape [32], params.shape [32000,9]
# 	 [[Node: ppo/observe-timestep/store/ScatterUpdate = ScatterUpdate[T=DT_FLOAT, Tindices=DT_INT32, _class=["loc:@ppo/initialize/latest/initialize/state-state"], use_locking=true, _device="/job:localhost/replica:0/task:0/device:CPU:0"](ppo/initialize/latest/initialize/state-state, ppo/observe-timestep/store/mod, ppo/strided_slice, ^ppo/observe-timestep/store/AssignSub)]]

# %%
### N population 6

fig = plt.figure()
ax = fig.add_subplot(111)
plt.ion()

fig.show()
fig.canvas.draw()
for i in range(n_epochs):
    Speaker = Speakers[np.random.choice(n_population)]
    Listener = Listeners[np.random.choice(n_population)]
    message_batch = []
    img_batch = []
    r = i%(2*freq)
    if r<1*freq:
        flip_s = False
        flip_l = True
    if r>=1*freq:
        flip_s = True
        flip_l = False
    l_rewards = []
    strokes = []
    for b in range(n_batches):
        strokes = []
#         for idx in range(2):
#             if idx ==0:
#                 feat = np.zeros((10,10), np.uint8)
#             else:
#                 im = message_to_image_sm(strokes, img_dim, img_dim)
# #                 feat = get_features([im])[0]
#                 feat = im.flatten()
        message = Speaker.act(states= game_pool[b].speaker_input(), independent=flip_s)  # (scalar between 0 and 4)
        message_batch.append(message)
#             strokes.append(message)
#         img = message_to_image(strokes, img_rows, img_cols)
#         img_batch.append(img)
#         Speaker.reset()

#     features_batch = get_features(intermediate_layer_model, img_batch)
#     message = Speaker.act(states= game_pool[b].speaker_input(feat), independent=flip_s)
    out_batch = []
    reward_batch = []
    for b in range(n_batches):
        out = Listener.act(states = game_pool[b].listener_input(message_batch[b]), independent = flip_l)
        out_batch.append(out)
        rew = game_pool[b].reward(out)
        reward_batch.append(rew)
        game_pool[b].reset()
    speaker_terminals = []
    rew_speaker = []
    for rew in reward_batch:
        speaker_terminals.extend([True])
        rew_speaker.extend([rew])

    if not flip_s:
#         print('e1')
        e1 = Speaker.model.observe(reward=rew_speaker, terminal=speaker_terminals)
    if not flip_l:
#         print('e2')
        e2 = Listener.model.observe(reward=reward_batch, terminal=[True]*n_batches)
#     assert e1 == e2
#     e = e1
    big_rewards.extend(reward_batch)
    big_rewards = big_rewards[-600:]
    if i%(100)==0:
#         print(" output: ", out)
        avg_rew = sum(big_rewards)/len(big_rewards)
        print(" message: ", message, " output: ", out, " epoch no: ", i, " avg reward", avg_rew)
        print(" epoch no: ", i, " avg reward", avg_rew)

        if(i!=0):
            data.append(avg_rew)
        ax.clear()
        ax.plot(data)
        if not flip_s:
            ax.set_xlabel('speaker')
        else:
            ax.set_xlabel('listener')
        fig.canvas.draw()


#     if sum(big_rewards)/len(big_rewards)>.75:
#         break
# Out:
# <img src="data:image/png;base64,..." width="639.230792677615">
#  message:  [4]  output:  0  epoch no:  0  avg reward 0.375
#  epoch no:  0  avg reward 0.375
#  message:  [0]  output:  2  epoch no:  100  avg reward 0.35333333333333333
#  epoch no:  100  avg reward 0.35333333333333333
#  message:  [3]  output:  0  epoch no:  200  avg reward 0.3516666666666667
#  epoch no:  200  avg reward 0.3516666666666667
#  message:  [0]  output:  0  epoch no:  300  avg reward 0.31
#  epoch no:  300  avg reward 0.31
#  message:  [0]  output:  1  epoch no:  400  avg reward 0.3283333333333333
#  epoch no:  400  avg reward 0.3283333333333333
#  message:  [1]  output:  2  epoch no:  500  avg reward 0.335
#  epoch no:  500  avg reward 0.335
#  message:  [1]  output:  0  epoch no:  600  avg reward 0.33666666666666667
#  epoch no:  600  avg reward 0.33666666666666667
#  message:  [3]  output:  0  epoch no:  700  avg reward 0.3416666666666667
#  epoch no:  700  avg reward 0.3416666666666667
#  message:  [2]  output:  2  epoch no:  800  avg reward 0.33666666666666667
#  epoch no:  800  avg reward 0.33666666666666667
#  message:  [2]  output:  1  epoch no:  900  avg reward 0.345
#  epoch no:  900  avg reward 0.345
#  message:  [1]  output:  1  epoch no:  1000  avg reward 0.3433333333333333
#  epoch no:  1000  avg reward 0.3433333333333333
#  message:  [4]  output:  2  epoch no:  1100  avg reward 0.325
#  epoch no:  1100  avg reward 0.325
#  message:  [4]  output:  1  epoch no:  1200  avg reward 0.325
#  epoch no:  1200  avg reward 0.325
#  message:  [0]  output:  0  epoch no:  1300  avg reward 0.33166666666666667
#  epoch no:  1300  avg reward 0.33166666666666667
#  message:  [4]  output:  2  epoch no:  1400  avg reward 0.345
#  epoch no:  1400  avg reward 0.345
#  message:  [3]  output:  2  epoch no:  1500  avg reward 0.34833333333333333
#  epoch no:  1500  avg reward 0.34833333333333333
#  message:  [0]  output:  1  epoch no:  1600  avg reward 0.36666666666666664
#  epoch no:  1600  avg reward 0.36666666666666664
#  message:  [1]  output:  0  epoch no:  1700  avg reward 0.3416666666666667
#  epoch no:  1700  avg reward 0.3416666666666667
#  message:  [3]  output:  0  epoch no:  1800  avg reward 0.33
#  epoch no:  1800  avg reward 0.33
#  message:  [0]  output:  1  epoch no:  1900  avg reward 0.32666666666666666
#  epoch no:  1900  avg reward 0.32666666666666666
#  message:  [0]  output:  0  epoch no:  2000  avg reward 0.325
#  epoch no:  2000  avg reward 0.325
#  message:  [2]  output:  1  epoch no:  2100  avg reward 0.32166666666666666
#  epoch no:  2100  avg reward 0.32166666666666666
#  message:  [1]  output:  2  epoch no:  2200  avg reward 0.31333333333333335
#  epoch no:  2200  avg reward 0.31333333333333335
#  message:  [1]  output:  2  epoch no:  2300  avg reward 0.35
#  epoch no:  2300  avg reward 0.35
#  message:  [4]  output:  1  epoch no:  2400  avg reward 0.3383333333333333
#  epoch no:  2400  avg reward 0.3383333333333333
#  message:  [2]  output:  2  epoch no:  2500  avg reward 0.3466666666666667
#  epoch no:  2500  avg reward 0.3466666666666667
#  message:  [3]  output:  2  epoch no:  2600  avg reward 0.36
#  epoch no:  2600  avg reward 0.36
#  message:  [2]  output:  0  epoch no:  2700  avg reward 0.36666666666666664
#  epoch no:  2700  avg reward 0.36666666666666664
#  message:  [2]  output:  2  epoch no:  2800  avg reward 0.31166666666666665
#  epoch no:  2800  avg reward 0.31166666666666665
#  message:  [1]  output:  2  epoch no:  2900  avg reward 0.31333333333333335
#  epoch no:  2900  avg reward 0.31333333333333335
#  message:  [2]  output:  2  epoch no:  3000  avg reward 0.32666666666666666
#  epoch no:  3000  avg reward 0.32666666666666666
#  message:  [0]  output:  1  epoch no:  3100  avg reward 0.31833333333333336
#  epoch no:  3100  avg reward 0.31833333333333336
#  message:  [0]  output:  0  epoch no:  3200  avg reward 0.31666666666666665
#  epoch no:  3200  avg reward 0.31666666666666665
#  message:  [4]  output:  2  epoch no:  3300  avg reward 0.3383333333333333
#  epoch no:  3300  avg reward 0.3383333333333333
#  message:  [4]  output:  0  epoch no:  3400  avg reward 0.3
#  epoch no:  3400  avg reward 0.3
#  message:  [2]  output:  2  epoch no:  3500  avg reward 0.3233333333333333
#  epoch no:  3500  avg reward 0.3233333333333333
#  message:  [1]  output:  0  epoch no:  3600  avg reward 0.33666666666666667
#  epoch no:  3600  avg reward 0.33666666666666667
#  message:  [0]  output:  2  epoch no:  3700  avg reward 0.3
#  epoch no:  3700  avg reward 0.3
#  message:  [4]  output:  0  epoch no:  3800  avg reward 0.33166666666666667
#  epoch no:  3800  avg reward 0.33166666666666667
#  message:  [1]  output:  2  epoch no:  3900  avg reward 0.30833333333333335
#  epoch no:  3900  avg reward 0.30833333333333335
#  message:  [0]  output:  0  epoch no:  4000  avg reward 0.325
#  epoch no:  4000  avg reward 0.325
#  message:  [1]  output:  2  epoch no:  4100  avg reward 0.315
#  epoch no:  4100  avg reward 0.315
#  message:  [0]  output:  1  epoch no:  4200  avg reward 0.3416666666666667
#  epoch no:  4200  avg reward 0.3416666666666667
#  message:  [1]  output:  0  epoch no:  4300  avg reward 0.33166666666666667
#  epoch no:  4300  avg reward 0.33166666666666667
#  message:  [3]  output:  1  epoch no:  4400  avg reward 0.32666666666666666
#  epoch no:  4400  avg reward 0.32666666666666666
#  message:  [0]  output:  0  epoch no:  4500  avg reward 0.3516666666666667
#  epoch no:  4500  avg reward 0.3516666666666667
#  message:  [2]  output:  2  epoch no:  4600  avg reward 0.32
#  epoch no:  4600  avg reward 0.32
#  message:  [3]  output:  0  epoch no:  4700  avg reward 0.36833333333333335
#  epoch no:  4700  avg reward 0.36833333333333335
#  message:  [2]  output:  1  epoch no:  4800  avg reward 0.355
#  epoch no:  4800  avg reward 0.355
#  message:  [2]  output:  0  epoch no:  4900  avg reward 0.345
#  epoch no:  4900  avg reward 0.345
#  message:  [1]  output:  1  epoch no:  5000  avg reward 0.335
#  epoch no:  5000  avg reward 0.335
#  message:  [2]  output:  2  epoch no:  5100  avg reward 0.31166666666666665
#  epoch no:  5100  avg reward 0.31166666666666665
#  message:  [4]  output:  0  epoch no:  5200  avg reward 0.35333333333333333
#  epoch no:  5200  avg reward 0.35333333333333333
#  message:  [4]  output:  1  epoch no:  5300  avg reward 0.3516666666666667
#  epoch no:  5300  avg reward 0.3516666666666667
#  message:  [1]  output:  1  epoch no:  5400  avg reward 0.3566666666666667
#  epoch no:  5400  avg reward 0.3566666666666667
#  message:  [2]  output:  0  epoch no:  5500  avg reward 0.32666666666666666
#  epoch no:  5500  avg reward 0.32666666666666666
#  message:  [0]  output:  2  epoch no:  5600  avg reward 0.3383333333333333
#  epoch no:  5600  avg reward 0.3383333333333333
#  message:  [0]  output:  2  epoch no:  5700  avg reward 0.34833333333333333
#  epoch no:  5700  avg reward 0.34833333333333333
#  message:  [0]  output:  0  epoch no:  5800  avg reward 0.355
#  epoch no:  5800  avg reward 0.355
#  message:  [1]  output:  0  epoch no:  5900  avg reward 0.2966666666666667
#  epoch no:  5900  avg reward 0.2966666666666667
#  message:  [1]  output:  0  epoch no:  6000  avg reward 0.36666666666666664
#  epoch no:  6000  avg reward 0.36666666666666664
#  message:  [0]  output:  2  epoch no:  6100  avg reward 0.355
#  epoch no:  6100  avg reward 0.355
#  message:  [2]  output:  0  epoch no:  6200  avg reward 0.3566666666666667
#  epoch no:  6200  avg reward 0.3566666666666667
#  message:  [1]  output:  2  epoch no:  6300  avg reward 0.37333333333333335
#  epoch no:  6300  avg reward 0.37333333333333335
#  message:  [2]  output:  0  epoch no:  6400  avg reward 0.40166666666666667
#  epoch no:  6400  avg reward 0.40166666666666667
#  message:  [4]  output:  0  epoch no:  6500  avg reward 0.38333333333333336
#  epoch no:  6500  avg reward 0.38333333333333336
#  message:  [2]  output:  2  epoch no:  6600  avg reward 0.36666666666666664
#  epoch no:  6600  avg reward 0.36666666666666664
#  message:  [3]  output:  0  epoch no:  6700  avg reward 0.3416666666666667
#  epoch no:  6700  avg reward 0.3416666666666667
#  message:  [4]  output:  0  epoch no:  6800  avg reward 0.39166666666666666
#  epoch no:  6800  avg reward 0.39166666666666666
#  message:  [4]  output:  0  epoch no:  6900  avg reward 0.4066666666666667
#  epoch no:  6900  avg reward 0.4066666666666667
#  message:  [2]  output:  0  epoch no:  7000  avg reward 0.43333333333333335
#  epoch no:  7000  avg reward 0.43333333333333335
#  message:  [2]  output:  2  epoch no:  7100  avg reward 0.4266666666666667
#  epoch no:  7100  avg reward 0.4266666666666667
#  message:  [0]  output:  0  epoch no:  7200  avg reward 0.43666666666666665
#  epoch no:  7200  avg reward 0.43666666666666665
#  message:  [3]  output:  0  epoch no:  7300  avg reward 0.415
#  epoch no:  7300  avg reward 0.415
#  message:  [1]  output:  2  epoch no:  7400  avg reward 0.48
#  epoch no:  7400  avg reward 0.48
#  message:  [0]  output:  2  epoch no:  7500  avg reward 0.49
#  epoch no:  7500  avg reward 0.49
#  message:  [0]  output:  1  epoch no:  7600  avg reward 0.49166666666666664
#  epoch no:  7600  avg reward 0.49166666666666664
#  message:  [4]  output:  2  epoch no:  7700  avg reward 0.455
#  epoch no:  7700  avg reward 0.455
#  message:  [2]  output:  0  epoch no:  7800  avg reward 0.505
#  epoch no:  7800  avg reward 0.505
#  message:  [3]  output:  1  epoch no:  7900  avg reward 0.5116666666666667
#  epoch no:  7900  avg reward 0.5116666666666667
#  message:  [1]  output:  1  epoch no:  8000  avg reward 0.57
#  epoch no:  8000  avg reward 0.57
#  message:  [1]  output:  0  epoch no:  8100  avg reward 0.5183333333333333
#  epoch no:  8100  avg reward 0.5183333333333333
#  message:  [3]  output:  0  epoch no:  8200  avg reward 0.5416666666666666
#  epoch no:  8200  avg reward 0.5416666666666666
#  message:  [2]  output:  0  epoch no:  8300  avg reward 0.5433333333333333
#  epoch no:  8300  avg reward 0.5433333333333333
#  message:  [4]  output:  1  epoch no:  8400  avg reward 0.5316666666666666
#  epoch no:  8400  avg reward 0.5316666666666666
#  message:  [3]  output:  2  epoch no:  8500  avg reward 0.5516666666666666
#  epoch no:  8500  avg reward 0.5516666666666666
#  message:  [3]  output:  0  epoch no:  8600  avg reward 0.5233333333333333
#  epoch no:  8600  avg reward 0.5233333333333333
#  message:  [1]  output:  1  epoch no:  8700  avg reward 0.5483333333333333
#  epoch no:  8700  avg reward 0.5483333333333333
#  message:  [3]  output:  1  epoch no:  8800  avg reward 0.5683333333333334
#  epoch no:  8800  avg reward 0.5683333333333334
#  message:  [0]  output:  2  epoch no:  8900  avg reward 0.5466666666666666
#  epoch no:  8900  avg reward 0.5466666666666666
#  message:  [2]  output:  1  epoch no:  9000  avg reward 0.5533333333333333
#  epoch no:  9000  avg reward 0.5533333333333333
#  message:  [0]  output:  2  epoch no:  9100  avg reward 0.5216666666666666
#  epoch no:  9100  avg reward 0.5216666666666666
#  message:  [4]  output:  2  epoch no:  9200  avg reward 0.5633333333333334
#  epoch no:  9200  avg reward 0.5633333333333334
#  message:  [3]  output:  2  epoch no:  9300  avg reward 0.56
#  epoch no:  9300  avg reward 0.56
#  message:  [0]  output:  0  epoch no:  9400  avg reward 0.5833333333333334
#  epoch no:  9400  avg reward 0.5833333333333334
#  message:  [3]  output:  2  epoch no:  9500  avg reward 0.6033333333333334
#  epoch no:  9500  avg reward 0.6033333333333334
#  message:  [0]  output:  2  epoch no:  9600  avg reward 0.57
#  epoch no:  9600  avg reward 0.57
#  message:  [4]  output:  2  epoch no:  9700  avg reward 0.5816666666666667
#  epoch no:  9700  avg reward 0.5816666666666667
#  message:  [0]  output:  0  epoch no:  9800  avg reward 0.5566666666666666
#  epoch no:  9800  avg reward 0.5566666666666666
#  message:  [4]  output:  2  epoch no:  9900  avg reward 0.5416666666666666
#  epoch no:  9900  avg reward 0.5416666666666666
#  message:  [1]  output:  0  epoch no:  10000  avg reward 0.5583333333333333
#  epoch no:  10000  avg reward 0.5583333333333333
#  message:  [4]  output:  1  epoch no:  10100  avg reward 0.575
#  epoch no:  10100  avg reward 0.575
#  message:  [1]  output:  2  epoch no:  10200  avg reward 0.635
#  epoch no:  10200  avg reward 0.635
#  message:  [4]  output:  1  epoch no:  10300  avg reward 0.5883333333333334
#  epoch no:  10300  avg reward 0.5883333333333334
#  message:  [0]  output:  0  epoch no:  10400  avg reward 0.5666666666666667
#  epoch no:  10400  avg reward 0.5666666666666667
#  message:  [4]  output:  0  epoch no:  10500  avg reward 0.56
#  epoch no:  10500  avg reward 0.56
#  message:  [0]  output:  1  epoch no:  10600  avg reward 0.5966666666666667
#  epoch no:  10600  avg reward 0.5966666666666667
#  message:  [3]  output:  0  epoch no:  10700  avg reward 0.6133333333333333
#  epoch no:  10700  avg reward 0.6133333333333333
#  message:  [1]  output:  2  epoch no:  10800  avg reward 0.6266666666666667
#  epoch no:  10800  avg reward 0.6266666666666667
#  message:  [0]  output:  2  epoch no:  10900  avg reward 0.6466666666666666
#  epoch no:  10900  avg reward 0.6466666666666666
#  message:  [0]  output:  0  epoch no:  11000  avg reward 0.59
#  epoch no:  11000  avg reward 0.59
#  message:  [4]  output:  2  epoch no:  11100  avg reward 0.6033333333333334
#  epoch no:  11100  avg reward 0.6033333333333334
#  message:  [4]  output:  0  epoch no:  11200  avg reward 0.6116666666666667
#  epoch no:  11200  avg reward 0.6116666666666667
#  message:  [4]  output:  2  epoch no:  11300  avg reward 0.615
#  epoch no:  11300  avg reward 0.615
#  message:  [4]  output:  1  epoch no:  11400  avg reward 0.5833333333333334
#  epoch no:  11400  avg reward 0.5833333333333334
#  message:  [3]  output:  0  epoch no:  11500  avg reward 0.6066666666666667
#  epoch no:  11500  avg reward 0.6066666666666667
#  message:  [0]  output:  0  epoch no:  11600  avg reward 0.5566666666666666
#  epoch no:  11600  avg reward 0.5566666666666666
#  message:  [0]  output:  1  epoch no:  11700  avg reward 0.5883333333333334
#  epoch no:  11700  avg reward 0.5883333333333334
#  message:  [4]  output:  2  epoch no:  11800  avg reward 0.6266666666666667
#  epoch no:  11800  avg reward 0.6266666666666667
#  message:  [4]  output:  0  epoch no:  11900  avg reward 0.5883333333333334
#  epoch no:  11900  avg reward 0.5883333333333334
#  message:  [3]  output:  2  epoch no:  12000  avg reward 0.615
#  epoch no:  12000  avg reward 0.615
#  message:  [0]  output:  2  epoch no:  12100  avg reward 0.6216666666666667
#  epoch no:  12100  avg reward 0.6216666666666667
#  message:  [1]  output:  0  epoch no:  12200  avg reward 0.5716666666666667
#  epoch no:  12200  avg reward 0.5716666666666667
#  message:  [0]  output:  1  epoch no:  12300  avg reward 0.6233333333333333
#  epoch no:  12300  avg reward 0.6233333333333333
#  message:  [4]  output:  0  epoch no:  12400  avg reward 0.6316666666666667
#  epoch no:  12400  avg reward 0.6316666666666667
#  message:  [3]  output:  0  epoch no:  12500  avg reward 0.6033333333333334
#  epoch no:  12500  avg reward 0.6033333333333334
#  message:  [0]  output:  1  epoch no:  12600  avg reward 0.6166666666666667
#  epoch no:  12600  avg reward 0.6166666666666667
#  message:  [4]  output:  0  epoch no:  12700  avg reward 0.6183333333333333
#  epoch no:  12700  avg reward 0.6183333333333333
#  message:  [0]  output:  0  epoch no:  12800  avg reward 0.6316666666666667
#  epoch no:  12800  avg reward 0.6316666666666667
#  message:  [4]  output:  2  epoch no:  12900  avg reward 0.61
#  epoch no:  12900  avg reward 0.61
#  message:  [3]  output:  0  epoch no:  13000  avg reward 0.6333333333333333
#  epoch no:  13000  avg reward 0.6333333333333333
#  message:  [4]  output:  1  epoch no:  13100  avg reward 0.6316666666666667
#  epoch no:  13100  avg reward 0.6316666666666667
#  message:  [2]  output:  2  epoch no:  13200  avg reward 0.6166666666666667
#  epoch no:  13200  avg reward 0.6166666666666667
#  message:  [4]  output:  2  epoch no:  13300  avg reward 0.6133333333333333
#  epoch no:  13300  avg reward 0.6133333333333333
#  message:  [4]  output:  2  epoch no:  13400  avg reward 0.6233333333333333
#  epoch no:  13400  avg reward 0.6233333333333333
#  message:  [4]  output:  0  epoch no:  13500  avg reward 0.6583333333333333
#  epoch no:  13500  avg reward 0.6583333333333333
#  message:  [1]  output:  2  epoch no:  13600  avg reward 0.6016666666666667
#  epoch no:  13600  avg reward 0.6016666666666667
#  message:  [0]  output:  1  epoch no:  13700  avg reward 0.615
#  epoch no:  13700  avg reward 0.615
#  message:  [4]  output:  0  epoch no:  13800  avg reward 0.6516666666666666
#  epoch no:  13800  avg reward 0.6516666666666666
#  message:  [0]  output:  2  epoch no:  13900  avg reward 0.6516666666666666
#  epoch no:  13900  avg reward 0.6516666666666666
#  message:  [4]  output:  1  epoch no:  14000  avg reward 0.6466666666666666
#  epoch no:  14000  avg reward 0.6466666666666666
#  message:  [4]  output:  0  epoch no:  14100  avg reward 0.6133333333333333
#  epoch no:  14100  avg reward 0.6133333333333333
#  message:  [1]  output:  2  epoch no:  14200  avg reward 0.615
#  epoch no:  14200  avg reward 0.615
#  message:  [4]  output:  0  epoch no:  14300  avg reward 0.6333333333333333
#  epoch no:  14300  avg reward 0.6333333333333333
#  message:  [0]  output:  1  epoch no:  14400  avg reward 0.6466666666666666
#  epoch no:  14400  avg reward 0.6466666666666666
#  message:  [4]  output:  2  epoch no:  14500  avg reward 0.6283333333333333
#  epoch no:  14500  avg reward 0.6283333333333333
#  message:  [4]  output:  2  epoch no:  14600  avg reward 0.59
#  epoch no:  14600  avg reward 0.59
#  message:  [1]  output:  0  epoch no:  14700  avg reward 0.645
#  epoch no:  14700  avg reward 0.645
#  message:  [2]  output:  0  epoch no:  14800  avg reward 0.645
#  epoch no:  14800  avg reward 0.645
#  message:  [4]  output:  0  epoch no:  14900  avg reward 0.6566666666666666
#  epoch no:  14900  avg reward 0.6566666666666666
#  message:  [2]  output:  2  epoch no:  15000  avg reward 0.635
#  epoch no:  15000  avg reward 0.635
#  message:  [4]  output:  2  epoch no:  15100  avg reward 0.6633333333333333
#  epoch no:  15100  avg reward 0.6633333333333333
#  message:  [3]  output:  0  epoch no:  15200  avg reward 0.6733333333333333
#  epoch no:  15200  avg reward 0.6733333333333333
#  message:  [2]  output:  0  epoch no:  15300  avg reward 0.61
#  epoch no:  15300  avg reward 0.61
#  message:  [0]  output:  1  epoch no:  15400  avg reward 0.6766666666666666
#  epoch no:  15400  avg reward 0.6766666666666666
#  message:  [4]  output:  0  epoch no:  15500  avg reward 0.6666666666666666
#  epoch no:  15500  avg reward 0.6666666666666666
#  message:  [4]  output:  2  epoch no:  15600  avg reward 0.7033333333333334
#  epoch no:  15600  avg reward 0.7033333333333334
#  message:  [0]  output:  2  epoch no:  15700  avg reward 0.6816666666666666
#  epoch no:  15700  avg reward 0.6816666666666666
#  message:  [1]  output:  1  epoch no:  15800  avg reward 0.66
#  epoch no:  15800  avg reward 0.66
#  message:  [3]  output:  1  epoch no:  15900  avg reward 0.6716666666666666
#  epoch no:  15900  avg reward 0.6716666666666666
#  message:  [2]  output:  0  epoch no:  16000  avg reward 0.7216666666666667
#  epoch no:  16000  avg reward 0.7216666666666667
#  message:  [4]  output:  2  epoch no:  16100  avg reward 0.6666666666666666
#  epoch no:  16100  avg reward 0.6666666666666666
#  message:  [0]  output:  0  epoch no:  16200  avg reward 0.6766666666666666
#  epoch no:  16200  avg reward 0.6766666666666666
#  message:  [3]  output:  0  epoch no:  16300  avg reward 0.6916666666666667
#  epoch no:  16300  avg reward 0.6916666666666667
#  message:  [4]  output:  0  epoch no:  16400  avg reward 0.645
#  epoch no:  16400  avg reward 0.645
#  message:  [4]  output:  0  epoch no:  16500  avg reward 0.69
#  epoch no:  16500  avg reward 0.69
#  message:  [4]  output:  1  epoch no:  16600  avg reward 0.735
#  epoch no:  16600  avg reward 0.735
#  message:  [2]  output:  2  epoch no:  16700  avg reward 0.69
#  epoch no:  16700  avg reward 0.69
#  message:  [4]  output:  2  epoch no:  16800  avg reward 0.695
#  epoch no:  16800  avg reward 0.695
#  message:  [1]  output:  1  epoch no:  16900  avg reward 0.74
#  epoch no:  16900  avg reward 0.74
#  message:  [4]  output:  0  epoch no:  17000  avg reward 0.76
#  epoch no:  17000  avg reward 0.76
#  message:  [0]  output:  1  epoch no:  17100  avg reward 0.6716666666666666
#  epoch no:  17100  avg reward 0.6716666666666666
#  message:  [2]  output:  2  epoch no:  17200  avg reward 0.715
#  epoch no:  17200  avg reward 0.715
#  message:  [2]  output:  1  epoch no:  17300  avg reward 0.7166666666666667
#  epoch no:  17300  avg reward 0.7166666666666667
#  message:  [0]  output:  2  epoch no:  17400  avg reward 0.74
#  epoch no:  17400  avg reward 0.74
#  message:  [2]  output:  0  epoch no:  17500  avg reward 0.6833333333333333
#  epoch no:  17500  avg reward 0.6833333333333333
#  message:  [2]  output:  1  epoch no:  17600  avg reward 0.7233333333333334
#  epoch no:  17600  avg reward 0.7233333333333334
#  message:  [4]  output:  0  epoch no:  17700  avg reward 0.695
#  epoch no:  17700  avg reward 0.695
#  message:  [2]  output:  1  epoch no:  17800  avg reward 0.6633333333333333
#  epoch no:  17800  avg reward 0.6633333333333333
#  message:  [0]  output:  1  epoch no:  17900  avg reward 0.735
#  epoch no:  17900  avg reward 0.735
#  message:  [0]  output:  1  epoch no:  18000  avg reward 0.745
#  epoch no:  18000  avg reward 0.745
#  message:  [0]  output:  1  epoch no:  18100  avg reward 0.7
#  epoch no:  18100  avg reward 0.7
#  message:  [2]  output:  0  epoch no:  18200  avg reward 0.76
#  epoch no:  18200  avg reward 0.76
#  message:  [3]  output:  0  epoch no:  18300  avg reward 0.765
#  epoch no:  18300  avg reward 0.765
#  message:  [0]  output:  0  epoch no:  18400  avg reward 0.675
#  epoch no:  18400  avg reward 0.675
#  message:  [4]  output:  1  epoch no:  18500  avg reward 0.7716666666666666
#  epoch no:  18500  avg reward 0.7716666666666666
#  message:  [0]  output:  1  epoch no:  18600  avg reward 0.7316666666666667
#  epoch no:  18600  avg reward 0.7316666666666667
#  message:  [0]  output:  1  epoch no:  18700  avg reward 0.71
#  epoch no:  18700  avg reward 0.71
#  message:  [4]  output:  0  epoch no:  18800  avg reward 0.6966666666666667
#  epoch no:  18800  avg reward 0.6966666666666667
#  message:  [4]  output:  0  epoch no:  18900  avg reward 0.7233333333333334
#  epoch no:  18900  avg reward 0.7233333333333334
#  message:  [2]  output:  1  epoch no:  19000  avg reward 0.7633333333333333
#  epoch no:  19000  avg reward 0.7633333333333333
#  message:  [0]  output:  1  epoch no:  19100  avg reward 0.7433333333333333
#  epoch no:  19100  avg reward 0.7433333333333333
#  message:  [4]  output:  2  epoch no:  19200  avg reward 0.7166666666666667
#  epoch no:  19200  avg reward 0.7166666666666667
#  message:  [3]  output:  2  epoch no:  19300  avg reward 0.795
#  epoch no:  19300  avg reward 0.795
#  message:  [2]  output:  0  epoch no:  19400  avg reward 0.7183333333333334
#  epoch no:  19400  avg reward 0.7183333333333334
#  message:  [0]  output:  1  epoch no:  19500  avg reward 0.7433333333333333
#  epoch no:  19500  avg reward 0.7433333333333333
#  message:  [2]  output:  2  epoch no:  19600  avg reward 0.7283333333333334
#  epoch no:  19600  avg reward 0.7283333333333334
#  message:  [4]  output:  2  epoch no:  19700  avg reward 0.7483333333333333
#  epoch no:  19700  avg reward 0.7483333333333333
#  message:  [0]  output:  2  epoch no:  19800  avg reward 0.7733333333333333
#  epoch no:  19800  avg reward 0.7733333333333333
#  message:  [4]  output:  0  epoch no:  19900  avg reward 0.7283333333333334
#  epoch no:  19900  avg reward 0.7283333333333334
#  message:  [3]  output:  0  epoch no:  20000  avg reward 0.7583333333333333
#  epoch no:  20000  avg reward 0.7583333333333333
#  message:  [3]  output:  0  epoch no:  20100  avg reward 0.7233333333333334
#  epoch no:  20100  avg reward 0.7233333333333334
#  message:  [0]  output:  1  epoch no:  20200  avg reward 0.7316666666666667
#  epoch no:  20200  avg reward 0.7316666666666667
#  message:  [0]  output:  2  epoch no:  20300  avg reward 0.6833333333333333
#  epoch no:  20300  avg reward 0.6833333333333333
#  message:  [2]  output:  0  epoch no:  20400  avg reward 0.7416666666666667
#  epoch no:  20400  avg reward 0.7416666666666667
#  message:  [2]  output:  1  epoch no:  20500  avg reward 0.7383333333333333
#  epoch no:  20500  avg reward 0.7383333333333333
#  message:  [0]  output:  0  epoch no:  20600  avg reward 0.7733333333333333
#  epoch no:  20600  avg reward 0.7733333333333333
#  message:  [4]  output:  1  epoch no:  20700  avg reward 0.725
#  epoch no:  20700  avg reward 0.725
#  message:  [2]  output:  2  epoch no:  20800  avg reward 0.7683333333333333
#  epoch no:  20800  avg reward 0.7683333333333333
#  message:  [3]  output:  2  epoch no:  20900  avg reward 0.7483333333333333
#  epoch no:  20900  avg reward 0.7483333333333333
#  message:  [4]  output:  2  epoch no:  21000  avg reward 0.7816666666666666
#  epoch no:  21000  avg reward 0.7816666666666666
#  message:  [3]  output:  0  epoch no:  21100  avg reward 0.7116666666666667
#  epoch no:  21100  avg reward 0.7116666666666667
#  message:  [0]  output:  1  epoch no:  21200  avg reward 0.7533333333333333
#  epoch no:  21200  avg reward 0.7533333333333333
#  message:  [0]  output:  0  epoch no:  21300  avg reward 0.7566666666666667
#  epoch no:  21300  avg reward 0.7566666666666667
#  message:  [4]  output:  0  epoch no:  21400  avg reward 0.7383333333333333
#  epoch no:  21400  avg reward 0.7383333333333333
#  message:  [2]  output:  2  epoch no:  21500  avg reward 0.79
#  epoch no:  21500  avg reward 0.79
#  message:  [2]  output:  0  epoch no:  21600  avg reward 0.7266666666666667
#  epoch no:  21600  avg reward 0.7266666666666667
#  message:  [0]  output:  2  epoch no:  21700  avg reward 0.7516666666666667
#  epoch no:  21700  avg reward 0.7516666666666667
#  message:  [2]  output:  0  epoch no:  21800  avg reward 0.73
#  epoch no:  21800  avg reward 0.73
#  message:  [4]  output:  2  epoch no:  21900  avg reward 0.7966666666666666
#  epoch no:  21900  avg reward 0.7966666666666666
#  message:  [2]  output:  1  epoch no:  22000  avg reward 0.7766666666666666
#  epoch no:  22000  avg reward 0.7766666666666666
#  message:  [1]  output:  2  epoch no:  22100  avg reward 0.76
#  epoch no:  22100  avg reward 0.76
#  message:  [0]  output:  0  epoch no:  22200  avg reward 0.7883333333333333
#  epoch no:  22200  avg reward 0.7883333333333333
#  message:  [0]  output:  1  epoch no:  22300  avg reward 0.715
#  epoch no:  22300  avg reward 0.715
#  message:  [2]  output:  1  epoch no:  22400  avg reward 0.7216666666666667
#  epoch no:  22400  avg reward 0.7216666666666667
#  message:  [2]  output:  1  epoch no:  22500  avg reward 0.7683333333333333
#  epoch no:  22500  avg reward 0.7683333333333333
#  message:  [0]  output:  1  epoch no:  22600  avg reward 0.7983333333333333
#  epoch no:  22600  avg reward 0.7983333333333333
#  message:  [2]  output:  1  epoch no:  22700  avg reward 0.7466666666666667
#  epoch no:  22700  avg reward 0.7466666666666667
#  message:  [4]  output:  2  epoch no:  22800  avg reward 0.7216666666666667
#  epoch no:  22800  avg reward 0.7216666666666667
#  message:  [2]  output:  2  epoch no:  22900  avg reward 0.7883333333333333
#  epoch no:  22900  avg reward 0.7883333333333333
#  message:  [3]  output:  0  epoch no:  23000  avg reward 0.7316666666666667
#  epoch no:  23000  avg reward 0.7316666666666667
#  message:  [0]  output:  0  epoch no:  23100  avg reward 0.7633333333333333
#  epoch no:  23100  avg reward 0.7633333333333333
#  message:  [0]  output:  2  epoch no:  23200  avg reward 0.7783333333333333
#  epoch no:  23200  avg reward 0.7783333333333333
#  message:  [4]  output:  1  epoch no:  23300  avg reward 0.745
#  epoch no:  23300  avg reward 0.745
#  message:  [0]  output:  1  epoch no:  23400  avg reward 0.7666666666666667
#  epoch no:  23400  avg reward 0.7666666666666667
#  message:  [4]  output:  1  epoch no:  23500  avg reward 0.7833333333333333
#  epoch no:  23500  avg reward 0.7833333333333333
#  message:  [4]  output:  0  epoch no:  23600  avg reward 0.7583333333333333
#  epoch no:  23600  avg reward 0.7583333333333333
#  message:  [3]  output:  1  epoch no:  23700  avg reward 0.7583333333333333
#  epoch no:  23700  avg reward 0.7583333333333333
#  message:  [2]  output:  0  epoch no:  23800  avg reward 0.775
#  epoch no:  23800  avg reward 0.775
#  message:  [2]  output:  2  epoch no:  23900  avg reward 0.805
#  epoch no:  23900  avg reward 0.805
#  message:  [2]  output:  0  epoch no:  24000  avg reward 0.795
#  epoch no:  24000  avg reward 0.795
#  message:  [0]  output:  0  epoch no:  24100  avg reward 0.75
#  epoch no:  24100  avg reward 0.75
#  message:  [2]  output:  0  epoch no:  24200  avg reward 0.735
#  epoch no:  24200  avg reward 0.735
#  message:  [4]  output:  0  epoch no:  24300  avg reward 0.7716666666666666
#  epoch no:  24300  avg reward 0.7716666666666666
#  message:  [2]  output:  2  epoch no:  24400  avg reward 0.8283333333333334
#  epoch no:  24400  avg reward 0.8283333333333334
#  message:  [3]  output:  0  epoch no:  24500  avg reward 0.775
#  epoch no:  24500  avg reward 0.775
#  message:  [2]  output:  2  epoch no:  24600  avg reward 0.765
#  epoch no:  24600  avg reward 0.765
#  message:  [0]  output:  1  epoch no:  24700  avg reward 0.7466666666666667
#  epoch no:  24700  avg reward 0.7466666666666667
#  message:  [4]  output:  2  epoch no:  24800  avg reward 0.7783333333333333
#  epoch no:  24800  avg reward 0.7783333333333333
#  message:  [3]  output:  1  epoch no:  24900  avg reward 0.71
#  epoch no:  24900  avg reward 0.71
#  message:  [4]  output:  2  epoch no:  25000  avg reward 0.7583333333333333
#  epoch no:  25000  avg reward 0.7583333333333333
#  message:  [4]  output:  2  epoch no:  25100  avg reward 0.805
#  epoch no:  25100  avg reward 0.805
#  message:  [4]  output:  0  epoch no:  25200  avg reward 0.7433333333333333
#  epoch no:  25200  avg reward 0.7433333333333333
#  message:  [2]  output:  2  epoch no:  25300  avg reward 0.825
#  epoch no:  25300  avg reward 0.825
#  message:  [0]  output:  2  epoch no:  25400  avg reward 0.7733333333333333
#  epoch no:  25400  avg reward 0.7733333333333333
#  message:  [3]  output:  1  epoch no:  25500  avg reward 0.7433333333333333
#  epoch no:  25500  avg reward 0.7433333333333333
#  message:  [2]  output:  0  epoch no:  25600  avg reward 0.7816666666666666
#  epoch no:  25600  avg reward 0.7816666666666666
#  message:  [0]  output:  2  epoch no:  25700  avg reward 0.7716666666666666
#  epoch no:  25700  avg reward 0.7716666666666666
#  message:  [0]  output:  0  epoch no:  25800  avg reward 0.7983333333333333
#  epoch no:  25800  avg reward 0.7983333333333333
#  message:  [4]  output:  2  epoch no:  25900  avg reward 0.745
#  epoch no:  25900  avg reward 0.745
#  message:  [2]  output:  2  epoch no:  26000  avg reward 0.77
#  epoch no:  26000  avg reward 0.77
#  message:  [2]  output:  0  epoch no:  26100  avg reward 0.7633333333333333
#  epoch no:  26100  avg reward 0.7633333333333333
#  message:  [4]  output:  2  epoch no:  26200  avg reward 0.79
#  epoch no:  26200  avg reward 0.79
#  message:  [0]  output:  1  epoch no:  26300  avg reward 0.7533333333333333
#  epoch no:  26300  avg reward 0.7533333333333333
#  message:  [4]  output:  2  epoch no:  26400  avg reward 0.735
#  epoch no:  26400  avg reward 0.735
#  message:  [3]  output:  2  epoch no:  26500  avg reward 0.8183333333333334
#  epoch no:  26500  avg reward 0.8183333333333334
#  message:  [0]  output:  2  epoch no:  26600  avg reward 0.8066666666666666
#  epoch no:  26600  avg reward 0.8066666666666666
#  message:  [2]  output:  0  epoch no:  26700  avg reward 0.7833333333333333
#  epoch no:  26700  avg reward 0.7833333333333333
#  message:  [4]  output:  0  epoch no:  26800  avg reward 0.7616666666666667
#  epoch no:  26800  avg reward 0.7616666666666667
#  message:  [4]  output:  1  epoch no:  26900  avg reward 0.755
#  epoch no:  26900  avg reward 0.755
#  message:  [2]  output:  2  epoch no:  27000  avg reward 0.865
#  epoch no:  27000  avg reward 0.865
#  message:  [3]  output:  0  epoch no:  27100  avg reward 0.745
#  epoch no:  27100  avg reward 0.745
#  message:  [1]  output:  2  epoch no:  27200  avg reward 0.785
#  epoch no:  27200  avg reward 0.785
#  message:  [2]  output:  1  epoch no:  27300  avg reward 0.7833333333333333
#  epoch no:  27300  avg reward 0.7833333333333333
#  message:  [4]  output:  0  epoch no:  27400  avg reward 0.7883333333333333
#  epoch no:  27400  avg reward 0.7883333333333333
#  message:  [0]  output:  2  epoch no:  27500  avg reward 0.8416666666666667
#  epoch no:  27500  avg reward 0.8416666666666667
#  message:  [2]  output:  1  epoch no:  27600  avg reward 0.81
#  epoch no:  27600  avg reward 0.81
#  message:  [0]  output:  2  epoch no:  27700  avg reward 0.81
#  epoch no:  27700  avg reward 0.81
#  message:  [4]  output:  1  epoch no:  27800  avg reward 0.795
#  epoch no:  27800  avg reward 0.795
#  message:  [4]  output:  2  epoch no:  27900  avg reward 0.7883333333333333
#  epoch no:  27900  avg reward 0.7883333333333333
#  message:  [4]  output:  2  epoch no:  28000  avg reward 0.835
#  epoch no:  28000  avg reward 0.835
#  message:  [2]  output:  2  epoch no:  28100  avg reward 0.8133333333333334
#  epoch no:  28100  avg reward 0.8133333333333334
#  message:  [0]  output:  0  epoch no:  28200  avg reward 0.8366666666666667
#  epoch no:  28200  avg reward 0.8366666666666667
#  message:  [2]  output:  2  epoch no:  28300  avg reward 0.8
#  epoch no:  28300  avg reward 0.8
#  message:  [4]  output:  2  epoch no:  28400  avg reward 0.8283333333333334
#  epoch no:  28400  avg reward 0.8283333333333334
#  message:  [2]  output:  1  epoch no:  28500  avg reward 0.7433333333333333
#  epoch no:  28500  avg reward 0.7433333333333333
#  message:  [3]  output:  2  epoch no:  28600  avg reward 0.84
#  epoch no:  28600  avg reward 0.84
#  message:  [4]  output:  0  epoch no:  28700  avg reward 0.755
#  epoch no:  28700  avg reward 0.755
#  message:  [2]  output:  1  epoch no:  28800  avg reward 0.8033333333333333
#  epoch no:  28800  avg reward 0.8033333333333333
#  message:  [0]  output:  2  epoch no:  28900  avg reward 0.7666666666666667
#  epoch no:  28900  avg reward 0.7666666666666667
#  message:  [4]  output:  0  epoch no:  29000  avg reward 0.7483333333333333
#  epoch no:  29000  avg reward 0.7483333333333333
#  message:  [1]  output:  0  epoch no:  29100  avg reward 0.8
#  epoch no:  29100  avg reward 0.8
#  message:  [0]  output:  2  epoch no:  29200  avg reward 0.8333333333333334
#  epoch no:  29200  avg reward 0.8333333333333334
#  message:  [1]  output:  0  epoch no:  29300  avg reward 0.81
#  epoch no:  29300  avg reward 0.81
#  message:  [4]  output:  2  epoch no:  29400  avg reward 0.7916666666666666
#  epoch no:  29400  avg reward 0.7916666666666666
#  message:  [2]  output:  0  epoch no:  29500  avg reward 0.7733333333333333
#  epoch no:  29500  avg reward 0.7733333333333333
#  message:  [4]  output:  0  epoch no:  29600  avg reward 0.835
#  epoch no:  29600  avg reward 0.835
#  message:  [2]  output:  1  epoch no:  29700  avg reward 0.8033333333333333
#  epoch no:  29700  avg reward 0.8033333333333333
#  message:  [3]  output:  2  epoch no:  29800  avg reward 0.8266666666666667
#  epoch no:  29800  avg reward 0.8266666666666667
#  message:  [2]  output:  2  epoch no:  29900  avg reward 0.79
#  epoch no:  29900  avg reward 0.79
#  message:  [0]  output:  0  epoch no:  30000  avg reward 0.78
#  epoch no:  30000  avg reward 0.78
#  message:  [2]  output:  2  epoch no:  30100  avg reward 0.7783333333333333
#  epoch no:  30100  avg reward 0.7783333333333333
#  message:  [0]  output:  2  epoch no:  30200  avg reward 0.815
#  epoch no:  30200  avg reward 0.815
#  message:  [2]  output:  1  epoch no:  30300  avg reward 0.835
#  epoch no:  30300  avg reward 0.835
#  message:  [2]  output:  2  epoch no:  30400  avg reward 0.8233333333333334
#  epoch no:  30400  avg reward 0.8233333333333334
#  message:  [2]  output:  1  epoch no:  30500  avg reward 0.8316666666666667
#  epoch no:  30500  avg reward 0.8316666666666667
#  message:  [2]  output:  2  epoch no:  30600  avg reward 0.82
#  epoch no:  30600  avg reward 0.82
#  message:  [4]  output:  2  epoch no:  30700  avg reward 0.8066666666666666
#  epoch no:  30700  avg reward 0.8066666666666666
#  message:  [4]  output:  0  epoch no:  30800  avg reward 0.845
#  epoch no:  30800  avg reward 0.845
#  message:  [1]  output:  0  epoch no:  30900  avg reward 0.84
#  epoch no:  30900  avg reward 0.84
#  message:  [2]  output:  0  epoch no:  31000  avg reward 0.8333333333333334
#  epoch no:  31000  avg reward 0.8333333333333334
#  message:  [0]  output:  1  epoch no:  31100  avg reward 0.825
#  epoch no:  31100  avg reward 0.825
#  message:  [2]  output:  2  epoch no:  31200  avg reward 0.8316666666666667
#  epoch no:  31200  avg reward 0.8316666666666667
#  message:  [2]  output:  1  epoch no:  31300  avg reward 0.8366666666666667
#  epoch no:  31300  avg reward 0.8366666666666667
#  message:  [0]  output:  2  epoch no:  31400  avg reward 0.8183333333333334
#  epoch no:  31400  avg reward 0.8183333333333334
#  message:  [2]  output:  0  epoch no:  31500  avg reward 0.83
#  epoch no:  31500  avg reward 0.83
#  message:  [0]  output:  2  epoch no:  31600  avg reward 0.8183333333333334
#  epoch no:  31600  avg reward 0.8183333333333334
#  message:  [2]  output:  2  epoch no:  31700  avg reward 0.8233333333333334
#  epoch no:  31700  avg reward 0.8233333333333334
#  message:  [1]  output:  2  epoch no:  31800  avg reward 0.795
#  epoch no:  31800  avg reward 0.795
#  message:  [3]  output:  2  epoch no:  31900  avg reward 0.7716666666666666
#  epoch no:  31900  avg reward 0.7716666666666666
#  message:  [4]  output:  0  epoch no:  32000  avg reward 0.8233333333333334
#  epoch no:  32000  avg reward 0.8233333333333334
#  message:  [2]  output:  0  epoch no:  32100  avg reward 0.825
#  epoch no:  32100  avg reward 0.825
#  message:  [2]  output:  0  epoch no:  32200  avg reward 0.8316666666666667
#  epoch no:  32200  avg reward 0.8316666666666667
#  message:  [0]  output:  0  epoch no:  32300  avg reward 0.83
#  epoch no:  32300  avg reward 0.83
#  message:  [2]  output:  0  epoch no:  32400  avg reward 0.815
#  epoch no:  32400  avg reward 0.815
#  message:  [1]  output:  2  epoch no:  32500  avg reward 0.8383333333333334
#  epoch no:  32500  avg reward 0.8383333333333334
#  message:  [2]  output:  0  epoch no:  32600  avg reward 0.8616666666666667
#  epoch no:  32600  avg reward 0.8616666666666667
#  message:  [0]  output:  0  epoch no:  32700  avg reward 0.815
#  epoch no:  32700  avg reward 0.815
#  message:  [4]  output:  1  epoch no:  32800  avg reward 0.84
#  epoch no:  32800  avg reward 0.84
#  message:  [4]  output:  0  epoch no:  32900  avg reward 0.8166666666666667
#  epoch no:  32900  avg reward 0.8166666666666667
#  message:  [1]  output:  2  epoch no:  33000  avg reward 0.7583333333333333
#  epoch no:  33000  avg reward 0.7583333333333333
#  message:  [4]  output:  0  epoch no:  33100  avg reward 0.8216666666666667
#  epoch no:  33100  avg reward 0.8216666666666667
#  message:  [0]  output:  2  epoch no:  33200  avg reward 0.8166666666666667
#  epoch no:  33200  avg reward 0.8166666666666667
#  message:  [2]  output:  0  epoch no:  33300  avg reward 0.795
#  epoch no:  33300  avg reward 0.795
#  message:  [4]  output:  0  epoch no:  33400  avg reward 0.845
#  epoch no:  33400  avg reward 0.845
#  message:  [1]  output:  1  epoch no:  33500  avg reward 0.79
#  epoch no:  33500  avg reward 0.79
#  message:  [4]  output:  0  epoch no:  33600  avg reward 0.855
#  epoch no:  33600  avg reward 0.855
#  message:  [4]  output:  0  epoch no:  33700  avg reward 0.8033333333333333
#  epoch no:  33700  avg reward 0.8033333333333333
#  message:  [2]  output:  2  epoch no:  33800  avg reward 0.81
#  epoch no:  33800  avg reward 0.81
#  message:  [4]  output:  2  epoch no:  33900  avg reward 0.8216666666666667
#  epoch no:  33900  avg reward 0.8216666666666667
#  message:  [2]  output:  0  epoch no:  34000  avg reward 0.845
#  epoch no:  34000  avg reward 0.845
#  message:  [0]  output:  1  epoch no:  34100  avg reward 0.8216666666666667
#  epoch no:  34100  avg reward 0.8216666666666667
#  message:  [0]  output:  1  epoch no:  34200  avg reward 0.8433333333333334
#  epoch no:  34200  avg reward 0.8433333333333334
#  message:  [4]  output:  0  epoch no:  34300  avg reward 0.7766666666666666
#  epoch no:  34300  avg reward 0.7766666666666666
#  message:  [3]  output:  1  epoch no:  34400  avg reward 0.8266666666666667
#  epoch no:  34400  avg reward 0.8266666666666667
#  message:  [4]  output:  2  epoch no:  34500  avg reward 0.8733333333333333
#  epoch no:  34500  avg reward 0.8733333333333333
#  message:  [4]  output:  2  epoch no:  34600  avg reward 0.7716666666666666
#  epoch no:  34600  avg reward 0.7716666666666666
#  message:  [4]  output:  1  epoch no:  34700  avg reward 0.7933333333333333
#  epoch no:  34700  avg reward 0.7933333333333333
#  message:  [4]  output:  1  epoch no:  34800  avg reward 0.8566666666666667
#  epoch no:  34800  avg reward 0.8566666666666667
#  message:  [2]  output:  1  epoch no:  34900  avg reward 0.8383333333333334
#  epoch no:  34900  avg reward 0.8383333333333334
#  message:  [1]  output:  1  epoch no:  35000  avg reward 0.8433333333333334
#  epoch no:  35000  avg reward 0.8433333333333334
#  message:  [2]  output:  2  epoch no:  35100  avg reward 0.8266666666666667
#  epoch no:  35100  avg reward 0.8266666666666667
#  message:  [0]  output:  0  epoch no:  35200  avg reward 0.7933333333333333
#  epoch no:  35200  avg reward 0.7933333333333333
#  message:  [4]  output:  0  epoch no:  35300  avg reward 0.8316666666666667
#  epoch no:  35300  avg reward 0.8316666666666667
#  message:  [2]  output:  2  epoch no:  35400  avg reward 0.82
#  epoch no:  35400  avg reward 0.82
#  message:  [2]  output:  2  epoch no:  35500  avg reward 0.825
#  epoch no:  35500  avg reward 0.825
#  message:  [0]  output:  0  epoch no:  35600  avg reward 0.8933333333333333
#  epoch no:  35600  avg reward 0.8933333333333333
#  message:  [4]  output:  0  epoch no:  35700  avg reward 0.845
#  epoch no:  35700  avg reward 0.845
#  message:  [2]  output:  0  epoch no:  35800  avg reward 0.8233333333333334
#  epoch no:  35800  avg reward 0.8233333333333334
#  message:  [2]  output:  0  epoch no:  35900  avg reward 0.8533333333333334
#  epoch no:  35900  avg reward 0.8533333333333334
#  message:  [1]  output:  2  epoch no:  36000  avg reward 0.8566666666666667
#  epoch no:  36000  avg reward 0.8566666666666667
#  message:  [1]  output:  1  epoch no:  36100  avg reward 0.8183333333333334
#  epoch no:  36100  avg reward 0.8183333333333334
#  message:  [0]  output:  2  epoch no:  36200  avg reward 0.8366666666666667
#  epoch no:  36200  avg reward 0.8366666666666667
#  message:  [2]  output:  0  epoch no:  36300  avg reward 0.8616666666666667
#  epoch no:  36300  avg reward 0.8616666666666667
#  message:  [4]  output:  0  epoch no:  36400  avg reward 0.8516666666666667
#  epoch no:  36400  avg reward 0.8516666666666667
#  message:  [0]  output:  0  epoch no:  36500  avg reward 0.8883333333333333
#  epoch no:  36500  avg reward 0.8883333333333333
#  message:  [4]  output:  0  epoch no:  36600  avg reward 0.84
#  epoch no:  36600  avg reward 0.84
#  message:  [0]  output:  1  epoch no:  36700  avg reward 0.885
#  epoch no:  36700  avg reward 0.885
#  message:  [4]  output:  0  epoch no:  36800  avg reward 0.825
#  epoch no:  36800  avg reward 0.825
#  message:  [4]  output:  0  epoch no:  36900  avg reward 0.83
#  epoch no:  36900  avg reward 0.83
#  message:  [0]  output:  2  epoch no:  37000  avg reward 0.885
#  epoch no:  37000  avg reward 0.885
#  message:  [4]  output:  1  epoch no:  37100  avg reward 0.8833333333333333
#  epoch no:  37100  avg reward 0.8833333333333333
#  message:  [2]  output:  1  epoch no:  37200  avg reward 0.8583333333333333
#  epoch no:  37200  avg reward 0.8583333333333333
#  message:  [4]  output:  1  epoch no:  37300  avg reward 0.8966666666666666
#  epoch no:  37300  avg reward 0.8966666666666666
#  message:  [2]  output:  0  epoch no:  37400  avg reward 0.8583333333333333
#  epoch no:  37400  avg reward 0.8583333333333333
#  message:  [1]  output:  0  epoch no:  37500  avg reward 0.8483333333333334
#  epoch no:  37500  avg reward 0.8483333333333334
#  message:  [2]  output:  2  epoch no:  37600  avg reward 0.8833333333333333
#  epoch no:  37600  avg reward 0.8833333333333333
#  message:  [4]  output:  0  epoch no:  37700  avg reward 0.8116666666666666
#  epoch no:  37700  avg reward 0.8116666666666666
#  message:  [3]  output:  0  epoch no:  37800  avg reward 0.86
#  epoch no:  37800  avg reward 0.86
#  message:  [2]  output:  0  epoch no:  37900  avg reward 0.8933333333333333
#  epoch no:  37900  avg reward 0.8933333333333333
#  message:  [2]  output:  0  epoch no:  38000  avg reward 0.865
#  epoch no:  38000  avg reward 0.865
#  message:  [2]  output:  0  epoch no:  38100  avg reward 0.8516666666666667
#  epoch no:  38100  avg reward 0.8516666666666667
#  message:  [3]  output:  1  epoch no:  38200  avg reward 0.8716666666666667
#  epoch no:  38200  avg reward 0.8716666666666667
#  message:  [1]  output:  1  epoch no:  38300  avg reward 0.85
#  epoch no:  38300  avg reward 0.85
#  message:  [2]  output:  2  epoch no:  38400  avg reward 0.875
#  epoch no:  38400  avg reward 0.875
#  message:  [2]  output:  1  epoch no:  38500  avg reward 0.8483333333333334
#  epoch no:  38500  avg reward 0.8483333333333334
#  message:  [2]  output:  2  epoch no:  38600  avg reward 0.8166666666666667
#  epoch no:  38600  avg reward 0.8166666666666667
#  message:  [4]  output:  0  epoch no:  38700  avg reward 0.8416666666666667
#  epoch no:  38700  avg reward 0.8416666666666667
#  message:  [4]  output:  0  epoch no:  38800  avg reward 0.8516666666666667
#  epoch no:  38800  avg reward 0.8516666666666667
#  message:  [0]  output:  0  epoch no:  38900  avg reward 0.8233333333333334
#  epoch no:  38900  avg reward 0.8233333333333334
#  message:  [2]  output:  0  epoch no:  39000  avg reward 0.8483333333333334
#  epoch no:  39000  avg reward 0.8483333333333334
#  message:  [1]  output:  2  epoch no:  39100  avg reward 0.8333333333333334
#  epoch no:  39100  avg reward 0.8333333333333334
#  message:  [3]  output:  1  epoch no:  39200  avg reward 0.8316666666666667
#  epoch no:  39200  avg reward 0.8316666666666667
#  message:  [2]  output:  2  epoch no:  39300  avg reward 0.8116666666666666
#  epoch no:  39300  avg reward 0.8116666666666666
#  message:  [0]  output:  1  epoch no:  39400  avg reward 0.815
#  epoch no:  39400  avg reward 0.815
#  message:  [2]  output:  1  epoch no:  39500  avg reward 0.8716666666666667
#  epoch no:  39500  avg reward 0.8716666666666667
#  message:  [3]  output:  0  epoch no:  39600  avg reward 0.8483333333333334
#  epoch no:  39600  avg reward 0.8483333333333334
#  message:  [4]  output:  2  epoch no:  39700  avg reward 0.8816666666666667
#  epoch no:  39700  avg reward 0.8816666666666667
#  message:  [2]  output:  2  epoch no:  39800  avg reward 0.8833333333333333
#  epoch no:  39800  avg reward 0.8833333333333333
#  message:  [1]  output:  2  epoch no:  39900  avg reward 0.855
#  epoch no:  39900  avg reward 0.855
#  message:  [0]  output:  2  epoch no:  40000  avg reward 0.845
#  epoch no:  40000  avg reward 0.845
#  message:  [2]  output:  0  epoch no:  40100  avg reward 0.8816666666666667
#  epoch no:  40100  avg reward 0.8816666666666667
#  message:  [4]  output:  2  epoch no:  40200  avg reward 0.8466666666666667
#  epoch no:  40200  avg reward 0.8466666666666667
#  message:  [3]  output:  0  epoch no:  40300  avg reward 0.865
#  epoch no:  40300  avg reward 0.865
#  message:  [0]  output:  2  epoch no:  40400  avg reward 0.815
#  epoch no:  40400  avg reward 0.815
#  message:  [1]  output:  1  epoch no:  40500  avg reward 0.835
#  epoch no:  40500  avg reward 0.835
#  message:  [2]  output:  0  epoch no:  40600  avg reward 0.8433333333333334
#  epoch no:  40600  avg reward 0.8433333333333334
#  message:  [0]  output:  2  epoch no:  40700  avg reward 0.8183333333333334
#  epoch no:  40700  avg reward 0.8183333333333334
#  message:  [2]  output:  0  epoch no:  40800  avg reward 0.8633333333333333
#  epoch no:  40800  avg reward 0.8633333333333333
#  message:  [3]  output:  1  epoch no:  40900  avg reward 0.8566666666666667
#  epoch no:  40900  avg reward 0.8566666666666667
#  message:  [4]  output:  1  epoch no:  41000  avg reward 0.8866666666666667
#  epoch no:  41000  avg reward 0.8866666666666667
#  message:  [2]  output:  2  epoch no:  41100  avg reward 0.8733333333333333
#  epoch no:  41100  avg reward 0.8733333333333333
#  message:  [1]  output:  2  epoch no:  41200  avg reward 0.8383333333333334
#  epoch no:  41200  avg reward 0.8383333333333334
#  message:  [4]  output:  0  epoch no:  41300  avg reward 0.8983333333333333
# ...
#  message:  [3]  output:  0  epoch no:  47800  avg reward 0.8866666666666667
#  epoch no:  47800  avg reward 0.8866666666666667
#  message:  [4]  output:  2  epoch no:  47900  avg reward 0.88
#  epoch no:  47900  avg reward 0.88
#  message:  [4]  output:  2  epoch no:  48000  avg reward 0.855
#  epoch no:  48000  avg reward 0.855
#  message:  [2]  output:  0  epoch no:  48100  avg reward 0.865
#  epoch no:  48100  avg reward 0.865
#  message:  [2]  output:  1  epoch no:  48200  avg reward 0.8816666666666667
#  epoch no:  48200  avg reward 0.8816666666666667
#  message:  [0]  output:  0  epoch no:  48300  avg reward 0.9033333333333333
#  epoch no:  48300  avg reward 0.9033333333333333
#  message:  [2]  output:  0  epoch no:  48400  avg reward 0.875
#  epoch no:  48400  avg reward 0.875
#  message:  [2]  output:  2  epoch no:  48500  avg reward 0.8533333333333334
#  epoch no:  48500  avg reward 0.8533333333333334
#  message:  [1]  output:  0  epoch no:  48600  avg reward 0.875
#  epoch no:  48600  avg reward 0.875
#  message:  [4]  output:  0  epoch no:  48700  avg reward 0.9066666666666666
#  epoch no:  48700  avg reward 0.9066666666666666
#  message:  [3]  output:  2  epoch no:  48800  avg reward 0.9016666666666666
#  epoch no:  48800  avg reward 0.9016666666666666
#  message:  [3]  output:  0  epoch no:  48900  avg reward 0.8866666666666667
#  epoch no:  48900  avg reward 0.8866666666666667
#  message:  [0]  output:  2  epoch no:  49000  avg reward 0.8966666666666666
#  epoch no:  49000  avg reward 0.8966666666666666
#  message:  [0]  output:  1  epoch no:  49100  avg reward 0.865
#  epoch no:  49100  avg reward 0.865
#  message:  [1]  output:  2  epoch no:  49200  avg reward 0.8583333333333333
#  epoch no:  49200  avg reward 0.8583333333333333
#  message:  [0]  output:  0  epoch no:  49300  avg reward 0.8733333333333333
#  epoch no:  49300  avg reward 0.8733333333333333
#  message:  [0]  output:  2  epoch no:  49400  avg reward 0.8866666666666667
#  epoch no:  49400  avg reward 0.8866666666666667
#  message:  [2]  output:  1  epoch no:  49500  avg reward 0.8533333333333334
#  epoch no:  49500  avg reward 0.8533333333333334
#  message:  [2]  output:  2  epoch no:  49600  avg reward 0.9183333333333333
#  epoch no:  49600  avg reward 0.9183333333333333
#  message:  [3]  output:  1  epoch no:  49700  avg reward 0.8833333333333333
#  epoch no:  49700  avg reward 0.8833333333333333
#  message:  [3]  output:  1  epoch no:  49800  avg reward 0.9216666666666666
#  epoch no:  49800  avg reward 0.9216666666666666
#  message:  [4]  output:  2  epoch no:  49900  avg reward 0.895
#  epoch no:  49900  avg reward 0.895
#  message:  [1]  output:  1  epoch no:  50000  avg reward 0.9
#  epoch no:  50000  avg reward 0.9
#  message:  [0]  output:  2  epoch no:  50100  avg reward 0.8533333333333334
#  epoch no:  50100  avg reward 0.8533333333333334
#  message:  [1]  output:  0  epoch no:  50200  avg reward 0.9116666666666666
#  epoch no:  50200  avg reward 0.9116666666666666
#  message:  [3]  output:  2  epoch no:  50300  avg reward 0.8916666666666667
#  epoch no:  50300  avg reward 0.8916666666666667
#  message:  [0]  output:  0  epoch no:  50400  avg reward 0.8916666666666667
#  epoch no:  50400  avg reward 0.8916666666666667
#  message:  [1]  output:  0  epoch no:  50500  avg reward 0.9066666666666666
#  epoch no:  50500  avg reward 0.9066666666666666
#  message:  [2]  output:  1  epoch no:  50600  avg reward 0.8783333333333333
#  epoch no:  50600  avg reward 0.8783333333333333
#  message:  [1]  output:  1  epoch no:  50700  avg reward 0.8533333333333334
#  epoch no:  50700  avg reward 0.8533333333333334
#  message:  [3]  output:  0  epoch no:  50800  avg reward 0.8633333333333333
#  epoch no:  50800  avg reward 0.8633333333333333
#  message:  [4]  output:  0  epoch no:  50900  avg reward 0.8783333333333333
#  epoch no:  50900  avg reward 0.8783333333333333
#  message:  [4]  output:  2  epoch no:  51000  avg reward 0.8733333333333333
#  epoch no:  51000  avg reward 0.8733333333333333
#  message:  [0]  output:  1  epoch no:  51100  avg reward 0.9183333333333333
#  epoch no:  51100  avg reward 0.9183333333333333
#  message:  [2]  output:  0  epoch no:  51200  avg reward 0.8733333333333333
#  epoch no:  51200  avg reward 0.8733333333333333
#  message:  [0]  output:  1  epoch no:  51300  avg reward 0.8783333333333333
#  epoch no:  51300  avg reward 0.8783333333333333
#  message:  [2]  output:  0  epoch no:  51400  avg reward 0.8116666666666666
#  epoch no:  51400  avg reward 0.8116666666666666
#  message:  [3]  output:  0  epoch no:  51500  avg reward 0.9033333333333333
#  epoch no:  51500  avg reward 0.9033333333333333
#  message:  [2]  output:  0  epoch no:  51600  avg reward 0.8666666666666667
#  epoch no:  51600  avg reward 0.8666666666666667
#  message:  [2]  output:  2  epoch no:  51700  avg reward 0.9
#  epoch no:  51700  avg reward 0.9
#  message:  [4]  output:  0  epoch no:  51800  avg reward 0.9116666666666666
#  epoch no:  51800  avg reward 0.9116666666666666
#  message:  [0]  output:  2  epoch no:  51900  avg reward 0.8716666666666667
#  epoch no:  51900  avg reward 0.8716666666666667
#  message:  [4]  output:  2  epoch no:  52000  avg reward 0.86
#  epoch no:  52000  avg reward 0.86
#  message:  [2]  output:  2  epoch no:  52100  avg reward 0.8933333333333333
#  epoch no:  52100  avg reward 0.8933333333333333
#  message:  [0]  output:  2  epoch no:  52200  avg reward 0.875
#  epoch no:  52200  avg reward 0.875
#  message:  [4]  output:  0  epoch no:  52300  avg reward 0.9116666666666666
#  epoch no:  52300  avg reward 0.9116666666666666
#  message:  [3]  output:  2  epoch no:  52400  avg reward 0.8883333333333333
#  epoch no:  52400  avg reward 0.8883333333333333
#  message:  [2]  output:  0  epoch no:  52500  avg reward 0.9033333333333333
#  epoch no:  52500  avg reward 0.9033333333333333
#  message:  [2]  output:  0  epoch no:  52600  avg reward 0.8983333333333333
#  epoch no:  52600  avg reward 0.8983333333333333
#  message:  [4]  output:  2  epoch no:  52700  avg reward 0.905
#  epoch no:  52700  avg reward 0.905
#  message:  [0]  output:  0  epoch no:  52800  avg reward 0.895
#  epoch no:  52800  avg reward 0.895
#  message:  [0]  output:  0  epoch no:  52900  avg reward 0.9016666666666666
#  epoch no:  52900  avg reward 0.9016666666666666
#  message:  [2]  output:  0  epoch no:  53000  avg reward 0.88
#  epoch no:  53000  avg reward 0.88
#  message:  [3]  output:  0  epoch no:  53100  avg reward 0.8866666666666667
#  epoch no:  53100  avg reward 0.8866666666666667
#  message:  [3]  output:  2  epoch no:  53200  avg reward 0.905
#  epoch no:  53200  avg reward 0.905
#  message:  [2]  output:  0  epoch no:  53300  avg reward 0.9033333333333333
#  epoch no:  53300  avg reward 0.9033333333333333
#  message:  [1]  output:  1  epoch no:  53400  avg reward 0.8716666666666667
#  epoch no:  53400  avg reward 0.8716666666666667
#  message:  [0]  output:  0  epoch no:  53500  avg reward 0.8966666666666666
#  epoch no:  53500  avg reward 0.8966666666666666
#  message:  [2]  output:  0  epoch no:  53600  avg reward 0.865
#  epoch no:  53600  avg reward 0.865
#  message:  [4]  output:  0  epoch no:  53700  avg reward 0.8783333333333333
#  epoch no:  53700  avg reward 0.8783333333333333
#  message:  [2]  output:  2  epoch no:  53800  avg reward 0.885
#  epoch no:  53800  avg reward 0.885
#  message:  [3]  output:  1  epoch no:  53900  avg reward 0.8783333333333333
#  epoch no:  53900  avg reward 0.8783333333333333
#  message:  [2]  output:  2  epoch no:  54000  avg reward 0.9
#  epoch no:  54000  avg reward 0.9
#  message:  [0]  output:  1  epoch no:  54100  avg reward 0.8916666666666667
#  epoch no:  54100  avg reward 0.8916666666666667
#  message:  [2]  output:  1  epoch no:  54200  avg reward 0.93
#  epoch no:  54200  avg reward 0.93
#  message:  [1]  output:  0  epoch no:  54300  avg reward 0.9083333333333333
#  epoch no:  54300  avg reward 0.9083333333333333
#  message:  [4]  output:  2  epoch no:  54400  avg reward 0.9216666666666666
#  epoch no:  54400  avg reward 0.9216666666666666
#  message:  [1]  output:  0  epoch no:  54500  avg reward 0.92
#  epoch no:  54500  avg reward 0.92
#  message:  [1]  output:  0  epoch no:  54600  avg reward 0.89
#  epoch no:  54600  avg reward 0.89
#  message:  [3]  output:  0  epoch no:  54700  avg reward 0.915
#  epoch no:  54700  avg reward 0.915
#  message:  [0]  output:  1  epoch no:  54800  avg reward 0.9
#  epoch no:  54800  avg reward 0.9
#  message:  [2]  output:  1  epoch no:  54900  avg reward 0.8933333333333333
#  epoch no:  54900  avg reward 0.8933333333333333
#  message:  [2]  output:  0  epoch no:  55000  avg reward 0.915
#  epoch no:  55000  avg reward 0.915
#  message:  [3]  output:  0  epoch no:  55100  avg reward 0.9
#  epoch no:  55100  avg reward 0.9
#  message:  [0]  output:  1  epoch no:  55200  avg reward 0.9066666666666666
#  epoch no:  55200  avg reward 0.9066666666666666
#  message:  [0]  output:  2  epoch no:  55300  avg reward 0.9183333333333333
#  epoch no:  55300  avg reward 0.9183333333333333
#  message:  [2]  output:  1  epoch no:  55400  avg reward 0.8783333333333333
#  epoch no:  55400  avg reward 0.8783333333333333
#  message:  [4]  output:  1  epoch no:  55500  avg reward 0.9216666666666666
#  epoch no:  55500  avg reward 0.9216666666666666
#  message:  [2]  output:  2  epoch no:  55600  avg reward 0.92
#  epoch no:  55600  avg reward 0.92
#  message:  [0]  output:  2  epoch no:  55700  avg reward 0.9233333333333333
#  epoch no:  55700  avg reward 0.9233333333333333
#  message:  [0]  output:  1  epoch no:  55800  avg reward 0.9183333333333333
#  epoch no:  55800  avg reward 0.9183333333333333
#  message:  [4]  output:  0  epoch no:  55900  avg reward 0.8866666666666667
#  epoch no:  55900  avg reward 0.8866666666666667
#  message:  [1]  output:  2  epoch no:  56000  avg reward 0.8983333333333333
#  epoch no:  56000  avg reward 0.8983333333333333
#  message:  [1]  output:  1  epoch no:  56100  avg reward 0.885
#  epoch no:  56100  avg reward 0.885
#  message:  [1]  output:  1  epoch no:  56200  avg reward 0.9183333333333333
#  epoch no:  56200  avg reward 0.9183333333333333
#  message:  [2]  output:  1  epoch no:  56300  avg reward 0.91
#  epoch no:  56300  avg reward 0.91
#  message:  [0]  output:  2  epoch no:  56400  avg reward 0.8916666666666667
#  epoch no:  56400  avg reward 0.8916666666666667
#  message:  [3]  output:  1  epoch no:  56500  avg reward 0.9316666666666666
#  epoch no:  56500  avg reward 0.9316666666666666
#  message:  [4]  output:  2  epoch no:  56600  avg reward 0.8983333333333333
#  epoch no:  56600  avg reward 0.8983333333333333
#  message:  [2]  output:  0  epoch no:  56700  avg reward 0.9333333333333333
#  epoch no:  56700  avg reward 0.9333333333333333
#  message:  [2]  output:  0  epoch no:  56800  avg reward 0.8883333333333333
#  epoch no:  56800  avg reward 0.8883333333333333
#  message:  [4]  output:  0  epoch no:  56900  avg reward 0.9233333333333333
#  epoch no:  56900  avg reward 0.9233333333333333
#  message:  [2]  output:  1  epoch no:  57000  avg reward 0.9383333333333334
#  epoch no:  57000  avg reward 0.9383333333333334
#  message:  [2]  output:  0  epoch no:  57100  avg reward 0.8783333333333333
#  epoch no:  57100  avg reward 0.8783333333333333
#  message:  [2]  output:  2  epoch no:  57200  avg reward 0.8983333333333333
#  epoch no:  57200  avg reward 0.8983333333333333
#  message:  [1]  output:  1  epoch no:  57300  avg reward 0.9183333333333333
#  epoch no:  57300  avg reward 0.9183333333333333
#  message:  [3]  output:  0  epoch no:  57400  avg reward 0.895
#  epoch no:  57400  avg reward 0.895
#  message:  [2]  output:  2  epoch no:  57500  avg reward 0.905
#  epoch no:  57500  avg reward 0.905
#  message:  [0]  output:  0  epoch no:  57600  avg reward 0.8733333333333333
#  epoch no:  57600  avg reward 0.8733333333333333
#  message:  [2]  output:  0  epoch no:  57700  avg reward 0.935
#  epoch no:  57700  avg reward 0.935
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-b76a066a981f> in <module>
#      58     if not flip_l:
#      59 #         print('e2')
# ---> 60         e2 = Listener.model.observe(reward=reward_batch, terminal=[True]*n_batches)
#      61 #     assert e1 == e2
#      62 #     e = e1
#
# /usr/local/lib/python3.5/dist-packages/tensorforce/models/model.py in observe(self, terminal, reward)
#    1423         feed_dict = self.get_feed_dict(terminal=terminal, reward=reward)
#    1424
# -> 1425         episode = self.monitored_session.run(fetches=fetches, feed_dict=feed_dict)
#    1426
#    1427         return episode
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/training/monitored_session.py in run(self, fetches, feed_dict, options, run_metadata)
#     544                           feed_dict=feed_dict,
#     545                           options=options,
# --> 546                           run_metadata=run_metadata)
#     547
#     548   def run_step_fn(self, step_fn):
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/training/monitored_session.py in run(self, *args, **kwargs)
#    1096   def run(self, *args, **kwargs):
#    1097     try:
# -> 1098       return self._sess.run(*args, **kwargs)
#    1099     except _PREEMPTION_ERRORS:
#    1100       raise
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/training/monitored_session.py in run(self, fetches, feed_dict, options, run_metadata)
#    1168                                   feed_dict=feed_dict,
#    1169                                   options=options,
# -> 1170                                   run_metadata=run_metadata)
#    1171
#    1172     for hook in self._hooks:
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/training/monitored_session.py in run(self, *args, **kwargs)
#     948
#     949   def run(self, *args, **kwargs):
# --> 950     return self._sess.run(*args, **kwargs)
#     951
#     952   def run_step_fn(self, step_fn, raw_session, run_with_hooks):
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     903     try:
#     904       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 905                          run_metadata_ptr)
#     906       if run_metadata:
#     907         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1138     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1139       results = self._do_run(handle, final_targets, final_fetches,
# -> 1140                              feed_dict_tensor, options, run_metadata)
#    1141     else:
#    1142       results = []
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1319     if handle is None:
#    1320       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1321                            run_metadata)
#    1322     else:
#    1323       return self._do_call(_prun_fn, handle, feeds, fetches)
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1325   def _do_call(self, fn, *args):
#    1326     try:
# -> 1327       return fn(*args)
#    1328     except errors.OpError as e:
#    1329       message = compat.as_text(e.message)
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1310       self._extend_graph()
#    1311       return self._call_tf_sessionrun(
# -> 1312           options, feed_dict, fetch_list, target_list, run_metadata)
#    1313
#    1314     def _prun_fn(handle, feed_dict, fetch_list):
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1418         return tf_session.TF_Run(
#    1419             self._session, options, feed_dict, fetch_list, target_list,
# -> 1420             status, run_metadata)
#    1421
#    1422   def _call_tf_sessionprun(self, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %%
### N population 8

fig = plt.figure()
ax = fig.add_subplot(111)
plt.ion()

fig.show()
fig.canvas.draw()
for i in range(n_epochs):
    Speaker = Speakers[np.random.choice(n_population)]
    Listener = Listeners[np.random.choice(n_population)]
    message_batch = []
    img_batch = []
    r = i%(2*freq)
    if r<1*freq:
        flip_s = False
        flip_l = True
    if r>=1*freq:
        flip_s = True
        flip_l = False
    l_rewards = []
    strokes = []
    for b in range(n_batches):
        strokes = []
#         for idx in range(2):
#             if idx ==0:
#                 feat = np.zeros((10,10), np.uint8)
#             else:
#                 im = message_to_image_sm(strokes, img_dim, img_dim)
# #                 feat = get_features([im])[0]
#                 feat = im.flatten()
        message = Speaker.act(states= game_pool[b].speaker_input(), independent=flip_s)  # (scalar between 0 and 4)
        message_batch.append(message)
#             strokes.append(message)
#         img = message_to_image(strokes, img_rows, img_cols)
#         img_batch.append(img)
#         Speaker.reset()

#     features_batch = get_features(intermediate_layer_model, img_batch)
#     message = Speaker.act(states= game_pool[b].speaker_input(feat), independent=flip_s)
    out_batch = []
    reward_batch = []
    for b in range(n_batches):
        out = Listener.act(states = game_pool[b].listener_input(message_batch[b]), independent = flip_l)
        out_batch.append(out)
        rew = game_pool[b].reward(out)
        reward_batch.append(rew)
        game_pool[b].reset()
    speaker_terminals = []
    rew_speaker = []
    for rew in reward_batch:
        speaker_terminals.extend([True])
        rew_speaker.extend([rew])

    if not flip_s:
#         print('e1')
        e1 = Speaker.model.observe(reward=rew_speaker, terminal=speaker_terminals)
    if not flip_l:
#         print('e2')
        e2 = Listener.model.observe(reward=reward_batch, terminal=[True]*n_batches)
#     assert e1 == e2
#     e = e1
    big_rewards.extend(reward_batch)
    big_rewards = big_rewards[-600:]
    if i%(100)==0:
#         print(" output: ", out)
        avg_rew = sum(big_rewards)/len(big_rewards)
        print(" message: ", message, " output: ", out, " epoch no: ", i, " avg reward", avg_rew)
        print(" epoch no: ", i, " avg reward", avg_rew)

        if(i!=0):
            data.append(avg_rew)
        ax.clear()
        ax.plot(data)
        if not flip_s:
            ax.set_xlabel('speaker')
        else:
            ax.set_xlabel('listener')
        fig.canvas.draw()


#     if sum(big_rewards)/len(big_rewards)>.75:
#         break
# Out:
# <img src="data:image/png;base64,..." width="639.230792677615">
#  message:  [3]  output:  1  epoch no:  0  avg reward 0.5
#  epoch no:  0  avg reward 0.5
#  message:  [4]  output:  0  epoch no:  100  avg reward 0.3466666666666667
#  epoch no:  100  avg reward 0.3466666666666667
#  message:  [3]  output:  0  epoch no:  200  avg reward 0.3233333333333333
#  epoch no:  200  avg reward 0.3233333333333333
#  message:  [2]  output:  1  epoch no:  300  avg reward 0.355
#  epoch no:  300  avg reward 0.355
#  message:  [2]  output:  1  epoch no:  400  avg reward 0.35333333333333333
#  epoch no:  400  avg reward 0.35333333333333333
#  message:  [0]  output:  0  epoch no:  500  avg reward 0.33666666666666667
#  epoch no:  500  avg reward 0.33666666666666667
#  message:  [1]  output:  2  epoch no:  600  avg reward 0.31333333333333335
#  epoch no:  600  avg reward 0.31333333333333335
#  message:  [1]  output:  1  epoch no:  700  avg reward 0.325
#  epoch no:  700  avg reward 0.325
#  message:  [3]  output:  2  epoch no:  800  avg reward 0.345
#  epoch no:  800  avg reward 0.345
#  message:  [4]  output:  1  epoch no:  900  avg reward 0.30333333333333334
#  epoch no:  900  avg reward 0.30333333333333334
#  message:  [0]  output:  0  epoch no:  1000  avg reward 0.33666666666666667
#  epoch no:  1000  avg reward 0.33666666666666667
#  message:  [1]  output:  0  epoch no:  1100  avg reward 0.33166666666666667
#  epoch no:  1100  avg reward 0.33166666666666667
#  message:  [0]  output:  2  epoch no:  1200  avg reward 0.28833333333333333
#  epoch no:  1200  avg reward 0.28833333333333333
#  message:  [4]  output:  0  epoch no:  1300  avg reward 0.345
#  epoch no:  1300  avg reward 0.345
#  message:  [1]  output:  1  epoch no:  1400  avg reward 0.35
#  epoch no:  1400  avg reward 0.35
#  message:  [0]  output:  2  epoch no:  1500  avg reward 0.31666666666666665
#  epoch no:  1500  avg reward 0.31666666666666665
#  message:  [3]  output:  0  epoch no:  1600  avg reward 0.32166666666666666
#  epoch no:  1600  avg reward 0.32166666666666666
#  message:  [1]  output:  1  epoch no:  1700  avg reward 0.3416666666666667
#  epoch no:  1700  avg reward 0.3416666666666667
#  message:  [2]  output:  1  epoch no:  1800  avg reward 0.3466666666666667
#  epoch no:  1800  avg reward 0.3466666666666667
#  message:  [2]  output:  2  epoch no:  1900  avg reward 0.35
#  epoch no:  1900  avg reward 0.35
#  message:  [4]  output:  0  epoch no:  2000  avg reward 0.3433333333333333
#  epoch no:  2000  avg reward 0.3433333333333333
#  message:  [2]  output:  1  epoch no:  2100  avg reward 0.33
#  epoch no:  2100  avg reward 0.33
#  message:  [0]  output:  2  epoch no:  2200  avg reward 0.365
#  epoch no:  2200  avg reward 0.365
#  message:  [3]  output:  0  epoch no:  2300  avg reward 0.345
#  epoch no:  2300  avg reward 0.345
#  message:  [2]  output:  0  epoch no:  2400  avg reward 0.345
#  epoch no:  2400  avg reward 0.345
#  message:  [1]  output:  0  epoch no:  2500  avg reward 0.33166666666666667
#  epoch no:  2500  avg reward 0.33166666666666667
#  message:  [0]  output:  1  epoch no:  2600  avg reward 0.33666666666666667
#  epoch no:  2600  avg reward 0.33666666666666667
#  message:  [0]  output:  0  epoch no:  2700  avg reward 0.27666666666666667
#  epoch no:  2700  avg reward 0.27666666666666667
#  message:  [2]  output:  2  epoch no:  2800  avg reward 0.3283333333333333
#  epoch no:  2800  avg reward 0.3283333333333333
#  message:  [3]  output:  1  epoch no:  2900  avg reward 0.33
#  epoch no:  2900  avg reward 0.33
#  message:  [0]  output:  1  epoch no:  3000  avg reward 0.3516666666666667
#  epoch no:  3000  avg reward 0.3516666666666667
#  message:  [1]  output:  1  epoch no:  3100  avg reward 0.37333333333333335
#  epoch no:  3100  avg reward 0.37333333333333335
#  message:  [0]  output:  1  epoch no:  3200  avg reward 0.305
#  epoch no:  3200  avg reward 0.305
#  message:  [2]  output:  0  epoch no:  3300  avg reward 0.36833333333333335
#  epoch no:  3300  avg reward 0.36833333333333335
#  message:  [2]  output:  1  epoch no:  3400  avg reward 0.3283333333333333
#  epoch no:  3400  avg reward 0.3283333333333333
#  message:  [2]  output:  0  epoch no:  3500  avg reward 0.31333333333333335
#  epoch no:  3500  avg reward 0.31333333333333335
#  message:  [2]  output:  2  epoch no:  3600  avg reward 0.33
#  epoch no:  3600  avg reward 0.33
#  message:  [0]  output:  0  epoch no:  3700  avg reward 0.3233333333333333
#  epoch no:  3700  avg reward 0.3233333333333333
#  message:  [2]  output:  0  epoch no:  3800  avg reward 0.355
#  epoch no:  3800  avg reward 0.355
#  message:  [1]  output:  2  epoch no:  3900  avg reward 0.33
#  epoch no:  3900  avg reward 0.33
#  message:  [2]  output:  0  epoch no:  4000  avg reward 0.32666666666666666
#  epoch no:  4000  avg reward 0.32666666666666666
#  message:  [0]  output:  1  epoch no:  4100  avg reward 0.33166666666666667
#  epoch no:  4100  avg reward 0.33166666666666667
#  message:  [1]  output:  2  epoch no:  4200  avg reward 0.3283333333333333
#  epoch no:  4200  avg reward 0.3283333333333333
#  message:  [2]  output:  0  epoch no:  4300  avg reward 0.315
#  epoch no:  4300  avg reward 0.315
#  message:  [1]  output:  1  epoch no:  4400  avg reward 0.38166666666666665
#  epoch no:  4400  avg reward 0.38166666666666665
#  message:  [1]  output:  0  epoch no:  4500  avg reward 0.32166666666666666
#  epoch no:  4500  avg reward 0.32166666666666666
#  message:  [0]  output:  0  epoch no:  4600  avg reward 0.335
#  epoch no:  4600  avg reward 0.335
#  message:  [1]  output:  2  epoch no:  4700  avg reward 0.365
#  epoch no:  4700  avg reward 0.365
#  message:  [4]  output:  1  epoch no:  4800  avg reward 0.345
#  epoch no:  4800  avg reward 0.345
#  message:  [1]  output:  0  epoch no:  4900  avg reward 0.3433333333333333
#  epoch no:  4900  avg reward 0.3433333333333333
#  message:  [1]  output:  0  epoch no:  5000  avg reward 0.325
#  epoch no:  5000  avg reward 0.325
#  message:  [1]  output:  1  epoch no:  5100  avg reward 0.3016666666666667
#  epoch no:  5100  avg reward 0.3016666666666667
#  message:  [3]  output:  1  epoch no:  5200  avg reward 0.29
#  epoch no:  5200  avg reward 0.29
#  message:  [1]  output:  2  epoch no:  5300  avg reward 0.32
#  epoch no:  5300  avg reward 0.32
#  message:  [3]  output:  2  epoch no:  5400  avg reward 0.3433333333333333
#  epoch no:  5400  avg reward 0.3433333333333333
#  message:  [0]  output:  1  epoch no:  5500  avg reward 0.3516666666666667
#  epoch no:  5500  avg reward 0.3516666666666667
#  message:  [0]  output:  0  epoch no:  5600  avg reward 0.3383333333333333
#  epoch no:  5600  avg reward 0.3383333333333333
#  message:  [1]  output:  2  epoch no:  5700  avg reward 0.35
#  epoch no:  5700  avg reward 0.35
#  message:  [3]  output:  0  epoch no:  5800  avg reward 0.32166666666666666
#  epoch no:  5800  avg reward 0.32166666666666666
#  message:  [1]  output:  2  epoch no:  5900  avg reward 0.355
#  epoch no:  5900  avg reward 0.355
#  message:  [2]  output:  0  epoch no:  6000  avg reward 0.31666666666666665
#  epoch no:  6000  avg reward 0.31666666666666665
#  message:  [3]  output:  2  epoch no:  6100  avg reward 0.32666666666666666
#  epoch no:  6100  avg reward 0.32666666666666666
#  message:  [3]  output:  2  epoch no:  6200  avg reward 0.3283333333333333
#  epoch no:  6200  avg reward 0.3283333333333333
#  message:  [3]  output:  2  epoch no:  6300  avg reward 0.3566666666666667
#  epoch no:  6300  avg reward 0.3566666666666667
#  message:  [4]  output:  1  epoch no:  6400  avg reward 0.3383333333333333
#  epoch no:  6400  avg reward 0.3383333333333333
#  message:  [1]  output:  0  epoch no:  6500  avg reward 0.375
#  epoch no:  6500  avg reward 0.375
#  message:  [1]  output:  0  epoch no:  6600  avg reward 0.31666666666666665
#  epoch no:  6600  avg reward 0.31666666666666665
#  message:  [3]  output:  2  epoch no:  6700  avg reward 0.29333333333333333
#  epoch no:  6700  avg reward 0.29333333333333333
#  message:  [0]  output:  2  epoch no:  6800  avg reward 0.3466666666666667
#  epoch no:  6800  avg reward 0.3466666666666667
#  message:  [1]  output:  2  epoch no:  6900  avg reward 0.30666666666666664
#  epoch no:  6900  avg reward 0.30666666666666664
#  message:  [2]  output:  2  epoch no:  7000  avg reward 0.3616666666666667
#  epoch no:  7000  avg reward 0.3616666666666667
#  message:  [4]  output:  0  epoch no:  7100  avg reward 0.34
#  epoch no:  7100  avg reward 0.34
#  message:  [3]  output:  2  epoch no:  7200  avg reward 0.3433333333333333
#  epoch no:  7200  avg reward 0.3433333333333333
#  message:  [1]  output:  1  epoch no:  7300  avg reward 0.36333333333333334
#  epoch no:  7300  avg reward 0.36333333333333334
#  message:  [2]  output:  0  epoch no:  7400  avg reward 0.32666666666666666
#  epoch no:  7400  avg reward 0.32666666666666666
#  message:  [3]  output:  0  epoch no:  7500  avg reward 0.32
#  epoch no:  7500  avg reward 0.32
#  message:  [4]  output:  2  epoch no:  7600  avg reward 0.3333333333333333
#  epoch no:  7600  avg reward 0.3333333333333333
#  message:  [2]  output:  0  epoch no:  7700  avg reward 0.36833333333333335
#  epoch no:  7700  avg reward 0.36833333333333335
#  message:  [3]  output:  0  epoch no:  7800  avg reward 0.37
#  epoch no:  7800  avg reward 0.37
#  message:  [0]  output:  1  epoch no:  7900  avg reward 0.32666666666666666
#  epoch no:  7900  avg reward 0.32666666666666666
#  message:  [4]  output:  2  epoch no:  8000  avg reward 0.38
#  epoch no:  8000  avg reward 0.38
#  message:  [3]  output:  2  epoch no:  8100  avg reward 0.33166666666666667
#  epoch no:  8100  avg reward 0.33166666666666667
#  message:  [2]  output:  0  epoch no:  8200  avg reward 0.3516666666666667
#  epoch no:  8200  avg reward 0.3516666666666667
#  message:  [2]  output:  2  epoch no:  8300  avg reward 0.37666666666666665
#  epoch no:  8300  avg reward 0.37666666666666665
#  message:  [2]  output:  0  epoch no:  8400  avg reward 0.39
#  epoch no:  8400  avg reward 0.39
#  message:  [0]  output:  1  epoch no:  8500  avg reward 0.3616666666666667
#  epoch no:  8500  avg reward 0.3616666666666667
#  message:  [4]  output:  2  epoch no:  8600  avg reward 0.39166666666666666
#  epoch no:  8600  avg reward 0.39166666666666666
#  message:  [4]  output:  2  epoch no:  8700  avg reward 0.3983333333333333
#  epoch no:  8700  avg reward 0.3983333333333333
#  message:  [3]  output:  2  epoch no:  8800  avg reward 0.3616666666666667
#  epoch no:  8800  avg reward 0.3616666666666667
#  message:  [0]  output:  1  epoch no:  8900  avg reward 0.37166666666666665
#  epoch no:  8900  avg reward 0.37166666666666665
#  message:  [3]  output:  0  epoch no:  9000  avg reward 0.37
#  epoch no:  9000  avg reward 0.37
#  message:  [4]  output:  0  epoch no:  9100  avg reward 0.4166666666666667
#  epoch no:  9100  avg reward 0.4166666666666667
#  message:  [3]  output:  2  epoch no:  9200  avg reward 0.435
#  epoch no:  9200  avg reward 0.435
#  message:  [3]  output:  2  epoch no:  9300  avg reward 0.4
#  epoch no:  9300  avg reward 0.4
#  message:  [4]  output:  1  epoch no:  9400  avg reward 0.37833333333333335
#  epoch no:  9400  avg reward 0.37833333333333335
#  message:  [0]  output:  2  epoch no:  9500  avg reward 0.42
#  epoch no:  9500  avg reward 0.42
#  message:  [3]  output:  0  epoch no:  9600  avg reward 0.435
#  epoch no:  9600  avg reward 0.435
#  message:  [4]  output:  0  epoch no:  9700  avg reward 0.45166666666666666
#  epoch no:  9700  avg reward 0.45166666666666666
#  message:  [3]  output:  0  epoch no:  9800  avg reward 0.43166666666666664
#  epoch no:  9800  avg reward 0.43166666666666664
#  message:  [4]  output:  2  epoch no:  9900  avg reward 0.4533333333333333
#  epoch no:  9900  avg reward 0.4533333333333333
#  message:  [4]  output:  2  epoch no:  10000  avg reward 0.46
#  epoch no:  10000  avg reward 0.46
#  message:  [0]  output:  2  epoch no:  10100  avg reward 0.45
#  epoch no:  10100  avg reward 0.45
#  message:  [2]  output:  0  epoch no:  10200  avg reward 0.45666666666666667
#  epoch no:  10200  avg reward 0.45666666666666667
#  message:  [3]  output:  1  epoch no:  10300  avg reward 0.47833333333333333
#  epoch no:  10300  avg reward 0.47833333333333333
#  message:  [0]  output:  0  epoch no:  10400  avg reward 0.5016666666666667
#  epoch no:  10400  avg reward 0.5016666666666667
#  message:  [1]  output:  2  epoch no:  10500  avg reward 0.5083333333333333
#  epoch no:  10500  avg reward 0.5083333333333333
#  message:  [0]  output:  1  epoch no:  10600  avg reward 0.52
#  epoch no:  10600  avg reward 0.52
#  message:  [1]  output:  0  epoch no:  10700  avg reward 0.48
#  epoch no:  10700  avg reward 0.48
#  message:  [4]  output:  2  epoch no:  10800  avg reward 0.5183333333333333
#  epoch no:  10800  avg reward 0.5183333333333333
#  message:  [3]  output:  1  epoch no:  10900  avg reward 0.5233333333333333
#  epoch no:  10900  avg reward 0.5233333333333333
#  message:  [0]  output:  0  epoch no:  11000  avg reward 0.5133333333333333
#  epoch no:  11000  avg reward 0.5133333333333333
#  message:  [4]  output:  2  epoch no:  11100  avg reward 0.52
#  epoch no:  11100  avg reward 0.52
#  message:  [4]  output:  0  epoch no:  11200  avg reward 0.5283333333333333
#  epoch no:  11200  avg reward 0.5283333333333333
#  message:  [0]  output:  1  epoch no:  11300  avg reward 0.5216666666666666
#  epoch no:  11300  avg reward 0.5216666666666666
#  message:  [1]  output:  2  epoch no:  11400  avg reward 0.535
#  epoch no:  11400  avg reward 0.535
#  message:  [3]  output:  1  epoch no:  11500  avg reward 0.5016666666666667
#  epoch no:  11500  avg reward 0.5016666666666667
#  message:  [1]  output:  2  epoch no:  11600  avg reward 0.54
#  epoch no:  11600  avg reward 0.54
#  message:  [3]  output:  0  epoch no:  11700  avg reward 0.5466666666666666
#  epoch no:  11700  avg reward 0.5466666666666666
#  message:  [3]  output:  0  epoch no:  11800  avg reward 0.5183333333333333
#  epoch no:  11800  avg reward 0.5183333333333333
#  message:  [4]  output:  0  epoch no:  11900  avg reward 0.5366666666666666
#  epoch no:  11900  avg reward 0.5366666666666666
#  message:  [3]  output:  0  epoch no:  12000  avg reward 0.515
#  epoch no:  12000  avg reward 0.515
#  message:  [1]  output:  1  epoch no:  12100  avg reward 0.5266666666666666
#  epoch no:  12100  avg reward 0.5266666666666666
#  message:  [0]  output:  2  epoch no:  12200  avg reward 0.5633333333333334
#  epoch no:  12200  avg reward 0.5633333333333334
#  message:  [1]  output:  0  epoch no:  12300  avg reward 0.51
#  epoch no:  12300  avg reward 0.51
#  message:  [4]  output:  2  epoch no:  12400  avg reward 0.545
#  epoch no:  12400  avg reward 0.545
#  message:  [0]  output:  2  epoch no:  12500  avg reward 0.535
#  epoch no:  12500  avg reward 0.535
#  message:  [3]  output:  1  epoch no:  12600  avg reward 0.545
#  epoch no:  12600  avg reward 0.545
#  message:  [1]  output:  1  epoch no:  12700  avg reward 0.54
#  epoch no:  12700  avg reward 0.54
#  message:  [4]  output:  0  epoch no:  12800  avg reward 0.5433333333333333
#  epoch no:  12800  avg reward 0.5433333333333333
#  message:  [1]  output:  2  epoch no:  12900  avg reward 0.5233333333333333
#  epoch no:  12900  avg reward 0.5233333333333333
#  message:  [0]  output:  1  epoch no:  13000  avg reward 0.565
#  epoch no:  13000  avg reward 0.565
#  message:  [4]  output:  0  epoch no:  13100  avg reward 0.545
#  epoch no:  13100  avg reward 0.545
#  message:  [0]  output:  1  epoch no:  13200  avg reward 0.5216666666666666
#  epoch no:  13200  avg reward 0.5216666666666666
#  message:  [4]  output:  1  epoch no:  13300  avg reward 0.5216666666666666
#  epoch no:  13300  avg reward 0.5216666666666666
#  message:  [2]  output:  2  epoch no:  13400  avg reward 0.5866666666666667
#  epoch no:  13400  avg reward 0.5866666666666667
#  message:  [1]  output:  1  epoch no:  13500  avg reward 0.605
#  epoch no:  13500  avg reward 0.605
#  message:  [3]  output:  1  epoch no:  13600  avg reward 0.6016666666666667
#  epoch no:  13600  avg reward 0.6016666666666667
#  message:  [0]  output:  1  epoch no:  13700  avg reward 0.6183333333333333
#  epoch no:  13700  avg reward 0.6183333333333333
#  message:  [1]  output:  1  epoch no:  13800  avg reward 0.575
#  epoch no:  13800  avg reward 0.575
#  message:  [2]  output:  1  epoch no:  13900  avg reward 0.5233333333333333
#  epoch no:  13900  avg reward 0.5233333333333333
#  message:  [3]  output:  0  epoch no:  14000  avg reward 0.555
#  epoch no:  14000  avg reward 0.555
#  message:  [3]  output:  0  epoch no:  14100  avg reward 0.545
#  epoch no:  14100  avg reward 0.545
#  message:  [1]  output:  1  epoch no:  14200  avg reward 0.56
#  epoch no:  14200  avg reward 0.56
#  message:  [3]  output:  0  epoch no:  14300  avg reward 0.5666666666666667
#  epoch no:  14300  avg reward 0.5666666666666667
#  message:  [1]  output:  1  epoch no:  14400  avg reward 0.54
#  epoch no:  14400  avg reward 0.54
#  message:  [0]  output:  2  epoch no:  14500  avg reward 0.5816666666666667
#  epoch no:  14500  avg reward 0.5816666666666667
#  message:  [4]  output:  1  epoch no:  14600  avg reward 0.5533333333333333
#  epoch no:  14600  avg reward 0.5533333333333333
#  message:  [4]  output:  0  epoch no:  14700  avg reward 0.5583333333333333
#  epoch no:  14700  avg reward 0.5583333333333333
#  message:  [0]  output:  1  epoch no:  14800  avg reward 0.5816666666666667
#  epoch no:  14800  avg reward 0.5816666666666667
#  message:  [0]  output:  2  epoch no:  14900  avg reward 0.5266666666666666
#  epoch no:  14900  avg reward 0.5266666666666666
#  message:  [0]  output:  2  epoch no:  15000  avg reward 0.55
#  epoch no:  15000  avg reward 0.55
#  message:  [4]  output:  1  epoch no:  15100  avg reward 0.5566666666666666
#  epoch no:  15100  avg reward 0.5566666666666666
#  message:  [0]  output:  0  epoch no:  15200  avg reward 0.5483333333333333
#  epoch no:  15200  avg reward 0.5483333333333333
#  message:  [3]  output:  1  epoch no:  15300  avg reward 0.5833333333333334
#  epoch no:  15300  avg reward 0.5833333333333334
#  message:  [3]  output:  2  epoch no:  15400  avg reward 0.59
#  epoch no:  15400  avg reward 0.59
#  message:  [0]  output:  0  epoch no:  15500  avg reward 0.5766666666666667
#  epoch no:  15500  avg reward 0.5766666666666667
#  message:  [4]  output:  1  epoch no:  15600  avg reward 0.6033333333333334
#  epoch no:  15600  avg reward 0.6033333333333334
#  message:  [1]  output:  2  epoch no:  15700  avg reward 0.5516666666666666
#  epoch no:  15700  avg reward 0.5516666666666666
#  message:  [4]  output:  1  epoch no:  15800  avg reward 0.59
#  epoch no:  15800  avg reward 0.59
#  message:  [4]  output:  1  epoch no:  15900  avg reward 0.58
#  epoch no:  15900  avg reward 0.58
#  message:  [0]  output:  0  epoch no:  16000  avg reward 0.59
#  epoch no:  16000  avg reward 0.59
#  message:  [2]  output:  2  epoch no:  16100  avg reward 0.555
#  epoch no:  16100  avg reward 0.555
#  message:  [0]  output:  0  epoch no:  16200  avg reward 0.5966666666666667
#  epoch no:  16200  avg reward 0.5966666666666667
#  message:  [1]  output:  1  epoch no:  16300  avg reward 0.595
#  epoch no:  16300  avg reward 0.595
#  message:  [0]  output:  0  epoch no:  16400  avg reward 0.605
#  epoch no:  16400  avg reward 0.605
#  message:  [1]  output:  1  epoch no:  16500  avg reward 0.61
#  epoch no:  16500  avg reward 0.61
#  message:  [1]  output:  2  epoch no:  16600  avg reward 0.6233333333333333
#  epoch no:  16600  avg reward 0.6233333333333333
#  message:  [3]  output:  2  epoch no:  16700  avg reward 0.5883333333333334
#  epoch no:  16700  avg reward 0.5883333333333334
#  message:  [4]  output:  1  epoch no:  16800  avg reward 0.595
#  epoch no:  16800  avg reward 0.595
#  message:  [4]  output:  0  epoch no:  16900  avg reward 0.595
#  epoch no:  16900  avg reward 0.595
#  message:  [1]  output:  1  epoch no:  17000  avg reward 0.6116666666666667
#  epoch no:  17000  avg reward 0.6116666666666667
#  message:  [4]  output:  0  epoch no:  17100  avg reward 0.57
#  epoch no:  17100  avg reward 0.57
#  message:  [0]  output:  1  epoch no:  17200  avg reward 0.6033333333333334
#  epoch no:  17200  avg reward 0.6033333333333334
#  message:  [0]  output:  2  epoch no:  17300  avg reward 0.5883333333333334
#  epoch no:  17300  avg reward 0.5883333333333334
#  message:  [0]  output:  2  epoch no:  17400  avg reward 0.6016666666666667
#  epoch no:  17400  avg reward 0.6016666666666667
#  message:  [2]  output:  1  epoch no:  17500  avg reward 0.6266666666666667
#  epoch no:  17500  avg reward 0.6266666666666667
#  message:  [3]  output:  0  epoch no:  17600  avg reward 0.63
#  epoch no:  17600  avg reward 0.63
#  message:  [3]  output:  0  epoch no:  17700  avg reward 0.63
#  epoch no:  17700  avg reward 0.63
#  message:  [3]  output:  1  epoch no:  17800  avg reward 0.6583333333333333
#  epoch no:  17800  avg reward 0.6583333333333333
#  message:  [4]  output:  2  epoch no:  17900  avg reward 0.595
#  epoch no:  17900  avg reward 0.595
#  message:  [1]  output:  0  epoch no:  18000  avg reward 0.6533333333333333
#  epoch no:  18000  avg reward 0.6533333333333333
#  message:  [3]  output:  1  epoch no:  18100  avg reward 0.6216666666666667
#  epoch no:  18100  avg reward 0.6216666666666667
#  message:  [3]  output:  0  epoch no:  18200  avg reward 0.5883333333333334
#  epoch no:  18200  avg reward 0.5883333333333334
#  message:  [4]  output:  2  epoch no:  18300  avg reward 0.635
#  epoch no:  18300  avg reward 0.635
#  message:  [1]  output:  1  epoch no:  18400  avg reward 0.6183333333333333
#  epoch no:  18400  avg reward 0.6183333333333333
#  message:  [3]  output:  0  epoch no:  18500  avg reward 0.585
#  epoch no:  18500  avg reward 0.585
#  message:  [1]  output:  2  epoch no:  18600  avg reward 0.6033333333333334
#  epoch no:  18600  avg reward 0.6033333333333334
#  message:  [2]  output:  1  epoch no:  18700  avg reward 0.65
#  epoch no:  18700  avg reward 0.65
#  message:  [2]  output:  0  epoch no:  18800  avg reward 0.6583333333333333
#  epoch no:  18800  avg reward 0.6583333333333333
#  message:  [2]  output:  1  epoch no:  18900  avg reward 0.6633333333333333
#  epoch no:  18900  avg reward 0.6633333333333333
#  message:  [2]  output:  1  epoch no:  19000  avg reward 0.7166666666666667
#  epoch no:  19000  avg reward 0.7166666666666667
#  message:  [0]  output:  0  epoch no:  19100  avg reward 0.64
#  epoch no:  19100  avg reward 0.64
#  message:  [3]  output:  2  epoch no:  19200  avg reward 0.6483333333333333
#  epoch no:  19200  avg reward 0.6483333333333333
#  message:  [2]  output:  0  epoch no:  19300  avg reward 0.6966666666666667
#  epoch no:  19300  avg reward 0.6966666666666667
#  message:  [2]  output:  2  epoch no:  19400  avg reward 0.6133333333333333
#  epoch no:  19400  avg reward 0.6133333333333333
#  message:  [3]  output:  0  epoch no:  19500  avg reward 0.6433333333333333
#  epoch no:  19500  avg reward 0.6433333333333333
#  message:  [3]  output:  2  epoch no:  19600  avg reward 0.67
#  epoch no:  19600  avg reward 0.67
#  message:  [3]  output:  0  epoch no:  19700  avg reward 0.69
#  epoch no:  19700  avg reward 0.69
#  message:  [2]  output:  0  epoch no:  19800  avg reward 0.6666666666666666
#  epoch no:  19800  avg reward 0.6666666666666666
#  message:  [0]  output:  1  epoch no:  19900  avg reward 0.5816666666666667
#  epoch no:  19900  avg reward 0.5816666666666667
#  message:  [2]  output:  0  epoch no:  20000  avg reward 0.7016666666666667
#  epoch no:  20000  avg reward 0.7016666666666667
#  message:  [3]  output:  2  epoch no:  20100  avg reward 0.6733333333333333
#  epoch no:  20100  avg reward 0.6733333333333333
#  message:  [2]  output:  0  epoch no:  20200  avg reward 0.6433333333333333
#  epoch no:  20200  avg reward 0.6433333333333333
#  message:  [2]  output:  2  epoch no:  20300  avg reward 0.6433333333333333
#  epoch no:  20300  avg reward 0.6433333333333333
#  message:  [2]  output:  2  epoch no:  20400  avg reward 0.67
#  epoch no:  20400  avg reward 0.67
#  message:  [2]  output:  1  epoch no:  20500  avg reward 0.665
#  epoch no:  20500  avg reward 0.665
#  message:  [2]  output:  2  epoch no:  20600  avg reward 0.65
#  epoch no:  20600  avg reward 0.65
#  message:  [0]  output:  0  epoch no:  20700  avg reward 0.655
#  epoch no:  20700  avg reward 0.655
#  message:  [4]  output:  0  epoch no:  20800  avg reward 0.6516666666666666
#  epoch no:  20800  avg reward 0.6516666666666666
#  message:  [2]  output:  1  epoch no:  20900  avg reward 0.6533333333333333
#  epoch no:  20900  avg reward 0.6533333333333333
#  message:  [3]  output:  1  epoch no:  21000  avg reward 0.6633333333333333
#  epoch no:  21000  avg reward 0.6633333333333333
#  message:  [2]  output:  2  epoch no:  21100  avg reward 0.6416666666666667
#  epoch no:  21100  avg reward 0.6416666666666667
#  message:  [2]  output:  1  epoch no:  21200  avg reward 0.6466666666666666
#  epoch no:  21200  avg reward 0.6466666666666666
#  message:  [3]  output:  2  epoch no:  21300  avg reward 0.6633333333333333
#  epoch no:  21300  avg reward 0.6633333333333333
#  message:  [3]  output:  2  epoch no:  21400  avg reward 0.68
#  epoch no:  21400  avg reward 0.68
#  message:  [3]  output:  0  epoch no:  21500  avg reward 0.725
#  epoch no:  21500  avg reward 0.725
#  message:  [2]  output:  0  epoch no:  21600  avg reward 0.6383333333333333
#  epoch no:  21600  avg reward 0.6383333333333333
#  message:  [4]  output:  2  epoch no:  21700  avg reward 0.69
#  epoch no:  21700  avg reward 0.69
#  message:  [1]  output:  2  epoch no:  21800  avg reward 0.6916666666666667
#  epoch no:  21800  avg reward 0.6916666666666667
#  message:  [2]  output:  0  epoch no:  21900  avg reward 0.5783333333333334
#  epoch no:  21900  avg reward 0.5783333333333334
#  message:  [2]  output:  1  epoch no:  22000  avg reward 0.6983333333333334
#  epoch no:  22000  avg reward 0.6983333333333334
#  message:  [3]  output:  0  epoch no:  22100  avg reward 0.6766666666666666
#  epoch no:  22100  avg reward 0.6766666666666666
#  message:  [3]  output:  1  epoch no:  22200  avg reward 0.6666666666666666
#  epoch no:  22200  avg reward 0.6666666666666666
#  message:  [4]  output:  0  epoch no:  22300  avg reward 0.7066666666666667
#  epoch no:  22300  avg reward 0.7066666666666667
#  message:  [1]  output:  2  epoch no:  22400  avg reward 0.69
#  epoch no:  22400  avg reward 0.69
#  message:  [2]  output:  1  epoch no:  22500  avg reward 0.7066666666666667
#  epoch no:  22500  avg reward 0.7066666666666667
#  message:  [4]  output:  0  epoch no:  22600  avg reward 0.6216666666666667
#  epoch no:  22600  avg reward 0.6216666666666667
#  message:  [0]  output:  2  epoch no:  22700  avg reward 0.64
#  epoch no:  22700  avg reward 0.64
#  message:  [3]  output:  0  epoch no:  22800  avg reward 0.6416666666666667
#  epoch no:  22800  avg reward 0.6416666666666667
#  message:  [0]  output:  0  epoch no:  22900  avg reward 0.715
#  epoch no:  22900  avg reward 0.715
#  message:  [0]  output:  1  epoch no:  23000  avg reward 0.7
#  epoch no:  23000  avg reward 0.7
#  message:  [2]  output:  2  epoch no:  23100  avg reward 0.6666666666666666
#  epoch no:  23100  avg reward 0.6666666666666666
#  message:  [2]  output:  0  epoch no:  23200  avg reward 0.6366666666666667
#  epoch no:  23200  avg reward 0.6366666666666667
#  message:  [3]  output:  1  epoch no:  23300  avg reward 0.6683333333333333
#  epoch no:  23300  avg reward 0.6683333333333333
#  message:  [2]  output:  0  epoch no:  23400  avg reward 0.7016666666666667
#  epoch no:  23400  avg reward 0.7016666666666667
#  message:  [3]  output:  1  epoch no:  23500  avg reward 0.7083333333333334
#  epoch no:  23500  avg reward 0.7083333333333334
#  message:  [4]  output:  0  epoch no:  23600  avg reward 0.6633333333333333
#  epoch no:  23600  avg reward 0.6633333333333333
#  message:  [4]  output:  2  epoch no:  23700  avg reward 0.6883333333333334
#  epoch no:  23700  avg reward 0.6883333333333334
#  message:  [2]  output:  2  epoch no:  23800  avg reward 0.6983333333333334
#  epoch no:  23800  avg reward 0.6983333333333334
#  message:  [3]  output:  0  epoch no:  23900  avg reward 0.725
#  epoch no:  23900  avg reward 0.725
#  message:  [3]  output:  1  epoch no:  24000  avg reward 0.705
#  epoch no:  24000  avg reward 0.705
#  message:  [3]  output:  1  epoch no:  24100  avg reward 0.655
#  epoch no:  24100  avg reward 0.655
#  message:  [4]  output:  0  epoch no:  24200  avg reward 0.69
#  epoch no:  24200  avg reward 0.69
#  message:  [1]  output:  1  epoch no:  24300  avg reward 0.7016666666666667
#  epoch no:  24300  avg reward 0.7016666666666667
#  message:  [0]  output:  1  epoch no:  24400  avg reward 0.7
#  epoch no:  24400  avg reward 0.7
#  message:  [1]  output:  0  epoch no:  24500  avg reward 0.7033333333333334
#  epoch no:  24500  avg reward 0.7033333333333334
#  message:  [4]  output:  1  epoch no:  24600  avg reward 0.6716666666666666
#  epoch no:  24600  avg reward 0.6716666666666666
#  message:  [2]  output:  2  epoch no:  24700  avg reward 0.7183333333333334
#  epoch no:  24700  avg reward 0.7183333333333334
#  message:  [2]  output:  2  epoch no:  24800  avg reward 0.6933333333333334
#  epoch no:  24800  avg reward 0.6933333333333334
#  message:  [1]  output:  0  epoch no:  24900  avg reward 0.7183333333333334
#  epoch no:  24900  avg reward 0.7183333333333334
#  message:  [2]  output:  0  epoch no:  25000  avg reward 0.69
#  epoch no:  25000  avg reward 0.69
#  message:  [2]  output:  2  epoch no:  25100  avg reward 0.7033333333333334
#  epoch no:  25100  avg reward 0.7033333333333334
#  message:  [4]  output:  2  epoch no:  25200  avg reward 0.7733333333333333
#  epoch no:  25200  avg reward 0.7733333333333333
#  message:  [2]  output:  1  epoch no:  25300  avg reward 0.6733333333333333
#  epoch no:  25300  avg reward 0.6733333333333333
#  message:  [0]  output:  2  epoch no:  25400  avg reward 0.7483333333333333
#  epoch no:  25400  avg reward 0.7483333333333333
#  message:  [4]  output:  2  epoch no:  25500  avg reward 0.6816666666666666
#  epoch no:  25500  avg reward 0.6816666666666666
#  message:  [2]  output:  1  epoch no:  25600  avg reward 0.7483333333333333
#  epoch no:  25600  avg reward 0.7483333333333333
#  message:  [0]  output:  1  epoch no:  25700  avg reward 0.7183333333333334
#  epoch no:  25700  avg reward 0.7183333333333334
#  message:  [0]  output:  2  epoch no:  25800  avg reward 0.73
#  epoch no:  25800  avg reward 0.73
#  message:  [2]  output:  2  epoch no:  25900  avg reward 0.7483333333333333
#  epoch no:  25900  avg reward 0.7483333333333333
#  message:  [4]  output:  2  epoch no:  26000  avg reward 0.67
#  epoch no:  26000  avg reward 0.67
#  message:  [0]  output:  1  epoch no:  26100  avg reward 0.705
#  epoch no:  26100  avg reward 0.705
#  message:  [0]  output:  1  epoch no:  26200  avg reward 0.7133333333333334
#  epoch no:  26200  avg reward 0.7133333333333334
#  message:  [4]  output:  1  epoch no:  26300  avg reward 0.71
#  epoch no:  26300  avg reward 0.71
#  message:  [3]  output:  1  epoch no:  26400  avg reward 0.735
#  epoch no:  26400  avg reward 0.735
#  message:  [1]  output:  0  epoch no:  26500  avg reward 0.705
#  epoch no:  26500  avg reward 0.705
#  message:  [2]  output:  2  epoch no:  26600  avg reward 0.705
#  epoch no:  26600  avg reward 0.705
#  message:  [2]  output:  2  epoch no:  26700  avg reward 0.695
#  epoch no:  26700  avg reward 0.695
#  message:  [0]  output:  2  epoch no:  26800  avg reward 0.735
#  epoch no:  26800  avg reward 0.735
#  message:  [4]  output:  0  epoch no:  26900  avg reward 0.6666666666666666
#  epoch no:  26900  avg reward 0.6666666666666666
#  message:  [0]  output:  0  epoch no:  27000  avg reward 0.76
#  epoch no:  27000  avg reward 0.76
#  message:  [2]  output:  0  epoch no:  27100  avg reward 0.6816666666666666
#  epoch no:  27100  avg reward 0.6816666666666666
#  message:  [3]  output:  0  epoch no:  27200  avg reward 0.7683333333333333
#  epoch no:  27200  avg reward 0.7683333333333333
#  message:  [4]  output:  2  epoch no:  27300  avg reward 0.75
#  epoch no:  27300  avg reward 0.75
#  message:  [3]  output:  2  epoch no:  27400  avg reward 0.7533333333333333
#  epoch no:  27400  avg reward 0.7533333333333333
#  message:  [4]  output:  0  epoch no:  27500  avg reward 0.7333333333333333
#  epoch no:  27500  avg reward 0.7333333333333333
#  message:  [3]  output:  2  epoch no:  27600  avg reward 0.7766666666666666
#  epoch no:  27600  avg reward 0.7766666666666666
#  message:  [2]  output:  1  epoch no:  27700  avg reward 0.745
#  epoch no:  27700  avg reward 0.745
#  message:  [4]  output:  2  epoch no:  27800  avg reward 0.7516666666666667
#  epoch no:  27800  avg reward 0.7516666666666667
#  message:  [4]  output:  1  epoch no:  27900  avg reward 0.72
#  epoch no:  27900  avg reward 0.72
#  message:  [0]  output:  0  epoch no:  28000  avg reward 0.7683333333333333
#  epoch no:  28000  avg reward 0.7683333333333333
#  message:  [3]  output:  0  epoch no:  28100  avg reward 0.7433333333333333
#  epoch no:  28100  avg reward 0.7433333333333333
#  message:  [2]  output:  2  epoch no:  28200  avg reward 0.7883333333333333
#  epoch no:  28200  avg reward 0.7883333333333333
#  message:  [2]  output:  0  epoch no:  28300  avg reward 0.72
#  epoch no:  28300  avg reward 0.72
#  message:  [2]  output:  2  epoch no:  28400  avg reward 0.7116666666666667
#  epoch no:  28400  avg reward 0.7116666666666667
#  message:  [3]  output:  2  epoch no:  28500  avg reward 0.7316666666666667
#  epoch no:  28500  avg reward 0.7316666666666667
#  message:  [0]  output:  0  epoch no:  28600  avg reward 0.7233333333333334
#  epoch no:  28600  avg reward 0.7233333333333334
#  message:  [3]  output:  0  epoch no:  28700  avg reward 0.7216666666666667
#  epoch no:  28700  avg reward 0.7216666666666667
#  message:  [0]  output:  2  epoch no:  28800  avg reward 0.7483333333333333
#  epoch no:  28800  avg reward 0.7483333333333333
#  message:  [3]  output:  2  epoch no:  28900  avg reward 0.7983333333333333
#  epoch no:  28900  avg reward 0.7983333333333333
#  message:  [2]  output:  1  epoch no:  29000  avg reward 0.755
#  epoch no:  29000  avg reward 0.755
#  message:  [4]  output:  1  epoch no:  29100  avg reward 0.7316666666666667
#  epoch no:  29100  avg reward 0.7316666666666667
#  message:  [2]  output:  0  epoch no:  29200  avg reward 0.795
#  epoch no:  29200  avg reward 0.795
#  message:  [1]  output:  1  epoch no:  29300  avg reward 0.77
#  epoch no:  29300  avg reward 0.77
#  message:  [0]  output:  1  epoch no:  29400  avg reward 0.7866666666666666
#  epoch no:  29400  avg reward 0.7866666666666666
#  message:  [1]  output:  2  epoch no:  29500  avg reward 0.7666666666666667
#  epoch no:  29500  avg reward 0.7666666666666667
#  message:  [2]  output:  0  epoch no:  29600  avg reward 0.7816666666666666
#  epoch no:  29600  avg reward 0.7816666666666666
#  message:  [3]  output:  1  epoch no:  29700  avg reward 0.7716666666666666
#  epoch no:  29700  avg reward 0.7716666666666666
#  message:  [0]  output:  2  epoch no:  29800  avg reward 0.72
#  epoch no:  29800  avg reward 0.72
#  message:  [3]  output:  2  epoch no:  29900  avg reward 0.77
#  epoch no:  29900  avg reward 0.77
#  message:  [2]  output:  2  epoch no:  30000  avg reward 0.8116666666666666
#  epoch no:  30000  avg reward 0.8116666666666666
#  message:  [3]  output:  1  epoch no:  30100  avg reward 0.8016666666666666
#  epoch no:  30100  avg reward 0.8016666666666666
#  message:  [0]  output:  0  epoch no:  30200  avg reward 0.745
#  epoch no:  30200  avg reward 0.745
#  message:  [3]  output:  0  epoch no:  30300  avg reward 0.7283333333333334
#  epoch no:  30300  avg reward 0.7283333333333334
#  message:  [0]  output:  0  epoch no:  30400  avg reward 0.775
#  epoch no:  30400  avg reward 0.775
#  message:  [2]  output:  2  epoch no:  30500  avg reward 0.745
#  epoch no:  30500  avg reward 0.745
#  message:  [1]  output:  0  epoch no:  30600  avg reward 0.7433333333333333
#  epoch no:  30600  avg reward 0.7433333333333333
#  message:  [0]  output:  2  epoch no:  30700  avg reward 0.77
#  epoch no:  30700  avg reward 0.77
#  message:  [0]  output:  0  epoch no:  30800  avg reward 0.7483333333333333
#  epoch no:  30800  avg reward 0.7483333333333333
#  message:  [2]  output:  2  epoch no:  30900  avg reward 0.7183333333333334
#  epoch no:  30900  avg reward 0.7183333333333334
#  message:  [4]  output:  1  epoch no:  31000  avg reward 0.7883333333333333
#  epoch no:  31000  avg reward 0.7883333333333333
#  message:  [1]  output:  0  epoch no:  31100  avg reward 0.7733333333333333
#  epoch no:  31100  avg reward 0.7733333333333333
#  message:  [4]  output:  2  epoch no:  31200  avg reward 0.7916666666666666
#  epoch no:  31200  avg reward 0.7916666666666666
#  message:  [0]  output:  2  epoch no:  31300  avg reward 0.7466666666666667
#  epoch no:  31300  avg reward 0.7466666666666667
#  message:  [2]  output:  2  epoch no:  31400  avg reward 0.7633333333333333
#  epoch no:  31400  avg reward 0.7633333333333333
#  message:  [3]  output:  0  epoch no:  31500  avg reward 0.775
#  epoch no:  31500  avg reward 0.775
#  message:  [2]  output:  1  epoch no:  31600  avg reward 0.7433333333333333
#  epoch no:  31600  avg reward 0.7433333333333333
#  message:  [2]  output:  0  epoch no:  31700  avg reward 0.8316666666666667
#  epoch no:  31700  avg reward 0.8316666666666667
#  message:  [4]  output:  0  epoch no:  31800  avg reward 0.7933333333333333
#  epoch no:  31800  avg reward 0.7933333333333333
#  message:  [2]  output:  1  epoch no:  31900  avg reward 0.73
#  epoch no:  31900  avg reward 0.73
#  message:  [0]  output:  0  epoch no:  32000  avg reward 0.8
#  epoch no:  32000  avg reward 0.8
#  message:  [0]  output:  0  epoch no:  32100  avg reward 0.7666666666666667
#  epoch no:  32100  avg reward 0.7666666666666667
#  message:  [2]  output:  1  epoch no:  32200  avg reward 0.78
#  epoch no:  32200  avg reward 0.78
#  message:  [0]  output:  1  epoch no:  32300  avg reward 0.7966666666666666
#  epoch no:  32300  avg reward 0.7966666666666666
#  message:  [1]  output:  0  epoch no:  32400  avg reward 0.7733333333333333
#  epoch no:  32400  avg reward 0.7733333333333333
#  message:  [2]  output:  2  epoch no:  32500  avg reward 0.7733333333333333
#  epoch no:  32500  avg reward 0.7733333333333333
#  message:  [1]  output:  1  epoch no:  32600  avg reward 0.7966666666666666
#  epoch no:  32600  avg reward 0.7966666666666666
#  message:  [0]  output:  1  epoch no:  32700  avg reward 0.815
#  epoch no:  32700  avg reward 0.815
#  message:  [2]  output:  0  epoch no:  32800  avg reward 0.7683333333333333
#  epoch no:  32800  avg reward 0.7683333333333333
#  message:  [2]  output:  1  epoch no:  32900  avg reward 0.7966666666666666
#  epoch no:  32900  avg reward 0.7966666666666666
#  message:  [4]  output:  0  epoch no:  33000  avg reward 0.8366666666666667
#  epoch no:  33000  avg reward 0.8366666666666667
#  message:  [2]  output:  0  epoch no:  33100  avg reward 0.8
#  epoch no:  33100  avg reward 0.8
#  message:  [3]  output:  0  epoch no:  33200  avg reward 0.785
#  epoch no:  33200  avg reward 0.785
#  message:  [0]  output:  2  epoch no:  33300  avg reward 0.815
#  epoch no:  33300  avg reward 0.815
#  message:  [1]  output:  0  epoch no:  33400  avg reward 0.75
#  epoch no:  33400  avg reward 0.75
#  message:  [0]  output:  1  epoch no:  33500  avg reward 0.7566666666666667
#  epoch no:  33500  avg reward 0.7566666666666667
#  message:  [0]  output:  0  epoch no:  33600  avg reward 0.7433333333333333
#  epoch no:  33600  avg reward 0.7433333333333333
#  message:  [3]  output:  2  epoch no:  33700  avg reward 0.7216666666666667
#  epoch no:  33700  avg reward 0.7216666666666667
#  message:  [3]  output:  2  epoch no:  33800  avg reward 0.765
#  epoch no:  33800  avg reward 0.765
#  message:  [2]  output:  1  epoch no:  33900  avg reward 0.7616666666666667
#  epoch no:  33900  avg reward 0.7616666666666667
#  message:  [3]  output:  2  epoch no:  34000  avg reward 0.735
#  epoch no:  34000  avg reward 0.735
#  message:  [2]  output:  1  epoch no:  34100  avg reward 0.7266666666666667
#  epoch no:  34100  avg reward 0.7266666666666667
#  message:  [2]  output:  2  epoch no:  34200  avg reward 0.7616666666666667
#  epoch no:  34200  avg reward 0.7616666666666667
#  message:  [0]  output:  2  epoch no:  34300  avg reward 0.7683333333333333
#  epoch no:  34300  avg reward 0.7683333333333333
#  message:  [0]  output:  1  epoch no:  34400  avg reward 0.7316666666666667
#  epoch no:  34400  avg reward 0.7316666666666667
#  message:  [3]  output:  2  epoch no:  34500  avg reward 0.7733333333333333
#  epoch no:  34500  avg reward 0.7733333333333333
#  message:  [1]  output:  1  epoch no:  34600  avg reward 0.7516666666666667
#  epoch no:  34600  avg reward 0.7516666666666667
#  message:  [3]  output:  0  epoch no:  34700  avg reward 0.7733333333333333
#  epoch no:  34700  avg reward 0.7733333333333333
#  message:  [1]  output:  0  epoch no:  34800  avg reward 0.7916666666666666
#  epoch no:  34800  avg reward 0.7916666666666666
#  message:  [2]  output:  2  epoch no:  34900  avg reward 0.7733333333333333
#  epoch no:  34900  avg reward 0.7733333333333333
#  message:  [0]  output:  0  epoch no:  35000  avg reward 0.745
#  epoch no:  35000  avg reward 0.745
#  message:  [0]  output:  2  epoch no:  35100  avg reward 0.82
#  epoch no:  35100  avg reward 0.82
#  message:  [0]  output:  1  epoch no:  35200  avg reward 0.7966666666666666
#  epoch no:  35200  avg reward 0.7966666666666666
#  message:  [2]  output:  1  epoch no:  35300  avg reward 0.7616666666666667
#  epoch no:  35300  avg reward 0.7616666666666667
#  message:  [0]  output:  0  epoch no:  35400  avg reward 0.79
#  epoch no:  35400  avg reward 0.79
#  message:  [0]  output:  0  epoch no:  35500  avg reward 0.8
#  epoch no:  35500  avg reward 0.8
#  message:  [2]  output:  2  epoch no:  35600  avg reward 0.7766666666666666
#  epoch no:  35600  avg reward 0.7766666666666666
#  message:  [2]  output:  1  epoch no:  35700  avg reward 0.7966666666666666
#  epoch no:  35700  avg reward 0.7966666666666666
#  message:  [0]  output:  1  epoch no:  35800  avg reward 0.7733333333333333
#  epoch no:  35800  avg reward 0.7733333333333333
#  message:  [3]  output:  1  epoch no:  35900  avg reward 0.7616666666666667
#  epoch no:  35900  avg reward 0.7616666666666667
#  message:  [0]  output:  0  epoch no:  36000  avg reward 0.75
#  epoch no:  36000  avg reward 0.75
#  message:  [0]  output:  1  epoch no:  36100  avg reward 0.7866666666666666
#  epoch no:  36100  avg reward 0.7866666666666666
#  message:  [3]  output:  1  epoch no:  36200  avg reward 0.7633333333333333
#  epoch no:  36200  avg reward 0.7633333333333333
#  message:  [0]  output:  1  epoch no:  36300  avg reward 0.75
#  epoch no:  36300  avg reward 0.75
#  message:  [0]  output:  0  epoch no:  36400  avg reward 0.7533333333333333
#  epoch no:  36400  avg reward 0.7533333333333333
#  message:  [0]  output:  0  epoch no:  36500  avg reward 0.7366666666666667
#  epoch no:  36500  avg reward 0.7366666666666667
#  message:  [4]  output:  2  epoch no:  36600  avg reward 0.8466666666666667
#  epoch no:  36600  avg reward 0.8466666666666667
#  message:  [4]  output:  1  epoch no:  36700  avg reward 0.805
#  epoch no:  36700  avg reward 0.805
#  message:  [4]  output:  0  epoch no:  36800  avg reward 0.8133333333333334
#  epoch no:  36800  avg reward 0.8133333333333334
#  message:  [2]  output:  1  epoch no:  36900  avg reward 0.775
#  epoch no:  36900  avg reward 0.775
#  message:  [3]  output:  2  epoch no:  37000  avg reward 0.7433333333333333
#  epoch no:  37000  avg reward 0.7433333333333333
#  message:  [3]  output:  1  epoch no:  37100  avg reward 0.7733333333333333
#  epoch no:  37100  avg reward 0.7733333333333333
#  message:  [2]  output:  0  epoch no:  37200  avg reward 0.7616666666666667
#  epoch no:  37200  avg reward 0.7616666666666667
#  message:  [3]  output:  2  epoch no:  37300  avg reward 0.7583333333333333
#  epoch no:  37300  avg reward 0.7583333333333333
#  message:  [2]  output:  2  epoch no:  37400  avg reward 0.815
#  epoch no:  37400  avg reward 0.815
#  message:  [2]  output:  2  epoch no:  37500  avg reward 0.795
#  epoch no:  37500  avg reward 0.795
#  message:  [3]  output:  2  epoch no:  37600  avg reward 0.715
#  epoch no:  37600  avg reward 0.715
#  message:  [2]  output:  2  epoch no:  37700  avg reward 0.7883333333333333
#  epoch no:  37700  avg reward 0.7883333333333333
#  message:  [4]  output:  2  epoch no:  37800  avg reward 0.7883333333333333
#  epoch no:  37800  avg reward 0.7883333333333333
#  message:  [3]  output:  0  epoch no:  37900  avg reward 0.7816666666666666
#  epoch no:  37900  avg reward 0.7816666666666666
#  message:  [0]  output:  1  epoch no:  38000  avg reward 0.78
#  epoch no:  38000  avg reward 0.78
#  message:  [4]  output:  0  epoch no:  38100  avg reward 0.775
#  epoch no:  38100  avg reward 0.775
#  message:  [2]  output:  1  epoch no:  38200  avg reward 0.7866666666666666
#  epoch no:  38200  avg reward 0.7866666666666666
#  message:  [2]  output:  0  epoch no:  38300  avg reward 0.7366666666666667
#  epoch no:  38300  avg reward 0.7366666666666667
#  message:  [0]  output:  0  epoch no:  38400  avg reward 0.7966666666666666
#  epoch no:  38400  avg reward 0.7966666666666666
#  message:  [0]  output:  2  epoch no:  38500  avg reward 0.7433333333333333
#  epoch no:  38500  avg reward 0.7433333333333333
#  message:  [1]  output:  0  epoch no:  38600  avg reward 0.7883333333333333
#  epoch no:  38600  avg reward 0.7883333333333333
#  message:  [4]  output:  2  epoch no:  38700  avg reward 0.7683333333333333
#  epoch no:  38700  avg reward 0.7683333333333333
#  message:  [4]  output:  2  epoch no:  38800  avg reward 0.7933333333333333
#  epoch no:  38800  avg reward 0.7933333333333333
#  message:  [4]  output:  1  epoch no:  38900  avg reward 0.7716666666666666
#  epoch no:  38900  avg reward 0.7716666666666666
#  message:  [2]  output:  0  epoch no:  39000  avg reward 0.7516666666666667
#  epoch no:  39000  avg reward 0.7516666666666667
#  message:  [0]  output:  1  epoch no:  39100  avg reward 0.8133333333333334
#  epoch no:  39100  avg reward 0.8133333333333334
#  message:  [0]  output:  1  epoch no:  39200  avg reward 0.7483333333333333
#  epoch no:  39200  avg reward 0.7483333333333333
#  message:  [2]  output:  0  epoch no:  39300  avg reward 0.8066666666666666
#  epoch no:  39300  avg reward 0.8066666666666666
#  message:  [3]  output:  0  epoch no:  39400  avg reward 0.7666666666666667
#  epoch no:  39400  avg reward 0.7666666666666667
#  message:  [1]  output:  2  epoch no:  39500  avg reward 0.7516666666666667
#  epoch no:  39500  avg reward 0.7516666666666667
#  message:  [0]  output:  0  epoch no:  39600  avg reward 0.8033333333333333
#  epoch no:  39600  avg reward 0.8033333333333333
#  message:  [0]  output:  2  epoch no:  39700  avg reward 0.8083333333333333
#  epoch no:  39700  avg reward 0.8083333333333333
#  message:  [4]  output:  0  epoch no:  39800  avg reward 0.7783333333333333
#  epoch no:  39800  avg reward 0.7783333333333333
#  message:  [4]  output:  2  epoch no:  39900  avg reward 0.8133333333333334
#  epoch no:  39900  avg reward 0.8133333333333334
#  message:  [4]  output:  0  epoch no:  40000  avg reward 0.8366666666666667
#  epoch no:  40000  avg reward 0.8366666666666667
#  message:  [3]  output:  0  epoch no:  40100  avg reward 0.79
#  epoch no:  40100  avg reward 0.79
#  message:  [1]  output:  2  epoch no:  40200  avg reward 0.7533333333333333
#  epoch no:  40200  avg reward 0.7533333333333333
#  message:  [2]  output:  0  epoch no:  40300  avg reward 0.8066666666666666
#  epoch no:  40300  avg reward 0.8066666666666666
#  message:  [2]  output:  0  epoch no:  40400  avg reward 0.79
#  epoch no:  40400  avg reward 0.79
#  message:  [4]  output:  2  epoch no:  40500  avg reward 0.8166666666666667
#  epoch no:  40500  avg reward 0.8166666666666667
#  message:  [4]  output:  1  epoch no:  40600  avg reward 0.7933333333333333
#  epoch no:  40600  avg reward 0.7933333333333333
#  message:  [4]  output:  1  epoch no:  40700  avg reward 0.7733333333333333
#  epoch no:  40700  avg reward 0.7733333333333333
#  message:  [1]  output:  2  epoch no:  40800  avg reward 0.81
#  epoch no:  40800  avg reward 0.81
#  message:  [2]  output:  2  epoch no:  40900  avg reward 0.78
#  epoch no:  40900  avg reward 0.78
#  message:  [2]  output:  2  epoch no:  41000  avg reward 0.82
#  epoch no:  41000  avg reward 0.82
#  message:  [0]  output:  2  epoch no:  41100  avg reward 0.8683333333333333
#  epoch no:  41100  avg reward 0.8683333333333333
#  message:  [4]  output:  2  epoch no:  41200  avg reward 0.7983333333333333
#  epoch no:  41200  avg reward 0.7983333333333333
#  message:  [4]  output:  0  epoch no:  41300  avg reward 0.83
#  epoch no:  41300  avg reward 0.83
#  message:  [4]  output:  0  epoch no:  41400  avg reward 0.8583333333333333
#  epoch no:  41400  avg reward 0.8583333333333333
#  message:  [3]  output:  2  epoch no:  41500  avg reward 0.8416666666666667
#  epoch no:  41500  avg reward 0.8416666666666667
#  message:  [0]  output:  0  epoch no:  41600  avg reward 0.8733333333333333
# ...
#  message:  [3]  output:  1  epoch no:  252000  avg reward 0.8433333333333334
#  epoch no:  252000  avg reward 0.8433333333333334
#  message:  [1]  output:  1  epoch no:  252100  avg reward 0.825
#  epoch no:  252100  avg reward 0.825
#  message:  [2]  output:  0  epoch no:  252200  avg reward 0.93
#  epoch no:  252200  avg reward 0.93
#  message:  [1]  output:  0  epoch no:  252300  avg reward 0.945
#  epoch no:  252300  avg reward 0.945
#  message:  [0]  output:  2  epoch no:  252400  avg reward 0.8633333333333333
#  epoch no:  252400  avg reward 0.8633333333333333
#  message:  [4]  output:  2  epoch no:  252500  avg reward 0.8966666666666666
#  epoch no:  252500  avg reward 0.8966666666666666
#  message:  [4]  output:  0  epoch no:  252600  avg reward 0.8866666666666667
#  epoch no:  252600  avg reward 0.8866666666666667
#  message:  [2]  output:  0  epoch no:  252700  avg reward 0.8416666666666667
#  epoch no:  252700  avg reward 0.8416666666666667
#  message:  [3]  output:  0  epoch no:  252800  avg reward 0.93
#  epoch no:  252800  avg reward 0.93
#  message:  [4]  output:  0  epoch no:  252900  avg reward 0.8966666666666666
#  epoch no:  252900  avg reward 0.8966666666666666
#  message:  [1]  output:  2  epoch no:  253000  avg reward 0.8933333333333333
#  epoch no:  253000  avg reward 0.8933333333333333
#  message:  [1]  output:  0  epoch no:  253100  avg reward 0.8666666666666667
#  epoch no:  253100  avg reward 0.8666666666666667
#  message:  [2]  output:  0  epoch no:  253200  avg reward 0.8516666666666667
#  epoch no:  253200  avg reward 0.8516666666666667
#  message:  [0]  output:  0  epoch no:  253300  avg reward 0.8933333333333333
#  epoch no:  253300  avg reward 0.8933333333333333
#  message:  [1]  output:  2  epoch no:  253400  avg reward 0.9416666666666667
#  epoch no:  253400  avg reward 0.9416666666666667
#  message:  [2]  output:  0  epoch no:  253500  avg reward 0.8283333333333334
#  epoch no:  253500  avg reward 0.8283333333333334
#  message:  [1]  output:  0  epoch no:  253600  avg reward 0.9683333333333334
#  epoch no:  253600  avg reward 0.9683333333333334
#  message:  [2]  output:  2  epoch no:  253700  avg reward 0.855
#  epoch no:  253700  avg reward 0.855
#  message:  [2]  output:  2  epoch no:  253800  avg reward 0.8916666666666667
#  epoch no:  253800  avg reward 0.8916666666666667
#  message:  [1]  output:  0  epoch no:  253900  avg reward 0.885
#  epoch no:  253900  avg reward 0.885
#  message:  [3]  output:  0  epoch no:  254000  avg reward 0.9216666666666666
#  epoch no:  254000  avg reward 0.9216666666666666
#  message:  [2]  output:  2  epoch no:  254100  avg reward 0.93
#  epoch no:  254100  avg reward 0.93
#  message:  [0]  output:  2  epoch no:  254200  avg reward 0.8733333333333333
#  epoch no:  254200  avg reward 0.8733333333333333
#  message:  [0]  output:  1  epoch no:  254300  avg reward 0.8966666666666666
#  epoch no:  254300  avg reward 0.8966666666666666
#  message:  [0]  output:  1  epoch no:  254400  avg reward 0.8616666666666667
#  epoch no:  254400  avg reward 0.8616666666666667
#  message:  [2]  output:  1  epoch no:  254500  avg reward 0.9016666666666666
#  epoch no:  254500  avg reward 0.9016666666666666
#  message:  [2]  output:  2  epoch no:  254600  avg reward 0.9866666666666667
#  epoch no:  254600  avg reward 0.9866666666666667
#  message:  [3]  output:  1  epoch no:  254700  avg reward 0.8816666666666667
#  epoch no:  254700  avg reward 0.8816666666666667
#  message:  [3]  output:  2  epoch no:  254800  avg reward 0.9033333333333333
#  epoch no:  254800  avg reward 0.9033333333333333
#  message:  [4]  output:  2  epoch no:  254900  avg reward 0.7683333333333333
#  epoch no:  254900  avg reward 0.7683333333333333
#  message:  [3]  output:  1  epoch no:  255000  avg reward 0.9183333333333333
#  epoch no:  255000  avg reward 0.9183333333333333
#  message:  [1]  output:  2  epoch no:  255100  avg reward 0.9316666666666666
#  epoch no:  255100  avg reward 0.9316666666666666
#  message:  [0]  output:  0  epoch no:  255200  avg reward 0.9233333333333333
#  epoch no:  255200  avg reward 0.9233333333333333
#  message:  [1]  output:  1  epoch no:  255300  avg reward 0.8
#  epoch no:  255300  avg reward 0.8
#  message:  [3]  output:  1  epoch no:  255400  avg reward 0.8633333333333333
#  epoch no:  255400  avg reward 0.8633333333333333
#  message:  [0]  output:  0  epoch no:  255500  avg reward 0.93
#  epoch no:  255500  avg reward 0.93
#  message:  [1]  output:  0  epoch no:  255600  avg reward 0.9566666666666667
#  epoch no:  255600  avg reward 0.9566666666666667
#  message:  [2]  output:  1  epoch no:  255700  avg reward 0.9433333333333334
#  epoch no:  255700  avg reward 0.9433333333333334
#  message:  [0]  output:  1  epoch no:  255800  avg reward 0.8916666666666667
#  epoch no:  255800  avg reward 0.8916666666666667
#  message:  [2]  output:  0  epoch no:  255900  avg reward 0.9133333333333333
#  epoch no:  255900  avg reward 0.9133333333333333
#  message:  [2]  output:  2  epoch no:  256000  avg reward 0.8783333333333333
#  epoch no:  256000  avg reward 0.8783333333333333
#  message:  [2]  output:  2  epoch no:  256100  avg reward 0.8816666666666667
#  epoch no:  256100  avg reward 0.8816666666666667
#  message:  [0]  output:  2  epoch no:  256200  avg reward 0.9466666666666667
#  epoch no:  256200  avg reward 0.9466666666666667
#  message:  [4]  output:  0  epoch no:  256300  avg reward 0.9333333333333333
#  epoch no:  256300  avg reward 0.9333333333333333
#  message:  [0]  output:  2  epoch no:  256400  avg reward 0.9333333333333333
#  epoch no:  256400  avg reward 0.9333333333333333
#  message:  [0]  output:  1  epoch no:  256500  avg reward 0.8433333333333334
#  epoch no:  256500  avg reward 0.8433333333333334
#  message:  [4]  output:  1  epoch no:  256600  avg reward 0.855
#  epoch no:  256600  avg reward 0.855
#  message:  [4]  output:  0  epoch no:  256700  avg reward 0.8383333333333334
#  epoch no:  256700  avg reward 0.8383333333333334
#  message:  [3]  output:  1  epoch no:  256800  avg reward 0.9183333333333333
#  epoch no:  256800  avg reward 0.9183333333333333
#  message:  [2]  output:  0  epoch no:  256900  avg reward 0.8416666666666667
#  epoch no:  256900  avg reward 0.8416666666666667
#  message:  [2]  output:  1  epoch no:  257000  avg reward 0.8
#  epoch no:  257000  avg reward 0.8
#  message:  [3]  output:  0  epoch no:  257100  avg reward 0.85
#  epoch no:  257100  avg reward 0.85
#  message:  [3]  output:  0  epoch no:  257200  avg reward 0.825
#  epoch no:  257200  avg reward 0.825
#  message:  [2]  output:  1  epoch no:  257300  avg reward 0.8733333333333333
#  epoch no:  257300  avg reward 0.8733333333333333
#  message:  [4]  output:  1  epoch no:  257400  avg reward 0.875
#  epoch no:  257400  avg reward 0.875
#  message:  [2]  output:  0  epoch no:  257500  avg reward 0.9466666666666667
#  epoch no:  257500  avg reward 0.9466666666666667
#  message:  [1]  output:  0  epoch no:  257600  avg reward 0.8383333333333334
#  epoch no:  257600  avg reward 0.8383333333333334
#  message:  [2]  output:  1  epoch no:  257700  avg reward 0.845
#  epoch no:  257700  avg reward 0.845
#  message:  [2]  output:  2  epoch no:  257800  avg reward 0.8966666666666666
#  epoch no:  257800  avg reward 0.8966666666666666
#  message:  [3]  output:  1  epoch no:  257900  avg reward 0.9183333333333333
#  epoch no:  257900  avg reward 0.9183333333333333
#  message:  [4]  output:  1  epoch no:  258000  avg reward 0.9516666666666667
#  epoch no:  258000  avg reward 0.9516666666666667
#  message:  [0]  output:  1  epoch no:  258100  avg reward 0.9016666666666666
#  epoch no:  258100  avg reward 0.9016666666666666
#  message:  [1]  output:  0  epoch no:  258200  avg reward 0.89
#  epoch no:  258200  avg reward 0.89
#  message:  [4]  output:  0  epoch no:  258300  avg reward 0.845
#  epoch no:  258300  avg reward 0.845
#  message:  [0]  output:  2  epoch no:  258400  avg reward 0.82
#  epoch no:  258400  avg reward 0.82
#  message:  [3]  output:  0  epoch no:  258500  avg reward 0.8466666666666667
#  epoch no:  258500  avg reward 0.8466666666666667
#  message:  [1]  output:  0  epoch no:  258600  avg reward 0.8666666666666667
#  epoch no:  258600  avg reward 0.8666666666666667
#  message:  [2]  output:  1  epoch no:  258700  avg reward 0.9083333333333333
#  epoch no:  258700  avg reward 0.9083333333333333
#  message:  [0]  output:  2  epoch no:  258800  avg reward 0.9016666666666666
#  epoch no:  258800  avg reward 0.9016666666666666
#  message:  [2]  output:  2  epoch no:  258900  avg reward 0.86
#  epoch no:  258900  avg reward 0.86
#  message:  [1]  output:  0  epoch no:  259000  avg reward 0.935
#  epoch no:  259000  avg reward 0.935
#  message:  [1]  output:  0  epoch no:  259100  avg reward 0.8483333333333334
#  epoch no:  259100  avg reward 0.8483333333333334
#  message:  [3]  output:  0  epoch no:  259200  avg reward 0.8666666666666667
#  epoch no:  259200  avg reward 0.8666666666666667
#  message:  [2]  output:  1  epoch no:  259300  avg reward 0.9033333333333333
#  epoch no:  259300  avg reward 0.9033333333333333
#  message:  [2]  output:  2  epoch no:  259400  avg reward 0.9033333333333333
#  epoch no:  259400  avg reward 0.9033333333333333
#  message:  [4]  output:  1  epoch no:  259500  avg reward 0.94
#  epoch no:  259500  avg reward 0.94
#  message:  [0]  output:  2  epoch no:  259600  avg reward 0.86
#  epoch no:  259600  avg reward 0.86
#  message:  [0]  output:  1  epoch no:  259700  avg reward 0.9516666666666667
#  epoch no:  259700  avg reward 0.9516666666666667
#  message:  [0]  output:  2  epoch no:  259800  avg reward 0.86
#  epoch no:  259800  avg reward 0.86
#  message:  [4]  output:  0  epoch no:  259900  avg reward 0.8183333333333334
#  epoch no:  259900  avg reward 0.8183333333333334
#  message:  [3]  output:  2  epoch no:  260000  avg reward 0.9133333333333333
#  epoch no:  260000  avg reward 0.9133333333333333
#  message:  [2]  output:  2  epoch no:  260100  avg reward 0.9066666666666666
#  epoch no:  260100  avg reward 0.9066666666666666
#  message:  [4]  output:  0  epoch no:  260200  avg reward 0.8916666666666667
#  epoch no:  260200  avg reward 0.8916666666666667
#  message:  [2]  output:  1  epoch no:  260300  avg reward 0.95
#  epoch no:  260300  avg reward 0.95
#  message:  [2]  output:  0  epoch no:  260400  avg reward 0.975
#  epoch no:  260400  avg reward 0.975
#  message:  [4]  output:  2  epoch no:  260500  avg reward 0.89
#  epoch no:  260500  avg reward 0.89
#  message:  [1]  output:  1  epoch no:  260600  avg reward 0.8916666666666667
#  epoch no:  260600  avg reward 0.8916666666666667
#  message:  [3]  output:  1  epoch no:  260700  avg reward 0.925
#  epoch no:  260700  avg reward 0.925
#  message:  [3]  output:  0  epoch no:  260800  avg reward 0.885
#  epoch no:  260800  avg reward 0.885
#  message:  [0]  output:  2  epoch no:  260900  avg reward 0.9066666666666666
#  epoch no:  260900  avg reward 0.9066666666666666
#  message:  [4]  output:  0  epoch no:  261000  avg reward 0.8416666666666667
#  epoch no:  261000  avg reward 0.8416666666666667
#  message:  [2]  output:  1  epoch no:  261100  avg reward 0.9016666666666666
#  epoch no:  261100  avg reward 0.9016666666666666
#  message:  [2]  output:  0  epoch no:  261200  avg reward 0.98
#  epoch no:  261200  avg reward 0.98
#  message:  [2]  output:  0  epoch no:  261300  avg reward 0.9166666666666666
#  epoch no:  261300  avg reward 0.9166666666666666
#  message:  [1]  output:  2  epoch no:  261400  avg reward 0.9133333333333333
#  epoch no:  261400  avg reward 0.9133333333333333
#  message:  [4]  output:  2  epoch no:  261500  avg reward 0.8383333333333334
#  epoch no:  261500  avg reward 0.8383333333333334
#  message:  [0]  output:  2  epoch no:  261600  avg reward 0.8416666666666667
#  epoch no:  261600  avg reward 0.8416666666666667
#  message:  [3]  output:  1  epoch no:  261700  avg reward 0.8916666666666667
#  epoch no:  261700  avg reward 0.8916666666666667
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-16430dcd3b7a> in <module>
#      58     if not flip_l:
#      59 #         print('e2')
# ---> 60         e2 = Listener.model.observe(reward=reward_batch, terminal=[True]*n_batches)
#      61 #     assert e1 == e2
#      62 #     e = e1
#
# /usr/local/lib/python3.5/dist-packages/tensorforce/models/model.py in observe(self, terminal, reward)
#    1423         feed_dict = self.get_feed_dict(terminal=terminal, reward=reward)
#    1424
# -> 1425         episode = self.monitored_session.run(fetches=fetches, feed_dict=feed_dict)
#    1426
#    1427         return episode
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/training/monitored_session.py in run(self, fetches, feed_dict, options, run_metadata)
#     544                           feed_dict=feed_dict,
#     545                           options=options,
# --> 546                           run_metadata=run_metadata)
#     547
#     548   def run_step_fn(self, step_fn):
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/training/monitored_session.py in run(self, *args, **kwargs)
#    1096   def run(self, *args, **kwargs):
#    1097     try:
# -> 1098       return self._sess.run(*args, **kwargs)
#    1099     except _PREEMPTION_ERRORS:
#    1100       raise
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/training/monitored_session.py in run(self, fetches, feed_dict, options, run_metadata)
#    1168                                   feed_dict=feed_dict,
#    1169                                   options=options,
# -> 1170                                   run_metadata=run_metadata)
#    1171
#    1172     for hook in self._hooks:
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/training/monitored_session.py in run(self, *args, **kwargs)
#     948
#     949   def run(self, *args, **kwargs):
# --> 950     return self._sess.run(*args, **kwargs)
#     951
#     952   def run_step_fn(self, step_fn, raw_session, run_with_hooks):
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     903     try:
#     904       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 905                          run_metadata_ptr)
#     906       if run_metadata:
#     907         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1138     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1139       results = self._do_run(handle, final_targets, final_fetches,
# -> 1140                              feed_dict_tensor, options, run_metadata)
#    1141     else:
#    1142       results = []
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1319     if handle is None:
#    1320       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1321                            run_metadata)
#    1322     else:
#    1323       return self._do_call(_prun_fn, handle, feeds, fetches)
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1325   def _do_call(self, fn, *args):
#    1326     try:
# -> 1327       return fn(*args)
#    1328     except errors.OpError as e:
#    1329       message = compat.as_text(e.message)
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1310       self._extend_graph()
#    1311       return self._call_tf_sessionrun(
# -> 1312           options, feed_dict, fetch_list, target_list, run_metadata)
#    1313
#    1314     def _prun_fn(handle, feed_dict, fetch_list):
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1418         return tf_session.TF_Run(
#    1419             self._session, options, feed_dict, fetch_list, target_list,
# -> 1420             status, run_metadata)
#    1421
#    1422   def _call_tf_sessionprun(self, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %%
### N population 10

fig = plt.figure()
ax = fig.add_subplot(111)
plt.ion()

fig.show()
fig.canvas.draw()
for i in range(n_epochs):
    Speaker = Speakers[np.random.choice(n_population)]
    Listener = Listeners[np.random.choice(n_population)]
    message_batch = []
    img_batch = []
    r = i%(2*freq)
    if r<1*freq:
        flip_s = False
        flip_l = True
    if r>=1*freq:
        flip_s = True
        flip_l = False
    l_rewards = []
    strokes = []
    for b in range(n_batches):
        strokes = []
#         for idx in range(2):
#             if idx ==0:
#                 feat = np.zeros((10,10), np.uint8)
#             else:
#                 im = message_to_image_sm(strokes, img_dim, img_dim)
# #                 feat = get_features([im])[0]
#                 feat = im.flatten()
        message = Speaker.act(states= game_pool[b].speaker_input(), independent=flip_s)  # (scalar between 0 and 4)
        message_batch.append(message)
#             strokes.append(message)
#         img = message_to_image(strokes, img_rows, img_cols)
#         img_batch.append(img)
#         Speaker.reset()

#     features_batch = get_features(intermediate_layer_model, img_batch)
#     message = Speaker.act(states= game_pool[b].speaker_input(feat), independent=flip_s)
    out_batch = []
    reward_batch = []
    for b in range(n_batches):
        out = Listener.act(states = game_pool[b].listener_input(message_batch[b]), independent = flip_l)
        out_batch.append(out)
        rew = game_pool[b].reward(out)
        reward_batch.append(rew)
        game_pool[b].reset()
    speaker_terminals = []
    rew_speaker = []
    for rew in reward_batch:
        speaker_terminals.extend([True])
        rew_speaker.extend([rew])

    if not flip_s:
#         print('e1')
        e1 = Speaker.model.observe(reward=rew_speaker, terminal=speaker_terminals)
    if not flip_l:
#         print('e2')
        e2 = Listener.model.observe(reward=reward_batch, terminal=[True]*n_batches)
#     assert e1 == e2
#     e = e1
    big_rewards.extend(reward_batch)
    big_rewards = big_rewards[-600:]
    if i%(100)==0:
#         print(" output: ", out)
        avg_rew = sum(big_rewards)/len(big_rewards)
        print(" message: ", message, " output: ", out, " epoch no: ", i, " avg reward", avg_rew)
        print(" epoch no: ", i, " avg reward", avg_rew)

        if(i!=0):
            data.append(avg_rew)
        ax.clear()
        ax.plot(data)
        if not flip_s:
            ax.set_xlabel('speaker')
        else:
            ax.set_xlabel('listener')
        fig.canvas.draw()


#     if sum(big_rewards)/len(big_rewards)>.75:
#         break
# Out:
# <img src="data:image/png;base64,..." width="639.230792677615">
#  message:  [0]  output:  0  epoch no:  0  avg reward 0.8166666666666667
#  epoch no:  0  avg reward 0.8166666666666667
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1326     try:
# -> 1327       return fn(*args)
#    1328     except errors.OpError as e:
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1311       return self._call_tf_sessionrun(
# -> 1312           options, feed_dict, fetch_list, target_list, run_metadata)
#    1313
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1419             self._session, options, feed_dict, fetch_list, target_list,
# -> 1420             status, run_metadata)
#    1421
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/framework/errors_impl.py in __exit__(self, type_arg, value_arg, traceback_arg)
#     515             compat.as_text(c_api.TF_Message(self.status.status)),
# --> 516             c_api.TF_GetCode(self.status.status))
#     517     # Delete the underlying status object from memory otherwise it stays alive
#
# InvalidArgumentError: Must have updates.shape = indices.shape + params.shape[1:], got updates.shape [64,9], indices.shape [32], params.shape [32000,9]
# 	 [[Node: ppo/observe-timestep/store/ScatterUpdate = ScatterUpdate[T=DT_FLOAT, Tindices=DT_INT32, _class=["loc:@ppo/initialize/latest/initialize/state-state"], use_locking=true, _device="/job:localhost/replica:0/task:0/device:CPU:0"](ppo/initialize/latest/initialize/state-state, ppo/observe-timestep/store/mod, ppo/strided_slice, ^ppo/observe-timestep/store/AssignSub)]]
#
# During handling of the above exception, another exception occurred:
#
# InvalidArgumentError                      Traceback (most recent call last)
# <ipython-input-5-d7d47dd5283e> in <module>
#      54     if not flip_s:
#      55 #         print('e1')
# ---> 56         e1 = Speaker.model.observe(reward=rew_speaker, terminal=speaker_terminals)
#      57     if not flip_l:
#      58 #         print('e2')
#
# /usr/local/lib/python3.5/dist-packages/tensorforce/models/model.py in observe(self, terminal, reward)
#    1423         feed_dict = self.get_feed_dict(terminal=terminal, reward=reward)
#    1424
# -> 1425         episode = self.monitored_session.run(fetches=fetches, feed_dict=feed_dict)
#    1426
#    1427         return episode
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/training/monitored_session.py in run(self, fetches, feed_dict, options, run_metadata)
#     544                           feed_dict=feed_dict,
#     545                           options=options,
# --> 546                           run_metadata=run_metadata)
#     547
#     548   def run_step_fn(self, step_fn):
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/training/monitored_session.py in run(self, *args, **kwargs)
#    1111         raise six.reraise(*original_exc_info)
#    1112       else:
# -> 1113         raise six.reraise(*original_exc_info)
#    1114
#    1115
#
# /usr/local/lib/python3.5/dist-packages/six.py in reraise(tp, value, tb)
#     691             if value.__traceback__ is not tb:
#     692                 raise value.with_traceback(tb)
# --> 693             raise value
#     694         finally:
#     695             value = None
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/training/monitored_session.py in run(self, *args, **kwargs)
#    1096   def run(self, *args, **kwargs):
#    1097     try:
# -> 1098       return self._sess.run(*args, **kwargs)
#    1099     except _PREEMPTION_ERRORS:
#    1100       raise
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/training/monitored_session.py in run(self, fetches, feed_dict, options, run_metadata)
#    1168                                   feed_dict=feed_dict,
#    1169                                   options=options,
# -> 1170                                   run_metadata=run_metadata)
#    1171
#    1172     for hook in self._hooks:
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/training/monitored_session.py in run(self, *args, **kwargs)
#     948
#     949   def run(self, *args, **kwargs):
# --> 950     return self._sess.run(*args, **kwargs)
#     951
#     952   def run_step_fn(self, step_fn, raw_session, run_with_hooks):
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     903     try:
#     904       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 905                          run_metadata_ptr)
#     906       if run_metadata:
#     907         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1138     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1139       results = self._do_run(handle, final_targets, final_fetches,
# -> 1140                              feed_dict_tensor, options, run_metadata)
#    1141     else:
#    1142       results = []
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1319     if handle is None:
#    1320       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1321                            run_metadata)
#    1322     else:
#    1323       return self._do_call(_prun_fn, handle, feeds, fetches)
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1338         except KeyError:
#    1339           pass
# -> 1340       raise type(e)(node_def, op, message)
#    1341
#    1342   def _extend_graph(self):
#
# InvalidArgumentError: Must have updates.shape = indices.shape + params.shape[1:], got updates.shape [64,9], indices.shape [32], params.shape [32000,9]
# 	 [[Node: ppo/observe-timestep/store/ScatterUpdate = ScatterUpdate[T=DT_FLOAT, Tindices=DT_INT32, _class=["loc:@ppo/initialize/latest/initialize/state-state"], use_locking=true, _device="/job:localhost/replica:0/task:0/device:CPU:0"](ppo/initialize/latest/initialize/state-state, ppo/observe-timestep/store/mod, ppo/strided_slice, ^ppo/observe-timestep/store/AssignSub)]]
#
# Caused by op 'ppo/observe-timestep/store/ScatterUpdate', defined at:
#   File "/usr/lib/python3.5/runpy.py", line 184, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/usr/lib/python3.5/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/usr/local/lib/python3.5/dist-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/usr/local/lib/python3.5/dist-packages/ipykernel/kernelapp.py", line 499, in start
#     self.io_loop.start()
#   File "/usr/local/lib/python3.5/dist-packages/tornado/platform/asyncio.py", line 132, in start
#     self.asyncio_loop.run_forever()
#   File "/usr/lib/python3.5/asyncio/base_events.py", line 345, in run_forever
#     self._run_once()
#   File "/usr/lib/python3.5/asyncio/base_events.py", line 1312, in _run_once
#     handle._run()
#   File "/usr/lib/python3.5/asyncio/events.py", line 125, in _run
#     self._callback(*self._args)
#   File "/usr/local/lib/python3.5/dist-packages/tornado/ioloop.py", line 758, in _run_callback
#     ret = callback()
#   File "/usr/local/lib/python3.5/dist-packages/tornado/stack_context.py", line 300, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/usr/local/lib/python3.5/dist-packages/tornado/gen.py", line 1233, in inner
#     self.run()
#   File "/usr/local/lib/python3.5/dist-packages/tornado/gen.py", line 1147, in run
#     yielded = self.gen.send(value)
#   File "/usr/local/lib/python3.5/dist-packages/ipykernel/kernelbase.py", line 346, in process_one
#     yield gen.maybe_future(dispatch(*args))
#   File "/usr/local/lib/python3.5/dist-packages/tornado/gen.py", line 326, in wrapper
#     yielded = next(result)
#   File "/usr/local/lib/python3.5/dist-packages/ipykernel/kernelbase.py", line 259, in dispatch_shell
#     yield gen.maybe_future(handler(stream, idents, msg))
#   File "/usr/local/lib/python3.5/dist-packages/tornado/gen.py", line 326, in wrapper
#     yielded = next(result)
#   File "/usr/local/lib/python3.5/dist-packages/ipykernel/kernelbase.py", line 513, in execute_request
#     user_expressions, allow_stdin,
#   File "/usr/local/lib/python3.5/dist-packages/tornado/gen.py", line 326, in wrapper
#     yielded = next(result)
#   File "/usr/local/lib/python3.5/dist-packages/ipykernel/ipkernel.py", line 294, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/usr/local/lib/python3.5/dist-packages/ipykernel/zmqshell.py", line 536, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/usr/local/lib/python3.5/dist-packages/IPython/core/interactiveshell.py", line 2817, in run_cell
#     raw_cell, store_history, silent, shell_futures)
#   File "/usr/local/lib/python3.5/dist-packages/IPython/core/interactiveshell.py", line 2843, in _run_cell
#     return runner(coro)
#   File "/usr/local/lib/python3.5/dist-packages/IPython/core/async_helpers.py", line 67, in _pseudo_sync_runner
#     coro.send(None)
#   File "/usr/local/lib/python3.5/dist-packages/IPython/core/interactiveshell.py", line 3018, in run_cell_async
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/usr/local/lib/python3.5/dist-packages/IPython/core/interactiveshell.py", line 3183, in run_ast_nodes
#     if (yield from self.run_code(code, result)):
#   File "/usr/local/lib/python3.5/dist-packages/IPython/core/interactiveshell.py", line 3265, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-3-719b2fb8640c>", line 7, in <module>
#     Speaker1, Listener1 = get_agents(ppo_config, network_config, sender_type, n_features, img_dim, img_features_len, n_samples, num_actions, action_size)
#   File "/media/petrichor/data/future/emergence-of-writing-systems/agents.py", line 22, in get_agents
#     network=network_deep,
#   File "/usr/local/lib/python3.5/dist-packages/tensorforce/agents/agent.py", line 283, in from_spec
#     kwargs=kwargs
#   File "/usr/local/lib/python3.5/dist-packages/tensorforce/util.py", line 192, in get_object
#     return obj(*args, **kwargs)
#   File "/usr/local/lib/python3.5/dist-packages/tensorforce/agents/ppo_agent.py", line 155, in __init__
#     entropy_regularization=entropy_regularization
#   File "/usr/local/lib/python3.5/dist-packages/tensorforce/agents/learning_agent.py", line 141, in __init__
#     batching_capacity=batching_capacity
#   File "/usr/local/lib/python3.5/dist-packages/tensorforce/agents/agent.py", line 80, in __init__
#     self.model = self.initialize_model()
#   File "/usr/local/lib/python3.5/dist-packages/tensorforce/agents/ppo_agent.py", line 183, in initialize_model
#     likelihood_ratio_clipping=self.likelihood_ratio_clipping
#   File "/usr/local/lib/python3.5/dist-packages/tensorforce/models/pg_prob_ratio_model.py", line 88, in __init__
#     gae_lambda=gae_lambda
#   File "/usr/local/lib/python3.5/dist-packages/tensorforce/models/pg_model.py", line 98, in __init__
#     requires_deterministic=False
#   File "/usr/local/lib/python3.5/dist-packages/tensorforce/models/distribution_model.py", line 90, in __init__
#     discount=discount
#   File "/usr/local/lib/python3.5/dist-packages/tensorforce/models/memory_model.py", line 114, in __init__
#     reward_preprocessing=reward_preprocessing
#   File "/usr/local/lib/python3.5/dist-packages/tensorforce/models/model.py", line 217, in __init__
#     self.setup()
#   File "/usr/local/lib/python3.5/dist-packages/tensorforce/models/model.py", line 290, in setup
#     independent=independent
#   File "/usr/local/lib/python3.5/dist-packages/tensorforce/models/memory_model.py", line 605, in create_operations
#     independent=independent
#   File "/usr/local/lib/python3.5/dist-packages/tensorforce/models/model.py", line 1195, in create_operations
#     self.create_observe_operations(reward=reward, terminal=terminal)
#   File "/usr/local/lib/python3.5/dist-packages/tensorforce/models/model.py", line 1129, in create_observe_operations
#     reward=reward
#   File "/usr/local/lib/python3.5/dist-packages/tensorflow/python/ops/template.py", line 464, in __call__
#     result = self._call_func(args, kwargs)
#   File "/usr/local/lib/python3.5/dist-packages/tensorflow/python/ops/template.py", line 406, in _call_func
#     result = self._func(*args, **kwargs)
#   File "/usr/local/lib/python3.5/dist-packages/tensorforce/models/memory_model.py", line 504, in tf_observe_timestep
#     reward=reward
#   File "/usr/local/lib/python3.5/dist-packages/tensorflow/python/ops/template.py", line 455, in __call__
#     result = self._call_func(args, kwargs)
#   File "/usr/local/lib/python3.5/dist-packages/tensorflow/python/ops/template.py", line 400, in _call_func
#     result = self._func(*args, **kwargs)
#   File "/usr/local/lib/python3.5/dist-packages/tensorforce/core/memories/queue.py", line 176, in tf_store
#     updates=states[name]
#   File "/usr/local/lib/python3.5/dist-packages/tensorflow/python/ops/state_ops.py", line 356, in scatter_update
#     use_locking=use_locking, name=name)
#   File "/usr/local/lib/python3.5/dist-packages/tensorflow/python/ops/gen_state_ops.py", line 984, in scatter_update
#     use_locking=use_locking, name=name)
#   File "/usr/local/lib/python3.5/dist-packages/tensorflow/python/framework/op_def_library.py", line 787, in _apply_op_helper
#     op_def=op_def)
#   File "/usr/local/lib/python3.5/dist-packages/tensorflow/python/framework/ops.py", line 3290, in create_op
#     op_def=op_def)
#   File "/usr/local/lib/python3.5/dist-packages/tensorflow/python/framework/ops.py", line 1654, in __init__
#     self._traceback = self._graph._extract_stack()  # pylint: disable=protected-access
#
# InvalidArgumentError (see above for traceback): Must have updates.shape = indices.shape + params.shape[1:], got updates.shape [64,9], indices.shape [32], params.shape [32000,9]
# 	 [[Node: ppo/observe-timestep/store/ScatterUpdate = ScatterUpdate[T=DT_FLOAT, Tindices=DT_INT32, _class=["loc:@ppo/initialize/latest/initialize/state-state"], use_locking=true, _device="/job:localhost/replica:0/task:0/device:CPU:0"](ppo/initialize/latest/initialize/state-state, ppo/observe-timestep/store/mod, ppo/strided_slice, ^ppo/observe-timestep/store/AssignSub)]]

# %%
### N population 16

fig = plt.figure()
ax = fig.add_subplot(111)
plt.ion()

fig.show()
fig.canvas.draw()
for i in range(n_epochs):
    Speaker = Speakers[np.random.choice(n_population)]
    Listener = Listeners[np.random.choice(n_population)]
    message_batch = []
    img_batch = []
    r = i%(2*freq)
    if r<1*freq:
        flip_s = False
        flip_l = True
    if r>=1*freq:
        flip_s = True
        flip_l = False
    l_rewards = []
    strokes = []
    for b in range(n_batches):
        strokes = []
#         for idx in range(2):
#             if idx ==0:
#                 feat = np.zeros((10,10), np.uint8)
#             else:
#                 im = message_to_image_sm(strokes, img_dim, img_dim)
# #                 feat = get_features([im])[0]
#                 feat = im.flatten()
        message = Speaker.act(states= game_pool[b].speaker_input(), independent=flip_s)  # (scalar between 0 and 4)
        message_batch.append(message)
#             strokes.append(message)
#         img = message_to_image(strokes, img_rows, img_cols)
#         img_batch.append(img)
#         Speaker.reset()

#     features_batch = get_features(intermediate_layer_model, img_batch)
#     message = Speaker.act(states= game_pool[b].speaker_input(feat), independent=flip_s)
    out_batch = []
    reward_batch = []
    for b in range(n_batches):
        out = Listener.act(states = game_pool[b].listener_input(message_batch[b]), independent = flip_l)
        out_batch.append(out)
        rew = game_pool[b].reward(out)
        reward_batch.append(rew)
        game_pool[b].reset()
    speaker_terminals = []
    rew_speaker = []
    for rew in reward_batch:
        speaker_terminals.extend([True])
        rew_speaker.extend([rew])

    if not flip_s:
#         print('e1')
        e1 = Speaker.model.observe(reward=rew_speaker, terminal=speaker_terminals)
    if not flip_l:
#         print('e2')
        e2 = Listener.model.observe(reward=reward_batch, terminal=[True]*n_batches)
#     assert e1 == e2
#     e = e1
    big_rewards.extend(reward_batch)
    big_rewards = big_rewards[-600:]
    if i%(100)==0:
#         print(" output: ", out)
        avg_rew = sum(big_rewards)/len(big_rewards)
        print(" message: ", message, " output: ", out, " epoch no: ", i, " avg reward", avg_rew)
        print(" epoch no: ", i, " avg reward", avg_rew)

        if(i!=0):
            data.append(avg_rew)
        ax.clear()
        ax.plot(data)
        if not flip_s:
            ax.set_xlabel('speaker')
        else:
            ax.set_xlabel('listener')
        fig.canvas.draw()


#     if sum(big_rewards)/len(big_rewards)>.75:
#         break
# Out:
# <img src="data:image/png;base64,..." width="639.230792677615">
#  message:  [2]  output:  2  epoch no:  0  avg reward 0.28125
#  epoch no:  0  avg reward 0.28125
#  message:  [2]  output:  2  epoch no:  100  avg reward 0.3516666666666667
#  epoch no:  100  avg reward 0.3516666666666667
#  message:  [0]  output:  0  epoch no:  200  avg reward 0.31833333333333336
#  epoch no:  200  avg reward 0.31833333333333336
#  message:  [4]  output:  0  epoch no:  300  avg reward 0.315
#  epoch no:  300  avg reward 0.315
#  message:  [1]  output:  2  epoch no:  400  avg reward 0.35
#  epoch no:  400  avg reward 0.35
#  message:  [2]  output:  1  epoch no:  500  avg reward 0.3283333333333333
#  epoch no:  500  avg reward 0.3283333333333333
#  message:  [3]  output:  1  epoch no:  600  avg reward 0.33
#  epoch no:  600  avg reward 0.33
#  message:  [1]  output:  0  epoch no:  700  avg reward 0.3616666666666667
#  epoch no:  700  avg reward 0.3616666666666667
#  message:  [2]  output:  1  epoch no:  800  avg reward 0.32666666666666666
#  epoch no:  800  avg reward 0.32666666666666666
#  message:  [4]  output:  0  epoch no:  900  avg reward 0.31666666666666665
#  epoch no:  900  avg reward 0.31666666666666665
#  message:  [3]  output:  0  epoch no:  1000  avg reward 0.315
#  epoch no:  1000  avg reward 0.315
#  message:  [0]  output:  1  epoch no:  1100  avg reward 0.29333333333333333
#  epoch no:  1100  avg reward 0.29333333333333333
#  message:  [2]  output:  0  epoch no:  1200  avg reward 0.35
#  epoch no:  1200  avg reward 0.35
#  message:  [4]  output:  2  epoch no:  1300  avg reward 0.31333333333333335
#  epoch no:  1300  avg reward 0.31333333333333335
#  message:  [4]  output:  0  epoch no:  1400  avg reward 0.3283333333333333
#  epoch no:  1400  avg reward 0.3283333333333333
#  message:  [3]  output:  0  epoch no:  1500  avg reward 0.31333333333333335
#  epoch no:  1500  avg reward 0.31333333333333335
#  message:  [3]  output:  0  epoch no:  1600  avg reward 0.3516666666666667
#  epoch no:  1600  avg reward 0.3516666666666667
#  message:  [4]  output:  2  epoch no:  1700  avg reward 0.3383333333333333
#  epoch no:  1700  avg reward 0.3383333333333333
#  message:  [2]  output:  0  epoch no:  1800  avg reward 0.3433333333333333
#  epoch no:  1800  avg reward 0.3433333333333333
#  message:  [3]  output:  2  epoch no:  1900  avg reward 0.35
#  epoch no:  1900  avg reward 0.35
#  message:  [0]  output:  0  epoch no:  2000  avg reward 0.31333333333333335
#  epoch no:  2000  avg reward 0.31333333333333335
#  message:  [3]  output:  0  epoch no:  2100  avg reward 0.36
#  epoch no:  2100  avg reward 0.36
#  message:  [0]  output:  2  epoch no:  2200  avg reward 0.335
#  epoch no:  2200  avg reward 0.335
#  message:  [4]  output:  0  epoch no:  2300  avg reward 0.34
#  epoch no:  2300  avg reward 0.34
#  message:  [2]  output:  1  epoch no:  2400  avg reward 0.2966666666666667
#  epoch no:  2400  avg reward 0.2966666666666667
#  message:  [3]  output:  0  epoch no:  2500  avg reward 0.35833333333333334
#  epoch no:  2500  avg reward 0.35833333333333334
#  message:  [4]  output:  1  epoch no:  2600  avg reward 0.31166666666666665
#  epoch no:  2600  avg reward 0.31166666666666665
#  message:  [0]  output:  0  epoch no:  2700  avg reward 0.33
#  epoch no:  2700  avg reward 0.33
#  message:  [2]  output:  2  epoch no:  2800  avg reward 0.33666666666666667
#  epoch no:  2800  avg reward 0.33666666666666667
#  message:  [1]  output:  2  epoch no:  2900  avg reward 0.3383333333333333
#  epoch no:  2900  avg reward 0.3383333333333333
#  message:  [1]  output:  2  epoch no:  3000  avg reward 0.38
#  epoch no:  3000  avg reward 0.38
#  message:  [4]  output:  1  epoch no:  3100  avg reward 0.35333333333333333
#  epoch no:  3100  avg reward 0.35333333333333333
#  message:  [2]  output:  2  epoch no:  3200  avg reward 0.34
#  epoch no:  3200  avg reward 0.34
#  message:  [0]  output:  0  epoch no:  3300  avg reward 0.3333333333333333
#  epoch no:  3300  avg reward 0.3333333333333333
#  message:  [0]  output:  2  epoch no:  3400  avg reward 0.2966666666666667
#  epoch no:  3400  avg reward 0.2966666666666667
#  message:  [4]  output:  2  epoch no:  3500  avg reward 0.31666666666666665
#  epoch no:  3500  avg reward 0.31666666666666665
#  message:  [1]  output:  1  epoch no:  3600  avg reward 0.295
#  epoch no:  3600  avg reward 0.295
#  message:  [1]  output:  2  epoch no:  3700  avg reward 0.34
#  epoch no:  3700  avg reward 0.34
#  message:  [0]  output:  0  epoch no:  3800  avg reward 0.31666666666666665
#  epoch no:  3800  avg reward 0.31666666666666665
#  message:  [1]  output:  1  epoch no:  3900  avg reward 0.3383333333333333
#  epoch no:  3900  avg reward 0.3383333333333333
#  message:  [1]  output:  1  epoch no:  4000  avg reward 0.30833333333333335
#  epoch no:  4000  avg reward 0.30833333333333335
#  message:  [4]  output:  2  epoch no:  4100  avg reward 0.31
#  epoch no:  4100  avg reward 0.31
#  message:  [1]  output:  1  epoch no:  4200  avg reward 0.32166666666666666
#  epoch no:  4200  avg reward 0.32166666666666666
#  message:  [0]  output:  0  epoch no:  4300  avg reward 0.34
#  epoch no:  4300  avg reward 0.34
#  message:  [0]  output:  0  epoch no:  4400  avg reward 0.32
#  epoch no:  4400  avg reward 0.32
#  message:  [0]  output:  2  epoch no:  4500  avg reward 0.3433333333333333
#  epoch no:  4500  avg reward 0.3433333333333333
#  message:  [3]  output:  2  epoch no:  4600  avg reward 0.32666666666666666
#  epoch no:  4600  avg reward 0.32666666666666666
#  message:  [4]  output:  0  epoch no:  4700  avg reward 0.35
#  epoch no:  4700  avg reward 0.35
#  message:  [3]  output:  2  epoch no:  4800  avg reward 0.3333333333333333
#  epoch no:  4800  avg reward 0.3333333333333333
#  message:  [4]  output:  0  epoch no:  4900  avg reward 0.3333333333333333
#  epoch no:  4900  avg reward 0.3333333333333333
#  message:  [3]  output:  2  epoch no:  5000  avg reward 0.30833333333333335
#  epoch no:  5000  avg reward 0.30833333333333335
#  message:  [2]  output:  2  epoch no:  5100  avg reward 0.37166666666666665
#  epoch no:  5100  avg reward 0.37166666666666665
#  message:  [4]  output:  0  epoch no:  5200  avg reward 0.3233333333333333
#  epoch no:  5200  avg reward 0.3233333333333333
#  message:  [0]  output:  2  epoch no:  5300  avg reward 0.30333333333333334
#  epoch no:  5300  avg reward 0.30333333333333334
#  message:  [4]  output:  0  epoch no:  5400  avg reward 0.335
#  epoch no:  5400  avg reward 0.335
#  message:  [2]  output:  2  epoch no:  5500  avg reward 0.31166666666666665
#  epoch no:  5500  avg reward 0.31166666666666665
#  message:  [1]  output:  2  epoch no:  5600  avg reward 0.33166666666666667
#  epoch no:  5600  avg reward 0.33166666666666667
#  message:  [0]  output:  1  epoch no:  5700  avg reward 0.32166666666666666
#  epoch no:  5700  avg reward 0.32166666666666666
#  message:  [2]  output:  2  epoch no:  5800  avg reward 0.32666666666666666
#  epoch no:  5800  avg reward 0.32666666666666666
#  message:  [4]  output:  1  epoch no:  5900  avg reward 0.3466666666666667
#  epoch no:  5900  avg reward 0.3466666666666667
#  message:  [2]  output:  2  epoch no:  6000  avg reward 0.3283333333333333
#  epoch no:  6000  avg reward 0.3283333333333333
#  message:  [1]  output:  2  epoch no:  6100  avg reward 0.31166666666666665
#  epoch no:  6100  avg reward 0.31166666666666665
#  message:  [1]  output:  0  epoch no:  6200  avg reward 0.33166666666666667
#  epoch no:  6200  avg reward 0.33166666666666667
#  message:  [3]  output:  0  epoch no:  6300  avg reward 0.3333333333333333
#  epoch no:  6300  avg reward 0.3333333333333333
#  message:  [0]  output:  1  epoch no:  6400  avg reward 0.325
#  epoch no:  6400  avg reward 0.325
#  message:  [0]  output:  2  epoch no:  6500  avg reward 0.3333333333333333
#  epoch no:  6500  avg reward 0.3333333333333333
#  message:  [2]  output:  0  epoch no:  6600  avg reward 0.355
#  epoch no:  6600  avg reward 0.355
#  message:  [3]  output:  0  epoch no:  6700  avg reward 0.3383333333333333
#  epoch no:  6700  avg reward 0.3383333333333333
#  message:  [0]  output:  0  epoch no:  6800  avg reward 0.35833333333333334
#  epoch no:  6800  avg reward 0.35833333333333334
#  message:  [3]  output:  1  epoch no:  6900  avg reward 0.3333333333333333
#  epoch no:  6900  avg reward 0.3333333333333333
#  message:  [2]  output:  1  epoch no:  7000  avg reward 0.33166666666666667
#  epoch no:  7000  avg reward 0.33166666666666667
#  message:  [1]  output:  2  epoch no:  7100  avg reward 0.33666666666666667
#  epoch no:  7100  avg reward 0.33666666666666667
#  message:  [3]  output:  1  epoch no:  7200  avg reward 0.3466666666666667
#  epoch no:  7200  avg reward 0.3466666666666667
#  message:  [0]  output:  2  epoch no:  7300  avg reward 0.3466666666666667
#  epoch no:  7300  avg reward 0.3466666666666667
#  message:  [2]  output:  2  epoch no:  7400  avg reward 0.31166666666666665
#  epoch no:  7400  avg reward 0.31166666666666665
#  message:  [2]  output:  1  epoch no:  7500  avg reward 0.36
#  epoch no:  7500  avg reward 0.36
#  message:  [4]  output:  0  epoch no:  7600  avg reward 0.30666666666666664
#  epoch no:  7600  avg reward 0.30666666666666664
#  message:  [1]  output:  1  epoch no:  7700  avg reward 0.33
#  epoch no:  7700  avg reward 0.33
#  message:  [1]  output:  0  epoch no:  7800  avg reward 0.335
#  epoch no:  7800  avg reward 0.335
#  message:  [0]  output:  0  epoch no:  7900  avg reward 0.315
#  epoch no:  7900  avg reward 0.315
#  message:  [3]  output:  0  epoch no:  8000  avg reward 0.34
#  epoch no:  8000  avg reward 0.34
#  message:  [4]  output:  1  epoch no:  8100  avg reward 0.325
#  epoch no:  8100  avg reward 0.325
#  message:  [3]  output:  2  epoch no:  8200  avg reward 0.33166666666666667
#  epoch no:  8200  avg reward 0.33166666666666667
#  message:  [3]  output:  2  epoch no:  8300  avg reward 0.31166666666666665
#  epoch no:  8300  avg reward 0.31166666666666665
#  message:  [2]  output:  1  epoch no:  8400  avg reward 0.3383333333333333
#  epoch no:  8400  avg reward 0.3383333333333333
#  message:  [2]  output:  2  epoch no:  8500  avg reward 0.29833333333333334
#  epoch no:  8500  avg reward 0.29833333333333334
#  message:  [2]  output:  1  epoch no:  8600  avg reward 0.31833333333333336
#  epoch no:  8600  avg reward 0.31833333333333336
#  message:  [2]  output:  2  epoch no:  8700  avg reward 0.3616666666666667
#  epoch no:  8700  avg reward 0.3616666666666667
#  message:  [2]  output:  2  epoch no:  8800  avg reward 0.30833333333333335
#  epoch no:  8800  avg reward 0.30833333333333335
#  message:  [2]  output:  2  epoch no:  8900  avg reward 0.325
#  epoch no:  8900  avg reward 0.325
#  message:  [2]  output:  2  epoch no:  9000  avg reward 0.3566666666666667
#  epoch no:  9000  avg reward 0.3566666666666667
#  message:  [2]  output:  2  epoch no:  9100  avg reward 0.3616666666666667
#  epoch no:  9100  avg reward 0.3616666666666667
#  message:  [3]  output:  0  epoch no:  9200  avg reward 0.34833333333333333
#  epoch no:  9200  avg reward 0.34833333333333333
#  message:  [1]  output:  2  epoch no:  9300  avg reward 0.31666666666666665
#  epoch no:  9300  avg reward 0.31666666666666665
#  message:  [0]  output:  2  epoch no:  9400  avg reward 0.3283333333333333
#  epoch no:  9400  avg reward 0.3283333333333333
#  message:  [4]  output:  0  epoch no:  9500  avg reward 0.33
#  epoch no:  9500  avg reward 0.33
#  message:  [4]  output:  2  epoch no:  9600  avg reward 0.29833333333333334
#  epoch no:  9600  avg reward 0.29833333333333334
#  message:  [4]  output:  0  epoch no:  9700  avg reward 0.3433333333333333
#  epoch no:  9700  avg reward 0.3433333333333333
#  message:  [2]  output:  2  epoch no:  9800  avg reward 0.31333333333333335
#  epoch no:  9800  avg reward 0.31333333333333335
#  message:  [4]  output:  1  epoch no:  9900  avg reward 0.28833333333333333
#  epoch no:  9900  avg reward 0.28833333333333333
#  message:  [4]  output:  0  epoch no:  10000  avg reward 0.34833333333333333
#  epoch no:  10000  avg reward 0.34833333333333333
#  message:  [4]  output:  1  epoch no:  10100  avg reward 0.33
#  epoch no:  10100  avg reward 0.33
#  message:  [4]  output:  1  epoch no:  10200  avg reward 0.33
#  epoch no:  10200  avg reward 0.33
#  message:  [1]  output:  2  epoch no:  10300  avg reward 0.37333333333333335
#  epoch no:  10300  avg reward 0.37333333333333335
#  message:  [4]  output:  0  epoch no:  10400  avg reward 0.32666666666666666
#  epoch no:  10400  avg reward 0.32666666666666666
#  message:  [0]  output:  0  epoch no:  10500  avg reward 0.3233333333333333
#  epoch no:  10500  avg reward 0.3233333333333333
#  message:  [1]  output:  0  epoch no:  10600  avg reward 0.36
#  epoch no:  10600  avg reward 0.36
#  message:  [0]  output:  2  epoch no:  10700  avg reward 0.31666666666666665
#  epoch no:  10700  avg reward 0.31666666666666665
#  message:  [3]  output:  0  epoch no:  10800  avg reward 0.32
#  epoch no:  10800  avg reward 0.32
#  message:  [2]  output:  1  epoch no:  10900  avg reward 0.3
#  epoch no:  10900  avg reward 0.3
#  message:  [4]  output:  2  epoch no:  11000  avg reward 0.3566666666666667
#  epoch no:  11000  avg reward 0.3566666666666667
#  message:  [0]  output:  0  epoch no:  11100  avg reward 0.3433333333333333
#  epoch no:  11100  avg reward 0.3433333333333333
#  message:  [3]  output:  2  epoch no:  11200  avg reward 0.35333333333333333
#  epoch no:  11200  avg reward 0.35333333333333333
#  message:  [2]  output:  2  epoch no:  11300  avg reward 0.31666666666666665
#  epoch no:  11300  avg reward 0.31666666666666665
#  message:  [0]  output:  0  epoch no:  11400  avg reward 0.31166666666666665
#  epoch no:  11400  avg reward 0.31166666666666665
#  message:  [2]  output:  0  epoch no:  11500  avg reward 0.37166666666666665
#  epoch no:  11500  avg reward 0.37166666666666665
#  message:  [4]  output:  1  epoch no:  11600  avg reward 0.31666666666666665
#  epoch no:  11600  avg reward 0.31666666666666665
#  message:  [0]  output:  1  epoch no:  11700  avg reward 0.325
#  epoch no:  11700  avg reward 0.325
#  message:  [2]  output:  0  epoch no:  11800  avg reward 0.335
#  epoch no:  11800  avg reward 0.335
#  message:  [0]  output:  0  epoch no:  11900  avg reward 0.325
#  epoch no:  11900  avg reward 0.325
#  message:  [2]  output:  1  epoch no:  12000  avg reward 0.3016666666666667
#  epoch no:  12000  avg reward 0.3016666666666667
#  message:  [1]  output:  2  epoch no:  12100  avg reward 0.345
#  epoch no:  12100  avg reward 0.345
#  message:  [4]  output:  2  epoch no:  12200  avg reward 0.3283333333333333
#  epoch no:  12200  avg reward 0.3283333333333333
#  message:  [0]  output:  1  epoch no:  12300  avg reward 0.35
#  epoch no:  12300  avg reward 0.35
#  message:  [2]  output:  2  epoch no:  12400  avg reward 0.32166666666666666
#  epoch no:  12400  avg reward 0.32166666666666666
#  message:  [3]  output:  2  epoch no:  12500  avg reward 0.31833333333333336
#  epoch no:  12500  avg reward 0.31833333333333336
#  message:  [0]  output:  0  epoch no:  12600  avg reward 0.30666666666666664
#  epoch no:  12600  avg reward 0.30666666666666664
#  message:  [1]  output:  0  epoch no:  12700  avg reward 0.3516666666666667
#  epoch no:  12700  avg reward 0.3516666666666667
#  message:  [2]  output:  2  epoch no:  12800  avg reward 0.325
#  epoch no:  12800  avg reward 0.325
#  message:  [2]  output:  2  epoch no:  12900  avg reward 0.33166666666666667
#  epoch no:  12900  avg reward 0.33166666666666667
#  message:  [4]  output:  1  epoch no:  13000  avg reward 0.36
#  epoch no:  13000  avg reward 0.36
#  message:  [3]  output:  2  epoch no:  13100  avg reward 0.32
#  epoch no:  13100  avg reward 0.32
#  message:  [2]  output:  0  epoch no:  13200  avg reward 0.34
#  epoch no:  13200  avg reward 0.34
#  message:  [0]  output:  0  epoch no:  13300  avg reward 0.3616666666666667
#  epoch no:  13300  avg reward 0.3616666666666667
#  message:  [2]  output:  2  epoch no:  13400  avg reward 0.31666666666666665
#  epoch no:  13400  avg reward 0.31666666666666665
#  message:  [2]  output:  1  epoch no:  13500  avg reward 0.305
#  epoch no:  13500  avg reward 0.305
#  message:  [2]  output:  1  epoch no:  13600  avg reward 0.3283333333333333
#  epoch no:  13600  avg reward 0.3283333333333333
#  message:  [0]  output:  2  epoch no:  13700  avg reward 0.3616666666666667
#  epoch no:  13700  avg reward 0.3616666666666667
#  message:  [4]  output:  1  epoch no:  13800  avg reward 0.33
#  epoch no:  13800  avg reward 0.33
#  message:  [3]  output:  2  epoch no:  13900  avg reward 0.3283333333333333
#  epoch no:  13900  avg reward 0.3283333333333333
#  message:  [2]  output:  0  epoch no:  14000  avg reward 0.29833333333333334
#  epoch no:  14000  avg reward 0.29833333333333334
#  message:  [0]  output:  2  epoch no:  14100  avg reward 0.37166666666666665
#  epoch no:  14100  avg reward 0.37166666666666665
#  message:  [0]  output:  2  epoch no:  14200  avg reward 0.36833333333333335
#  epoch no:  14200  avg reward 0.36833333333333335
#  message:  [4]  output:  0  epoch no:  14300  avg reward 0.305
#  epoch no:  14300  avg reward 0.305
#  message:  [3]  output:  2  epoch no:  14400  avg reward 0.345
#  epoch no:  14400  avg reward 0.345
#  message:  [3]  output:  0  epoch no:  14500  avg reward 0.3416666666666667
#  epoch no:  14500  avg reward 0.3416666666666667
#  message:  [2]  output:  2  epoch no:  14600  avg reward 0.3233333333333333
#  epoch no:  14600  avg reward 0.3233333333333333
#  message:  [2]  output:  2  epoch no:  14700  avg reward 0.35333333333333333
#  epoch no:  14700  avg reward 0.35333333333333333
#  message:  [1]  output:  0  epoch no:  14800  avg reward 0.32
#  epoch no:  14800  avg reward 0.32
#  message:  [4]  output:  2  epoch no:  14900  avg reward 0.3233333333333333
#  epoch no:  14900  avg reward 0.3233333333333333
#  message:  [2]  output:  0  epoch no:  15000  avg reward 0.35333333333333333
#  epoch no:  15000  avg reward 0.35333333333333333
#  message:  [0]  output:  1  epoch no:  15100  avg reward 0.38
#  epoch no:  15100  avg reward 0.38
#  message:  [0]  output:  0  epoch no:  15200  avg reward 0.335
#  epoch no:  15200  avg reward 0.335
#  message:  [4]  output:  2  epoch no:  15300  avg reward 0.36
#  epoch no:  15300  avg reward 0.36
#  message:  [0]  output:  1  epoch no:  15400  avg reward 0.37833333333333335
#  epoch no:  15400  avg reward 0.37833333333333335
#  message:  [4]  output:  2  epoch no:  15500  avg reward 0.36
#  epoch no:  15500  avg reward 0.36
#  message:  [2]  output:  1  epoch no:  15600  avg reward 0.365
#  epoch no:  15600  avg reward 0.365
#  message:  [2]  output:  0  epoch no:  15700  avg reward 0.36333333333333334
#  epoch no:  15700  avg reward 0.36333333333333334
#  message:  [0]  output:  0  epoch no:  15800  avg reward 0.3616666666666667
#  epoch no:  15800  avg reward 0.3616666666666667
#  message:  [4]  output:  2  epoch no:  15900  avg reward 0.35
#  epoch no:  15900  avg reward 0.35
#  message:  [4]  output:  0  epoch no:  16000  avg reward 0.37166666666666665
#  epoch no:  16000  avg reward 0.37166666666666665
#  message:  [4]  output:  0  epoch no:  16100  avg reward 0.39666666666666667
#  epoch no:  16100  avg reward 0.39666666666666667
#  message:  [0]  output:  1  epoch no:  16200  avg reward 0.41333333333333333
#  epoch no:  16200  avg reward 0.41333333333333333
#  message:  [4]  output:  2  epoch no:  16300  avg reward 0.395
#  epoch no:  16300  avg reward 0.395
#  message:  [0]  output:  0  epoch no:  16400  avg reward 0.42
#  epoch no:  16400  avg reward 0.42
#  message:  [3]  output:  0  epoch no:  16500  avg reward 0.3883333333333333
#  epoch no:  16500  avg reward 0.3883333333333333
#  message:  [0]  output:  1  epoch no:  16600  avg reward 0.4083333333333333
#  epoch no:  16600  avg reward 0.4083333333333333
#  message:  [0]  output:  2  epoch no:  16700  avg reward 0.4483333333333333
#  epoch no:  16700  avg reward 0.4483333333333333
#  message:  [0]  output:  0  epoch no:  16800  avg reward 0.425
#  epoch no:  16800  avg reward 0.425
#  message:  [0]  output:  2  epoch no:  16900  avg reward 0.37333333333333335
#  epoch no:  16900  avg reward 0.37333333333333335
#  message:  [4]  output:  2  epoch no:  17000  avg reward 0.42
#  epoch no:  17000  avg reward 0.42
#  message:  [2]  output:  2  epoch no:  17100  avg reward 0.43666666666666665
#  epoch no:  17100  avg reward 0.43666666666666665
#  message:  [2]  output:  2  epoch no:  17200  avg reward 0.43833333333333335
#  epoch no:  17200  avg reward 0.43833333333333335
#  message:  [4]  output:  1  epoch no:  17300  avg reward 0.47333333333333333
#  epoch no:  17300  avg reward 0.47333333333333333
#  message:  [4]  output:  2  epoch no:  17400  avg reward 0.4116666666666667
#  epoch no:  17400  avg reward 0.4116666666666667
#  message:  [4]  output:  2  epoch no:  17500  avg reward 0.4066666666666667
#  epoch no:  17500  avg reward 0.4066666666666667
#  message:  [3]  output:  1  epoch no:  17600  avg reward 0.43666666666666665
#  epoch no:  17600  avg reward 0.43666666666666665
#  message:  [0]  output:  2  epoch no:  17700  avg reward 0.41833333333333333
#  epoch no:  17700  avg reward 0.41833333333333333
#  message:  [0]  output:  2  epoch no:  17800  avg reward 0.4583333333333333
#  epoch no:  17800  avg reward 0.4583333333333333
#  message:  [4]  output:  1  epoch no:  17900  avg reward 0.43833333333333335
#  epoch no:  17900  avg reward 0.43833333333333335
#  message:  [0]  output:  0  epoch no:  18000  avg reward 0.4483333333333333
#  epoch no:  18000  avg reward 0.4483333333333333
#  message:  [2]  output:  2  epoch no:  18100  avg reward 0.51
#  epoch no:  18100  avg reward 0.51
#  message:  [0]  output:  1  epoch no:  18200  avg reward 0.415
#  epoch no:  18200  avg reward 0.415
#  message:  [0]  output:  0  epoch no:  18300  avg reward 0.44333333333333336
#  epoch no:  18300  avg reward 0.44333333333333336
#  message:  [0]  output:  1  epoch no:  18400  avg reward 0.435
#  epoch no:  18400  avg reward 0.435
#  message:  [2]  output:  0  epoch no:  18500  avg reward 0.42833333333333334
#  epoch no:  18500  avg reward 0.42833333333333334
#  message:  [0]  output:  1  epoch no:  18600  avg reward 0.47
#  epoch no:  18600  avg reward 0.47
#  message:  [0]  output:  1  epoch no:  18700  avg reward 0.5216666666666666
#  epoch no:  18700  avg reward 0.5216666666666666
#  message:  [4]  output:  2  epoch no:  18800  avg reward 0.475
#  epoch no:  18800  avg reward 0.475
#  message:  [1]  output:  0  epoch no:  18900  avg reward 0.4583333333333333
#  epoch no:  18900  avg reward 0.4583333333333333
#  message:  [0]  output:  1  epoch no:  19000  avg reward 0.475
#  epoch no:  19000  avg reward 0.475
#  message:  [3]  output:  1  epoch no:  19100  avg reward 0.515
#  epoch no:  19100  avg reward 0.515
#  message:  [0]  output:  2  epoch no:  19200  avg reward 0.495
#  epoch no:  19200  avg reward 0.495
#  message:  [0]  output:  1  epoch no:  19300  avg reward 0.52
#  epoch no:  19300  avg reward 0.52
#  message:  [3]  output:  1  epoch no:  19400  avg reward 0.48333333333333334
#  epoch no:  19400  avg reward 0.48333333333333334
#  message:  [0]  output:  0  epoch no:  19500  avg reward 0.495
#  epoch no:  19500  avg reward 0.495
#  message:  [1]  output:  2  epoch no:  19600  avg reward 0.49166666666666664
#  epoch no:  19600  avg reward 0.49166666666666664
#  message:  [0]  output:  2  epoch no:  19700  avg reward 0.49333333333333335
#  epoch no:  19700  avg reward 0.49333333333333335
#  message:  [0]  output:  1  epoch no:  19800  avg reward 0.48833333333333334
#  epoch no:  19800  avg reward 0.48833333333333334
#  message:  [0]  output:  2  epoch no:  19900  avg reward 0.4766666666666667
#  epoch no:  19900  avg reward 0.4766666666666667
#  message:  [0]  output:  2  epoch no:  20000  avg reward 0.555
#  epoch no:  20000  avg reward 0.555
#  message:  [3]  output:  1  epoch no:  20100  avg reward 0.5033333333333333
#  epoch no:  20100  avg reward 0.5033333333333333
#  message:  [0]  output:  2  epoch no:  20200  avg reward 0.4766666666666667
#  epoch no:  20200  avg reward 0.4766666666666667
#  message:  [0]  output:  2  epoch no:  20300  avg reward 0.5033333333333333
#  epoch no:  20300  avg reward 0.5033333333333333
#  message:  [4]  output:  0  epoch no:  20400  avg reward 0.48
#  epoch no:  20400  avg reward 0.48
#  message:  [4]  output:  1  epoch no:  20500  avg reward 0.45166666666666666
#  epoch no:  20500  avg reward 0.45166666666666666
#  message:  [0]  output:  2  epoch no:  20600  avg reward 0.5233333333333333
#  epoch no:  20600  avg reward 0.5233333333333333
#  message:  [1]  output:  2  epoch no:  20700  avg reward 0.5016666666666667
#  epoch no:  20700  avg reward 0.5016666666666667
#  message:  [1]  output:  2  epoch no:  20800  avg reward 0.485
#  epoch no:  20800  avg reward 0.485
#  message:  [4]  output:  2  epoch no:  20900  avg reward 0.5216666666666666
#  epoch no:  20900  avg reward 0.5216666666666666
#  message:  [3]  output:  1  epoch no:  21000  avg reward 0.48
#  epoch no:  21000  avg reward 0.48
#  message:  [3]  output:  2  epoch no:  21100  avg reward 0.48333333333333334
#  epoch no:  21100  avg reward 0.48333333333333334
#  message:  [1]  output:  2  epoch no:  21200  avg reward 0.5
#  epoch no:  21200  avg reward 0.5
#  message:  [0]  output:  0  epoch no:  21300  avg reward 0.48333333333333334
#  epoch no:  21300  avg reward 0.48333333333333334
#  message:  [0]  output:  2  epoch no:  21400  avg reward 0.525
#  epoch no:  21400  avg reward 0.525
#  message:  [0]  output:  2  epoch no:  21500  avg reward 0.5316666666666666
#  epoch no:  21500  avg reward 0.5316666666666666
#  message:  [0]  output:  1  epoch no:  21600  avg reward 0.48
#  epoch no:  21600  avg reward 0.48
#  message:  [2]  output:  0  epoch no:  21700  avg reward 0.5483333333333333
#  epoch no:  21700  avg reward 0.5483333333333333
#  message:  [2]  output:  0  epoch no:  21800  avg reward 0.5333333333333333
#  epoch no:  21800  avg reward 0.5333333333333333
#  message:  [0]  output:  0  epoch no:  21900  avg reward 0.5333333333333333
#  epoch no:  21900  avg reward 0.5333333333333333
#  message:  [4]  output:  2  epoch no:  22000  avg reward 0.5
#  epoch no:  22000  avg reward 0.5
#  message:  [3]  output:  1  epoch no:  22100  avg reward 0.555
#  epoch no:  22100  avg reward 0.555
#  message:  [0]  output:  2  epoch no:  22200  avg reward 0.5416666666666666
#  epoch no:  22200  avg reward 0.5416666666666666
#  message:  [0]  output:  1  epoch no:  22300  avg reward 0.48833333333333334
#  epoch no:  22300  avg reward 0.48833333333333334
#  message:  [0]  output:  0  epoch no:  22400  avg reward 0.5533333333333333
#  epoch no:  22400  avg reward 0.5533333333333333
#  message:  [0]  output:  1  epoch no:  22500  avg reward 0.5316666666666666
#  epoch no:  22500  avg reward 0.5316666666666666
#  message:  [0]  output:  2  epoch no:  22600  avg reward 0.5166666666666667
#  epoch no:  22600  avg reward 0.5166666666666667
#  message:  [3]  output:  2  epoch no:  22700  avg reward 0.5583333333333333
#  epoch no:  22700  avg reward 0.5583333333333333
#  message:  [3]  output:  1  epoch no:  22800  avg reward 0.5316666666666666
#  epoch no:  22800  avg reward 0.5316666666666666
#  message:  [0]  output:  0  epoch no:  22900  avg reward 0.505
#  epoch no:  22900  avg reward 0.505
#  message:  [0]  output:  2  epoch no:  23000  avg reward 0.545
#  epoch no:  23000  avg reward 0.545
#  message:  [4]  output:  0  epoch no:  23100  avg reward 0.51
#  epoch no:  23100  avg reward 0.51
#  message:  [4]  output:  2  epoch no:  23200  avg reward 0.55
#  epoch no:  23200  avg reward 0.55
#  message:  [0]  output:  1  epoch no:  23300  avg reward 0.5216666666666666
#  epoch no:  23300  avg reward 0.5216666666666666
#  message:  [0]  output:  2  epoch no:  23400  avg reward 0.46
#  epoch no:  23400  avg reward 0.46
#  message:  [0]  output:  0  epoch no:  23500  avg reward 0.49166666666666664
#  epoch no:  23500  avg reward 0.49166666666666664
#  message:  [0]  output:  2  epoch no:  23600  avg reward 0.5266666666666666
#  epoch no:  23600  avg reward 0.5266666666666666
#  message:  [4]  output:  0  epoch no:  23700  avg reward 0.5116666666666667
#  epoch no:  23700  avg reward 0.5116666666666667
#  message:  [0]  output:  2  epoch no:  23800  avg reward 0.5
#  epoch no:  23800  avg reward 0.5
#  message:  [0]  output:  0  epoch no:  23900  avg reward 0.5183333333333333
#  epoch no:  23900  avg reward 0.5183333333333333
#  message:  [4]  output:  0  epoch no:  24000  avg reward 0.525
#  epoch no:  24000  avg reward 0.525
#  message:  [3]  output:  2  epoch no:  24100  avg reward 0.5666666666666667
#  epoch no:  24100  avg reward 0.5666666666666667
#  message:  [2]  output:  2  epoch no:  24200  avg reward 0.5183333333333333
#  epoch no:  24200  avg reward 0.5183333333333333
#  message:  [2]  output:  1  epoch no:  24300  avg reward 0.5316666666666666
#  epoch no:  24300  avg reward 0.5316666666666666
#  message:  [3]  output:  1  epoch no:  24400  avg reward 0.5316666666666666
#  epoch no:  24400  avg reward 0.5316666666666666
#  message:  [0]  output:  0  epoch no:  24500  avg reward 0.53
#  epoch no:  24500  avg reward 0.53
#  message:  [0]  output:  2  epoch no:  24600  avg reward 0.5416666666666666
#  epoch no:  24600  avg reward 0.5416666666666666
#  message:  [2]  output:  2  epoch no:  24700  avg reward 0.49833333333333335
#  epoch no:  24700  avg reward 0.49833333333333335
#  message:  [2]  output:  2  epoch no:  24800  avg reward 0.5166666666666667
#  epoch no:  24800  avg reward 0.5166666666666667
#  message:  [0]  output:  2  epoch no:  24900  avg reward 0.5233333333333333
#  epoch no:  24900  avg reward 0.5233333333333333
#  message:  [3]  output:  2  epoch no:  25000  avg reward 0.515
#  epoch no:  25000  avg reward 0.515
#  message:  [3]  output:  0  epoch no:  25100  avg reward 0.5366666666666666
#  epoch no:  25100  avg reward 0.5366666666666666
#  message:  [2]  output:  0  epoch no:  25200  avg reward 0.5266666666666666
#  epoch no:  25200  avg reward 0.5266666666666666
#  message:  [3]  output:  2  epoch no:  25300  avg reward 0.55
#  epoch no:  25300  avg reward 0.55
#  message:  [3]  output:  0  epoch no:  25400  avg reward 0.5383333333333333
#  epoch no:  25400  avg reward 0.5383333333333333
#  message:  [0]  output:  1  epoch no:  25500  avg reward 0.5383333333333333
#  epoch no:  25500  avg reward 0.5383333333333333
#  message:  [4]  output:  0  epoch no:  25600  avg reward 0.5333333333333333
#  epoch no:  25600  avg reward 0.5333333333333333
#  message:  [3]  output:  1  epoch no:  25700  avg reward 0.5933333333333334
#  epoch no:  25700  avg reward 0.5933333333333334
#  message:  [0]  output:  2  epoch no:  25800  avg reward 0.5166666666666667
#  epoch no:  25800  avg reward 0.5166666666666667
#  message:  [3]  output:  0  epoch no:  25900  avg reward 0.5483333333333333
#  epoch no:  25900  avg reward 0.5483333333333333
#  message:  [0]  output:  1  epoch no:  26000  avg reward 0.5633333333333334
#  epoch no:  26000  avg reward 0.5633333333333334
#  message:  [3]  output:  1  epoch no:  26100  avg reward 0.5133333333333333
#  epoch no:  26100  avg reward 0.5133333333333333
#  message:  [4]  output:  2  epoch no:  26200  avg reward 0.5933333333333334
#  epoch no:  26200  avg reward 0.5933333333333334
#  message:  [4]  output:  1  epoch no:  26300  avg reward 0.54
#  epoch no:  26300  avg reward 0.54
#  message:  [2]  output:  2  epoch no:  26400  avg reward 0.54
#  epoch no:  26400  avg reward 0.54
#  message:  [0]  output:  1  epoch no:  26500  avg reward 0.5416666666666666
#  epoch no:  26500  avg reward 0.5416666666666666
#  message:  [0]  output:  0  epoch no:  26600  avg reward 0.51
#  epoch no:  26600  avg reward 0.51
#  message:  [0]  output:  2  epoch no:  26700  avg reward 0.5433333333333333
#  epoch no:  26700  avg reward 0.5433333333333333
#  message:  [1]  output:  2  epoch no:  26800  avg reward 0.5566666666666666
#  epoch no:  26800  avg reward 0.5566666666666666
#  message:  [0]  output:  1  epoch no:  26900  avg reward 0.555
#  epoch no:  26900  avg reward 0.555
#  message:  [0]  output:  2  epoch no:  27000  avg reward 0.5516666666666666
#  epoch no:  27000  avg reward 0.5516666666666666
#  message:  [3]  output:  2  epoch no:  27100  avg reward 0.5483333333333333
#  epoch no:  27100  avg reward 0.5483333333333333
#  message:  [2]  output:  2  epoch no:  27200  avg reward 0.5383333333333333
#  epoch no:  27200  avg reward 0.5383333333333333
#  message:  [2]  output:  2  epoch no:  27300  avg reward 0.5566666666666666
#  epoch no:  27300  avg reward 0.5566666666666666
#  message:  [4]  output:  1  epoch no:  27400  avg reward 0.48
#  epoch no:  27400  avg reward 0.48
#  message:  [0]  output:  2  epoch no:  27500  avg reward 0.495
#  epoch no:  27500  avg reward 0.495
#  message:  [0]  output:  2  epoch no:  27600  avg reward 0.5333333333333333
#  epoch no:  27600  avg reward 0.5333333333333333
#  message:  [3]  output:  2  epoch no:  27700  avg reward 0.535
#  epoch no:  27700  avg reward 0.535
#  message:  [0]  output:  2  epoch no:  27800  avg reward 0.555
#  epoch no:  27800  avg reward 0.555
#  message:  [0]  output:  2  epoch no:  27900  avg reward 0.5966666666666667
#  epoch no:  27900  avg reward 0.5966666666666667
#  message:  [2]  output:  2  epoch no:  28000  avg reward 0.5816666666666667
#  epoch no:  28000  avg reward 0.5816666666666667
#  message:  [3]  output:  0  epoch no:  28100  avg reward 0.5533333333333333
#  epoch no:  28100  avg reward 0.5533333333333333
#  message:  [1]  output:  2  epoch no:  28200  avg reward 0.5916666666666667
#  epoch no:  28200  avg reward 0.5916666666666667
#  message:  [4]  output:  0  epoch no:  28300  avg reward 0.5466666666666666
#  epoch no:  28300  avg reward 0.5466666666666666
#  message:  [0]  output:  2  epoch no:  28400  avg reward 0.5666666666666667
#  epoch no:  28400  avg reward 0.5666666666666667
#  message:  [0]  output:  0  epoch no:  28500  avg reward 0.5833333333333334
#  epoch no:  28500  avg reward 0.5833333333333334
#  message:  [0]  output:  1  epoch no:  28600  avg reward 0.5666666666666667
#  epoch no:  28600  avg reward 0.5666666666666667
#  message:  [0]  output:  0  epoch no:  28700  avg reward 0.5833333333333334
#  epoch no:  28700  avg reward 0.5833333333333334
#  message:  [2]  output:  2  epoch no:  28800  avg reward 0.6
#  epoch no:  28800  avg reward 0.6
#  message:  [4]  output:  0  epoch no:  28900  avg reward 0.5583333333333333
#  epoch no:  28900  avg reward 0.5583333333333333
#  message:  [1]  output:  2  epoch no:  29000  avg reward 0.5533333333333333
#  epoch no:  29000  avg reward 0.5533333333333333
#  message:  [1]  output:  0  epoch no:  29100  avg reward 0.6516666666666666
#  epoch no:  29100  avg reward 0.6516666666666666
#  message:  [2]  output:  0  epoch no:  29200  avg reward 0.5366666666666666
#  epoch no:  29200  avg reward 0.5366666666666666
#  message:  [0]  output:  0  epoch no:  29300  avg reward 0.5816666666666667
#  epoch no:  29300  avg reward 0.5816666666666667
#  message:  [1]  output:  1  epoch no:  29400  avg reward 0.6183333333333333
#  epoch no:  29400  avg reward 0.6183333333333333
#  message:  [4]  output:  2  epoch no:  29500  avg reward 0.575
#  epoch no:  29500  avg reward 0.575
#  message:  [3]  output:  2  epoch no:  29600  avg reward 0.575
#  epoch no:  29600  avg reward 0.575
#  message:  [4]  output:  1  epoch no:  29700  avg reward 0.605
#  epoch no:  29700  avg reward 0.605
#  message:  [1]  output:  2  epoch no:  29800  avg reward 0.6366666666666667
#  epoch no:  29800  avg reward 0.6366666666666667
#  message:  [3]  output:  2  epoch no:  29900  avg reward 0.57
#  epoch no:  29900  avg reward 0.57
#  message:  [1]  output:  2  epoch no:  30000  avg reward 0.5666666666666667
#  epoch no:  30000  avg reward 0.5666666666666667
#  message:  [0]  output:  0  epoch no:  30100  avg reward 0.5933333333333334
#  epoch no:  30100  avg reward 0.5933333333333334
#  message:  [1]  output:  2  epoch no:  30200  avg reward 0.5983333333333334
#  epoch no:  30200  avg reward 0.5983333333333334
#  message:  [1]  output:  1  epoch no:  30300  avg reward 0.6533333333333333
#  epoch no:  30300  avg reward 0.6533333333333333
#  message:  [1]  output:  1  epoch no:  30400  avg reward 0.6283333333333333
#  epoch no:  30400  avg reward 0.6283333333333333
#  message:  [1]  output:  0  epoch no:  30500  avg reward 0.63
#  epoch no:  30500  avg reward 0.63
#  message:  [0]  output:  0  epoch no:  30600  avg reward 0.5983333333333334
#  epoch no:  30600  avg reward 0.5983333333333334
#  message:  [0]  output:  0  epoch no:  30700  avg reward 0.61
#  epoch no:  30700  avg reward 0.61
#  message:  [4]  output:  2  epoch no:  30800  avg reward 0.6183333333333333
#  epoch no:  30800  avg reward 0.6183333333333333
#  message:  [4]  output:  2  epoch no:  30900  avg reward 0.5616666666666666
#  epoch no:  30900  avg reward 0.5616666666666666
#  message:  [0]  output:  2  epoch no:  31000  avg reward 0.58
#  epoch no:  31000  avg reward 0.58
#  message:  [3]  output:  2  epoch no:  31100  avg reward 0.6133333333333333
#  epoch no:  31100  avg reward 0.6133333333333333
#  message:  [4]  output:  2  epoch no:  31200  avg reward 0.59
#  epoch no:  31200  avg reward 0.59
#  message:  [3]  output:  2  epoch no:  31300  avg reward 0.5833333333333334
#  epoch no:  31300  avg reward 0.5833333333333334
#  message:  [3]  output:  2  epoch no:  31400  avg reward 0.5833333333333334
#  epoch no:  31400  avg reward 0.5833333333333334
#  message:  [1]  output:  0  epoch no:  31500  avg reward 0.6233333333333333
#  epoch no:  31500  avg reward 0.6233333333333333
#  message:  [0]  output:  0  epoch no:  31600  avg reward 0.6333333333333333
#  epoch no:  31600  avg reward 0.6333333333333333
#  message:  [0]  output:  2  epoch no:  31700  avg reward 0.65
#  epoch no:  31700  avg reward 0.65
#  message:  [4]  output:  0  epoch no:  31800  avg reward 0.6533333333333333
#  epoch no:  31800  avg reward 0.6533333333333333
#  message:  [0]  output:  0  epoch no:  31900  avg reward 0.58
#  epoch no:  31900  avg reward 0.58
#  message:  [1]  output:  0  epoch no:  32000  avg reward 0.5966666666666667
#  epoch no:  32000  avg reward 0.5966666666666667
#  message:  [1]  output:  2  epoch no:  32100  avg reward 0.5816666666666667
#  epoch no:  32100  avg reward 0.5816666666666667
#  message:  [3]  output:  0  epoch no:  32200  avg reward 0.6116666666666667
#  epoch no:  32200  avg reward 0.6116666666666667
#  message:  [0]  output:  1  epoch no:  32300  avg reward 0.6616666666666666
#  epoch no:  32300  avg reward 0.6616666666666666
#  message:  [0]  output:  2  epoch no:  32400  avg reward 0.6916666666666667
#  epoch no:  32400  avg reward 0.6916666666666667
#  message:  [2]  output:  2  epoch no:  32500  avg reward 0.6483333333333333
#  epoch no:  32500  avg reward 0.6483333333333333
#  message:  [1]  output:  2  epoch no:  32600  avg reward 0.6766666666666666
#  epoch no:  32600  avg reward 0.6766666666666666
#  message:  [3]  output:  1  epoch no:  32700  avg reward 0.6716666666666666
#  epoch no:  32700  avg reward 0.6716666666666666
#  message:  [4]  output:  0  epoch no:  32800  avg reward 0.685
#  epoch no:  32800  avg reward 0.685
#  message:  [2]  output:  2  epoch no:  32900  avg reward 0.635
#  epoch no:  32900  avg reward 0.635
#  message:  [1]  output:  2  epoch no:  33000  avg reward 0.6783333333333333
#  epoch no:  33000  avg reward 0.6783333333333333
#  message:  [3]  output:  1  epoch no:  33100  avg reward 0.6033333333333334
#  epoch no:  33100  avg reward 0.6033333333333334
#  message:  [0]  output:  2  epoch no:  33200  avg reward 0.6083333333333333
#  epoch no:  33200  avg reward 0.6083333333333333
#  message:  [1]  output:  2  epoch no:  33300  avg reward 0.6966666666666667
#  epoch no:  33300  avg reward 0.6966666666666667
#  message:  [0]  output:  1  epoch no:  33400  avg reward 0.6566666666666666
#  epoch no:  33400  avg reward 0.6566666666666666
#  message:  [1]  output:  0  epoch no:  33500  avg reward 0.6383333333333333
#  epoch no:  33500  avg reward 0.6383333333333333
#  message:  [0]  output:  1  epoch no:  33600  avg reward 0.6133333333333333
#  epoch no:  33600  avg reward 0.6133333333333333
#  message:  [2]  output:  2  epoch no:  33700  avg reward 0.6716666666666666
#  epoch no:  33700  avg reward 0.6716666666666666
#  message:  [0]  output:  0  epoch no:  33800  avg reward 0.6783333333333333
#  epoch no:  33800  avg reward 0.6783333333333333
#  message:  [0]  output:  0  epoch no:  33900  avg reward 0.6233333333333333
#  epoch no:  33900  avg reward 0.6233333333333333
#  message:  [4]  output:  0  epoch no:  34000  avg reward 0.67
#  epoch no:  34000  avg reward 0.67
#  message:  [1]  output:  2  epoch no:  34100  avg reward 0.625
#  epoch no:  34100  avg reward 0.625
#  message:  [0]  output:  0  epoch no:  34200  avg reward 0.7016666666666667
#  epoch no:  34200  avg reward 0.7016666666666667
#  message:  [3]  output:  1  epoch no:  34300  avg reward 0.67
#  epoch no:  34300  avg reward 0.67
#  message:  [4]  output:  2  epoch no:  34400  avg reward 0.6283333333333333
#  epoch no:  34400  avg reward 0.6283333333333333
#  message:  [4]  output:  0  epoch no:  34500  avg reward 0.6316666666666667
#  epoch no:  34500  avg reward 0.6316666666666667
#  message:  [1]  output:  1  epoch no:  34600  avg reward 0.7116666666666667
#  epoch no:  34600  avg reward 0.7116666666666667
#  message:  [4]  output:  2  epoch no:  34700  avg reward 0.7116666666666667
#  epoch no:  34700  avg reward 0.7116666666666667
#  message:  [0]  output:  1  epoch no:  34800  avg reward 0.6783333333333333
#  epoch no:  34800  avg reward 0.6783333333333333
#  message:  [0]  output:  2  epoch no:  34900  avg reward 0.68
#  epoch no:  34900  avg reward 0.68
#  message:  [2]  output:  0  epoch no:  35000  avg reward 0.7866666666666666
#  epoch no:  35000  avg reward 0.7866666666666666
#  message:  [4]  output:  1  epoch no:  35100  avg reward 0.6766666666666666
#  epoch no:  35100  avg reward 0.6766666666666666
#  message:  [1]  output:  0  epoch no:  35200  avg reward 0.6883333333333334
#  epoch no:  35200  avg reward 0.6883333333333334
#  message:  [0]  output:  0  epoch no:  35300  avg reward 0.675
#  epoch no:  35300  avg reward 0.675
#  message:  [1]  output:  2  epoch no:  35400  avg reward 0.7233333333333334
#  epoch no:  35400  avg reward 0.7233333333333334
#  message:  [0]  output:  2  epoch no:  35500  avg reward 0.7183333333333334
#  epoch no:  35500  avg reward 0.7183333333333334
#  message:  [0]  output:  0  epoch no:  35600  avg reward 0.7233333333333334
#  epoch no:  35600  avg reward 0.7233333333333334
#  message:  [1]  output:  1  epoch no:  35700  avg reward 0.7133333333333334
#  epoch no:  35700  avg reward 0.7133333333333334
#  message:  [0]  output:  1  epoch no:  35800  avg reward 0.7533333333333333
#  epoch no:  35800  avg reward 0.7533333333333333
#  message:  [0]  output:  1  epoch no:  35900  avg reward 0.6733333333333333
#  epoch no:  35900  avg reward 0.6733333333333333
#  message:  [0]  output:  2  epoch no:  36000  avg reward 0.64
#  epoch no:  36000  avg reward 0.64
#  message:  [0]  output:  2  epoch no:  36100  avg reward 0.6916666666666667
#  epoch no:  36100  avg reward 0.6916666666666667
#  message:  [1]  output:  0  epoch no:  36200  avg reward 0.69
#  epoch no:  36200  avg reward 0.69
#  message:  [3]  output:  2  epoch no:  36300  avg reward 0.69
#  epoch no:  36300  avg reward 0.69
#  message:  [0]  output:  2  epoch no:  36400  avg reward 0.675
#  epoch no:  36400  avg reward 0.675
#  message:  [3]  output:  0  epoch no:  36500  avg reward 0.665
#  epoch no:  36500  avg reward 0.665
#  message:  [2]  output:  0  epoch no:  36600  avg reward 0.75
#  epoch no:  36600  avg reward 0.75
#  message:  [1]  output:  0  epoch no:  36700  avg reward 0.7283333333333334
#  epoch no:  36700  avg reward 0.7283333333333334
#  message:  [3]  output:  1  epoch no:  36800  avg reward 0.6883333333333334
#  epoch no:  36800  avg reward 0.6883333333333334
#  message:  [0]  output:  0  epoch no:  36900  avg reward 0.7633333333333333
#  epoch no:  36900  avg reward 0.7633333333333333
#  message:  [3]  output:  2  epoch no:  37000  avg reward 0.715
#  epoch no:  37000  avg reward 0.715
#  message:  [4]  output:  2  epoch no:  37100  avg reward 0.6816666666666666
#  epoch no:  37100  avg reward 0.6816666666666666
#  message:  [3]  output:  1  epoch no:  37200  avg reward 0.68
#  epoch no:  37200  avg reward 0.68
#  message:  [1]  output:  0  epoch no:  37300  avg reward 0.7
#  epoch no:  37300  avg reward 0.7
#  message:  [0]  output:  0  epoch no:  37400  avg reward 0.645
#  epoch no:  37400  avg reward 0.645
#  message:  [1]  output:  1  epoch no:  37500  avg reward 0.6766666666666666
#  epoch no:  37500  avg reward 0.6766666666666666
#  message:  [0]  output:  1  epoch no:  37600  avg reward 0.7166666666666667
#  epoch no:  37600  avg reward 0.7166666666666667
#  message:  [4]  output:  0  epoch no:  37700  avg reward 0.705
#  epoch no:  37700  avg reward 0.705
#  message:  [0]  output:  1  epoch no:  37800  avg reward 0.685
#  epoch no:  37800  avg reward 0.685
#  message:  [3]  output:  2  epoch no:  37900  avg reward 0.7583333333333333
#  epoch no:  37900  avg reward 0.7583333333333333
#  message:  [0]  output:  0  epoch no:  38000  avg reward 0.6966666666666667
#  epoch no:  38000  avg reward 0.6966666666666667
#  message:  [3]  output:  2  epoch no:  38100  avg reward 0.7466666666666667
#  epoch no:  38100  avg reward 0.7466666666666667
#  message:  [4]  output:  2  epoch no:  38200  avg reward 0.7333333333333333
#  epoch no:  38200  avg reward 0.7333333333333333
#  message:  [2]  output:  0  epoch no:  38300  avg reward 0.7116666666666667
#  epoch no:  38300  avg reward 0.7116666666666667
#  message:  [1]  output:  0  epoch no:  38400  avg reward 0.6833333333333333
#  epoch no:  38400  avg reward 0.6833333333333333
#  message:  [2]  output:  0  epoch no:  38500  avg reward 0.6933333333333334
#  epoch no:  38500  avg reward 0.6933333333333334
#  message:  [1]  output:  2  epoch no:  38600  avg reward 0.7333333333333333
#  epoch no:  38600  avg reward 0.7333333333333333
#  message:  [1]  output:  0  epoch no:  38700  avg reward 0.7116666666666667
#  epoch no:  38700  avg reward 0.7116666666666667
#  message:  [1]  output:  1  epoch no:  38800  avg reward 0.71
#  epoch no:  38800  avg reward 0.71
#  message:  [1]  output:  1  epoch no:  38900  avg reward 0.7066666666666667
#  epoch no:  38900  avg reward 0.7066666666666667
#  message:  [4]  output:  0  epoch no:  39000  avg reward 0.78
#  epoch no:  39000  avg reward 0.78
#  message:  [1]  output:  1  epoch no:  39100  avg reward 0.71
#  epoch no:  39100  avg reward 0.71
#  message:  [3]  output:  2  epoch no:  39200  avg reward 0.6766666666666666
#  epoch no:  39200  avg reward 0.6766666666666666
#  message:  [0]  output:  1  epoch no:  39300  avg reward 0.7083333333333334
#  epoch no:  39300  avg reward 0.7083333333333334
#  message:  [1]  output:  2  epoch no:  39400  avg reward 0.7083333333333334
#  epoch no:  39400  avg reward 0.7083333333333334
#  message:  [4]  output:  0  epoch no:  39500  avg reward 0.71
#  epoch no:  39500  avg reward 0.71
#  message:  [0]  output:  2  epoch no:  39600  avg reward 0.705
#  epoch no:  39600  avg reward 0.705
#  message:  [0]  output:  0  epoch no:  39700  avg reward 0.7533333333333333
#  epoch no:  39700  avg reward 0.7533333333333333
#  message:  [0]  output:  1  epoch no:  39800  avg reward 0.6266666666666667
#  epoch no:  39800  avg reward 0.6266666666666667
#  message:  [0]  output:  2  epoch no:  39900  avg reward 0.705
#  epoch no:  39900  avg reward 0.705
#  message:  [4]  output:  2  epoch no:  40000  avg reward 0.7233333333333334
#  epoch no:  40000  avg reward 0.7233333333333334
#  message:  [0]  output:  2  epoch no:  40100  avg reward 0.7316666666666667
#  epoch no:  40100  avg reward 0.7316666666666667
#  message:  [0]  output:  2  epoch no:  40200  avg reward 0.7133333333333334
#  epoch no:  40200  avg reward 0.7133333333333334
#  message:  [1]  output:  0  epoch no:  40300  avg reward 0.7233333333333334
#  epoch no:  40300  avg reward 0.7233333333333334
#  message:  [0]  output:  1  epoch no:  40400  avg reward 0.7216666666666667
#  epoch no:  40400  avg reward 0.7216666666666667
#  message:  [1]  output:  2  epoch no:  40500  avg reward 0.7083333333333334
#  epoch no:  40500  avg reward 0.7083333333333334
#  message:  [1]  output:  2  epoch no:  40600  avg reward 0.665
#  epoch no:  40600  avg reward 0.665
#  message:  [1]  output:  1  epoch no:  40700  avg reward 0.76
#  epoch no:  40700  avg reward 0.76
#  message:  [1]  output:  1  epoch no:  40800  avg reward 0.7416666666666667
#  epoch no:  40800  avg reward 0.7416666666666667
#  message:  [0]  output:  1  epoch no:  40900  avg reward 0.75
#  epoch no:  40900  avg reward 0.75
#  message:  [4]  output:  0  epoch no:  41000  avg reward 0.7966666666666666
#  epoch no:  41000  avg reward 0.7966666666666666
#  message:  [0]  output:  2  epoch no:  41100  avg reward 0.765
#  epoch no:  41100  avg reward 0.765
#  message:  [1]  output:  2  epoch no:  41200  avg reward 0.76
#  epoch no:  41200  avg reward 0.76
#  message:  [0]  output:  1  epoch no:  41300  avg reward 0.7266666666666667
# ...
#  epoch no:  77400  avg reward 0.79
#  message:  [0]  output:  2  epoch no:  77500  avg reward 0.8133333333333334
#  epoch no:  77500  avg reward 0.8133333333333334
#  message:  [1]  output:  2  epoch no:  77600  avg reward 0.7566666666666667
#  epoch no:  77600  avg reward 0.7566666666666667
#  message:  [3]  output:  1  epoch no:  77700  avg reward 0.83
#  epoch no:  77700  avg reward 0.83
#  message:  [0]  output:  2  epoch no:  77800  avg reward 0.8033333333333333
#  epoch no:  77800  avg reward 0.8033333333333333
#  message:  [2]  output:  2  epoch no:  77900  avg reward 0.7933333333333333
#  epoch no:  77900  avg reward 0.7933333333333333
#  message:  [4]  output:  2  epoch no:  78000  avg reward 0.7783333333333333
#  epoch no:  78000  avg reward 0.7783333333333333
#  message:  [1]  output:  0  epoch no:  78100  avg reward 0.7666666666666667
#  epoch no:  78100  avg reward 0.7666666666666667
#  message:  [0]  output:  2  epoch no:  78200  avg reward 0.78
#  epoch no:  78200  avg reward 0.78
#  message:  [2]  output:  0  epoch no:  78300  avg reward 0.8333333333333334
#  epoch no:  78300  avg reward 0.8333333333333334
#  message:  [0]  output:  0  epoch no:  78400  avg reward 0.8216666666666667
#  epoch no:  78400  avg reward 0.8216666666666667
#  message:  [4]  output:  2  epoch no:  78500  avg reward 0.745
#  epoch no:  78500  avg reward 0.745
#  message:  [0]  output:  1  epoch no:  78600  avg reward 0.82
#  epoch no:  78600  avg reward 0.82
#  message:  [4]  output:  1  epoch no:  78700  avg reward 0.7933333333333333
#  epoch no:  78700  avg reward 0.7933333333333333
#  message:  [3]  output:  2  epoch no:  78800  avg reward 0.6833333333333333
#  epoch no:  78800  avg reward 0.6833333333333333
#  message:  [1]  output:  2  epoch no:  78900  avg reward 0.8383333333333334
#  epoch no:  78900  avg reward 0.8383333333333334
#  message:  [1]  output:  0  epoch no:  79000  avg reward 0.8666666666666667
#  epoch no:  79000  avg reward 0.8666666666666667
#  message:  [1]  output:  1  epoch no:  79100  avg reward 0.8933333333333333
#  epoch no:  79100  avg reward 0.8933333333333333
#  message:  [1]  output:  2  epoch no:  79200  avg reward 0.8
#  epoch no:  79200  avg reward 0.8
#  message:  [0]  output:  0  epoch no:  79300  avg reward 0.865
#  epoch no:  79300  avg reward 0.865
#  message:  [0]  output:  1  epoch no:  79400  avg reward 0.72
#  epoch no:  79400  avg reward 0.72
#  message:  [0]  output:  1  epoch no:  79500  avg reward 0.84
#  epoch no:  79500  avg reward 0.84
#  message:  [1]  output:  2  epoch no:  79600  avg reward 0.6883333333333334
#  epoch no:  79600  avg reward 0.6883333333333334
#  message:  [1]  output:  0  epoch no:  79700  avg reward 0.725
#  epoch no:  79700  avg reward 0.725
#  message:  [0]  output:  2  epoch no:  79800  avg reward 0.7433333333333333
#  epoch no:  79800  avg reward 0.7433333333333333
#  message:  [2]  output:  2  epoch no:  79900  avg reward 0.8216666666666667
#  epoch no:  79900  avg reward 0.8216666666666667
#  message:  [4]  output:  0  epoch no:  80000  avg reward 0.8416666666666667
#  epoch no:  80000  avg reward 0.8416666666666667
#  message:  [1]  output:  1  epoch no:  80100  avg reward 0.7016666666666667
#  epoch no:  80100  avg reward 0.7016666666666667
#  message:  [1]  output:  1  epoch no:  80200  avg reward 0.8483333333333334
#  epoch no:  80200  avg reward 0.8483333333333334
#  message:  [0]  output:  2  epoch no:  80300  avg reward 0.86
#  epoch no:  80300  avg reward 0.86
#  message:  [0]  output:  0  epoch no:  80400  avg reward 0.845
#  epoch no:  80400  avg reward 0.845
#  message:  [1]  output:  2  epoch no:  80500  avg reward 0.8516666666666667
#  epoch no:  80500  avg reward 0.8516666666666667
#  message:  [4]  output:  0  epoch no:  80600  avg reward 0.8133333333333334
#  epoch no:  80600  avg reward 0.8133333333333334
#  message:  [2]  output:  0  epoch no:  80700  avg reward 0.7666666666666667
#  epoch no:  80700  avg reward 0.7666666666666667
#  message:  [4]  output:  2  epoch no:  80800  avg reward 0.7266666666666667
#  epoch no:  80800  avg reward 0.7266666666666667
#  message:  [3]  output:  2  epoch no:  80900  avg reward 0.72
#  epoch no:  80900  avg reward 0.72
#  message:  [1]  output:  0  epoch no:  81000  avg reward 0.8066666666666666
#  epoch no:  81000  avg reward 0.8066666666666666
#  message:  [1]  output:  1  epoch no:  81100  avg reward 0.7616666666666667
#  epoch no:  81100  avg reward 0.7616666666666667
#  message:  [1]  output:  2  epoch no:  81200  avg reward 0.86
#  epoch no:  81200  avg reward 0.86
#  message:  [1]  output:  0  epoch no:  81300  avg reward 0.8716666666666667
#  epoch no:  81300  avg reward 0.8716666666666667
#  message:  [3]  output:  1  epoch no:  81400  avg reward 0.8633333333333333
#  epoch no:  81400  avg reward 0.8633333333333333
#  message:  [1]  output:  1  epoch no:  81500  avg reward 0.8716666666666667
#  epoch no:  81500  avg reward 0.8716666666666667
#  message:  [3]  output:  1  epoch no:  81600  avg reward 0.8733333333333333
#  epoch no:  81600  avg reward 0.8733333333333333
#  message:  [1]  output:  0  epoch no:  81700  avg reward 0.8883333333333333
#  epoch no:  81700  avg reward 0.8883333333333333
#  message:  [0]  output:  1  epoch no:  81800  avg reward 0.8616666666666667
#  epoch no:  81800  avg reward 0.8616666666666667
#  message:  [2]  output:  2  epoch no:  81900  avg reward 0.83
#  epoch no:  81900  avg reward 0.83
#  message:  [2]  output:  2  epoch no:  82000  avg reward 0.8083333333333333
#  epoch no:  82000  avg reward 0.8083333333333333
#  message:  [1]  output:  2  epoch no:  82100  avg reward 0.825
#  epoch no:  82100  avg reward 0.825
#  message:  [0]  output:  1  epoch no:  82200  avg reward 0.7866666666666666
#  epoch no:  82200  avg reward 0.7866666666666666
#  message:  [2]  output:  0  epoch no:  82300  avg reward 0.7533333333333333
#  epoch no:  82300  avg reward 0.7533333333333333
#  message:  [1]  output:  0  epoch no:  82400  avg reward 0.765
#  epoch no:  82400  avg reward 0.765
#  message:  [0]  output:  1  epoch no:  82500  avg reward 0.7416666666666667
#  epoch no:  82500  avg reward 0.7416666666666667
#  message:  [0]  output:  2  epoch no:  82600  avg reward 0.7783333333333333
#  epoch no:  82600  avg reward 0.7783333333333333
#  message:  [2]  output:  1  epoch no:  82700  avg reward 0.765
#  epoch no:  82700  avg reward 0.765
#  message:  [1]  output:  0  epoch no:  82800  avg reward 0.8583333333333333
#  epoch no:  82800  avg reward 0.8583333333333333
#  message:  [1]  output:  0  epoch no:  82900  avg reward 0.8616666666666667
#  epoch no:  82900  avg reward 0.8616666666666667
#  message:  [3]  output:  0  epoch no:  83000  avg reward 0.82
#  epoch no:  83000  avg reward 0.82
#  message:  [1]  output:  2  epoch no:  83100  avg reward 0.7533333333333333
#  epoch no:  83100  avg reward 0.7533333333333333
#  message:  [3]  output:  2  epoch no:  83200  avg reward 0.7883333333333333
#  epoch no:  83200  avg reward 0.7883333333333333
#  message:  [0]  output:  1  epoch no:  83300  avg reward 0.775
#  epoch no:  83300  avg reward 0.775
#  message:  [1]  output:  2  epoch no:  83400  avg reward 0.8283333333333334
#  epoch no:  83400  avg reward 0.8283333333333334
#  message:  [2]  output:  2  epoch no:  83500  avg reward 0.8116666666666666
#  epoch no:  83500  avg reward 0.8116666666666666
#  message:  [3]  output:  0  epoch no:  83600  avg reward 0.7533333333333333
#  epoch no:  83600  avg reward 0.7533333333333333
#  message:  [3]  output:  0  epoch no:  83700  avg reward 0.7933333333333333
#  epoch no:  83700  avg reward 0.7933333333333333
#  message:  [0]  output:  1  epoch no:  83800  avg reward 0.8066666666666666
#  epoch no:  83800  avg reward 0.8066666666666666
#  message:  [1]  output:  2  epoch no:  83900  avg reward 0.88
#  epoch no:  83900  avg reward 0.88
#  message:  [1]  output:  1  epoch no:  84000  avg reward 0.85
#  epoch no:  84000  avg reward 0.85
#  message:  [4]  output:  0  epoch no:  84100  avg reward 0.785
#  epoch no:  84100  avg reward 0.785
#  message:  [3]  output:  2  epoch no:  84200  avg reward 0.8533333333333334
#  epoch no:  84200  avg reward 0.8533333333333334
#  message:  [1]  output:  0  epoch no:  84300  avg reward 0.79
#  epoch no:  84300  avg reward 0.79
#  message:  [0]  output:  2  epoch no:  84400  avg reward 0.7533333333333333
#  epoch no:  84400  avg reward 0.7533333333333333
#  message:  [1]  output:  1  epoch no:  84500  avg reward 0.7733333333333333
#  epoch no:  84500  avg reward 0.7733333333333333
#  message:  [1]  output:  2  epoch no:  84600  avg reward 0.8366666666666667
#  epoch no:  84600  avg reward 0.8366666666666667
#  message:  [0]  output:  0  epoch no:  84700  avg reward 0.8966666666666666
#  epoch no:  84700  avg reward 0.8966666666666666
#  message:  [1]  output:  0  epoch no:  84800  avg reward 0.8716666666666667
#  epoch no:  84800  avg reward 0.8716666666666667
#  message:  [1]  output:  0  epoch no:  84900  avg reward 0.8383333333333334
#  epoch no:  84900  avg reward 0.8383333333333334
#  message:  [3]  output:  0  epoch no:  85000  avg reward 0.87
#  epoch no:  85000  avg reward 0.87
#  message:  [1]  output:  1  epoch no:  85100  avg reward 0.825
#  epoch no:  85100  avg reward 0.825
#  message:  [2]  output:  2  epoch no:  85200  avg reward 0.8583333333333333
#  epoch no:  85200  avg reward 0.8583333333333333
#  message:  [0]  output:  0  epoch no:  85300  avg reward 0.82
#  epoch no:  85300  avg reward 0.82
#  message:  [1]  output:  2  epoch no:  85400  avg reward 0.7566666666666667
#  epoch no:  85400  avg reward 0.7566666666666667
#  message:  [1]  output:  1  epoch no:  85500  avg reward 0.835
#  epoch no:  85500  avg reward 0.835
#  message:  [1]  output:  1  epoch no:  85600  avg reward 0.7633333333333333
#  epoch no:  85600  avg reward 0.7633333333333333
#  message:  [0]  output:  2  epoch no:  85700  avg reward 0.82
#  epoch no:  85700  avg reward 0.82
#  message:  [0]  output:  1  epoch no:  85800  avg reward 0.8583333333333333
#  epoch no:  85800  avg reward 0.8583333333333333
#  message:  [0]  output:  1  epoch no:  85900  avg reward 0.755
#  epoch no:  85900  avg reward 0.755
#  message:  [4]  output:  1  epoch no:  86000  avg reward 0.74
#  epoch no:  86000  avg reward 0.74
#  message:  [3]  output:  2  epoch no:  86100  avg reward 0.8133333333333334
#  epoch no:  86100  avg reward 0.8133333333333334
#  message:  [3]  output:  2  epoch no:  86200  avg reward 0.7983333333333333
#  epoch no:  86200  avg reward 0.7983333333333333
#  message:  [1]  output:  2  epoch no:  86300  avg reward 0.71
#  epoch no:  86300  avg reward 0.71
#  message:  [1]  output:  0  epoch no:  86400  avg reward 0.8033333333333333
#  epoch no:  86400  avg reward 0.8033333333333333
#  message:  [3]  output:  0  epoch no:  86500  avg reward 0.8266666666666667
#  epoch no:  86500  avg reward 0.8266666666666667
#  message:  [0]  output:  1  epoch no:  86600  avg reward 0.8066666666666666
#  epoch no:  86600  avg reward 0.8066666666666666
#  message:  [3]  output:  1  epoch no:  86700  avg reward 0.895
#  epoch no:  86700  avg reward 0.895
#  message:  [4]  output:  1  epoch no:  86800  avg reward 0.78
#  epoch no:  86800  avg reward 0.78
#  message:  [1]  output:  0  epoch no:  86900  avg reward 0.8716666666666667
#  epoch no:  86900  avg reward 0.8716666666666667
#  message:  [0]  output:  1  epoch no:  87000  avg reward 0.7
#  epoch no:  87000  avg reward 0.7
#  message:  [0]  output:  0  epoch no:  87100  avg reward 0.845
#  epoch no:  87100  avg reward 0.845
#  message:  [4]  output:  1  epoch no:  87200  avg reward 0.8483333333333334
#  epoch no:  87200  avg reward 0.8483333333333334
#  message:  [1]  output:  1  epoch no:  87300  avg reward 0.7983333333333333
#  epoch no:  87300  avg reward 0.7983333333333333
#  message:  [1]  output:  1  epoch no:  87400  avg reward 0.815
#  epoch no:  87400  avg reward 0.815
#  message:  [0]  output:  2  epoch no:  87500  avg reward 0.8633333333333333
#  epoch no:  87500  avg reward 0.8633333333333333
#  message:  [0]  output:  0  epoch no:  87600  avg reward 0.7933333333333333
#  epoch no:  87600  avg reward 0.7933333333333333
#  message:  [2]  output:  1  epoch no:  87700  avg reward 0.835
#  epoch no:  87700  avg reward 0.835
#  message:  [3]  output:  0  epoch no:  87800  avg reward 0.7883333333333333
#  epoch no:  87800  avg reward 0.7883333333333333
#  message:  [0]  output:  0  epoch no:  87900  avg reward 0.8416666666666667
#  epoch no:  87900  avg reward 0.8416666666666667
#  message:  [2]  output:  0  epoch no:  88000  avg reward 0.8116666666666666
#  epoch no:  88000  avg reward 0.8116666666666666
#  message:  [1]  output:  1  epoch no:  88100  avg reward 0.8433333333333334
#  epoch no:  88100  avg reward 0.8433333333333334
#  message:  [2]  output:  2  epoch no:  88200  avg reward 0.8133333333333334
#  epoch no:  88200  avg reward 0.8133333333333334
#  message:  [2]  output:  2  epoch no:  88300  avg reward 0.8433333333333334
#  epoch no:  88300  avg reward 0.8433333333333334
#  message:  [1]  output:  0  epoch no:  88400  avg reward 0.8783333333333333
#  epoch no:  88400  avg reward 0.8783333333333333
#  message:  [2]  output:  2  epoch no:  88500  avg reward 0.7616666666666667
#  epoch no:  88500  avg reward 0.7616666666666667
#  message:  [0]  output:  2  epoch no:  88600  avg reward 0.8433333333333334
#  epoch no:  88600  avg reward 0.8433333333333334
#  message:  [1]  output:  2  epoch no:  88700  avg reward 0.835
#  epoch no:  88700  avg reward 0.835
#  message:  [3]  output:  1  epoch no:  88800  avg reward 0.775
#  epoch no:  88800  avg reward 0.775
#  message:  [0]  output:  0  epoch no:  88900  avg reward 0.8316666666666667
#  epoch no:  88900  avg reward 0.8316666666666667
#  message:  [0]  output:  1  epoch no:  89000  avg reward 0.8033333333333333
#  epoch no:  89000  avg reward 0.8033333333333333
#  message:  [2]  output:  2  epoch no:  89100  avg reward 0.7316666666666667
#  epoch no:  89100  avg reward 0.7316666666666667
#  message:  [1]  output:  1  epoch no:  89200  avg reward 0.74
#  epoch no:  89200  avg reward 0.74
#  message:  [1]  output:  2  epoch no:  89300  avg reward 0.8
#  epoch no:  89300  avg reward 0.8
#  message:  [0]  output:  1  epoch no:  89400  avg reward 0.9
#  epoch no:  89400  avg reward 0.9
#  message:  [0]  output:  2  epoch no:  89500  avg reward 0.76
#  epoch no:  89500  avg reward 0.76
#  message:  [0]  output:  0  epoch no:  89600  avg reward 0.8166666666666667
#  epoch no:  89600  avg reward 0.8166666666666667
#  message:  [1]  output:  0  epoch no:  89700  avg reward 0.76
#  epoch no:  89700  avg reward 0.76
#  message:  [4]  output:  2  epoch no:  89800  avg reward 0.8233333333333334
#  epoch no:  89800  avg reward 0.8233333333333334
#  message:  [2]  output:  0  epoch no:  89900  avg reward 0.8116666666666666
#  epoch no:  89900  avg reward 0.8116666666666666
#  message:  [1]  output:  0  epoch no:  90000  avg reward 0.805
#  epoch no:  90000  avg reward 0.805
#  message:  [1]  output:  1  epoch no:  90100  avg reward 0.7616666666666667
#  epoch no:  90100  avg reward 0.7616666666666667
#  message:  [3]  output:  0  epoch no:  90200  avg reward 0.7866666666666666
#  epoch no:  90200  avg reward 0.7866666666666666
#  message:  [0]  output:  2  epoch no:  90300  avg reward 0.8333333333333334
#  epoch no:  90300  avg reward 0.8333333333333334
#  message:  [1]  output:  2  epoch no:  90400  avg reward 0.7533333333333333
#  epoch no:  90400  avg reward 0.7533333333333333
#  message:  [1]  output:  0  epoch no:  90500  avg reward 0.8366666666666667
#  epoch no:  90500  avg reward 0.8366666666666667
#  message:  [1]  output:  0  epoch no:  90600  avg reward 0.8383333333333334
#  epoch no:  90600  avg reward 0.8383333333333334
#  message:  [0]  output:  2  epoch no:  90700  avg reward 0.8233333333333334
#  epoch no:  90700  avg reward 0.8233333333333334
#  message:  [0]  output:  2  epoch no:  90800  avg reward 0.85
#  epoch no:  90800  avg reward 0.85
#  message:  [0]  output:  0  epoch no:  90900  avg reward 0.785
#  epoch no:  90900  avg reward 0.785
#  message:  [3]  output:  1  epoch no:  91000  avg reward 0.875
#  epoch no:  91000  avg reward 0.875
#  message:  [2]  output:  1  epoch no:  91100  avg reward 0.8816666666666667
#  epoch no:  91100  avg reward 0.8816666666666667
#  message:  [0]  output:  2  epoch no:  91200  avg reward 0.7883333333333333
#  epoch no:  91200  avg reward 0.7883333333333333
